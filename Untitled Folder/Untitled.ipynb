# %%
from finlab import data

data.get('price:收盤價')

# %%
from finlab import data
close = data.get('price:收盤價')
close

# %%
from finlab import data

close = data.get('price:收盤價')
position = close >= close.rolling(300).max()
position
# Out:
#              0015   0050   0051   0052   0053   0054   0055   0056   0057  \
# date
# 2007-04-23  False  False  False  False  False  False  False  False  False
# 2007-04-24  False  False  False  False  False  False  False  False  False
# 2007-04-25  False  False  False  False  False  False  False  False  False
# 2007-04-26  False  False  False  False  False  False  False  False  False
# 2007-04-27  False  False  False  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2022-09-14  False  False  False  False  False  False  False  False  False
# 2022-09-15  False  False  False  False  False  False  False  False  False
# 2022-09-16  False  False  False  False  False  False  False  False  False
# 2022-09-19  False  False  False  False  False  False  False  False  False
# 2022-09-20  False  False  False  False  False  False  False  False  False
#
#              0058  ...   9944   9945   9946   9949   9950   9951   9955  \
# date               ...
# 2007-04-23  False  ...  False  False  False  False  False  False  False
# 2007-04-24  False  ...  False  False  False  False  False  False  False
# 2007-04-25  False  ...  False  False  False  False  False  False  False
# 2007-04-26  False  ...  False  False  False  False  False  False  False
# 2007-04-27  False  ...  False  False  False  False  False  False  False
# ...           ...  ...    ...    ...    ...    ...    ...    ...    ...
# 2022-09-14  False  ...  False  False  False  False  False  False  False
# 2022-09-15  False  ...  False  False  False  False  False  False  False
# 2022-09-16  False  ...  False  False  False  False  False  False  False
# 2022-09-19  False  ...  False  False  False  False  False  False  False
# 2022-09-20  False  ...  False  False  False  False  False  False  False
#
#              9958   9960   9962
# date
# 2007-04-23  False  False  False
# 2007-04-24  False  False  False
# 2007-04-25  False  False  False
# 2007-04-26  False  False  False
# 2007-04-27  False  False  False
# ...           ...    ...    ...
# 2022-09-14  False  False  False
# 2022-09-15  False  False  False
# 2022-09-16  False  False  False
# 2022-09-19  False  False  False
# 2022-09-20  False  False  False
#
# [3804 rows x 2354 columns]

# %%
def bias(n):
    return close / close.rolling(n, min_periods=1).mean()

def acc(n):
    return close.shift(n) / (close.shift(2*n) + close) * 2

def rsv(n):
    l = close.rolling(n, min_periods=1).min()
    h = close.rolling(n, min_periods=1).max()
    
    return (close - l) / (h - l)

def mom(n):
    return (rev / rev.shift(1)).shift(n)

features = {
    'mom1': mom(1),
    'mom2': mom(2),
    'mom3': mom(3),
    'mom4': mom(4),
    'mom5': mom(5),
    'mom6': mom(6),
    'mom7': mom(7),
    'mom8': mom(8),
    'mom9': mom(9),
    
    'bias5': bias(5),
    'bias10': bias(10),
    'bias20': bias(20),
    'bias60': bias(60),
    'bias120': bias(120),
    'bias240': bias(240),
    
    'acc5': acc(5),
    'acc10': acc(10),
    'acc20': acc(20),
    'acc60': acc(60),
    'acc120': acc(120),
    'acc240': acc(240),
    
    'rsv5': rsv(5),
    'rsv10': rsv(10),
    'rsv20': rsv(20),
    'rsv60': rsv(60),
    'rsv120': rsv(120),
    'rsv240': rsv(240),
}

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from finlab.data import Data
#       2 data = Data()
#       3 close = data.get('收盤價')
#
# ModuleNotFoundError: No module named 'finlab'
