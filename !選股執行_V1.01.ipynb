# %% [markdown]
# # Final Project

# %%
# 移除不必要的警告
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 獲取歷史資料

# %%
from finlab.data import Data
#from finlab.ml import fundamental_features
#fdf = fundamental_features()

data = Data()

close = data.get("收盤價")
open_ = data.get("開盤價")
high = data.get("最高價")
low = data.get("最低價")
vol = data.get("成交股數")

PB = data.get("股價淨值比")
pe = data.get("本益比")

#bi = data.get("營業利益")


#close = data.get_adj("收盤價").round(2)

#財務指標
rev = data.get("當月營收")
l_rev = data.get("去年當月營收")

#t123 = data.get('土地')

bargin_i=data.get("投信買賣超股數")/data.get("成交股數")
bargin_f=data.get("外資自營商買賣超股數")/data.get("成交股數")
bargin_s=data.get("自營商買賣超股數(自行買賣)")/data.get("成交股數")
#

vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

rev.index = rev.index.shift(5, "d")         #每月頻率
#周頻率

# %% [markdown]
# ### 計算features

# %%
#MFI  = data.talib("MFI")
##MFI.tail()
#ub,mb,lb =data.talib("BBANDS")

# %% [markdown]
# #### 營收相關

# %%
##############################################　　　自己加入的　　　##############################################
import pandas as pd
from finlab.__init__ import talib_all_stock
from talib import abstract

# %%
def bias(n):
    return close / close.rolling(n, min_periods=1).mean()

def acc(n):
    return close.shift(n) / (close.shift(2*n) + close) * 2

def rsv(n):
    l = close.rolling(n, min_periods=1).min() 
    h = close.rolling(n, min_periods=1).max()
    
    return (close - l) / (h - l)

def mom(n):
    return (rev / rev.shift(1)).shift(n)

def yoy(n):
    return (rev.shift(n) / rev.shift(12+n)) -1

def bi(n):
    return bargin_i/bargin_i.rolling(n).mean()

def bf(n):
    return bargin_f/bargin_f.rolling(n).mean()
    
def bs(n):
    return bargin_s/bargin_s.rolling(n).mean()

#-------------------------------------------

features = {
    'mom1': mom(1),
    'mom2': mom(2),
    'mom3': mom(3),
    'mom4': mom(4),
    'mom5': mom(5),
    'mom6': mom(6),
    'mom7': mom(7),
    'mom8': mom(8),
    'mom9': mom(9),

    
    'bias5': bias(5),
    'bias10': bias(10),
    'bias20': bias(20),
    'bias60': bias(60),
    'bias120': bias(120),
    'bias240': bias(240),
    
    'acc5': acc(5),
    'acc10': acc(10),
    'acc20': acc(20),
    'acc60': acc(60),
    'acc120': acc(120),
    'acc240': acc(240),
    
    'rsv5': rsv(5),
    'rsv10': rsv(10),
    'rsv20': rsv(20),
    'rsv60': rsv(60),
    'rsv120': rsv(120),
    'rsv240': rsv(240),
###############################################
    'yoy': yoy(1),
    'delta_yoy':yoy(1)-yoy(2),
    
    'PB':PB,
    'PE':pe,  
    
   #'bi5' : bi(5),
   #'bi10' : bi(10),
   #'bi20' : bi(20),
   #'bi60' : bi(60),
   # 
   #'bf5' : bf(5),
   # #'bf10' : bf(10),
   # #'bf20' : bf(20),
   # #'bf60' : bf(60),
   # 
   # 'bs5' : bs(5),
   # 'bs10' : bs(10),
   # 'bs20' : bs(20),
   # 'bs60' : bs(60),
    
}

# %%
#bi(60).dropna(how='all')

# %% [markdown]
# #### 財報指標

# %% [markdown]
# 兩個feature結合[[連結網址]](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7)
#
# ---
# ```python
# from finlab import ml
# from finlab.data import Data
#
# data = Data()
# rsi = data.talib("RSI")
#
# dataset = ml.fundamental_features()
# ml.add_feature(dataset, 'RSI', rsi)
# ```

# %%
from finlab.ml import fundamental_features
dataset_fundamental = fundamental_features()

# %%
#dataset_fundamental

# %% [markdown]
# #### 技術指標

# %% [raw]
# # https://zhuanlan.zhihu.com/p/342075180 talib函数功能一览表
#
# def bias(n):
#     return close / close.rolling(n, min_periods=1).mean()
#
# def acc(n):
#     return close.shift(n) / (close.shift(2*n) + close) * 2
#
# def rsv(n):
#     l = close.rolling(n, min_periods=1).min()
#     h = close.rolling(n, min_periods=1).max()
#
#     return (close - l) / (h - l)
#
# def mom(n):
#     return (rev / rev.shift(1)).shift(n)
#
#
# def bi_(n):
#     return (bargin_i / vol.shift(1)).shift(n)
#
# def bf(n):
#     return (bargin_f / vol.shift(1)).shift(n)
#
# def bs(n):
#     return (bargin_s / vol.shift(1)).shift(n)
#
# def rsi(n):
#     #return talib_all_stock(ndays=10000, func=abstract.RSI, timeperiod=n)
#     return data.talib("RSI",timeperiod=n)
#
# def MFI(n):
#     return data.talib("MFI",timeperiod=n)
#
# def obv(n):
#     return data.talib("OBV",timeperiod=n)
#
#
#
# features = {
#
#     #'ATR14':data.talib("ATR",timeperiod=14),
#     #'NATR14':data.talib('NATR',timeperiod=14),
#     #'TRANGE':data.talib('TRANGE'),
#     #'Adosc3':data.talib('ADOSC',timeperiod=3),
#
#     #"MFI5":MFI(5),
#     #"MFI10":MFI(10),
#
#     #'rsi6': rsi(6),  #DataFrame
#     #'rsi10': rsi(10),  #DataFrame
#     #'rsi14': rsi(14),  #DataFrame
#     #'rsi20': rsi(20),  #DataFrame
#     #'rsi50': rsi(50),  #DataFrame
#
#     'mom1': mom(1),
#     'mom2': mom(2),
#     'mom3': mom(3),
#     'mom4': mom(4),
#     'mom5': mom(5),
#     'mom6': mom(6),
#     'mom7': mom(7),
#     'mom8': mom(8),
#     'mom9': mom(9),
#
#     'yoy': yoy(1),
#     'delta_yoy':yoy(1)-yoy(2),
#
# #    'ff':ff,
#     'PB':PB,
#     'PE':pe,
# #
#     'bias5': bias(5),
#     'bias10': bias(10),
#     'bias20': bias(20),
#     'bias60': bias(60),
#     'bias120': bias(120),
#     'bias240': bias(240),
#
#     'acc5': acc(5),
#     'acc10': acc(10),
#     'acc20': acc(20),
#     'acc60': acc(60),
#     'acc120': acc(120),
#     'acc240': acc(240),
#
#     #'rsv5': rsv(5),
#     #'rsv10': rsv(10),
#     #'rsv20': rsv(20),
#     #'rsv60': rsv(60),
#     #'rsv120': rsv(120),
#     #'rsv240': rsv(240),
# }

# %% [raw]
# ```
# https://www.twblogs.net/a/5d3f3173bd9eee517422735f
# W-WED
# https://docs.python.org/zh-tw/3/library/calendar.html
# ```

# %% [markdown]
# 加入其他features
# * http://finlabcourse.imotor.com/viewthread.php?tid=660&extra=page%3D1
#
# ```python
# from finlab import ml
# from finlab.data import Data
#
# data = Data()
# rsi = data.talib("RSI")
#
# dataset = ml.fundamental_features()
# ml.add_feature(dataset, 'RSI', rsi)
# ```

# %% [markdown]
# #### 組合dataset

# %%
import pandas as pd

# %% [markdown]
# #### 確認各指標清單

# %%
#t1 = data.talib("NATR",timeperiod=14)
#t1.to_csv('myfile.csv')

# %% [markdown]
# ### 製作dataset
#
# ##### 設定買賣頻率

# %%
#rev.index = rev.index.tz_localize("Asia/Taipei")
every_month = rev.index
every_month
# Out:
# DatetimeIndex(['2005-02-15', '2005-03-15', '2005-04-15', '2005-05-15',
#                '2005-06-15', '2005-07-15', '2005-08-15', '2005-09-15',
#                '2005-10-15', '2005-11-15',
#                ...
#                '2022-03-15', '2022-04-15', '2022-05-15', '2022-06-15',
#                '2022-07-15', '2022-08-15', '2022-09-15', '2022-10-15',
#                '2022-11-15', '2022-12-15'],
#               dtype='datetime64[ns]', name='date', length=215, freq=None)

# %% [markdown]
# #### 將dataframe 組裝起來

# %%
# features['bias20'].reindex(every_month, method='ffill')

for name, f in features.items():
    features[name] = f.reindex(every_month, method='ffill')

# %%
for name, f in features.items():
    features[name] = f.unstack()

# %%
import pandas as pd
dataset = pd.DataFrame(features)

# %%
feature_names = list(dataset.columns)

# %%
from finlab import ml
ml.add_feature(dataset, 'vol_ma5', vol_ma5)

dataset
# Out:
#                          mom1      mom2      mom3      mom4      mom5  \
# stock_id date
# 0015     2005-02-15       NaN       NaN       NaN       NaN       NaN
#          2005-03-15       NaN       NaN       NaN       NaN       NaN
#          2005-04-15       NaN       NaN       NaN       NaN       NaN
#          2005-05-15       NaN       NaN       NaN       NaN       NaN
#          2005-06-15       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 9962     2022-08-15  1.694666  0.917472  0.678559  1.435387  1.209077
#          2022-09-15  0.641536  1.694666  0.917472  0.678559  1.435387
#          2022-10-15  1.280940  0.641536  1.694666  0.917472  0.678559
#          2022-11-15  0.830797  1.280940  0.641536  1.694666  0.917472
#          2022-12-15  1.163303  0.830797  1.280940  0.641536  1.694666
#
#                          mom6      mom7      mom8      mom9     bias5  ...  \
# stock_id date                                                          ...
# 0015     2005-02-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-03-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-04-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-05-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-06-15       NaN       NaN       NaN       NaN       NaN  ...
# ...                       ...       ...       ...       ...       ...  ...
# 9962     2022-08-15  0.859901  0.729493  1.238664  1.033162  1.042199  ...
#          2022-09-15  1.209077  0.859901  0.729493  1.238664  1.022514  ...
#          2022-10-15  1.435387  1.209077  0.859901  0.729493  0.956989  ...
#          2022-11-15  0.678559  1.435387  1.209077  0.859901  1.024242  ...
#          2022-12-15  0.917472  0.678559  1.435387  1.209077  1.022727  ...
#
#                       rsv10     rsv20     rsv60    rsv120    rsv240       yoy  \
# stock_id date
# 0015     2005-02-15     NaN       NaN       NaN       NaN       NaN       NaN
#          2005-03-15     NaN       NaN       NaN       NaN       NaN       NaN
#          2005-04-15     NaN       NaN       NaN       NaN       NaN       NaN
#          2005-05-15     NaN       NaN       NaN       NaN       NaN       NaN
#          2005-06-15     NaN       NaN       NaN       NaN       NaN       NaN
# ...                     ...       ...       ...       ...       ...       ...
# 9962     2022-08-15  1.0000  1.000000  0.820755  0.386667  0.386667  0.240544
#          2022-09-15  1.0000  1.000000  1.000000  0.391111  0.391111  0.286455
#          2022-10-15  0.1875  0.142857  0.130435  0.198582  0.124444  0.725788
#          2022-11-15  1.0000  1.000000  1.000000  0.933962  0.440000  0.003516
#          2022-12-15  1.0000  1.000000  0.937500  0.949495  0.417778  0.129923
#
#                      delta_yoy    PB    PE   vol_ma5
# stock_id date
# 0015     2005-02-15        NaN   NaN   NaN       NaN
#          2005-03-15        NaN   NaN   NaN       NaN
#          2005-04-15        NaN   NaN   NaN       NaN
#          2005-05-15        NaN   NaN   NaN       NaN
#          2005-06-15        NaN   NaN   NaN       NaN
# ...                        ...   ...   ...       ...
# 9962     2022-08-15   0.175498  1.35  7.48  818.5636
#          2022-09-15   0.045911  1.35  7.50  825.8902
#          2022-10-15   0.439333  1.10  6.12  638.6044
#          2022-11-15  -0.722271  1.33  7.01  462.1834
#          2022-12-15   0.126406  1.31  6.91  450.5504
#
# [439890 rows x 32 columns]

# %%
##############################################　　　自己加入的　　　##############################################
dataset.index = dataset.index.set_names(['stock_id','date'], level=[0,1])


#dataset.index.levels[1].name = 'date'
#dataset.index.levels[0].name = 'stock_id'

#因為你pandas更新到新版了
## profit.index.levels[0].name = 'year'
## profit.index.levels[1].name = 'month'
#這兩行的語法被棄用，請改成
#profit.index=profit.index.set_names('year', level=0)
#profit.index=profit.index.set_names('month', level=1)
#or profit.index=profit.index.set_names(['year','month'], level=[0,1])
#直接一行
#就可以了

# %%
list(dataset_fundamental.index)
# Out:
# [('1101', Timestamp('2013-05-15 00:00:00')),
#  ('1101', Timestamp('2013-08-14 00:00:00')),
#  ('1101', Timestamp('2013-11-14 00:00:00')),
#  ('1101', Timestamp('2014-03-31 00:00:00')),
#  ('1101', Timestamp('2014-05-15 00:00:00')),
#  ('1101', Timestamp('2014-08-14 00:00:00')),
#  ('1101', Timestamp('2014-11-14 00:00:00')),
#  ('1101', Timestamp('2015-03-31 00:00:00')),
#  ('1101', Timestamp('2015-05-15 00:00:00')),
#  ('1101', Timestamp('2015-08-14 00:00:00')),
#  ('1101', Timestamp('2015-11-14 00:00:00')),
#  ('1101', Timestamp('2016-03-31 00:00:00')),
#  ('1101', Timestamp('2016-05-15 00:00:00')),
#  ('1101', Timestamp('2016-08-14 00:00:00')),
#  ('1101', Timestamp('2016-11-14 00:00:00')),
#  ('1101', Timestamp('2017-03-31 00:00:00')),
#  ('1101', Timestamp('2017-05-15 00:00:00')),
#  ('1101', Timestamp('2017-08-14 00:00:00')),
#  ('1101', Timestamp('2017-11-14 00:00:00')),
#  ('1101', Timestamp('2018-03-31 00:00:00')),
#  ('1101', Timestamp('2018-05-15 00:00:00')),
#  ('1101', Timestamp('2018-08-14 00:00:00')),
#  ('1101', Timestamp('2018-11-14 00:00:00')),
#  ('1101', Timestamp('2019-03-31 00:00:00')),
#  ('1101', Timestamp('2019-05-15 00:00:00')),
#  ('1101', Timestamp('2019-08-14 00:00:00')),
#  ('1101', Timestamp('2019-11-14 00:00:00')),
#  ('1101', Timestamp('2020-03-31 00:00:00')),
#  ('1101', Timestamp('2020-05-15 00:00:00')),
#  ('1101', Timestamp('2020-08-14 00:00:00')),
#  ('1101', Timestamp('2020-11-14 00:00:00')),
#  ('1101', Timestamp('2021-03-31 00:00:00')),
#  ('1101', Timestamp('2021-05-15 00:00:00')),
#  ('1101', Timestamp('2021-08-14 00:00:00')),
#  ('1101', Timestamp('2021-11-14 00:00:00')),
#  ('1101', Timestamp('2022-03-31 00:00:00')),
#  ('1101', Timestamp('2022-05-15 00:00:00')),
#  ('1102', Timestamp('2013-05-15 00:00:00')),
#  ('1102', Timestamp('2013-08-14 00:00:00')),
#  ('1102', Timestamp('2013-11-14 00:00:00')),
#  ('1102', Timestamp('2014-03-31 00:00:00')),
#  ('1102', Timestamp('2014-05-15 00:00:00')),
#  ('1102', Timestamp('2014-08-14 00:00:00')),
#  ('1102', Timestamp('2014-11-14 00:00:00')),
#  ('1102', Timestamp('2015-03-31 00:00:00')),
#  ('1102', Timestamp('2015-05-15 00:00:00')),
#  ('1102', Timestamp('2015-08-14 00:00:00')),
#  ('1102', Timestamp('2015-11-14 00:00:00')),
#  ('1102', Timestamp('2016-03-31 00:00:00')),
#  ('1102', Timestamp('2016-05-15 00:00:00')),
#  ('1102', Timestamp('2016-08-14 00:00:00')),
#  ('1102', Timestamp('2016-11-14 00:00:00')),
#  ('1102', Timestamp('2017-03-31 00:00:00')),
#  ('1102', Timestamp('2017-05-15 00:00:00')),
#  ('1102', Timestamp('2017-08-14 00:00:00')),
#  ('1102', Timestamp('2017-11-14 00:00:00')),
#  ('1102', Timestamp('2018-03-31 00:00:00')),
#  ('1102', Timestamp('2018-05-15 00:00:00')),
#  ('1102', Timestamp('2018-08-14 00:00:00')),
#  ('1102', Timestamp('2018-11-14 00:00:00')),
#  ('1102', Timestamp('2019-03-31 00:00:00')),
#  ('1102', Timestamp('2019-05-15 00:00:00')),
#  ('1102', Timestamp('2019-08-14 00:00:00')),
#  ('1102', Timestamp('2019-11-14 00:00:00')),
#  ('1102', Timestamp('2020-03-31 00:00:00')),
#  ('1102', Timestamp('2020-05-15 00:00:00')),
#  ('1102', Timestamp('2020-08-14 00:00:00')),
#  ('1102', Timestamp('2020-11-14 00:00:00')),
#  ('1102', Timestamp('2021-03-31 00:00:00')),
#  ('1102', Timestamp('2021-05-15 00:00:00')),
#  ('1102', Timestamp('2021-08-14 00:00:00')),
#  ('1102', Timestamp('2021-11-14 00:00:00')),
#  ('1102', Timestamp('2022-03-31 00:00:00')),
#  ('1102', Timestamp('2022-05-15 00:00:00')),
#  ('1103', Timestamp('2013-05-15 00:00:00')),
#  ('1103', Timestamp('2013-08-14 00:00:00')),
#  ('1103', Timestamp('2013-11-14 00:00:00')),
#  ('1103', Timestamp('2014-03-31 00:00:00')),
#  ('1103', Timestamp('2014-05-15 00:00:00')),
#  ('1103', Timestamp('2014-08-14 00:00:00')),
#  ('1103', Timestamp('2014-11-14 00:00:00')),
#  ('1103', Timestamp('2015-03-31 00:00:00')),
#  ('1103', Timestamp('2015-05-15 00:00:00')),
#  ('1103', Timestamp('2015-08-14 00:00:00')),
#  ('1103', Timestamp('2015-11-14 00:00:00')),
#  ('1103', Timestamp('2016-03-31 00:00:00')),
#  ('1103', Timestamp('2016-05-15 00:00:00')),
#  ('1103', Timestamp('2016-08-14 00:00:00')),
#  ('1103', Timestamp('2016-11-14 00:00:00')),
#  ('1103', Timestamp('2017-03-31 00:00:00')),
#  ('1103', Timestamp('2017-05-15 00:00:00')),
#  ('1103', Timestamp('2017-08-14 00:00:00')),
#  ('1103', Timestamp('2017-11-14 00:00:00')),
#  ('1103', Timestamp('2018-03-31 00:00:00')),
#  ('1103', Timestamp('2018-05-15 00:00:00')),
#  ('1103', Timestamp('2018-08-14 00:00:00')),
#  ('1103', Timestamp('2018-11-14 00:00:00')),
#  ('1103', Timestamp('2019-03-31 00:00:00')),
#  ('1103', Timestamp('2019-05-15 00:00:00')),
#  ('1103', Timestamp('2019-08-14 00:00:00')),
#  ('1103', Timestamp('2019-11-14 00:00:00')),
#  ('1103', Timestamp('2020-03-31 00:00:00')),
#  ('1103', Timestamp('2020-05-15 00:00:00')),
#  ('1103', Timestamp('2020-08-14 00:00:00')),
#  ('1103', Timestamp('2020-11-14 00:00:00')),
#  ('1103', Timestamp('2021-03-31 00:00:00')),
#  ('1103', Timestamp('2021-05-15 00:00:00')),
#  ('1103', Timestamp('2021-08-14 00:00:00')),
#  ('1103', Timestamp('2021-11-14 00:00:00')),
#  ('1103', Timestamp('2022-03-31 00:00:00')),
#  ('1103', Timestamp('2022-05-15 00:00:00')),
#  ('1104', Timestamp('2013-05-15 00:00:00')),
#  ('1104', Timestamp('2013-08-14 00:00:00')),
#  ('1104', Timestamp('2013-11-14 00:00:00')),
#  ('1104', Timestamp('2014-03-31 00:00:00')),
#  ('1104', Timestamp('2014-05-15 00:00:00')),
#  ('1104', Timestamp('2014-08-14 00:00:00')),
#  ('1104', Timestamp('2014-11-14 00:00:00')),
#  ('1104', Timestamp('2015-03-31 00:00:00')),
#  ('1104', Timestamp('2015-05-15 00:00:00')),
#  ('1104', Timestamp('2015-08-14 00:00:00')),
#  ('1104', Timestamp('2015-11-14 00:00:00')),
#  ('1104', Timestamp('2016-03-31 00:00:00')),
#  ('1104', Timestamp('2016-05-15 00:00:00')),
#  ('1104', Timestamp('2016-08-14 00:00:00')),
#  ('1104', Timestamp('2016-11-14 00:00:00')),
#  ('1104', Timestamp('2017-03-31 00:00:00')),
#  ('1104', Timestamp('2017-05-15 00:00:00')),
#  ('1104', Timestamp('2017-08-14 00:00:00')),
#  ('1104', Timestamp('2017-11-14 00:00:00')),
#  ('1104', Timestamp('2018-03-31 00:00:00')),
#  ('1104', Timestamp('2018-05-15 00:00:00')),
#  ('1104', Timestamp('2018-08-14 00:00:00')),
#  ('1104', Timestamp('2018-11-14 00:00:00')),
#  ('1104', Timestamp('2019-03-31 00:00:00')),
#  ('1104', Timestamp('2019-05-15 00:00:00')),
#  ('1104', Timestamp('2019-08-14 00:00:00')),
#  ('1104', Timestamp('2019-11-14 00:00:00')),
#  ('1104', Timestamp('2020-03-31 00:00:00')),
#  ('1104', Timestamp('2020-05-15 00:00:00')),
#  ('1104', Timestamp('2020-08-14 00:00:00')),
#  ('1104', Timestamp('2020-11-14 00:00:00')),
#  ('1104', Timestamp('2021-03-31 00:00:00')),
#  ('1104', Timestamp('2021-05-15 00:00:00')),
#  ('1104', Timestamp('2021-08-14 00:00:00')),
#  ('1104', Timestamp('2021-11-14 00:00:00')),
#  ('1104', Timestamp('2022-03-31 00:00:00')),
#  ('1104', Timestamp('2022-05-15 00:00:00')),
#  ('1108', Timestamp('2013-05-15 00:00:00')),
#  ('1108', Timestamp('2013-08-14 00:00:00')),
#  ('1108', Timestamp('2013-11-14 00:00:00')),
#  ('1108', Timestamp('2014-03-31 00:00:00')),
#  ('1108', Timestamp('2014-05-15 00:00:00')),
#  ('1108', Timestamp('2014-08-14 00:00:00')),
#  ('1108', Timestamp('2014-11-14 00:00:00')),
#  ('1108', Timestamp('2015-03-31 00:00:00')),
#  ('1108', Timestamp('2015-05-15 00:00:00')),
#  ('1108', Timestamp('2015-08-14 00:00:00')),
#  ('1108', Timestamp('2015-11-14 00:00:00')),
#  ('1108', Timestamp('2016-03-31 00:00:00')),
#  ('1108', Timestamp('2016-05-15 00:00:00')),
#  ('1108', Timestamp('2016-08-14 00:00:00')),
#  ('1108', Timestamp('2016-11-14 00:00:00')),
#  ('1108', Timestamp('2017-03-31 00:00:00')),
#  ('1108', Timestamp('2017-05-15 00:00:00')),
#  ('1108', Timestamp('2017-08-14 00:00:00')),
#  ('1108', Timestamp('2017-11-14 00:00:00')),
#  ('1108', Timestamp('2018-03-31 00:00:00')),
#  ('1108', Timestamp('2018-05-15 00:00:00')),
#  ('1108', Timestamp('2018-08-14 00:00:00')),
#  ('1108', Timestamp('2018-11-14 00:00:00')),
#  ('1108', Timestamp('2019-03-31 00:00:00')),
#  ('1108', Timestamp('2019-05-15 00:00:00')),
#  ('1108', Timestamp('2019-08-14 00:00:00')),
#  ('1108', Timestamp('2019-11-14 00:00:00')),
#  ('1108', Timestamp('2020-03-31 00:00:00')),
#  ('1108', Timestamp('2020-05-15 00:00:00')),
#  ('1108', Timestamp('2020-08-14 00:00:00')),
#  ('1108', Timestamp('2020-11-14 00:00:00')),
#  ('1108', Timestamp('2021-03-31 00:00:00')),
#  ('1108', Timestamp('2021-05-15 00:00:00')),
#  ('1108', Timestamp('2021-08-14 00:00:00')),
#  ('1108', Timestamp('2021-11-14 00:00:00')),
#  ('1108', Timestamp('2022-03-31 00:00:00')),
#  ('1108', Timestamp('2022-05-15 00:00:00')),
#  ('1109', Timestamp('2013-05-15 00:00:00')),
#  ('1109', Timestamp('2013-08-14 00:00:00')),
#  ('1109', Timestamp('2013-11-14 00:00:00')),
#  ('1109', Timestamp('2014-03-31 00:00:00')),
#  ('1109', Timestamp('2014-05-15 00:00:00')),
#  ('1109', Timestamp('2014-08-14 00:00:00')),
#  ('1109', Timestamp('2014-11-14 00:00:00')),
#  ('1109', Timestamp('2015-03-31 00:00:00')),
#  ('1109', Timestamp('2015-05-15 00:00:00')),
#  ('1109', Timestamp('2015-08-14 00:00:00')),
#  ('1109', Timestamp('2015-11-14 00:00:00')),
#  ('1109', Timestamp('2016-03-31 00:00:00')),
#  ('1109', Timestamp('2016-05-15 00:00:00')),
#  ('1109', Timestamp('2016-08-14 00:00:00')),
#  ('1109', Timestamp('2016-11-14 00:00:00')),
#  ('1109', Timestamp('2017-03-31 00:00:00')),
#  ('1109', Timestamp('2017-05-15 00:00:00')),
#  ('1109', Timestamp('2017-08-14 00:00:00')),
#  ('1109', Timestamp('2017-11-14 00:00:00')),
#  ('1109', Timestamp('2018-03-31 00:00:00')),
#  ('1109', Timestamp('2018-05-15 00:00:00')),
#  ('1109', Timestamp('2018-08-14 00:00:00')),
#  ('1109', Timestamp('2018-11-14 00:00:00')),
#  ('1109', Timestamp('2019-03-31 00:00:00')),
#  ('1109', Timestamp('2019-05-15 00:00:00')),
#  ('1109', Timestamp('2019-08-14 00:00:00')),
#  ('1109', Timestamp('2019-11-14 00:00:00')),
#  ('1109', Timestamp('2020-03-31 00:00:00')),
#  ('1109', Timestamp('2020-05-15 00:00:00')),
#  ('1109', Timestamp('2020-08-14 00:00:00')),
#  ('1109', Timestamp('2020-11-14 00:00:00')),
#  ('1109', Timestamp('2021-03-31 00:00:00')),
#  ('1109', Timestamp('2021-05-15 00:00:00')),
#  ('1109', Timestamp('2021-08-14 00:00:00')),
#  ('1109', Timestamp('2021-11-14 00:00:00')),
#  ('1109', Timestamp('2022-03-31 00:00:00')),
#  ('1109', Timestamp('2022-05-15 00:00:00')),
#  ('1110', Timestamp('2013-05-15 00:00:00')),
#  ('1110', Timestamp('2013-08-14 00:00:00')),
#  ('1110', Timestamp('2013-11-14 00:00:00')),
#  ('1110', Timestamp('2014-03-31 00:00:00')),
#  ('1110', Timestamp('2014-05-15 00:00:00')),
#  ('1110', Timestamp('2014-08-14 00:00:00')),
#  ('1110', Timestamp('2014-11-14 00:00:00')),
#  ('1110', Timestamp('2015-03-31 00:00:00')),
#  ('1110', Timestamp('2015-05-15 00:00:00')),
#  ('1110', Timestamp('2015-08-14 00:00:00')),
#  ('1110', Timestamp('2015-11-14 00:00:00')),
#  ('1110', Timestamp('2016-03-31 00:00:00')),
#  ('1110', Timestamp('2016-05-15 00:00:00')),
#  ('1110', Timestamp('2016-08-14 00:00:00')),
#  ('1110', Timestamp('2016-11-14 00:00:00')),
#  ('1110', Timestamp('2017-03-31 00:00:00')),
#  ('1110', Timestamp('2017-05-15 00:00:00')),
#  ('1110', Timestamp('2017-08-14 00:00:00')),
#  ('1110', Timestamp('2017-11-14 00:00:00')),
#  ('1110', Timestamp('2018-03-31 00:00:00')),
#  ('1110', Timestamp('2018-05-15 00:00:00')),
#  ('1110', Timestamp('2018-08-14 00:00:00')),
#  ('1110', Timestamp('2018-11-14 00:00:00')),
#  ('1110', Timestamp('2019-03-31 00:00:00')),
#  ('1110', Timestamp('2019-05-15 00:00:00')),
#  ('1110', Timestamp('2019-08-14 00:00:00')),
#  ('1110', Timestamp('2019-11-14 00:00:00')),
#  ('1110', Timestamp('2020-03-31 00:00:00')),
#  ('1110', Timestamp('2020-05-15 00:00:00')),
#  ('1110', Timestamp('2020-08-14 00:00:00')),
#  ('1110', Timestamp('2020-11-14 00:00:00')),
#  ('1110', Timestamp('2021-03-31 00:00:00')),
#  ('1110', Timestamp('2021-05-15 00:00:00')),
#  ('1110', Timestamp('2021-08-14 00:00:00')),
#  ('1110', Timestamp('2021-11-14 00:00:00')),
#  ('1110', Timestamp('2022-03-31 00:00:00')),
#  ('1110', Timestamp('2022-05-15 00:00:00')),
#  ('1201', Timestamp('2013-05-15 00:00:00')),
#  ('1201', Timestamp('2013-08-14 00:00:00')),
#  ('1201', Timestamp('2013-11-14 00:00:00')),
#  ('1201', Timestamp('2014-03-31 00:00:00')),
#  ('1201', Timestamp('2014-05-15 00:00:00')),
#  ('1201', Timestamp('2014-08-14 00:00:00')),
#  ('1201', Timestamp('2014-11-14 00:00:00')),
#  ('1201', Timestamp('2015-03-31 00:00:00')),
#  ('1201', Timestamp('2015-05-15 00:00:00')),
#  ('1201', Timestamp('2015-08-14 00:00:00')),
#  ('1201', Timestamp('2015-11-14 00:00:00')),
#  ('1201', Timestamp('2016-03-31 00:00:00')),
#  ('1201', Timestamp('2016-05-15 00:00:00')),
#  ('1201', Timestamp('2016-08-14 00:00:00')),
#  ('1201', Timestamp('2016-11-14 00:00:00')),
#  ('1201', Timestamp('2017-03-31 00:00:00')),
#  ('1201', Timestamp('2017-05-15 00:00:00')),
#  ('1201', Timestamp('2017-08-14 00:00:00')),
#  ('1201', Timestamp('2017-11-14 00:00:00')),
#  ('1201', Timestamp('2018-03-31 00:00:00')),
#  ('1201', Timestamp('2018-05-15 00:00:00')),
#  ('1201', Timestamp('2018-08-14 00:00:00')),
#  ('1201', Timestamp('2018-11-14 00:00:00')),
#  ('1201', Timestamp('2019-03-31 00:00:00')),
#  ('1201', Timestamp('2019-05-15 00:00:00')),
#  ('1201', Timestamp('2019-08-14 00:00:00')),
#  ('1201', Timestamp('2019-11-14 00:00:00')),
#  ('1201', Timestamp('2020-03-31 00:00:00')),
#  ('1201', Timestamp('2020-05-15 00:00:00')),
#  ('1201', Timestamp('2020-08-14 00:00:00')),
#  ('1201', Timestamp('2020-11-14 00:00:00')),
#  ('1201', Timestamp('2021-03-31 00:00:00')),
#  ('1201', Timestamp('2021-05-15 00:00:00')),
#  ('1201', Timestamp('2021-08-14 00:00:00')),
#  ('1201', Timestamp('2021-11-14 00:00:00')),
#  ('1201', Timestamp('2022-03-31 00:00:00')),
#  ('1201', Timestamp('2022-05-15 00:00:00')),
#  ('1203', Timestamp('2013-05-15 00:00:00')),
#  ('1203', Timestamp('2013-08-14 00:00:00')),
#  ('1203', Timestamp('2013-11-14 00:00:00')),
#  ('1203', Timestamp('2014-03-31 00:00:00')),
#  ('1203', Timestamp('2014-05-15 00:00:00')),
#  ('1203', Timestamp('2014-08-14 00:00:00')),
#  ('1203', Timestamp('2014-11-14 00:00:00')),
#  ('1203', Timestamp('2015-03-31 00:00:00')),
#  ('1203', Timestamp('2015-05-15 00:00:00')),
#  ('1203', Timestamp('2015-08-14 00:00:00')),
#  ('1203', Timestamp('2015-11-14 00:00:00')),
#  ('1203', Timestamp('2016-03-31 00:00:00')),
#  ('1203', Timestamp('2016-05-15 00:00:00')),
#  ('1203', Timestamp('2016-08-14 00:00:00')),
#  ('1203', Timestamp('2016-11-14 00:00:00')),
#  ('1203', Timestamp('2017-03-31 00:00:00')),
#  ('1203', Timestamp('2017-05-15 00:00:00')),
#  ('1203', Timestamp('2017-08-14 00:00:00')),
#  ('1203', Timestamp('2017-11-14 00:00:00')),
#  ('1203', Timestamp('2018-03-31 00:00:00')),
#  ('1203', Timestamp('2018-05-15 00:00:00')),
#  ('1203', Timestamp('2018-08-14 00:00:00')),
#  ('1203', Timestamp('2018-11-14 00:00:00')),
#  ('1203', Timestamp('2019-03-31 00:00:00')),
#  ('1203', Timestamp('2019-05-15 00:00:00')),
#  ('1203', Timestamp('2019-08-14 00:00:00')),
#  ('1203', Timestamp('2019-11-14 00:00:00')),
#  ('1203', Timestamp('2020-03-31 00:00:00')),
#  ('1203', Timestamp('2020-05-15 00:00:00')),
#  ('1203', Timestamp('2020-08-14 00:00:00')),
#  ('1203', Timestamp('2020-11-14 00:00:00')),
#  ('1203', Timestamp('2021-03-31 00:00:00')),
#  ('1203', Timestamp('2021-05-15 00:00:00')),
#  ('1203', Timestamp('2021-08-14 00:00:00')),
#  ('1203', Timestamp('2021-11-14 00:00:00')),
#  ('1203', Timestamp('2022-03-31 00:00:00')),
#  ('1203', Timestamp('2022-05-15 00:00:00')),
#  ('1210', Timestamp('2013-05-15 00:00:00')),
#  ('1210', Timestamp('2013-08-14 00:00:00')),
#  ('1210', Timestamp('2013-11-14 00:00:00')),
#  ('1210', Timestamp('2014-03-31 00:00:00')),
#  ('1210', Timestamp('2014-05-15 00:00:00')),
#  ('1210', Timestamp('2014-08-14 00:00:00')),
#  ('1210', Timestamp('2014-11-14 00:00:00')),
#  ('1210', Timestamp('2015-03-31 00:00:00')),
#  ('1210', Timestamp('2015-05-15 00:00:00')),
#  ('1210', Timestamp('2015-08-14 00:00:00')),
#  ('1210', Timestamp('2015-11-14 00:00:00')),
#  ('1210', Timestamp('2016-03-31 00:00:00')),
#  ('1210', Timestamp('2016-05-15 00:00:00')),
#  ('1210', Timestamp('2016-08-14 00:00:00')),
#  ('1210', Timestamp('2016-11-14 00:00:00')),
#  ('1210', Timestamp('2017-03-31 00:00:00')),
#  ('1210', Timestamp('2017-05-15 00:00:00')),
#  ('1210', Timestamp('2017-08-14 00:00:00')),
#  ('1210', Timestamp('2017-11-14 00:00:00')),
#  ('1210', Timestamp('2018-03-31 00:00:00')),
#  ('1210', Timestamp('2018-05-15 00:00:00')),
#  ('1210', Timestamp('2018-08-14 00:00:00')),
#  ('1210', Timestamp('2018-11-14 00:00:00')),
#  ('1210', Timestamp('2019-03-31 00:00:00')),
#  ('1210', Timestamp('2019-05-15 00:00:00')),
#  ('1210', Timestamp('2019-08-14 00:00:00')),
#  ('1210', Timestamp('2019-11-14 00:00:00')),
#  ('1210', Timestamp('2020-03-31 00:00:00')),
#  ('1210', Timestamp('2020-05-15 00:00:00')),
#  ('1210', Timestamp('2020-08-14 00:00:00')),
#  ('1210', Timestamp('2020-11-14 00:00:00')),
#  ('1210', Timestamp('2021-03-31 00:00:00')),
#  ('1210', Timestamp('2021-05-15 00:00:00')),
#  ('1210', Timestamp('2021-08-14 00:00:00')),
#  ('1210', Timestamp('2021-11-14 00:00:00')),
#  ('1210', Timestamp('2022-03-31 00:00:00')),
#  ('1210', Timestamp('2022-05-15 00:00:00')),
#  ('1213', Timestamp('2013-05-15 00:00:00')),
#  ('1213', Timestamp('2013-08-14 00:00:00')),
#  ('1213', Timestamp('2013-11-14 00:00:00')),
#  ('1213', Timestamp('2014-03-31 00:00:00')),
#  ('1213', Timestamp('2014-05-15 00:00:00')),
#  ('1213', Timestamp('2014-08-14 00:00:00')),
#  ('1213', Timestamp('2014-11-14 00:00:00')),
#  ('1213', Timestamp('2015-03-31 00:00:00')),
#  ('1213', Timestamp('2015-05-15 00:00:00')),
#  ('1213', Timestamp('2015-08-14 00:00:00')),
#  ('1213', Timestamp('2015-11-14 00:00:00')),
#  ('1213', Timestamp('2016-03-31 00:00:00')),
#  ('1213', Timestamp('2016-05-15 00:00:00')),
#  ('1213', Timestamp('2016-08-14 00:00:00')),
#  ('1213', Timestamp('2016-11-14 00:00:00')),
#  ('1213', Timestamp('2017-03-31 00:00:00')),
#  ('1213', Timestamp('2017-05-15 00:00:00')),
#  ('1213', Timestamp('2017-08-14 00:00:00')),
#  ('1213', Timestamp('2017-11-14 00:00:00')),
#  ('1213', Timestamp('2018-03-31 00:00:00')),
#  ('1213', Timestamp('2018-05-15 00:00:00')),
#  ('1213', Timestamp('2018-08-14 00:00:00')),
#  ('1213', Timestamp('2018-11-14 00:00:00')),
#  ('1213', Timestamp('2019-03-31 00:00:00')),
#  ('1213', Timestamp('2019-05-15 00:00:00')),
#  ('1213', Timestamp('2019-08-14 00:00:00')),
#  ('1213', Timestamp('2019-11-14 00:00:00')),
#  ('1213', Timestamp('2020-03-31 00:00:00')),
#  ('1213', Timestamp('2020-05-15 00:00:00')),
#  ('1213', Timestamp('2020-08-14 00:00:00')),
#  ('1213', Timestamp('2020-11-14 00:00:00')),
#  ('1213', Timestamp('2021-03-31 00:00:00')),
#  ('1213', Timestamp('2021-05-15 00:00:00')),
#  ('1213', Timestamp('2021-08-14 00:00:00')),
#  ('1213', Timestamp('2021-11-14 00:00:00')),
#  ('1213', Timestamp('2022-03-31 00:00:00')),
#  ('1213', Timestamp('2022-05-15 00:00:00')),
#  ('1215', Timestamp('2013-05-15 00:00:00')),
#  ('1215', Timestamp('2013-08-14 00:00:00')),
#  ('1215', Timestamp('2013-11-14 00:00:00')),
#  ('1215', Timestamp('2014-03-31 00:00:00')),
#  ('1215', Timestamp('2014-05-15 00:00:00')),
#  ('1215', Timestamp('2014-08-14 00:00:00')),
#  ('1215', Timestamp('2014-11-14 00:00:00')),
#  ('1215', Timestamp('2015-03-31 00:00:00')),
#  ('1215', Timestamp('2015-05-15 00:00:00')),
#  ('1215', Timestamp('2015-08-14 00:00:00')),
#  ('1215', Timestamp('2015-11-14 00:00:00')),
#  ('1215', Timestamp('2016-03-31 00:00:00')),
#  ('1215', Timestamp('2016-05-15 00:00:00')),
#  ('1215', Timestamp('2016-08-14 00:00:00')),
#  ('1215', Timestamp('2016-11-14 00:00:00')),
#  ('1215', Timestamp('2017-03-31 00:00:00')),
#  ('1215', Timestamp('2017-05-15 00:00:00')),
#  ('1215', Timestamp('2017-08-14 00:00:00')),
#  ('1215', Timestamp('2017-11-14 00:00:00')),
#  ('1215', Timestamp('2018-03-31 00:00:00')),
#  ('1215', Timestamp('2018-05-15 00:00:00')),
#  ('1215', Timestamp('2018-08-14 00:00:00')),
#  ('1215', Timestamp('2018-11-14 00:00:00')),
#  ('1215', Timestamp('2019-03-31 00:00:00')),
#  ('1215', Timestamp('2019-05-15 00:00:00')),
#  ('1215', Timestamp('2019-08-14 00:00:00')),
#  ('1215', Timestamp('2019-11-14 00:00:00')),
#  ('1215', Timestamp('2020-03-31 00:00:00')),
#  ('1215', Timestamp('2020-05-15 00:00:00')),
#  ('1215', Timestamp('2020-08-14 00:00:00')),
#  ('1215', Timestamp('2020-11-14 00:00:00')),
#  ('1215', Timestamp('2021-03-31 00:00:00')),
#  ('1215', Timestamp('2021-05-15 00:00:00')),
#  ('1215', Timestamp('2021-08-14 00:00:00')),
#  ('1215', Timestamp('2021-11-14 00:00:00')),
#  ('1215', Timestamp('2022-03-31 00:00:00')),
#  ('1215', Timestamp('2022-05-15 00:00:00')),
#  ('1216', Timestamp('2013-05-15 00:00:00')),
#  ('1216', Timestamp('2013-08-14 00:00:00')),
#  ('1216', Timestamp('2013-11-14 00:00:00')),
#  ('1216', Timestamp('2014-03-31 00:00:00')),
#  ('1216', Timestamp('2014-05-15 00:00:00')),
#  ('1216', Timestamp('2014-08-14 00:00:00')),
#  ('1216', Timestamp('2014-11-14 00:00:00')),
#  ('1216', Timestamp('2015-03-31 00:00:00')),
#  ('1216', Timestamp('2015-05-15 00:00:00')),
#  ('1216', Timestamp('2015-08-14 00:00:00')),
#  ('1216', Timestamp('2015-11-14 00:00:00')),
#  ('1216', Timestamp('2016-03-31 00:00:00')),
#  ('1216', Timestamp('2016-05-15 00:00:00')),
#  ('1216', Timestamp('2016-08-14 00:00:00')),
#  ('1216', Timestamp('2016-11-14 00:00:00')),
#  ('1216', Timestamp('2017-03-31 00:00:00')),
#  ('1216', Timestamp('2017-05-15 00:00:00')),
#  ('1216', Timestamp('2017-08-14 00:00:00')),
#  ('1216', Timestamp('2017-11-14 00:00:00')),
#  ('1216', Timestamp('2018-03-31 00:00:00')),
#  ('1216', Timestamp('2018-05-15 00:00:00')),
#  ('1216', Timestamp('2018-08-14 00:00:00')),
#  ('1216', Timestamp('2018-11-14 00:00:00')),
#  ('1216', Timestamp('2019-03-31 00:00:00')),
#  ('1216', Timestamp('2019-05-15 00:00:00')),
#  ('1216', Timestamp('2019-08-14 00:00:00')),
#  ('1216', Timestamp('2019-11-14 00:00:00')),
#  ('1216', Timestamp('2020-03-31 00:00:00')),
#  ('1216', Timestamp('2020-05-15 00:00:00')),
#  ('1216', Timestamp('2020-08-14 00:00:00')),
#  ('1216', Timestamp('2020-11-14 00:00:00')),
#  ('1216', Timestamp('2021-03-31 00:00:00')),
#  ('1216', Timestamp('2021-05-15 00:00:00')),
#  ('1216', Timestamp('2021-08-14 00:00:00')),
#  ('1216', Timestamp('2021-11-14 00:00:00')),
#  ('1216', Timestamp('2022-03-31 00:00:00')),
#  ('1216', Timestamp('2022-05-15 00:00:00')),
#  ('1217', Timestamp('2013-05-15 00:00:00')),
#  ('1217', Timestamp('2013-08-14 00:00:00')),
#  ('1217', Timestamp('2013-11-14 00:00:00')),
#  ('1217', Timestamp('2014-03-31 00:00:00')),
#  ('1217', Timestamp('2014-05-15 00:00:00')),
#  ('1217', Timestamp('2014-08-14 00:00:00')),
#  ('1217', Timestamp('2014-11-14 00:00:00')),
#  ('1217', Timestamp('2015-03-31 00:00:00')),
#  ('1217', Timestamp('2015-05-15 00:00:00')),
#  ('1217', Timestamp('2015-08-14 00:00:00')),
#  ('1217', Timestamp('2015-11-14 00:00:00')),
#  ('1217', Timestamp('2016-03-31 00:00:00')),
#  ('1217', Timestamp('2016-05-15 00:00:00')),
#  ('1217', Timestamp('2016-08-14 00:00:00')),
#  ('1217', Timestamp('2016-11-14 00:00:00')),
#  ('1217', Timestamp('2017-03-31 00:00:00')),
#  ('1217', Timestamp('2017-05-15 00:00:00')),
#  ('1217', Timestamp('2017-08-14 00:00:00')),
#  ('1217', Timestamp('2017-11-14 00:00:00')),
#  ('1217', Timestamp('2018-03-31 00:00:00')),
#  ('1217', Timestamp('2018-05-15 00:00:00')),
#  ('1217', Timestamp('2018-08-14 00:00:00')),
#  ('1217', Timestamp('2018-11-14 00:00:00')),
#  ('1217', Timestamp('2019-03-31 00:00:00')),
#  ('1217', Timestamp('2019-05-15 00:00:00')),
#  ('1217', Timestamp('2019-08-14 00:00:00')),
#  ('1217', Timestamp('2019-11-14 00:00:00')),
#  ('1217', Timestamp('2020-03-31 00:00:00')),
#  ('1217', Timestamp('2020-05-15 00:00:00')),
#  ('1217', Timestamp('2020-08-14 00:00:00')),
#  ('1217', Timestamp('2020-11-14 00:00:00')),
#  ('1217', Timestamp('2021-03-31 00:00:00')),
#  ('1217', Timestamp('2021-05-15 00:00:00')),
#  ('1217', Timestamp('2021-08-14 00:00:00')),
#  ('1217', Timestamp('2021-11-14 00:00:00')),
#  ('1217', Timestamp('2022-03-31 00:00:00')),
#  ('1217', Timestamp('2022-05-15 00:00:00')),
#  ('1218', Timestamp('2013-05-15 00:00:00')),
#  ('1218', Timestamp('2013-08-14 00:00:00')),
#  ('1218', Timestamp('2013-11-14 00:00:00')),
#  ('1218', Timestamp('2014-03-31 00:00:00')),
#  ('1218', Timestamp('2014-05-15 00:00:00')),
#  ('1218', Timestamp('2014-08-14 00:00:00')),
#  ('1218', Timestamp('2014-11-14 00:00:00')),
#  ('1218', Timestamp('2015-03-31 00:00:00')),
#  ('1218', Timestamp('2015-05-15 00:00:00')),
#  ('1218', Timestamp('2015-08-14 00:00:00')),
#  ('1218', Timestamp('2015-11-14 00:00:00')),
#  ('1218', Timestamp('2016-03-31 00:00:00')),
#  ('1218', Timestamp('2016-05-15 00:00:00')),
#  ('1218', Timestamp('2016-08-14 00:00:00')),
#  ('1218', Timestamp('2016-11-14 00:00:00')),
#  ('1218', Timestamp('2017-03-31 00:00:00')),
#  ('1218', Timestamp('2017-05-15 00:00:00')),
#  ('1218', Timestamp('2017-08-14 00:00:00')),
#  ('1218', Timestamp('2017-11-14 00:00:00')),
#  ('1218', Timestamp('2018-03-31 00:00:00')),
#  ('1218', Timestamp('2018-05-15 00:00:00')),
#  ('1218', Timestamp('2018-08-14 00:00:00')),
#  ('1218', Timestamp('2018-11-14 00:00:00')),
#  ('1218', Timestamp('2019-03-31 00:00:00')),
#  ('1218', Timestamp('2019-05-15 00:00:00')),
#  ('1218', Timestamp('2019-08-14 00:00:00')),
#  ('1218', Timestamp('2019-11-14 00:00:00')),
#  ('1218', Timestamp('2020-03-31 00:00:00')),
#  ('1218', Timestamp('2020-05-15 00:00:00')),
#  ('1218', Timestamp('2020-08-14 00:00:00')),
#  ('1218', Timestamp('2020-11-14 00:00:00')),
#  ('1218', Timestamp('2021-03-31 00:00:00')),
#  ('1218', Timestamp('2021-05-15 00:00:00')),
#  ('1218', Timestamp('2021-08-14 00:00:00')),
#  ('1218', Timestamp('2021-11-14 00:00:00')),
#  ('1218', Timestamp('2022-03-31 00:00:00')),
#  ('1218', Timestamp('2022-05-15 00:00:00')),
#  ('1219', Timestamp('2013-05-15 00:00:00')),
#  ('1219', Timestamp('2013-08-14 00:00:00')),
#  ('1219', Timestamp('2013-11-14 00:00:00')),
#  ('1219', Timestamp('2014-03-31 00:00:00')),
#  ('1219', Timestamp('2014-05-15 00:00:00')),
#  ('1219', Timestamp('2014-08-14 00:00:00')),
#  ('1219', Timestamp('2014-11-14 00:00:00')),
#  ('1219', Timestamp('2015-03-31 00:00:00')),
#  ('1219', Timestamp('2015-05-15 00:00:00')),
#  ('1219', Timestamp('2015-08-14 00:00:00')),
#  ('1219', Timestamp('2015-11-14 00:00:00')),
#  ('1219', Timestamp('2016-03-31 00:00:00')),
#  ('1219', Timestamp('2016-05-15 00:00:00')),
#  ('1219', Timestamp('2016-08-14 00:00:00')),
#  ('1219', Timestamp('2016-11-14 00:00:00')),
#  ('1219', Timestamp('2017-03-31 00:00:00')),
#  ('1219', Timestamp('2017-05-15 00:00:00')),
#  ('1219', Timestamp('2017-08-14 00:00:00')),
#  ('1219', Timestamp('2017-11-14 00:00:00')),
#  ('1219', Timestamp('2018-03-31 00:00:00')),
#  ('1219', Timestamp('2018-05-15 00:00:00')),
#  ('1219', Timestamp('2018-08-14 00:00:00')),
#  ('1219', Timestamp('2018-11-14 00:00:00')),
#  ('1219', Timestamp('2019-03-31 00:00:00')),
#  ('1219', Timestamp('2019-05-15 00:00:00')),
#  ('1219', Timestamp('2019-08-14 00:00:00')),
#  ('1219', Timestamp('2019-11-14 00:00:00')),
#  ('1219', Timestamp('2020-03-31 00:00:00')),
#  ('1219', Timestamp('2020-05-15 00:00:00')),
#  ('1219', Timestamp('2020-08-14 00:00:00')),
#  ('1219', Timestamp('2020-11-14 00:00:00')),
#  ('1219', Timestamp('2021-03-31 00:00:00')),
#  ('1219', Timestamp('2021-05-15 00:00:00')),
#  ('1219', Timestamp('2021-08-14 00:00:00')),
#  ('1219', Timestamp('2021-11-14 00:00:00')),
#  ('1219', Timestamp('2022-03-31 00:00:00')),
#  ('1219', Timestamp('2022-05-15 00:00:00')),
#  ('1220', Timestamp('2013-05-15 00:00:00')),
#  ('1220', Timestamp('2013-08-14 00:00:00')),
#  ('1220', Timestamp('2013-11-14 00:00:00')),
#  ('1220', Timestamp('2014-03-31 00:00:00')),
#  ('1220', Timestamp('2014-05-15 00:00:00')),
#  ('1220', Timestamp('2014-08-14 00:00:00')),
#  ('1220', Timestamp('2014-11-14 00:00:00')),
#  ('1220', Timestamp('2015-03-31 00:00:00')),
#  ('1220', Timestamp('2015-05-15 00:00:00')),
#  ('1220', Timestamp('2015-08-14 00:00:00')),
#  ('1220', Timestamp('2015-11-14 00:00:00')),
#  ('1220', Timestamp('2016-03-31 00:00:00')),
#  ('1220', Timestamp('2016-05-15 00:00:00')),
#  ('1220', Timestamp('2016-08-14 00:00:00')),
#  ('1220', Timestamp('2016-11-14 00:00:00')),
#  ('1220', Timestamp('2017-03-31 00:00:00')),
#  ('1220', Timestamp('2017-05-15 00:00:00')),
#  ('1220', Timestamp('2017-08-14 00:00:00')),
#  ('1220', Timestamp('2017-11-14 00:00:00')),
#  ('1220', Timestamp('2018-03-31 00:00:00')),
#  ('1220', Timestamp('2018-05-15 00:00:00')),
#  ('1220', Timestamp('2018-08-14 00:00:00')),
#  ('1220', Timestamp('2018-11-14 00:00:00')),
#  ('1220', Timestamp('2019-03-31 00:00:00')),
#  ('1220', Timestamp('2019-05-15 00:00:00')),
#  ('1220', Timestamp('2019-08-14 00:00:00')),
#  ('1220', Timestamp('2019-11-14 00:00:00')),
#  ('1220', Timestamp('2020-03-31 00:00:00')),
#  ('1220', Timestamp('2020-05-15 00:00:00')),
#  ('1220', Timestamp('2020-08-14 00:00:00')),
#  ('1220', Timestamp('2020-11-14 00:00:00')),
#  ('1220', Timestamp('2021-03-31 00:00:00')),
#  ('1220', Timestamp('2021-05-15 00:00:00')),
#  ('1220', Timestamp('2021-08-14 00:00:00')),
#  ('1220', Timestamp('2021-11-14 00:00:00')),
#  ('1220', Timestamp('2022-03-31 00:00:00')),
#  ('1220', Timestamp('2022-05-15 00:00:00')),
#  ('1225', Timestamp('2013-05-15 00:00:00')),
#  ('1225', Timestamp('2013-08-14 00:00:00')),
#  ('1225', Timestamp('2013-11-14 00:00:00')),
#  ('1225', Timestamp('2014-03-31 00:00:00')),
#  ('1225', Timestamp('2014-05-15 00:00:00')),
#  ('1225', Timestamp('2014-08-14 00:00:00')),
#  ('1225', Timestamp('2014-11-14 00:00:00')),
#  ('1225', Timestamp('2015-03-31 00:00:00')),
#  ('1225', Timestamp('2015-05-15 00:00:00')),
#  ('1225', Timestamp('2015-08-14 00:00:00')),
#  ('1225', Timestamp('2015-11-14 00:00:00')),
#  ('1225', Timestamp('2016-03-31 00:00:00')),
#  ('1225', Timestamp('2016-05-15 00:00:00')),
#  ('1225', Timestamp('2016-08-14 00:00:00')),
#  ('1225', Timestamp('2016-11-14 00:00:00')),
#  ('1225', Timestamp('2017-03-31 00:00:00')),
#  ('1225', Timestamp('2017-05-15 00:00:00')),
#  ('1225', Timestamp('2017-08-14 00:00:00')),
#  ('1225', Timestamp('2017-11-14 00:00:00')),
#  ('1225', Timestamp('2018-03-31 00:00:00')),
#  ('1225', Timestamp('2018-05-15 00:00:00')),
#  ('1225', Timestamp('2018-08-14 00:00:00')),
#  ('1225', Timestamp('2018-11-14 00:00:00')),
#  ('1225', Timestamp('2019-03-31 00:00:00')),
#  ('1225', Timestamp('2019-05-15 00:00:00')),
#  ('1225', Timestamp('2019-08-14 00:00:00')),
#  ('1225', Timestamp('2019-11-14 00:00:00')),
#  ('1225', Timestamp('2020-03-31 00:00:00')),
#  ('1225', Timestamp('2020-05-15 00:00:00')),
#  ('1225', Timestamp('2020-08-14 00:00:00')),
#  ('1225', Timestamp('2020-11-14 00:00:00')),
#  ('1225', Timestamp('2021-03-31 00:00:00')),
#  ('1225', Timestamp('2021-05-15 00:00:00')),
#  ('1225', Timestamp('2021-08-14 00:00:00')),
#  ('1225', Timestamp('2021-11-14 00:00:00')),
#  ('1225', Timestamp('2022-03-31 00:00:00')),
#  ('1225', Timestamp('2022-05-15 00:00:00')),
#  ('1227', Timestamp('2013-05-15 00:00:00')),
#  ('1227', Timestamp('2013-08-14 00:00:00')),
#  ('1227', Timestamp('2013-11-14 00:00:00')),
#  ('1227', Timestamp('2014-03-31 00:00:00')),
#  ('1227', Timestamp('2014-05-15 00:00:00')),
#  ('1227', Timestamp('2014-08-14 00:00:00')),
#  ('1227', Timestamp('2014-11-14 00:00:00')),
#  ('1227', Timestamp('2015-03-31 00:00:00')),
#  ('1227', Timestamp('2015-05-15 00:00:00')),
#  ('1227', Timestamp('2015-08-14 00:00:00')),
#  ('1227', Timestamp('2015-11-14 00:00:00')),
#  ('1227', Timestamp('2016-03-31 00:00:00')),
#  ('1227', Timestamp('2016-05-15 00:00:00')),
#  ('1227', Timestamp('2016-08-14 00:00:00')),
#  ('1227', Timestamp('2016-11-14 00:00:00')),
#  ('1227', Timestamp('2017-03-31 00:00:00')),
#  ('1227', Timestamp('2017-05-15 00:00:00')),
#  ('1227', Timestamp('2017-08-14 00:00:00')),
#  ('1227', Timestamp('2017-11-14 00:00:00')),
#  ('1227', Timestamp('2018-03-31 00:00:00')),
#  ('1227', Timestamp('2018-05-15 00:00:00')),
#  ('1227', Timestamp('2018-08-14 00:00:00')),
#  ('1227', Timestamp('2018-11-14 00:00:00')),
#  ('1227', Timestamp('2019-03-31 00:00:00')),
#  ('1227', Timestamp('2019-05-15 00:00:00')),
#  ('1227', Timestamp('2019-08-14 00:00:00')),
#  ('1227', Timestamp('2019-11-14 00:00:00')),
#  ('1227', Timestamp('2020-03-31 00:00:00')),
#  ('1227', Timestamp('2020-05-15 00:00:00')),
#  ('1227', Timestamp('2020-08-14 00:00:00')),
#  ('1227', Timestamp('2020-11-14 00:00:00')),
#  ('1227', Timestamp('2021-03-31 00:00:00')),
#  ('1227', Timestamp('2021-05-15 00:00:00')),
#  ('1227', Timestamp('2021-08-14 00:00:00')),
#  ('1227', Timestamp('2021-11-14 00:00:00')),
#  ('1227', Timestamp('2022-03-31 00:00:00')),
#  ('1227', Timestamp('2022-05-15 00:00:00')),
#  ('1229', Timestamp('2013-05-15 00:00:00')),
#  ('1229', Timestamp('2013-08-14 00:00:00')),
#  ('1229', Timestamp('2013-11-14 00:00:00')),
#  ('1229', Timestamp('2014-03-31 00:00:00')),
#  ('1229', Timestamp('2014-05-15 00:00:00')),
#  ('1229', Timestamp('2014-08-14 00:00:00')),
#  ('1229', Timestamp('2014-11-14 00:00:00')),
#  ('1229', Timestamp('2015-03-31 00:00:00')),
#  ('1229', Timestamp('2015-05-15 00:00:00')),
#  ('1229', Timestamp('2015-08-14 00:00:00')),
#  ('1229', Timestamp('2015-11-14 00:00:00')),
#  ('1229', Timestamp('2016-03-31 00:00:00')),
#  ('1229', Timestamp('2016-05-15 00:00:00')),
#  ('1229', Timestamp('2016-08-14 00:00:00')),
#  ('1229', Timestamp('2016-11-14 00:00:00')),
#  ('1229', Timestamp('2017-03-31 00:00:00')),
#  ('1229', Timestamp('2017-05-15 00:00:00')),
#  ('1229', Timestamp('2017-08-14 00:00:00')),
#  ('1229', Timestamp('2017-11-14 00:00:00')),
#  ('1229', Timestamp('2018-03-31 00:00:00')),
#  ('1229', Timestamp('2018-05-15 00:00:00')),
#  ('1229', Timestamp('2018-08-14 00:00:00')),
#  ('1229', Timestamp('2018-11-14 00:00:00')),
#  ('1229', Timestamp('2019-03-31 00:00:00')),
#  ('1229', Timestamp('2019-05-15 00:00:00')),
#  ('1229', Timestamp('2019-08-14 00:00:00')),
#  ('1229', Timestamp('2019-11-14 00:00:00')),
#  ('1229', Timestamp('2020-03-31 00:00:00')),
#  ('1229', Timestamp('2020-05-15 00:00:00')),
#  ('1229', Timestamp('2020-08-14 00:00:00')),
#  ('1229', Timestamp('2020-11-14 00:00:00')),
#  ('1229', Timestamp('2021-03-31 00:00:00')),
#  ('1229', Timestamp('2021-05-15 00:00:00')),
#  ('1229', Timestamp('2021-08-14 00:00:00')),
#  ('1229', Timestamp('2021-11-14 00:00:00')),
#  ('1229', Timestamp('2022-03-31 00:00:00')),
#  ('1229', Timestamp('2022-05-15 00:00:00')),
#  ('1231', Timestamp('2013-05-15 00:00:00')),
#  ('1231', Timestamp('2013-08-14 00:00:00')),
#  ('1231', Timestamp('2013-11-14 00:00:00')),
#  ('1231', Timestamp('2014-03-31 00:00:00')),
#  ('1231', Timestamp('2014-05-15 00:00:00')),
#  ('1231', Timestamp('2014-08-14 00:00:00')),
#  ('1231', Timestamp('2014-11-14 00:00:00')),
#  ('1231', Timestamp('2015-03-31 00:00:00')),
#  ('1231', Timestamp('2015-05-15 00:00:00')),
#  ('1231', Timestamp('2015-08-14 00:00:00')),
#  ('1231', Timestamp('2015-11-14 00:00:00')),
#  ('1231', Timestamp('2016-03-31 00:00:00')),
#  ('1231', Timestamp('2016-05-15 00:00:00')),
#  ('1231', Timestamp('2016-08-14 00:00:00')),
#  ('1231', Timestamp('2016-11-14 00:00:00')),
#  ('1231', Timestamp('2017-03-31 00:00:00')),
#  ('1231', Timestamp('2017-05-15 00:00:00')),
#  ('1231', Timestamp('2017-08-14 00:00:00')),
#  ('1231', Timestamp('2017-11-14 00:00:00')),
#  ('1231', Timestamp('2018-03-31 00:00:00')),
#  ('1231', Timestamp('2018-05-15 00:00:00')),
#  ('1231', Timestamp('2018-08-14 00:00:00')),
#  ('1231', Timestamp('2018-11-14 00:00:00')),
#  ('1231', Timestamp('2019-03-31 00:00:00')),
#  ('1231', Timestamp('2019-05-15 00:00:00')),
#  ('1231', Timestamp('2019-08-14 00:00:00')),
#  ('1231', Timestamp('2019-11-14 00:00:00')),
#  ('1231', Timestamp('2020-03-31 00:00:00')),
#  ('1231', Timestamp('2020-05-15 00:00:00')),
#  ('1231', Timestamp('2020-08-14 00:00:00')),
#  ('1231', Timestamp('2020-11-14 00:00:00')),
#  ('1231', Timestamp('2021-03-31 00:00:00')),
#  ('1231', Timestamp('2021-05-15 00:00:00')),
#  ('1231', Timestamp('2021-08-14 00:00:00')),
#  ('1231', Timestamp('2021-11-14 00:00:00')),
#  ('1231', Timestamp('2022-03-31 00:00:00')),
#  ('1231', Timestamp('2022-05-15 00:00:00')),
#  ('1232', Timestamp('2013-05-15 00:00:00')),
#  ('1232', Timestamp('2013-08-14 00:00:00')),
#  ('1232', Timestamp('2013-11-14 00:00:00')),
#  ('1232', Timestamp('2014-03-31 00:00:00')),
#  ('1232', Timestamp('2014-05-15 00:00:00')),
#  ('1232', Timestamp('2014-08-14 00:00:00')),
#  ('1232', Timestamp('2014-11-14 00:00:00')),
#  ('1232', Timestamp('2015-03-31 00:00:00')),
#  ('1232', Timestamp('2015-05-15 00:00:00')),
#  ('1232', Timestamp('2015-08-14 00:00:00')),
#  ('1232', Timestamp('2015-11-14 00:00:00')),
#  ('1232', Timestamp('2016-03-31 00:00:00')),
#  ('1232', Timestamp('2016-05-15 00:00:00')),
#  ('1232', Timestamp('2016-08-14 00:00:00')),
#  ('1232', Timestamp('2016-11-14 00:00:00')),
#  ('1232', Timestamp('2017-03-31 00:00:00')),
#  ('1232', Timestamp('2017-05-15 00:00:00')),
#  ('1232', Timestamp('2017-08-14 00:00:00')),
#  ('1232', Timestamp('2017-11-14 00:00:00')),
#  ('1232', Timestamp('2018-03-31 00:00:00')),
#  ('1232', Timestamp('2018-05-15 00:00:00')),
#  ('1232', Timestamp('2018-08-14 00:00:00')),
#  ('1232', Timestamp('2018-11-14 00:00:00')),
#  ('1232', Timestamp('2019-03-31 00:00:00')),
#  ('1232', Timestamp('2019-05-15 00:00:00')),
#  ('1232', Timestamp('2019-08-14 00:00:00')),
#  ('1232', Timestamp('2019-11-14 00:00:00')),
#  ('1232', Timestamp('2020-03-31 00:00:00')),
#  ('1232', Timestamp('2020-05-15 00:00:00')),
#  ('1232', Timestamp('2020-08-14 00:00:00')),
#  ('1232', Timestamp('2020-11-14 00:00:00')),
#  ('1232', Timestamp('2021-03-31 00:00:00')),
#  ('1232', Timestamp('2021-05-15 00:00:00')),
#  ('1232', Timestamp('2021-08-14 00:00:00')),
#  ('1232', Timestamp('2021-11-14 00:00:00')),
#  ('1232', Timestamp('2022-03-31 00:00:00')),
#  ('1232', Timestamp('2022-05-15 00:00:00')),
#  ('1233', Timestamp('2013-05-15 00:00:00')),
#  ('1233', Timestamp('2013-08-14 00:00:00')),
#  ('1233', Timestamp('2013-11-14 00:00:00')),
#  ('1233', Timestamp('2014-03-31 00:00:00')),
#  ('1233', Timestamp('2014-05-15 00:00:00')),
#  ('1233', Timestamp('2014-08-14 00:00:00')),
#  ('1233', Timestamp('2014-11-14 00:00:00')),
#  ('1233', Timestamp('2015-03-31 00:00:00')),
#  ('1233', Timestamp('2015-05-15 00:00:00')),
#  ('1233', Timestamp('2015-08-14 00:00:00')),
#  ('1233', Timestamp('2015-11-14 00:00:00')),
#  ('1233', Timestamp('2016-03-31 00:00:00')),
#  ('1233', Timestamp('2016-05-15 00:00:00')),
#  ('1233', Timestamp('2016-08-14 00:00:00')),
#  ('1233', Timestamp('2016-11-14 00:00:00')),
#  ('1233', Timestamp('2017-03-31 00:00:00')),
#  ('1233', Timestamp('2017-05-15 00:00:00')),
#  ('1233', Timestamp('2017-08-14 00:00:00')),
#  ('1233', Timestamp('2017-11-14 00:00:00')),
#  ('1233', Timestamp('2018-03-31 00:00:00')),
#  ('1233', Timestamp('2018-05-15 00:00:00')),
#  ('1233', Timestamp('2018-08-14 00:00:00')),
#  ('1233', Timestamp('2018-11-14 00:00:00')),
#  ('1233', Timestamp('2019-03-31 00:00:00')),
#  ('1233', Timestamp('2019-05-15 00:00:00')),
#  ('1233', Timestamp('2019-08-14 00:00:00')),
#  ('1233', Timestamp('2019-11-14 00:00:00')),
#  ('1233', Timestamp('2020-03-31 00:00:00')),
#  ('1233', Timestamp('2020-05-15 00:00:00')),
#  ('1233', Timestamp('2020-08-14 00:00:00')),
#  ('1233', Timestamp('2020-11-14 00:00:00')),
#  ('1233', Timestamp('2021-03-31 00:00:00')),
#  ('1233', Timestamp('2021-05-15 00:00:00')),
#  ('1233', Timestamp('2021-08-14 00:00:00')),
#  ('1233', Timestamp('2021-11-14 00:00:00')),
#  ('1233', Timestamp('2022-03-31 00:00:00')),
#  ('1233', Timestamp('2022-05-15 00:00:00')),
#  ('1234', Timestamp('2013-05-15 00:00:00')),
#  ('1234', Timestamp('2013-08-14 00:00:00')),
#  ('1234', Timestamp('2013-11-14 00:00:00')),
#  ('1234', Timestamp('2014-03-31 00:00:00')),
#  ('1234', Timestamp('2014-05-15 00:00:00')),
#  ('1234', Timestamp('2014-08-14 00:00:00')),
#  ('1234', Timestamp('2014-11-14 00:00:00')),
#  ('1234', Timestamp('2015-03-31 00:00:00')),
#  ('1234', Timestamp('2015-05-15 00:00:00')),
#  ('1234', Timestamp('2015-08-14 00:00:00')),
#  ('1234', Timestamp('2015-11-14 00:00:00')),
#  ('1234', Timestamp('2016-03-31 00:00:00')),
#  ('1234', Timestamp('2016-05-15 00:00:00')),
#  ('1234', Timestamp('2016-08-14 00:00:00')),
#  ('1234', Timestamp('2016-11-14 00:00:00')),
#  ('1234', Timestamp('2017-03-31 00:00:00')),
#  ('1234', Timestamp('2017-05-15 00:00:00')),
#  ('1234', Timestamp('2017-08-14 00:00:00')),
#  ('1234', Timestamp('2017-11-14 00:00:00')),
#  ('1234', Timestamp('2018-03-31 00:00:00')),
#  ('1234', Timestamp('2018-05-15 00:00:00')),
#  ('1234', Timestamp('2018-08-14 00:00:00')),
#  ('1234', Timestamp('2018-11-14 00:00:00')),
#  ('1234', Timestamp('2019-03-31 00:00:00')),
#  ('1234', Timestamp('2019-05-15 00:00:00')),
#  ('1234', Timestamp('2019-08-14 00:00:00')),
#  ('1234', Timestamp('2019-11-14 00:00:00')),
#  ('1234', Timestamp('2020-03-31 00:00:00')),
#  ('1234', Timestamp('2020-05-15 00:00:00')),
#  ('1234', Timestamp('2020-08-14 00:00:00')),
#  ('1234', Timestamp('2020-11-14 00:00:00')),
#  ('1234', Timestamp('2021-03-31 00:00:00')),
#  ('1234', Timestamp('2021-05-15 00:00:00')),
#  ('1234', Timestamp('2021-08-14 00:00:00')),
#  ('1234', Timestamp('2021-11-14 00:00:00')),
#  ('1234', Timestamp('2022-03-31 00:00:00')),
#  ('1234', Timestamp('2022-05-15 00:00:00')),
#  ('1235', Timestamp('2013-05-15 00:00:00')),
#  ('1235', Timestamp('2013-08-14 00:00:00')),
#  ('1235', Timestamp('2013-11-14 00:00:00')),
#  ('1235', Timestamp('2014-03-31 00:00:00')),
#  ('1235', Timestamp('2014-05-15 00:00:00')),
#  ('1235', Timestamp('2014-08-14 00:00:00')),
#  ('1235', Timestamp('2014-11-14 00:00:00')),
#  ('1235', Timestamp('2015-03-31 00:00:00')),
#  ('1235', Timestamp('2015-05-15 00:00:00')),
#  ('1235', Timestamp('2015-08-14 00:00:00')),
#  ('1235', Timestamp('2015-11-14 00:00:00')),
#  ('1235', Timestamp('2016-03-31 00:00:00')),
#  ('1235', Timestamp('2016-05-15 00:00:00')),
#  ('1235', Timestamp('2016-08-14 00:00:00')),
#  ('1235', Timestamp('2016-11-14 00:00:00')),
#  ('1235', Timestamp('2017-03-31 00:00:00')),
#  ('1235', Timestamp('2017-05-15 00:00:00')),
#  ('1235', Timestamp('2017-08-14 00:00:00')),
#  ('1235', Timestamp('2017-11-14 00:00:00')),
#  ('1235', Timestamp('2018-03-31 00:00:00')),
#  ('1235', Timestamp('2018-05-15 00:00:00')),
#  ('1235', Timestamp('2018-08-14 00:00:00')),
#  ('1235', Timestamp('2018-11-14 00:00:00')),
#  ('1235', Timestamp('2019-03-31 00:00:00')),
#  ('1235', Timestamp('2019-05-15 00:00:00')),
#  ('1235', Timestamp('2019-08-14 00:00:00')),
#  ('1235', Timestamp('2019-11-14 00:00:00')),
#  ('1235', Timestamp('2020-03-31 00:00:00')),
#  ('1235', Timestamp('2020-05-15 00:00:00')),
#  ('1235', Timestamp('2020-08-14 00:00:00')),
#  ('1235', Timestamp('2020-11-14 00:00:00')),
#  ('1235', Timestamp('2021-03-31 00:00:00')),
#  ('1235', Timestamp('2021-05-15 00:00:00')),
#  ('1235', Timestamp('2021-08-14 00:00:00')),
#  ('1235', Timestamp('2021-11-14 00:00:00')),
#  ('1235', Timestamp('2022-03-31 00:00:00')),
#  ('1235', Timestamp('2022-05-15 00:00:00')),
#  ('1236', Timestamp('2013-05-15 00:00:00')),
#  ('1236', Timestamp('2013-08-14 00:00:00')),
#  ('1236', Timestamp('2013-11-14 00:00:00')),
#  ('1236', Timestamp('2014-03-31 00:00:00')),
#  ('1236', Timestamp('2014-05-15 00:00:00')),
#  ('1236', Timestamp('2014-08-14 00:00:00')),
#  ('1236', Timestamp('2014-11-14 00:00:00')),
#  ('1236', Timestamp('2015-03-31 00:00:00')),
#  ('1236', Timestamp('2015-05-15 00:00:00')),
#  ('1236', Timestamp('2015-08-14 00:00:00')),
#  ('1236', Timestamp('2015-11-14 00:00:00')),
#  ('1236', Timestamp('2016-03-31 00:00:00')),
#  ('1236', Timestamp('2016-05-15 00:00:00')),
#  ('1236', Timestamp('2016-08-14 00:00:00')),
#  ('1236', Timestamp('2016-11-14 00:00:00')),
#  ('1236', Timestamp('2017-03-31 00:00:00')),
#  ('1236', Timestamp('2017-05-15 00:00:00')),
#  ('1236', Timestamp('2017-08-14 00:00:00')),
#  ('1236', Timestamp('2017-11-14 00:00:00')),
#  ('1236', Timestamp('2018-03-31 00:00:00')),
#  ('1236', Timestamp('2018-05-15 00:00:00')),
#  ('1236', Timestamp('2018-08-14 00:00:00')),
#  ('1236', Timestamp('2018-11-14 00:00:00')),
#  ('1236', Timestamp('2019-03-31 00:00:00')),
#  ('1236', Timestamp('2019-05-15 00:00:00')),
#  ('1236', Timestamp('2019-08-14 00:00:00')),
#  ('1236', Timestamp('2019-11-14 00:00:00')),
#  ('1236', Timestamp('2020-03-31 00:00:00')),
#  ('1236', Timestamp('2020-05-15 00:00:00')),
#  ('1236', Timestamp('2020-08-14 00:00:00')),
#  ('1236', Timestamp('2020-11-14 00:00:00')),
#  ('1236', Timestamp('2021-03-31 00:00:00')),
#  ('1236', Timestamp('2021-05-15 00:00:00')),
#  ('1236', Timestamp('2021-08-14 00:00:00')),
#  ('1236', Timestamp('2021-11-14 00:00:00')),
#  ('1236', Timestamp('2022-03-31 00:00:00')),
#  ('1236', Timestamp('2022-05-15 00:00:00')),
#  ('1240', Timestamp('2013-05-15 00:00:00')),
#  ('1240', Timestamp('2013-08-14 00:00:00')),
#  ('1240', Timestamp('2013-11-14 00:00:00')),
#  ('1240', Timestamp('2014-03-31 00:00:00')),
#  ('1240', Timestamp('2014-05-15 00:00:00')),
#  ('1240', Timestamp('2014-08-14 00:00:00')),
#  ('1240', Timestamp('2014-11-14 00:00:00')),
#  ('1240', Timestamp('2015-03-31 00:00:00')),
#  ('1240', Timestamp('2015-05-15 00:00:00')),
#  ('1240', Timestamp('2015-08-14 00:00:00')),
#  ('1240', Timestamp('2015-11-14 00:00:00')),
#  ('1240', Timestamp('2016-03-31 00:00:00')),
#  ('1240', Timestamp('2016-05-15 00:00:00')),
#  ('1240', Timestamp('2016-08-14 00:00:00')),
#  ('1240', Timestamp('2016-11-14 00:00:00')),
#  ('1240', Timestamp('2017-03-31 00:00:00')),
#  ('1240', Timestamp('2017-05-15 00:00:00')),
#  ('1240', Timestamp('2017-08-14 00:00:00')),
#  ('1240', Timestamp('2017-11-14 00:00:00')),
#  ('1240', Timestamp('2018-03-31 00:00:00')),
#  ('1240', Timestamp('2018-05-15 00:00:00')),
#  ('1240', Timestamp('2018-08-14 00:00:00')),
#  ('1240', Timestamp('2018-11-14 00:00:00')),
#  ('1240', Timestamp('2019-03-31 00:00:00')),
#  ('1240', Timestamp('2019-05-15 00:00:00')),
#  ('1240', Timestamp('2019-08-14 00:00:00')),
#  ('1240', Timestamp('2019-11-14 00:00:00')),
#  ('1240', Timestamp('2020-03-31 00:00:00')),
#  ('1240', Timestamp('2020-05-15 00:00:00')),
#  ('1240', Timestamp('2020-08-14 00:00:00')),
#  ('1240', Timestamp('2020-11-14 00:00:00')),
#  ('1240', Timestamp('2021-03-31 00:00:00')),
#  ('1240', Timestamp('2021-05-15 00:00:00')),
#  ('1240', Timestamp('2021-08-14 00:00:00')),
#  ('1240', Timestamp('2021-11-14 00:00:00')),
#  ('1240', Timestamp('2022-03-31 00:00:00')),
#  ('1240', Timestamp('2022-05-15 00:00:00')),
#  ('1256', Timestamp('2013-05-15 00:00:00')),
#  ...]

# %%
dataset_fundamental.reindex(dataset.index).dropna()
# Out:
#                      T3395營業利益  T7210營運現金流  T3950歸屬母公司淨利    T7211折舊  \
# stock_id date
# 1101     2014-05-15  3684224.0   6895832.0     4015175.0  1594505.0
#          2015-05-15  1693508.0   5654152.0      349121.0  1711428.0
#          2016-05-15   483889.0   5608258.0     -333525.0  1723452.0
#          2017-05-15  1941630.0   1408140.0      993546.0  1530197.0
#          2018-05-15  4650691.0   2233014.0     8436811.0  1532636.0
# ...                        ...         ...           ...        ...
# 9955     2018-05-15   -44412.0     -2404.0      -43333.0    16052.0
#          2019-05-15     4525.0     66950.0        8798.0    15017.0
#          2020-05-15   -55371.0    -14402.0      -50396.0    13018.0
#          2021-05-15   -14190.0    -36705.0      -23126.0    13085.0
#          2022-05-15   -18487.0     98428.0      -10926.0    14456.0
#
#                       T0100流動資產   T1100流動負債  T7324取得不動產廠房及設備  T3970經常稅後淨利  \
# stock_id date
# 1101     2014-05-15  92121458.0  74388787.0        -940633.0    2791235.0
#          2015-05-15  92471096.0  69579858.0        -818460.0     974518.0
#          2016-05-15  78482102.0  64818835.0       -1499102.0      94527.0
#          2017-05-15  76640360.0  55787736.0        -134877.0    1163708.0
#          2018-05-15  75261374.0  53357480.0       -1115614.0    2865370.0
# ...                         ...         ...              ...          ...
# 9955     2018-05-15   1236034.0    796588.0           -560.0     -45317.0
#          2019-05-15    984072.0    760451.0          -3069.0       5271.0
#          2020-05-15    982420.0    841152.0          -5896.0     -48927.0
#          2021-05-15    905765.0    937218.0         -28012.0     -22146.0
#          2022-05-15    832282.0    829339.0         -16375.0     -15584.0
#
#                      R101_ROA稅後息前  R11V_ROA綜合損益  ...  R409_淨值成長率   R501_流動比率  \
# stock_id date                                    ...
# 1101     2014-05-15     -1.732411      1.630076  ...    8.866880  123.837828
#          2015-05-15     -2.315297      0.069454  ...    2.505042  132.899231
#          2016-05-15     -2.791650     -0.256684  ...   -4.604373  121.079162
#          2017-05-15     -2.558880      0.057603  ...   -4.653916  137.378509
#          2018-05-15      1.186485      3.015032  ...   12.344125  141.051215
# ...                           ...           ...  ...         ...         ...
# 9955     2018-05-15     -1.221556     -1.261243  ...   -4.798625  155.166033
#          2019-05-15      0.278277      0.284446  ...  -11.507622  129.406365
#          2020-05-15     -1.545101     -1.698205  ...   -3.179062  116.794586
#          2021-05-15     -0.672387     -0.794341  ...   -5.731071   96.644004
#          2022-05-15     -0.425360     -0.378016  ...   -5.407716  100.354861
#
#                       R502_速動比率  R503_利息支出率   R678_營運資金  R607_總資產週轉次數  \
# stock_id date
# 1101     2014-05-15  101.776758   -9.792979  17732671.0      0.093998
#          2015-05-15  109.303861   -7.153186  22891238.0      0.073611
#          2016-05-15   97.448632   -6.324010  13663267.0      0.061984
#          2017-05-15  113.578196   -7.329636  20852624.0      0.080450
#          2018-05-15  112.579035   16.342285  21903894.0      0.087031
# ...                         ...         ...         ...           ...
# 9955     2018-05-15   32.058354   -9.963928    439446.0      0.121118
#          2019-05-15   41.352960   48.441821    223621.0      0.142300
#          2020-05-15   44.527386   -8.378877    141268.0      0.130004
#          2021-05-15   27.735383  -16.401733    -31453.0      0.157824
#          2022-05-15   37.994475  -33.446122      2943.0      0.132195
#
#                      R610_存貨週轉率  R612_固定資產週轉次數  R613_淨值週轉率次  R69B_自由現金流量
# stock_id date
# 1101     2014-05-15    2.191306       0.245688     0.171327    4901868.0
#          2015-05-15    1.817298       0.195713     0.132250    8494249.0
#          2016-05-15    1.852197       0.158077     0.114263   12056561.0
#          2017-05-15    2.077924       0.212820     0.143618    4658280.0
#          2018-05-15    2.093896       0.254581     0.151875   11036357.0
# ...                         ...            ...          ...          ...
# 9955     2018-05-15    0.448572       0.196830     0.212243      18133.0
#          2019-05-15    0.596449       0.220210     0.257133      17694.0
#          2020-05-15    0.719951       0.200750     0.228754      32074.0
#          2021-05-15    0.706660       0.240481     0.291256      72112.0
#          2022-05-15    0.776541       0.197040     0.256967        498.0
#
# [9232 rows x 48 columns]

# %% [markdown]
# data[組合](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7)
# ```python
# new_df = pd.concat([dataset_fundamental['R406_經常利益成長率'],dataset],axis=1).dropna(how='any')
# ```

# %%
new_df = pd.concat([dataset_fundamental,dataset],axis=1).dropna(how='any')
dataset1 = new_df.fillna(method='ffill')#[(new_df.index.get_level_values('stock_id')=='2330')]
#dataset = dataset1

# %%
#feature_names=list(dataset1.columns)
#feature_names

# %% [markdown]
# ### 新增 label(績效/排名)
#  - 定義一下要比績效還是要比排名

# %%
from finlab import ml

ml.add_profit_prediction(dataset)
ml.add_rank_prediction(dataset)

# %%
#profit(return) rank
predi_target = 'rank'

# %% [markdown]
# ### 刪除太大太小的歷史資料

# %%
print(dataset.shape)

def drop_extreme_case(dataset, feature_names, thresh=0.01):
    
    extreme_cases = pd.Series(False, index=dataset.index)
    for f in feature_names:
        tf = dataset[f]
        extreme_cases = extreme_cases | (tf < tf.quantile(thresh)) | (tf > tf.quantile(1-thresh))
    dataset = dataset[~extreme_cases]
    return dataset

dataset_drop_extreme_case = drop_extreme_case(dataset , feature_names , thresh=0.01)

print(dataset_drop_extreme_case.shape)

##(436774, 25)
##(388157, 25)
# Out:
# (439890, 34)
# (380532, 34)

# %%
dataset_dropna = dataset_drop_extreme_case.dropna(how='any')
dataset_dropna = dataset_dropna.reset_index().set_index("date")

# %%
#dataset_drop_extreme_case.index.get_level_values("date")

# %%
##################################################################################################################
##############################################　　　自己加入的　　　##############################################
##################################################################################################################

dataset_dropna.index = pd.to_datetime(dataset_dropna.index)
dataset_dropna = dataset_dropna.sort_index()

#修復＜class ‘numpy.ndarray‘＞　https://blog.csdn.net/lxbin/article/details/114005757

# %% [markdown]
# ## Split Train Test dataset

# %%
dataset_train = dataset_dropna.loc[:'2015']
dataset_test = dataset_dropna.loc['2016':]

#date_arr = dataset.index.get_level_values('date') < '2020'
#dataset_train = dataset[date_arr]
#dataset_test = dataset[~date_arr]

# %%
train = dataset_train[feature_names] , dataset_train['return'] > 1
test = dataset_test[feature_names] , dataset_test['return'] > 1

# %% [markdown]
# ### 機器學習
#  - 目前只有三個，技術指標也要再增加一下feature_names

# %%
#feature_names = feature_names1

# %%
dataset_train.index
# Out:
# DatetimeIndex(['2010-01-15', '2010-01-15', '2010-01-15', '2010-01-15',
#                '2010-01-15', '2010-01-15', '2010-01-15', '2010-01-15',
#                '2010-01-15', '2010-01-15',
#                ...
#                '2015-12-15', '2015-12-15', '2015-12-15', '2015-12-15',
#                '2015-12-15', '2015-12-15', '2015-12-15', '2015-12-15',
#                '2015-12-15', '2015-12-15'],
#               dtype='datetime64[ns]', name='date', length=56502, freq=None)

# %% [markdown]
# #### kerascolumns

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers

import os


os.environ['KMP_DUPLICATE_LIB_OK']='True'

model = keras.models.Sequential()
model.add(layers.Dense(100, activation='relu',
                      input_shape=(len(feature_names),),
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dense(100, activation='relu',
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dropout(0.7))
model.add(layers.Dense(1, activation='sigmoid'))


model.summary()

model.compile(loss='mean_squared_error',
              optimizer="adam",)

print('start fitting')
history = model.fit(dataset_train[feature_names], dataset_train[predi_target],
                    batch_size=1000,         #1000  #每一个batch的大小
                    epochs=225, #225          #迭代次数
                    verbose=1,
                    validation_split=0.1,
                    #validation_data =        #(测试集的输入特征，测试集的标签），
                    #validation_split =       # 从测试集中划分多少比例给训练集，
                    #validation_freq = 20        #测试的epoch间隔数                     
                   )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               3200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 13,401
# Trainable params: 13,401
# Non-trainable params: 0
# _________________________________________________________________
# start fitting
# Epoch 1/225
# 51/51 [==============================] - ETA: 0s - loss: 0.262 - ETA: 0s - loss: 0.258 - ETA: 0s - loss: 0.250 - ETA: 0s - loss: 0.236 - ETA: 0s - loss: 0.215 - 0s 8ms/step - loss: 0.2121 - val_loss: 0.0905
# Epoch 2/225
# 51/51 [==============================] - ETA: 0s - loss: 0.110 - ETA: 0s - loss: 0.087 - ETA: 0s - loss: 0.081 - ETA: 0s - loss: 0.079 - ETA: 0s - loss: 0.078 - 0s 5ms/step - loss: 0.0782 - val_loss: 0.0733
# Epoch 3/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0737 - val_loss: 0.0733
# Epoch 4/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0736 - val_loss: 0.0732
# Epoch 5/225
# 51/51 [==============================] - ETA: 0s - loss: 0.077 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0736 - val_loss: 0.0732
# Epoch 6/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0736 - val_loss: 0.0733
# Epoch 7/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 7ms/step - loss: 0.0735 - val_loss: 0.0732
# Epoch 8/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0735 - val_loss: 0.0733
# Epoch 9/225
# 51/51 [==============================] - ETA: 0s - loss: 0.078 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0735 - val_loss: 0.0733
# Epoch 10/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0735 - val_loss: 0.0732
# Epoch 11/225
# 51/51 [==============================] - ETA: 0s - loss: 0.079 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0734 - val_loss: 0.0733
# Epoch 12/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0735 - val_loss: 0.0733
# Epoch 13/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0734 - val_loss: 0.0733
# Epoch 14/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0734 - val_loss: 0.0733
# Epoch 15/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0734 - val_loss: 0.0734
# Epoch 16/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0733 - val_loss: 0.0733
# Epoch 17/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0733 - val_loss: 0.0733
# Epoch 18/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0733 - val_loss: 0.0733
# Epoch 19/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0733 - val_loss: 0.0734
# Epoch 20/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0734 - val_loss: 0.0734
# Epoch 21/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0735 - val_loss: 0.0733
# Epoch 22/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0734 - val_loss: 0.0734
# Epoch 23/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0734 - val_loss: 0.0734
# Epoch 24/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0733 - val_loss: 0.0734
# Epoch 25/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0733 - val_loss: 0.0734
# Epoch 26/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0733 - val_loss: 0.0733
# Epoch 27/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0734
# Epoch 28/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0733 - val_loss: 0.0735
# Epoch 29/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0734 - val_loss: 0.0734
# Epoch 30/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0734
# Epoch 31/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0732 - val_loss: 0.0735
# Epoch 32/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0733 - val_loss: 0.0735
# Epoch 33/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0735
# Epoch 34/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0736
# Epoch 35/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0735
# Epoch 36/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0733 - val_loss: 0.0734
# Epoch 37/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0731 - val_loss: 0.0735
# Epoch 38/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 9ms/step - loss: 0.0732 - val_loss: 0.0735
# Epoch 39/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0732 - val_loss: 0.0734
# Epoch 40/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0735
# Epoch 41/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 7ms/step - loss: 0.0732 - val_loss: 0.0734
# Epoch 42/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0731 - val_loss: 0.0735
# Epoch 43/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0732 - val_loss: 0.0734
# Epoch 44/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0731 - val_loss: 0.0735
# Epoch 45/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0731 - val_loss: 0.0735
# Epoch 46/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0730 - val_loss: 0.0736
# Epoch 47/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0731 - val_loss: 0.0735
# Epoch 48/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0731 - val_loss: 0.0734
# Epoch 49/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0730 - val_loss: 0.0735
# Epoch 50/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0731 - val_loss: 0.0735
# Epoch 51/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0731 - val_loss: 0.0734
# Epoch 52/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0731 - val_loss: 0.0735
# Epoch 53/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0734
# Epoch 54/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 7ms/step - loss: 0.0731 - val_loss: 0.0735
# Epoch 55/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 7ms/step - loss: 0.0730 - val_loss: 0.0736
# Epoch 56/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0734
# Epoch 57/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0730 - val_loss: 0.0735
# Epoch 58/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0735
# Epoch 59/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0735
# Epoch 60/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0730 - val_loss: 0.0736
# Epoch 61/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0734
# Epoch 62/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0730 - val_loss: 0.0736
# Epoch 63/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0731 - val_loss: 0.0734
# Epoch 64/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0736
# Epoch 65/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0734
# Epoch 66/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0735
# Epoch 67/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0736
# Epoch 68/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0730 - val_loss: 0.0734
# Epoch 69/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 70/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0729 - val_loss: 0.0736
# Epoch 71/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 72/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0735
# Epoch 73/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 74/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0728 - val_loss: 0.0737
# Epoch 75/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 6ms/step - loss: 0.0729 - val_loss: 0.0734
# Epoch 76/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0728 - val_loss: 0.0735
# Epoch 77/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 78/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 79/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0730 - val_loss: 0.0735
# Epoch 80/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 81/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 82/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0728 - val_loss: 0.0735
# Epoch 83/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0728 - val_loss: 0.0736
# Epoch 84/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 85/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0736
# Epoch 86/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0728 - val_loss: 0.0734
# Epoch 87/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 88/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 89/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0728 - val_loss: 0.0736
# Epoch 90/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0728 - val_loss: 0.0735
# Epoch 91/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0728 - val_loss: 0.0736
# Epoch 92/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0728 - val_loss: 0.0736
# Epoch 93/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0728 - val_loss: 0.0737
# Epoch 94/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0728 - val_loss: 0.0735
# Epoch 95/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0727 - val_loss: 0.0736
# Epoch 96/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0727 - val_loss: 0.0735
# Epoch 97/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0727 - val_loss: 0.0736
# Epoch 98/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0727 - val_loss: 0.0735
# Epoch 99/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0727 - val_loss: 0.0735
# Epoch 100/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0727 - val_loss: 0.0736
# Epoch 101/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0727 - val_loss: 0.0737
# Epoch 102/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0727 - val_loss: 0.0736
# Epoch 103/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0727 - val_loss: 0.0735
# Epoch 104/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0727 - val_loss: 0.0736
# Epoch 105/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0737
# Epoch 106/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0726 - val_loss: 0.0735
# Epoch 107/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0726 - val_loss: 0.0735
# Epoch 108/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0726 - val_loss: 0.0737
# Epoch 109/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0726 - val_loss: 0.0736
# Epoch 110/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0726 - val_loss: 0.0738
# Epoch 111/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0726 - val_loss: 0.0736
# Epoch 112/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 8ms/step - loss: 0.0726 - val_loss: 0.0736
# Epoch 113/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0726 - val_loss: 0.0736
# Epoch 114/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0737
# Epoch 115/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0726 - val_loss: 0.0737
# Epoch 116/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0725 - val_loss: 0.0738
# Epoch 117/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0726 - val_loss: 0.0736
# Epoch 118/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0737
# Epoch 119/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0739
# Epoch 120/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0736
# Epoch 121/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0735
# Epoch 122/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0725 - val_loss: 0.0736
# Epoch 123/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0725 - val_loss: 0.0735
# Epoch 124/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0725 - val_loss: 0.0736
# Epoch 125/225
# 51/51 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0736
# Epoch 126/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0724 - val_loss: 0.0736
# Epoch 127/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0736
# Epoch 128/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0724 - val_loss: 0.0738
# Epoch 129/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0737
# Epoch 130/225
# 51/51 [==============================] - ETA: 0s - loss: 0.078 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0724 - val_loss: 0.0736
# Epoch 131/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0736
# Epoch 132/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0724 - val_loss: 0.0738
# Epoch 133/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0724 - val_loss: 0.0737
# Epoch 134/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0738
# Epoch 135/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0723 - val_loss: 0.0737
# Epoch 136/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0724 - val_loss: 0.0737
# Epoch 137/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0724 - val_loss: 0.0736
# Epoch 138/225
# 51/51 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0723 - val_loss: 0.0738
# Epoch 139/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0724 - val_loss: 0.0738
# Epoch 140/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0724 - val_loss: 0.0736
# Epoch 141/225
# 51/51 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0723 - val_loss: 0.0736
# Epoch 142/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0723 - val_loss: 0.0737
# Epoch 143/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0723 - val_loss: 0.0737
# Epoch 144/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0724 - val_loss: 0.0740
# Epoch 145/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0723 - val_loss: 0.0736
# Epoch 146/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0723 - val_loss: 0.0737
# Epoch 147/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0724 - val_loss: 0.0738
# Epoch 148/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0723 - val_loss: 0.0737
# Epoch 149/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0723 - val_loss: 0.0739
# Epoch 150/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0723 - val_loss: 0.0737
# Epoch 151/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0722 - val_loss: 0.0739
# Epoch 152/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0723 - val_loss: 0.0737
# Epoch 153/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0722 - val_loss: 0.0736
# Epoch 154/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0723 - val_loss: 0.0741
# Epoch 155/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0723 - val_loss: 0.0738
# Epoch 156/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 8ms/step - loss: 0.0723 - val_loss: 0.0738
# Epoch 157/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0722 - val_loss: 0.0737
# Epoch 158/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0722 - val_loss: 0.0736
# Epoch 159/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0722 - val_loss: 0.0737
# Epoch 160/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0721 - val_loss: 0.0738
# Epoch 161/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0721 - val_loss: 0.0736
# Epoch 162/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0723 - val_loss: 0.0738
# Epoch 163/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0721 - val_loss: 0.0738
# Epoch 164/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0721 - val_loss: 0.0736
# Epoch 165/225
# 51/51 [==============================] - ETA: 0s - loss: 0.067 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0722 - val_loss: 0.0736
# Epoch 166/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0722 - val_loss: 0.0737
# Epoch 167/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0722 - val_loss: 0.0736
# Epoch 168/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0721 - val_loss: 0.0737
# Epoch 169/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0739
# Epoch 170/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0721 - val_loss: 0.0737
# Epoch 171/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0722 - val_loss: 0.0738
# Epoch 172/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0721 - val_loss: 0.0738
# Epoch 173/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0739
# Epoch 174/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0722 - val_loss: 0.0737
# Epoch 175/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0720 - val_loss: 0.0738
# Epoch 176/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0721 - val_loss: 0.0737
# Epoch 177/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0721 - val_loss: 0.0741
# Epoch 178/225
# 51/51 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 7ms/step - loss: 0.0721 - val_loss: 0.0736
# Epoch 179/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0721 - val_loss: 0.0737
# Epoch 180/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0721 - val_loss: 0.0738
# Epoch 181/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0721 - val_loss: 0.0735
# Epoch 182/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0736
# Epoch 183/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0720 - val_loss: 0.0740
# Epoch 184/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0721 - val_loss: 0.0738
# Epoch 185/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0719 - val_loss: 0.0739
# Epoch 186/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0739
# Epoch 187/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0720 - val_loss: 0.0737
# Epoch 188/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0737
# Epoch 189/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0720 - val_loss: 0.0740
# Epoch 190/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0720 - val_loss: 0.0738
# Epoch 191/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0719 - val_loss: 0.0739
# Epoch 192/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0738
# Epoch 193/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0721 - val_loss: 0.0740
# Epoch 194/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0738
# Epoch 195/225
# 51/51 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0738
# Epoch 196/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0742
# Epoch 197/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0739
# Epoch 198/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0737
# Epoch 199/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0739
# Epoch 200/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0720 - val_loss: 0.0737
# Epoch 201/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0719 - val_loss: 0.0737
# Epoch 202/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0718 - val_loss: 0.0739
# Epoch 203/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - 0s 7ms/step - loss: 0.0719 - val_loss: 0.0739
# Epoch 204/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0719 - val_loss: 0.0738
# Epoch 205/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0718 - val_loss: 0.0738
# Epoch 206/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0718 - val_loss: 0.0738
# Epoch 207/225
# 51/51 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0719 - val_loss: 0.0737
# Epoch 208/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0738
# Epoch 209/225
# 51/51 [==============================] - ETA: 0s - loss: 0.066 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0738
# Epoch 210/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0717 - val_loss: 0.0738
# Epoch 211/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0740
# Epoch 212/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 6ms/step - loss: 0.0719 - val_loss: 0.0740
# Epoch 213/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0720 - val_loss: 0.0736
# Epoch 214/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0738
# Epoch 215/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0736
# Epoch 216/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0740
# Epoch 217/225
# 51/51 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0717 - val_loss: 0.0737
# Epoch 218/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0717 - val_loss: 0.0739
# Epoch 219/225
# 51/51 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0736
# Epoch 220/225
# 51/51 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0718 - val_loss: 0.0741
# Epoch 221/225
# 51/51 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0738
# Epoch 222/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0718 - val_loss: 0.0737
# Epoch 223/225
# 51/51 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0737
# Epoch 224/225
# 51/51 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0738
# Epoch 225/225
# 51/51 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 6ms/step - loss: 0.0717 - val_loss: 0.0740

# %% [markdown]
# ##### 結果

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['val_loss'][1:])
plt.plot(history.history['loss'][1:])

# %% [markdown]
# #### lightgbm Model

# %%
##############################################　　　自己加入的　　　##############################################
import lightgbm as lgb

cf = lgb.LGBMRegressor(n_estimators=5000)

print('---cf.fit---')
print(cf.fit(*train))
print('---cf.score---')
print(cf.score(*test))
print('---predict---')
print(cf.predict(test[0]))
# Out:
# ---cf.fit---
# LGBMRegressor(n_estimators=5000)
# ---cf.score---
# -0.1163108836757496
# ---predict---
# [ 0.47301196  0.77938526  0.63202974 ...  0.39184303  0.36585392
#  -0.07095594]

# %% [markdown]
# ##### 參數優化_1110

# %%
#import lightgbm

fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [test],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

# %%
gs.fit(*train, **fit_params)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531739
# Early stopping, best iteration is:
# [112]	valid's auc: 0.532814
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535228
# Early stopping, best iteration is:
# [85]	valid's auc: 0.535877
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.533599
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531478
# Early stopping, best iteration is:
# [169]	valid's auc: 0.533325
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.535662
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532614
# Early stopping, best iteration is:
# [106]	valid's auc: 0.533083
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52938
# Early stopping, best iteration is:
# [147]	valid's auc: 0.531162
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536916
# [200]	valid's auc: 0.540652
# Early stopping, best iteration is:
# [170]	valid's auc: 0.541046
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533236
# Early stopping, best iteration is:
# [134]	valid's auc: 0.535544
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528731
# Early stopping, best iteration is:
# [102]	valid's auc: 0.52877
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534478
# Early stopping, best iteration is:
# [109]	valid's auc: 0.534867
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53216
# Early stopping, best iteration is:
# [108]	valid's auc: 0.532274
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52805
# Early stopping, best iteration is:
# [169]	valid's auc: 0.530692
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53584
# Early stopping, best iteration is:
# [121]	valid's auc: 0.536454
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529543
# Early stopping, best iteration is:
# [152]	valid's auc: 0.530958
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530823
# Early stopping, best iteration is:
# [167]	valid's auc: 0.533312
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534534
# Early stopping, best iteration is:
# [77]	valid's auc: 0.535981
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532545
# Early stopping, best iteration is:
# [80]	valid's auc: 0.533274
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531632
# Early stopping, best iteration is:
# [130]	valid's auc: 0.533177
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.534839
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533212
# Early stopping, best iteration is:
# [85]	valid's auc: 0.534192
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528296
# [200]	valid's auc: 0.529992
# Early stopping, best iteration is:
# [189]	valid's auc: 0.530748
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535084
# Early stopping, best iteration is:
# [151]	valid's auc: 0.536712
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531669
# Early stopping, best iteration is:
# [102]	valid's auc: 0.531735
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529964
# [200]	valid's auc: 0.532615
# Early stopping, best iteration is:
# [267]	valid's auc: 0.533373
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534138
# Early stopping, best iteration is:
# [163]	valid's auc: 0.535379
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530003
# Early stopping, best iteration is:
# [76]	valid's auc: 0.531194
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532429
# Early stopping, best iteration is:
# [158]	valid's auc: 0.534435
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.537873
# Early stopping, best iteration is:
# [117]	valid's auc: 0.538251
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.533552
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [68]	valid's auc: 0.53123
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535896
# Early stopping, best iteration is:
# [112]	valid's auc: 0.536139
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [51]	valid's auc: 0.530524
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531472
# Early stopping, best iteration is:
# [118]	valid's auc: 0.532132
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534296
# Early stopping, best iteration is:
# [159]	valid's auc: 0.536275
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533192
# Early stopping, best iteration is:
# [128]	valid's auc: 0.534172
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.526656
# Early stopping, best iteration is:
# [111]	valid's auc: 0.528393
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533873
# [200]	valid's auc: 0.53858
# Early stopping, best iteration is:
# [247]	valid's auc: 0.539989
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533075
# [200]	valid's auc: 0.535874
# Early stopping, best iteration is:
# [232]	valid's auc: 0.537056
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531512
# Early stopping, best iteration is:
# [111]	valid's auc: 0.532373
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.537045
# Early stopping, best iteration is:
# [115]	valid's auc: 0.537661
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532875
# Early stopping, best iteration is:
# [109]	valid's auc: 0.533716
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528281
# Early stopping, best iteration is:
# [142]	valid's auc: 0.531504
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534526
# Early stopping, best iteration is:
# [130]	valid's auc: 0.537449
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532321
# Early stopping, best iteration is:
# [139]	valid's auc: 0.534641
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53014
# [200]	valid's auc: 0.53253
# Early stopping, best iteration is:
# [191]	valid's auc: 0.532986
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [68]	valid's auc: 0.536691
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531618
# Early stopping, best iteration is:
# [126]	valid's auc: 0.532041
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528229
# [200]	valid's auc: 0.530664
# Early stopping, best iteration is:
# [199]	valid's auc: 0.530694
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53565
# Early stopping, best iteration is:
# [161]	valid's auc: 0.537339
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533873
# [200]	valid's auc: 0.534748
# Early stopping, best iteration is:
# [194]	valid's auc: 0.534755
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531282
# Early stopping, best iteration is:
# [98]	valid's auc: 0.531569
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536661
# Early stopping, best iteration is:
# [106]	valid's auc: 0.537257
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [54]	valid's auc: 0.529723
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52607
# Early stopping, best iteration is:
# [119]	valid's auc: 0.527365
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534146
# Early stopping, best iteration is:
# [125]	valid's auc: 0.535295
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530666
# Early stopping, best iteration is:
# [132]	valid's auc: 0.533148
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528853
# [200]	valid's auc: 0.531658
# Early stopping, best iteration is:
# [199]	valid's auc: 0.531763
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533703
# [200]	valid's auc: 0.53644
# Early stopping, best iteration is:
# [170]	valid's auc: 0.536673
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531263
# Early stopping, best iteration is:
# [111]	valid's auc: 0.531816
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528463
# Early stopping, best iteration is:
# [100]	valid's auc: 0.528463
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534428
# Early stopping, best iteration is:
# [100]	valid's auc: 0.534428
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532704
# Early stopping, best iteration is:
# [109]	valid's auc: 0.533247
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.527963
# Early stopping, best iteration is:
# [141]	valid's auc: 0.530643
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533965
# [200]	valid's auc: 0.53729
# Early stopping, best iteration is:
# [191]	valid's auc: 0.537812
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532403
# [200]	valid's auc: 0.534574
# Early stopping, best iteration is:
# [185]	valid's auc: 0.534839
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.531791
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.536766
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531751
# Early stopping, best iteration is:
# [81]	valid's auc: 0.532515
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531256
# Early stopping, best iteration is:
# [97]	valid's auc: 0.531418
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535476
# Early stopping, best iteration is:
# [111]	valid's auc: 0.53625
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [62]	valid's auc: 0.532816
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531238
# Early stopping, best iteration is:
# [127]	valid's auc: 0.532339
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535247
# Early stopping, best iteration is:
# [110]	valid's auc: 0.535585
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532084
# Early stopping, best iteration is:
# [87]	valid's auc: 0.532432
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.527588
# [200]	valid's auc: 0.529929
# Early stopping, best iteration is:
# [187]	valid's auc: 0.530469
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53397
# Early stopping, best iteration is:
# [167]	valid's auc: 0.537116
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534622
# Early stopping, best iteration is:
# [160]	valid's auc: 0.536226
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52831
# [200]	valid's auc: 0.52986
# Early stopping, best iteration is:
# [175]	valid's auc: 0.530188
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535064
# Early stopping, best iteration is:
# [92]	valid's auc: 0.535592
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533873
# Early stopping, best iteration is:
# [131]	valid's auc: 0.534692
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52959
# Early stopping, best iteration is:
# [93]	valid's auc: 0.52959
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534309
# Early stopping, best iteration is:
# [104]	valid's auc: 0.534851
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531537
# Early stopping, best iteration is:
# [103]	valid's auc: 0.531675
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533702
# Early stopping, best iteration is:
# [139]	valid's auc: 0.5346
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [53]	valid's auc: 0.535571
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [52]	valid's auc: 0.532212
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529379
# [200]	valid's auc: 0.531141
# Early stopping, best iteration is:
# [194]	valid's auc: 0.531983
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53804
# Early stopping, best iteration is:
# [108]	valid's auc: 0.538383
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [64]	valid's auc: 0.531247
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528746
# Early stopping, best iteration is:
# [151]	valid's auc: 0.530834
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5369
# [200]	valid's auc: 0.538954
# Early stopping, best iteration is:
# [204]	valid's auc: 0.53899
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533071
# Early stopping, best iteration is:
# [153]	valid's auc: 0.53462
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531834
# Early stopping, best iteration is:
# [114]	valid's auc: 0.532542
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.535116
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532749
# Early stopping, best iteration is:
# [72]	valid's auc: 0.53295
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530076
# Early stopping, best iteration is:
# [71]	valid's auc: 0.530822
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536367
# Early stopping, best iteration is:
# [124]	valid's auc: 0.537532
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531696
# Early stopping, best iteration is:
# [78]	valid's auc: 0.532286
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529568
# [200]	valid's auc: 0.531574
# Early stopping, best iteration is:
# [186]	valid's auc: 0.531944
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.538009
# [200]	valid's auc: 0.540539
# Early stopping, best iteration is:
# [172]	valid's auc: 0.541257
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534043
# [200]	valid's auc: 0.535141
# Early stopping, best iteration is:
# [247]	valid's auc: 0.536358
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532548
# Early stopping, best iteration is:
# [131]	valid's auc: 0.534587
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534532
# Early stopping, best iteration is:
# [106]	valid's auc: 0.535161
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533303
# Early stopping, best iteration is:
# [80]	valid's auc: 0.53412
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531592
# Early stopping, best iteration is:
# [89]	valid's auc: 0.532055
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [62]	valid's auc: 0.537581
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533644
# Early stopping, best iteration is:
# [78]	valid's auc: 0.534408
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528453
# Early stopping, best iteration is:
# [164]	valid's auc: 0.528453
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535832
# Early stopping, best iteration is:
# [110]	valid's auc: 0.536146
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53239
# Early stopping, best iteration is:
# [122]	valid's auc: 0.533435
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530943
# Early stopping, best iteration is:
# [98]	valid's auc: 0.531492
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536903
# Early stopping, best iteration is:
# [103]	valid's auc: 0.537305
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531768
# Early stopping, best iteration is:
# [137]	valid's auc: 0.533101
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52896
# [200]	valid's auc: 0.530992
# Early stopping, best iteration is:
# [231]	valid's auc: 0.532438
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535929
# Early stopping, best iteration is:
# [132]	valid's auc: 0.537345
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53108
# Early stopping, best iteration is:
# [89]	valid's auc: 0.531497
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.527434
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535759
# [200]	valid's auc: 0.540341
# Early stopping, best iteration is:
# [226]	valid's auc: 0.540646
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531838
# Early stopping, best iteration is:
# [116]	valid's auc: 0.533906
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.527648
# Early stopping, best iteration is:
# [111]	valid's auc: 0.528324
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536311
# [200]	valid's auc: 0.540746
# Early stopping, best iteration is:
# [213]	valid's auc: 0.540893
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531495
# Early stopping, best iteration is:
# [165]	valid's auc: 0.534362
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528186
# [200]	valid's auc: 0.530032
# Early stopping, best iteration is:
# [184]	valid's auc: 0.530097
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535054
# [200]	valid's auc: 0.537363
# Early stopping, best iteration is:
# [224]	valid's auc: 0.537566
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532762
# [200]	valid's auc: 0.534691
# Early stopping, best iteration is:
# [191]	valid's auc: 0.534904
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533449
# Early stopping, best iteration is:
# [93]	valid's auc: 0.534179
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [65]	valid's auc: 0.537547
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.532741
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528652
# [200]	valid's auc: 0.531359
# Early stopping, best iteration is:
# [242]	valid's auc: 0.532949
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534118
# [200]	valid's auc: 0.539665
# Early stopping, best iteration is:
# [209]	valid's auc: 0.540106
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53326
# [200]	valid's auc: 0.536906
# Early stopping, best iteration is:
# [260]	valid's auc: 0.537613
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530441
# Early stopping, best iteration is:
# [119]	valid's auc: 0.531512
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [58]	valid's auc: 0.535869
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [52]	valid's auc: 0.533647
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528765
# [200]	valid's auc: 0.530827
# Early stopping, best iteration is:
# [206]	valid's auc: 0.531161
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534935
# [200]	valid's auc: 0.53851
# Early stopping, best iteration is:
# [200]	valid's auc: 0.53851
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532318
# [200]	valid's auc: 0.535315
# Early stopping, best iteration is:
# [214]	valid's auc: 0.535427
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531213
# [200]	valid's auc: 0.532868
# Early stopping, best iteration is:
# [217]	valid's auc: 0.533648
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536784
# Early stopping, best iteration is:
# [78]	valid's auc: 0.536834
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532967
# Early stopping, best iteration is:
# [160]	valid's auc: 0.534342
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52815
# [200]	valid's auc: 0.530847
# Early stopping, best iteration is:
# [198]	valid's auc: 0.530982
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536524
# [200]	valid's auc: 0.541191
# Early stopping, best iteration is:
# [224]	valid's auc: 0.541364
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53433
# Early stopping, best iteration is:
# [140]	valid's auc: 0.537523
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529592
# Early stopping, best iteration is:
# [131]	valid's auc: 0.53033
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [60]	valid's auc: 0.534745
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532691
# Early stopping, best iteration is:
# [82]	valid's auc: 0.533007
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528265
# Early stopping, best iteration is:
# [144]	valid's auc: 0.530092
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533916
# [200]	valid's auc: 0.537569
# Early stopping, best iteration is:
# [203]	valid's auc: 0.53781
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533422
# Early stopping, best iteration is:
# [132]	valid's auc: 0.535544
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530515
# Early stopping, best iteration is:
# [169]	valid's auc: 0.534171
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535715
# Early stopping, best iteration is:
# [112]	valid's auc: 0.536215
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.534633
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531747
# Early stopping, best iteration is:
# [131]	valid's auc: 0.532803
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535964
# Early stopping, best iteration is:
# [88]	valid's auc: 0.53667
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533043
# Early stopping, best iteration is:
# [85]	valid's auc: 0.533706
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53295
# Early stopping, best iteration is:
# [126]	valid's auc: 0.533675
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536215
# Early stopping, best iteration is:
# [107]	valid's auc: 0.5365
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532818
# Early stopping, best iteration is:
# [70]	valid's auc: 0.533623
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529603
# [200]	valid's auc: 0.532208
# Early stopping, best iteration is:
# [260]	valid's auc: 0.533205
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536075
# Early stopping, best iteration is:
# [160]	valid's auc: 0.538427
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534297
# Early stopping, best iteration is:
# [133]	valid's auc: 0.5353
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [48]	valid's auc: 0.530805
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [58]	valid's auc: 0.536858
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.533418
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529656
# Early stopping, best iteration is:
# [127]	valid's auc: 0.531298
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535433
# Early stopping, best iteration is:
# [149]	valid's auc: 0.536753
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531264
# Early stopping, best iteration is:
# [166]	valid's auc: 0.53315
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.526098
# [200]	valid's auc: 0.528504
# Early stopping, best iteration is:
# [170]	valid's auc: 0.529174
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533017
# [200]	valid's auc: 0.536592
# Early stopping, best iteration is:
# [182]	valid's auc: 0.537078
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529463
# Early stopping, best iteration is:
# [128]	valid's auc: 0.532445
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531403
# Early stopping, best iteration is:
# [160]	valid's auc: 0.532893
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.534979
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531017
# Early stopping, best iteration is:
# [168]	valid's auc: 0.532708
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52815
# Early stopping, best iteration is:
# [129]	valid's auc: 0.529042
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536283
# [200]	valid's auc: 0.537151
# Early stopping, best iteration is:
# [171]	valid's auc: 0.537372
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532717
# Early stopping, best iteration is:
# [140]	valid's auc: 0.533427
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.527924
# [200]	valid's auc: 0.530571
# Early stopping, best iteration is:
# [180]	valid's auc: 0.531035
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536288
# Early stopping, best iteration is:
# [164]	valid's auc: 0.538747
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531665
# Early stopping, best iteration is:
# [131]	valid's auc: 0.533241
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531572
# [200]	valid's auc: 0.532713
# Early stopping, best iteration is:
# [219]	valid's auc: 0.532904
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536789
# Early stopping, best iteration is:
# [104]	valid's auc: 0.537225
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [68]	valid's auc: 0.534052
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.526312
# [200]	valid's auc: 0.529065
# Early stopping, best iteration is:
# [255]	valid's auc: 0.530342
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532561
# [200]	valid's auc: 0.537599
# Early stopping, best iteration is:
# [243]	valid's auc: 0.538385
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533282
# Early stopping, best iteration is:
# [162]	valid's auc: 0.534873
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.525653
# Early stopping, best iteration is:
# [159]	valid's auc: 0.528146
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53285
# Early stopping, best iteration is:
# [162]	valid's auc: 0.536437
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530695
# Early stopping, best iteration is:
# [95]	valid's auc: 0.531305
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528403
# [200]	valid's auc: 0.530831
# Early stopping, best iteration is:
# [170]	valid's auc: 0.530998
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535849
# [200]	valid's auc: 0.537383
# Early stopping, best iteration is:
# [188]	valid's auc: 0.537406
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534052
# Early stopping, best iteration is:
# [103]	valid's auc: 0.534178
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52739
# Early stopping, best iteration is:
# [151]	valid's auc: 0.529495
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535423
# [200]	valid's auc: 0.54165
# Early stopping, best iteration is:
# [202]	valid's auc: 0.541796
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532824
# [200]	valid's auc: 0.536098
# Early stopping, best iteration is:
# [203]	valid's auc: 0.536399
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528997
# [200]	valid's auc: 0.530383
# Early stopping, best iteration is:
# [194]	valid's auc: 0.530527
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535568
# Early stopping, best iteration is:
# [127]	valid's auc: 0.535949
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533672
# Early stopping, best iteration is:
# [123]	valid's auc: 0.534462
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530871
# Early stopping, best iteration is:
# [86]	valid's auc: 0.531638
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.531512
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.531473
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.525463
# [200]	valid's auc: 0.529207
# [300]	valid's auc: 0.529822
# Early stopping, best iteration is:
# [274]	valid's auc: 0.530371
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534485
# [200]	valid's auc: 0.539622
# Early stopping, best iteration is:
# [212]	valid's auc: 0.540224
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532776
# [200]	valid's auc: 0.535402
# Early stopping, best iteration is:
# [237]	valid's auc: 0.535771
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.527441
# [200]	valid's auc: 0.529608
# Early stopping, best iteration is:
# [235]	valid's auc: 0.530124
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534957
# Early stopping, best iteration is:
# [87]	valid's auc: 0.53559
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534369
# [200]	valid's auc: 0.535126
# Early stopping, best iteration is:
# [179]	valid's auc: 0.535926
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53191
# Early stopping, best iteration is:
# [101]	valid's auc: 0.532059
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.534327
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532269
# Early stopping, best iteration is:
# [134]	valid's auc: 0.532972
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.531748
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.538349
# Early stopping, best iteration is:
# [100]	valid's auc: 0.538349
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533066
# Early stopping, best iteration is:
# [139]	valid's auc: 0.533618
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529292
# [200]	valid's auc: 0.530944
# Early stopping, best iteration is:
# [184]	valid's auc: 0.531499
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536215
# [200]	valid's auc: 0.537328
# Early stopping, best iteration is:
# [197]	valid's auc: 0.537462
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532713
# [200]	valid's auc: 0.53523
# Early stopping, best iteration is:
# [205]	valid's auc: 0.535337
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528512
# [200]	valid's auc: 0.530908
# Early stopping, best iteration is:
# [260]	valid's auc: 0.531629
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536878
# [200]	valid's auc: 0.540969
# Early stopping, best iteration is:
# [201]	valid's auc: 0.541161
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533328
# Early stopping, best iteration is:
# [95]	valid's auc: 0.533891
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530388
# [200]	valid's auc: 0.533279
# Early stopping, best iteration is:
# [194]	valid's auc: 0.533532
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535616
# Early stopping, best iteration is:
# [127]	valid's auc: 0.535947
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53268
# Early stopping, best iteration is:
# [97]	valid's auc: 0.53309
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [61]	valid's auc: 0.531434
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.534723
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531846
# Early stopping, best iteration is:
# [83]	valid's auc: 0.532798
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529939
# Early stopping, best iteration is:
# [161]	valid's auc: 0.531789
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.534452
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532459
# [200]	valid's auc: 0.533685
# Early stopping, best iteration is:
# [177]	valid's auc: 0.534037
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529592
# Early stopping, best iteration is:
# [164]	valid's auc: 0.532174
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534727
# [200]	valid's auc: 0.537248
# Early stopping, best iteration is:
# [243]	valid's auc: 0.537774
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529883
# [200]	valid's auc: 0.531818
# Early stopping, best iteration is:
# [172]	valid's auc: 0.532118
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530986
# Early stopping, best iteration is:
# [125]	valid's auc: 0.531706
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.536986
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.532635
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531059
# Early stopping, best iteration is:
# [163]	valid's auc: 0.532697
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [68]	valid's auc: 0.537136
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.532633
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530009
# Early stopping, best iteration is:
# [159]	valid's auc: 0.531845
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [58]	valid's auc: 0.537729
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532461
# Early stopping, best iteration is:
# [78]	valid's auc: 0.534492
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53087
# [200]	valid's auc: 0.532606
# Early stopping, best iteration is:
# [184]	valid's auc: 0.533202
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.537378
# Early stopping, best iteration is:
# [97]	valid's auc: 0.538207
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532011
# Early stopping, best iteration is:
# [124]	valid's auc: 0.532771
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530422
# [200]	valid's auc: 0.531614
# Early stopping, best iteration is:
# [176]	valid's auc: 0.531797
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536606
# Early stopping, best iteration is:
# [79]	valid's auc: 0.537103
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532669
# Early stopping, best iteration is:
# [96]	valid's auc: 0.532972
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530014
# [200]	valid's auc: 0.531231
# Early stopping, best iteration is:
# [173]	valid's auc: 0.532119
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535162
# Early stopping, best iteration is:
# [144]	valid's auc: 0.53639
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532003
# Early stopping, best iteration is:
# [128]	valid's auc: 0.532597
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528377
# [200]	valid's auc: 0.53042
# Early stopping, best iteration is:
# [176]	valid's auc: 0.530966
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534374
# Early stopping, best iteration is:
# [157]	valid's auc: 0.536505
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531977
# Early stopping, best iteration is:
# [119]	valid's auc: 0.532846
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53062
# [200]	valid's auc: 0.532321
# Early stopping, best iteration is:
# [183]	valid's auc: 0.532751
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533939
# Early stopping, best iteration is:
# [160]	valid's auc: 0.537076
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53349
# Early stopping, best iteration is:
# [74]	valid's auc: 0.534119
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.527829
# [200]	valid's auc: 0.531437
# Early stopping, best iteration is:
# [223]	valid's auc: 0.532484
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534756
# Early stopping, best iteration is:
# [169]	valid's auc: 0.537878
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531627
# Early stopping, best iteration is:
# [167]	valid's auc: 0.533664
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530576
# Early stopping, best iteration is:
# [142]	valid's auc: 0.532774
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536316
# Early stopping, best iteration is:
# [159]	valid's auc: 0.538013
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531062
# Early stopping, best iteration is:
# [71]	valid's auc: 0.532148
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529229
# Early stopping, best iteration is:
# [115]	valid's auc: 0.530025
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536431
# Early stopping, best iteration is:
# [109]	valid's auc: 0.537467
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.530175
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531463
# Early stopping, best iteration is:
# [117]	valid's auc: 0.532277
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53603
# Early stopping, best iteration is:
# [130]	valid's auc: 0.536755
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531803
# [200]	valid's auc: 0.533237
# Early stopping, best iteration is:
# [213]	valid's auc: 0.533686
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530087
# Early stopping, best iteration is:
# [163]	valid's auc: 0.532318
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535986
# Early stopping, best iteration is:
# [158]	valid's auc: 0.537274
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532029
# Early stopping, best iteration is:
# [167]	valid's auc: 0.533664
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536829
# [200]	valid's auc: 0.537669
# Early stopping, best iteration is:
# [177]	valid's auc: 0.538083
# RandomizedSearchCV(cv=3,
#                    estimator=LGBMClassifier(metric='None', n_estimators=5000,
#                                             n_jobs=4, random_state=314),
#                    n_iter=100,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001BE1A3F2E48>,
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001BE1A3F2788>,
#                                         'min_child_weight': [1e-05, 0.001, 0.01,
#                                                              0.1, 1, 10.0,
#                                                              100.0, 1000.0,
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001BE1A3F2688>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001BE16C51748>},
#                    random_state=314, scoring='roc_auc', verbose=True)

# %%
#gs.best_estimator_

# %%
#
#gs.best_estimator_
#LGBMClassifier(colsample_bytree=0.6433117836032942, metric='None',
#               min_child_samples=224, min_child_weight=1e-05, n_estimators=5000,
#               n_jobs=4, num_leaves=20, random_state=314, reg_alpha=10,
#               reg_lambda=10, subsample=0.8945613420997809)

# %%
cf = lgb.LGBMRegressor(colsample_bytree=0.7173613575636579, metric='None',
               min_child_samples=134, min_child_weight=1e-05, n_estimators=5000,
               n_jobs=4, num_leaves=14, random_state=314, reg_alpha=0,
               reg_lambda=20, subsample=0.5813098915332424)

cf.fit(dataset_train[feature_names],dataset_train['return'] > 1, **fit_params)
cf.score(dataset_test[feature_names],dataset_test['return'] > 1)
# Out:
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.537041
# Early stopping, best iteration is:
# [169]	valid's auc: 0.538933
# -0.028378485999821956

# %%
cf.feature_importances_
# Out:
# array([ 65,  84,  62,  69,  74,  59,  87,  86,  85, 121,  50,  59,  73,
#         56,  82, 109,  75,  70,  89,  88, 142,  36,  25,  76,  44,  39,
#         51,  65,  51,  55,  70])

# %%
feature_imp = pd.DataFrame(zip(cf.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
sns.barplot(x="Value", y="Feature", data=feature_imp)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Feature'>

# %% [raw]
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551389
# Early stopping, best iteration is:
# [89]	valid's auc: 0.553699
# 0.003857956228475623

# %%
#print(cf.fit(*train))

# %%
#import lightgbm as lgb
#gbm = lgb.LGBMClassifier(n_estimators=100, random_state=5, learning_rate=0.01)
#gbm.fit(dataset_train[feature_names], dataset_train['return'] > 1)

# %%
#import tqdm
#
#n = 3
#
#X = []
#y = []
#indexes = []
#dataset_scaled_x = dataset_scaled[feature_names]
#
#for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-n)):
#    X.append(dataset_scaled_x.iloc[i:i+n].values)
#    y.append(dataset_scaled['return'].iloc[i+n-1])
#    indexes.append(dataset_scaled.index[i+n-1])
##dataset_scaled.head()

# %%
#import numpy as np
#X = np.array(X)
#y = np.array(y)

# %%
##import lightgbm as lgb
#cf = lgb.LGBMRegressor(colsample_bytree=0.7740467183023685, metric='None',
#               min_child_samples=395, min_child_weight=0.01, n_estimators=5000,
#               n_jobs=4, num_leaves=9, random_state=314, reg_alpha=5,
#               reg_lambda=10, subsample=0.4643892520208455)
#    
#cf.fit(dataset_train[feature_names].astype(float), dataset_train['rank'])

# %% [markdown]
# #### Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

cf2 = RandomForestRegressor(n_estimators=100)
cf2.fit(dataset_train[feature_names].astype(float), dataset_train[predi_target])
# Out:
# RandomForestRegressor()

# %% [markdown]
# ##### 參數優化_1110

# %%
#from scipy.stats import randint as sp_randint 
#from sklearn.model_selection import RandomizedSearchCV 
## build a classifier 
#clf = RandomForestRegressor(n_estimators=100) 
## specify parameters and distributions to sample from 
#param_dist = {"max_depth": [3, None], 
#              "max_features": sp_randint(1, 11), 
#              "min_samples_split": sp_randint(2, 11), 
#              "min_samples_leaf": sp_randint(1, 11), 
#              "bootstrap": [True, False], 
#              "criterion": ["mse", "mae"]} 
## run randomized search 
#n_iter_search = 20 
#rs = RandomizedSearchCV(clf, param_distributions=param_dist, 
#                                   n_iter=n_iter_search)

# %%
#rs.fit(dataset_train[features], dataset_train['return'] > 1)

# %% [markdown]
# ##### Split Train Test dataset

# %%
feature_imp = pd.DataFrame(zip(cf2.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
sns.barplot(x="Value", y="Feature", data=feature_imp)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Feature'>

# %%
select = dataset.index.get_level_values('date') < '2021'
dataset_train = dataset[select]
dataset_test = dataset[~select]

# %% [markdown]
# ### Ensemble learning

# %%
dataset_drop = dataset.dropna(subset=feature_names+['return'])

vals = model.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result1'] = pd.Series(vals.swapaxes(0,1)[0], dataset_drop.index)

vals = cf.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result2'] = pd.Series(vals, dataset_drop.index)

vals = cf2.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result3'] = pd.Series(vals, dataset_drop.index)

dataset_drop = dataset_drop.reset_index().set_index("date")

# %% [markdown]
# ## backtest

# %% [markdown]
# ## 把量加進來做篩選
#  * https://hahow.in/courses/5b9d3a6dca498a001e917383/shapeussions/60c96f5b018697e8a6131cbc

# %%
#把量加進來
vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

vol_filter=vol_ma5>1000
vol_filter=vol_filter[vol_filter].fillna(0)
#vol_filter
t1 = vol_filter

# %%
#t1

# %%
vol_filter = t1.reindex(every_month, method='ffill')#.loc['2010-02-15']
#vol_filter.loc['2010-02-15']

# %%
#t1 = vol_ma5.iloc[-1].dropna()
#t1.to_csv('./tmp/132.csv')
#t1.hist(bins=10)

# %%
vol = 100

# %%
import math


dates = sorted(list(set(dataset_drop.index)))

rs = []
for d in dates:
    #print(d)
    dataset_time = dataset_drop.loc[d]
    
    dataset_time = drop_extreme_case(dataset_time , feature_names , thresh=0.01)
    
    #print(dataset_time)
    
    predi_target = dataset_time['result1'] + dataset_time['result2'] + dataset_time['result3'] 
            ###
    predi_target = predi_target * (dataset_time['vol_ma5'] >vol).astype(float)
            ###

    condition = (predi_target >= predi_target.nlargest(20).iloc[-1]) 
    
    #print(vol_filter.loc[d])
    #print(condition)
    
    r = dataset_time['return'][condition].mean()

    rs.append(r * (1-3/1000-1.425/1000*2*0.6))

rs = pd.Series(rs, index=dates)['2016':].cumprod()

s0050 = close['0050']['2016':]

pd.DataFrame({'nn strategy return':rs.reindex(s0050.index, method='ffill'), '0050 return':s0050/s0050[0]}).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#import pickle
#
#return_history_1026 = pd.Series(rs, index=dates)['2021':].cumprod()
##eq = (gain[hold == 1].mean(axis=1)).fillna(1).cumprod()
#
#pickle.dump(rs, open('return_history_1026.pkl', 'wb'))

# %%
#import pyfolio as pf
#import pandas as pd
#
#close.index = close.index.tz_localize("Asia/Taipei")
##pf.create_returns_tear_sheet(close['0050'].pct_change())
#
## 得到 上一個單元的 回測結果
#ret = pickle.load(open("return_history_1026.pkl", "rb"))
#
## 將回測報酬率取出來
#ret = ret.pct_change().dropna()
#ret.index = pd.to_datetime(ret.index).tz_localize('Asia/Taipei')
#
## 利用pyfolio 比較報酬率
#pf.create_returns_tear_sheet(ret, benchmark_rets=close['0050'].pct_change())

# %% [markdown]
# ### 當月持股狀況

# %%
# get the latest dataset
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()


last_dataset = drop_extreme_case(last_dataset, feature_names , thresh=0.01)
t1 = last_dataset

# remove NaN testcases
last_dataset = last_dataset.dropna(subset=feature_names)

# predict

vals = model.predict(last_dataset[feature_names].astype(float))
last_dataset['result1'] = pd.Series(vals.swapaxes(0,1)[0], last_dataset.index)

vals = cf.predict(last_dataset[feature_names].astype(float))
last_dataset['result2'] = pd.Series(vals, last_dataset.index)

vals = cf2.predict(last_dataset[feature_names].astype(float))
last_dataset['result3'] = pd.Series(vals, last_dataset.index)


# calculate score

predi_target = last_dataset['result1'] + last_dataset['result2'] + last_dataset['result3']

#
##predi_target = predi_target * vol_filter.iloc[-1] #******加上量的濾網
predi_target = predi_target * (last_dataset['vol_ma5'] >vol).astype(float)



condition = (predi_target >= predi_target.nlargest(20).iloc[-1])
#vol_filter

# plot rank distribution
predi_target[predi_target!=0].hist(bins=20)


# show the best 20 stocks
slist1 = predi_target[condition].reset_index()['stock_id']

#https://keras-cn.readthedocs.io/en/latest/models/model/

# %%
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()

# %%
#rank.sort_values(ascending=False).head(20)

# %% [markdown]
# ## 平均分配資產於股票之中

# %%
close = data.get("收盤價")

money = 60000
stock_prices = close[slist1].iloc[-1]


print("股票平分張數:")
money / len(stock_prices) / stock_prices / 1000
# Out:
# 股票平分張數:
# stock_id
# 1104    0.132159
# 1419    0.072639
# 2027    0.067873
# 2385    0.035672
# 2488    0.102564
# 3052    0.285714
# 3090    0.055762
# 4163    0.028302
# 4527    0.103270
# 6024    0.080645
# 6111    0.055659
# 6197    0.073260
# 6227    0.074534
# 6248    0.135440
# 6263    0.034091
# 6664    0.029412
# 6669    0.003195
# 6670    0.013514
# 8234    0.085349
# 9904    0.090909
# Name: 2022-12-14 00:00:00, dtype: float64

# %% [markdown]
# ##########################
# ## [動窗格最佳化](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/61b4c90147843d0006cf2593)
# ##########################

# %%
import lightgbm as lgb

from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt

import numpy as np

# %matplotlib inline

def select(df):

    rank = df['pre']

    condition1 = (rank >= rank.nlargest(1).iloc[-1])

    return df['return'][condition1].mean() * (1-3/1000-1.425/1000*2*0.6)

end = 5

cf = lgb.LGBMRegressor(n_estimators=500)



train_time = ['2015','2016','2017','2018','2019']

s_time = ['2007','2008','2009','2010','2011']

test_time = ['2016','2017','2018','2019','2020']

#dataset_copy = dataset_dropna.copy()

store_mse = []


for time in range(end):

    print('%d 次執行中'%(time))

    dataset_dropna2_train = dataset_copy.loc[s_time[time]:train_time[time]] #2007~ 2015   2008~2016   2009~2017  2010~2018  ....

    dataset_dropna2_test = dataset_copy.loc[test_time[time]:test_time[time]]#            2016                2017               2018              2019  .....

    
 cf.fit(dataset_dropna2_train[feature_names].astype(float), dataset_dropna2_train['rank'])

    
 predict = cf.predict(dataset_dropna2_test[feature_names])

    dataset_dropna2_test['pre'] = predict

dates = dataset_dropna2_test.index.get_level_values('date')

b = dataset_dropna2_test.groupby(dates).apply(select).cumprod()

s0050 = close['0050'][test_time[time]:test_time[time]]

s0056 = close['0056'][test_time[time]:test_time[time]]

pd.DataFrame({'Best 1 stocks return(include handling fee)':b.reindex(s0050.index, method='ffill'), 

              '0050':s0050/s0050[0],'0056':s0056/s0056[0]}).plot()

plt.ylabel('return')
# Out:
#   File "<tokenize>", line 45
#     cf.fit(dataset_dropna2_train[feature_names].astype(float), dataset_dropna2_train['rank'])
#     ^
# IndentationError: unindent does not match any outer indentation level
