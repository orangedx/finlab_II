# %% [markdown]
# # Final Project

# %%
# 移除不必要的警告
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 獲取歷史資料

# %%
from finlab.data import Data
#from finlab.ml import fundamental_features
#fdf = fundamental_features()

data = Data()

close = data.get("收盤價")
open_ = data.get("開盤價")
high = data.get("最高價")
low = data.get("最低價")
vol = data.get("成交股數")

PB = data.get("股價淨值比")
pe = data.get("本益比")

#bi = data.get("營業利益")


#close = data.get_adj("收盤價").round(2)

#財務指標
rev = data.get("當月營收")
l_rev = data.get("去年當月營收")

#t123 = data.get('土地')

bargin_i=data.get("投信買賣超股數")/data.get("成交股數")
bargin_f=data.get("外資自營商買賣超股數")/data.get("成交股數")
bargin_s=data.get("自營商買賣超股數(自行買賣)")/data.get("成交股數")
#

vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

rev.index = rev.index.shift(5, "d")         #每月頻率
#周頻率

# %% [markdown]
# ### 計算features

# %%
#MFI  = data.talib("MFI")
##MFI.tail()
#ub,mb,lb =data.talib("BBANDS")

# %% [markdown]
# #### 營收相關

# %%
##############################################　　　自己加入的　　　##############################################
import pandas as pd
from finlab.__init__ import talib_all_stock
from talib import abstract

# %%
def bias(n):
    return close / close.rolling(n, min_periods=1).mean()

def acc(n):
    return close.shift(n) / (close.shift(2*n) + close) * 2

def rsv(n):
    l = close.rolling(n, min_periods=1).min() 
    h = close.rolling(n, min_periods=1).max()
    
    return (close - l) / (h - l)

def mom(n):
    return (rev / rev.shift(1)).shift(n)

def yoy(n):
    return (rev.shift(n) / rev.shift(12+n)) -1

def bi(n):
    return bargin_i/bargin_i.rolling(n).mean()

def bf(n):
    return bargin_f/bargin_f.rolling(n).mean()
    
def bs(n):
    return bargin_s/bargin_s.rolling(n).mean()

#-------------------------------------------

features = {
    'mom1': mom(1),
    'mom2': mom(2),
    'mom3': mom(3),
    'mom4': mom(4),
    'mom5': mom(5),
    'mom6': mom(6),
    'mom7': mom(7),
    'mom8': mom(8),
    'mom9': mom(9),

    
    'bias5': bias(5),
    'bias10': bias(10),
    'bias20': bias(20),
    'bias60': bias(60),
    'bias120': bias(120),
    'bias240': bias(240),
    
    'acc5': acc(5),
    'acc10': acc(10),
    'acc20': acc(20),
    'acc60': acc(60),
    'acc120': acc(120),
    'acc240': acc(240),
    
    'rsv5': rsv(5),
    'rsv10': rsv(10),
    'rsv20': rsv(20),
    'rsv60': rsv(60),
    'rsv120': rsv(120),
    'rsv240': rsv(240),
###############################################
    'yoy': yoy(1),
    'delta_yoy':yoy(1)-yoy(2),
    
    'PB':PB,
    'PE':pe,
    
    #'v/ma':vol/vol_ma5,
   #'bi5' : bi(5),
   #'bi10' : bi(10),
   #'bi20' : bi(20),
   #'bi60' : bi(60),
   # 
   #'bf5' : bf(5),
   # #'bf10' : bf(10),
   # #'bf20' : bf(20),
   # #'bf60' : bf(60),
   # 
   # 'bs5' : bs(5),
   # 'bs10' : bs(10),
   # 'bs20' : bs(20),
   # 'bs60' : bs(60),
    
}

# %%
yoy(1)
# Out:
# stock_id        1101      1102      1103      1104  1107      1108      1109  \
# date
# 2005-02-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2005-03-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2005-04-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2005-05-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2005-06-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# ...              ...       ...       ...       ...   ...       ...       ...
# 2022-12-15  0.188504 -0.196042  0.084332  0.136037   NaN  0.449827 -0.201942
# 2023-01-15 -0.008009 -0.075633  0.121301  0.066769   NaN  0.431791 -0.143446
# 2023-02-15  0.162910 -0.113063  0.333061  0.272864   NaN  0.309856 -0.336393
# 2023-03-15 -0.025629 -0.351210  0.209836 -0.148473   NaN -0.091673 -0.474314
# 2023-04-15  0.339072  0.522002  0.574272  0.698135   NaN  0.717416  1.262398
#
# stock_id        1110      1201      1203  ...      9944      9945      9946  \
# date                                      ...
# 2005-02-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2005-03-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2005-04-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2005-05-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2005-06-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# ...              ...       ...       ...  ...       ...       ...       ...
# 2022-12-15  0.304901  0.005675  0.212145  ...  0.010391  0.178078 -0.673026
# 2023-01-15  0.234091 -0.024680  0.384607  ... -0.037130  0.413395 -0.057254
# 2023-02-15 -0.092717 -0.099534  0.200326  ... -0.138579  0.619756 -0.773686
# 2023-03-15 -0.173711 -0.050133 -0.085944  ... -0.347208 -0.330394 -0.703003
# 2023-04-15  0.787794  0.153275  0.136535  ... -0.003137  0.870228 -0.314591
#
# stock_id        9949      9950      9951      9955      9958      9960  \
# date
# 2005-02-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-03-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-04-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-05-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-15       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-15  0.048772 -0.156177  0.245812 -0.294261  0.004491  0.010218
# 2023-01-15 -0.179187  1.294386  0.322786 -0.276645  0.101934  0.063968
# 2023-02-15 -0.041727  1.189093  0.225264 -0.463853  0.165291 -0.309252
# 2023-03-15 -0.215372  0.128140 -0.142444 -0.464537 -0.120989 -0.058771
# 2023-04-15 -0.176815  0.214471  0.215990 -0.350520  0.002525  0.314465
#
# stock_id        9962
# date
# 2005-02-15       NaN
# 2005-03-15       NaN
# 2005-04-15       NaN
# 2005-05-15       NaN
# 2005-06-15       NaN
# ...              ...
# 2022-12-15  0.129923
# 2023-01-15 -0.084119
# 2023-02-15  0.568746
# 2023-03-15  0.330021
# 2023-04-15  0.221827
#
# [219 rows x 2027 columns]

# %%
##def yoy(n):
##    if rev.shift(n) < 0:
##        return rev.shift(n)
##    else :
##        return (rev.shift(n) / rev.shift(12+n)) -1
##
##yoy(1)

# %%
#bi(60).dropna(how='all')

# %% [markdown]
# #### 財報指標

# %% [markdown]
# 兩個feature結合[[連結網址]](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7)
#
# ---
# ```python
# from finlab import ml
# from finlab.data import Data
#
# data = Data()
# rsi = data.talib("RSI")
#
# dataset = ml.fundamental_features()
# ml.add_feature(dataset, 'RSI', rsi)
# ```

# %%
from finlab.ml import fundamental_features
dataset_fundamental = fundamental_features()

# %%
#dataset_fundamental

# %% [markdown]
# #### 技術指標

# %% [raw]
# # https://zhuanlan.zhihu.com/p/342075180 talib函数功能一览表
#
# def bias(n):
#     return close / close.rolling(n, min_periods=1).mean()
#
# def acc(n):
#     return close.shift(n) / (close.shift(2*n) + close) * 2
#
# def rsv(n):
#     l = close.rolling(n, min_periods=1).min()
#     h = close.rolling(n, min_periods=1).max()
#
#     return (close - l) / (h - l)
#
# def mom(n):
#     return (rev / rev.shift(1)).shift(n)
#
#
# def bi_(n):
#     return (bargin_i / vol.shift(1)).shift(n)
#
# def bf(n):
#     return (bargin_f / vol.shift(1)).shift(n)
#
# def bs(n):
#     return (bargin_s / vol.shift(1)).shift(n)
#
# def rsi(n):
#     #return talib_all_stock(ndays=10000, func=abstract.RSI, timeperiod=n)
#     return data.talib("RSI",timeperiod=n)
#
# def MFI(n):
#     return data.talib("MFI",timeperiod=n)
#
# def obv(n):
#     return data.talib("OBV",timeperiod=n)
#
#
#
# features = {
#
#     #'ATR14':data.talib("ATR",timeperiod=14),
#     #'NATR14':data.talib('NATR',timeperiod=14),
#     #'TRANGE':data.talib('TRANGE'),
#     #'Adosc3':data.talib('ADOSC',timeperiod=3),
#
#     #"MFI5":MFI(5),
#     #"MFI10":MFI(10),
#
#     #'rsi6': rsi(6),  #DataFrame
#     #'rsi10': rsi(10),  #DataFrame
#     #'rsi14': rsi(14),  #DataFrame
#     #'rsi20': rsi(20),  #DataFrame
#     #'rsi50': rsi(50),  #DataFrame
#
#     'mom1': mom(1),
#     'mom2': mom(2),
#     'mom3': mom(3),
#     'mom4': mom(4),
#     'mom5': mom(5),
#     'mom6': mom(6),
#     'mom7': mom(7),
#     'mom8': mom(8),
#     'mom9': mom(9),
#
#     'yoy': yoy(1),
#     'delta_yoy':yoy(1)-yoy(2),
#
# #    'ff':ff,
#     'PB':PB,
#     'PE':pe,
# #
#     'bias5': bias(5),
#     'bias10': bias(10),
#     'bias20': bias(20),
#     'bias60': bias(60),
#     'bias120': bias(120),
#     'bias240': bias(240),
#
#     'acc5': acc(5),
#     'acc10': acc(10),
#     'acc20': acc(20),
#     'acc60': acc(60),
#     'acc120': acc(120),
#     'acc240': acc(240),
#
#     #'rsv5': rsv(5),
#     #'rsv10': rsv(10),
#     #'rsv20': rsv(20),
#     #'rsv60': rsv(60),
#     #'rsv120': rsv(120),
#     #'rsv240': rsv(240),
# }

# %% [raw]
# ```
# https://www.twblogs.net/a/5d3f3173bd9eee517422735f
# W-WED
# https://docs.python.org/zh-tw/3/library/calendar.html
# ```

# %% [markdown]
# 加入其他features
# * http://finlabcourse.imotor.com/viewthread.php?tid=660&extra=page%3D1
#
# ```python
# from finlab import ml
# from finlab.data import Data
#
# data = Data()
# rsi = data.talib("RSI")
#
# dataset = ml.fundamental_features()
# ml.add_feature(dataset, 'RSI', rsi)
# ```

# %% [markdown]
# #### 組合dataset

# %%
import pandas as pd

# %% [markdown]
# #### 確認各指標清單

# %%
#t1 = data.talib("NATR",timeperiod=14)
#t1.to_csv('myfile.csv')

# %% [markdown]
# ### 製作dataset
#
# ##### 設定買賣頻率

# %%
#rev.index = rev.index.tz_localize("Asia/Taipei")
every_month = rev.index
every_month
# Out:
# DatetimeIndex(['2005-02-15', '2005-03-15', '2005-04-15', '2005-05-15',
#                '2005-06-15', '2005-07-15', '2005-08-15', '2005-09-15',
#                '2005-10-15', '2005-11-15',
#                ...
#                '2022-07-15', '2022-08-15', '2022-09-15', '2022-10-15',
#                '2022-11-15', '2022-12-15', '2023-01-15', '2023-02-15',
#                '2023-03-15', '2023-04-15'],
#               dtype='datetime64[ns]', name='date', length=219, freq=None)

# %% [markdown]
# #### 將dataframe 組裝起來

# %%
# features['bias20'].reindex(every_month, method='ffill')

for name, f in features.items():
    features[name] = f.reindex(every_month, method='ffill')

# %%
for name, f in features.items():
    features[name] = f.unstack()

# %%
import pandas as pd
dataset = pd.DataFrame(features)

# %%
feature_names = list(dataset.columns)

# %% [markdown]
# ##### 裝自己要的

# %%
from finlab import ml

# %%
股本 = data.get('股本合計').reindex(close.index, method='ffill')
市值 = 股本 * close / 10 * 1000
#t1['2330'].dropna()
ml.add_feature(dataset, '市值', 市值)

# %%
ml.add_feature(dataset, 'vol_ma5', vol_ma5)

dataset
# Out:
#                          mom1      mom2      mom3      mom4      mom5  \
# stock_id date
# 0015     2005-02-15       NaN       NaN       NaN       NaN       NaN
#          2005-03-15       NaN       NaN       NaN       NaN       NaN
#          2005-04-15       NaN       NaN       NaN       NaN       NaN
#          2005-05-15       NaN       NaN       NaN       NaN       NaN
#          2005-06-15       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 9962     2022-12-15  1.163303  0.830797  1.280940  0.641536  1.694666
#          2023-01-15  1.004024  1.163303  0.830797  1.280940  0.641536
#          2023-02-15  1.249495  1.004024  1.163303  0.830797  1.280940
#          2023-03-15  0.729045  1.249495  1.004024  1.163303  0.830797
#          2023-04-15  1.110722  0.729045  1.249495  1.004024  1.163303
#
#                          mom6      mom7      mom8      mom9     bias5  ...  \
# stock_id date                                                          ...
# 0015     2005-02-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-03-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-04-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-05-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-06-15       NaN       NaN       NaN       NaN       NaN  ...
# ...                       ...       ...       ...       ...       ...  ...
# 9962     2022-12-15  0.917472  0.678559  1.435387  1.209077  1.024939  ...
#          2023-01-15  1.694666  0.917472  0.678559  1.435387  1.004331  ...
#          2023-02-15  0.641536  1.694666  0.917472  0.678559  1.005587  ...
#          2023-03-15  1.280940  0.641536  1.694666  0.917472  1.002268  ...
#          2023-04-15  0.830797  1.280940  0.641536  1.694666  0.950579  ...
#
#                         rsv20     rsv60    rsv120    rsv240       yoy  \
# stock_id date
# 0015     2005-02-15       NaN       NaN       NaN       NaN       NaN
#          2005-03-15       NaN       NaN       NaN       NaN       NaN
#          2005-04-15       NaN       NaN       NaN       NaN       NaN
#          2005-05-15       NaN       NaN       NaN       NaN       NaN
#          2005-06-15       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 9962     2022-12-15  1.000000  0.987500  0.989899  0.435556  0.129923
#          2023-01-15  0.895833  0.943820  0.957627  0.586667 -0.084119
#          2023-02-15  1.000000  1.000000  1.000000  0.697778  0.568746
#          2023-03-15  0.920000  0.968750  0.978723  0.902222  0.330021
#          2023-04-15  0.297872  0.702703  0.836634  0.850679  0.221827
#
#                      delta_yoy    PB    PE            市值    vol_ma5
# stock_id date
# 0015     2005-02-15        NaN   NaN   NaN           NaN        NaN
#          2005-03-15        NaN   NaN   NaN           NaN        NaN
#          2005-04-15        NaN   NaN   NaN           NaN        NaN
#          2005-05-15        NaN   NaN   NaN           NaN        NaN
#          2005-06-15        NaN   NaN   NaN           NaN        NaN
# ...                        ...   ...   ...           ...        ...
# 9962     2022-12-15   0.126406  1.32  6.99  1.520212e+09   632.1574
#          2023-01-15  -0.214041  1.46  7.70  1.673587e+09  3007.9848
#          2023-02-15   0.652864  1.55  8.22  1.786362e+09   932.8926
#          2023-03-15  -0.238725  1.73  9.17  1.993869e+09   831.0838
#          2023-04-15  -0.108194  1.60  9.05  1.926203e+09  4249.7718
#
# [450921 rows x 33 columns]

# %%
##############################################　　　自己加入的　　　##############################################
dataset.index = dataset.index.set_names(['stock_id','date'], level=[0,1])


#dataset.index.levels[1].name = 'date'
#dataset.index.levels[0].name = 'stock_id'

#因為你pandas更新到新版了
## profit.index.levels[0].name = 'year'
## profit.index.levels[1].name = 'month'
#這兩行的語法被棄用，請改成
#profit.index=profit.index.set_names('year', level=0)
#profit.index=profit.index.set_names('month', level=1)
#or profit.index=profit.index.set_names(['year','month'], level=[0,1])
#直接一行
#就可以了

# %%
#list(dataset_fundamental.index)

# %%
#dataset_fundamental.reindex(dataset.index).dropna()

# %% [markdown]
# data[組合](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7)
# ```python
# new_df = pd.concat([dataset_fundamental['R406_經常利益成長率'],dataset],axis=1).dropna(how='any')
# ```

# %%
new_df = pd.concat([dataset_fundamental,dataset],axis=1).dropna(how='any')
dataset1 = new_df.fillna(method='ffill')#[(new_df.index.get_level_values('stock_id')=='2330')]
#dataset = dataset1

# %%
#feature_names=list(dataset1.columns)
#feature_names

# %% [markdown]
# ### 新增 label(績效/排名)
#  - 定義一下要比績效還是要比排名

# %%
from finlab import ml

ml.add_profit_prediction(dataset)
ml.add_rank_prediction(dataset)

# %%
#profit(return) rank
predi_target = 'rank'

# %% [markdown]
# ### 刪除太大太小的歷史資料

# %%
print(dataset.shape)

def drop_extreme_case(dataset, feature_names, thresh=0.01):
    
    extreme_cases = pd.Series(False, index=dataset.index)
    for f in feature_names:
        tf = dataset[f]
        extreme_cases = extreme_cases | (tf < tf.quantile(thresh)) | (tf > tf.quantile(1-thresh))
    dataset = dataset[~extreme_cases]
    return dataset

dataset_drop_extreme_case = drop_extreme_case(dataset , feature_names , thresh=0.01)

print(dataset_drop_extreme_case.shape)

##(436774, 25)
##(388157, 25)
# Out:
# (450921, 35)
# (390252, 35)

# %%
dataset_dropna = dataset_drop_extreme_case.dropna(how='any')
dataset_dropna = dataset_dropna.reset_index().set_index("date")

# %%
#dataset_drop_extreme_case.index.get_level_values("date")

# %%
##################################################################################################################
##############################################　　　自己加入的　　　##############################################
##################################################################################################################

dataset_dropna.index = pd.to_datetime(dataset_dropna.index)
dataset_dropna = dataset_dropna.sort_index()

#修復＜class ‘numpy.ndarray‘＞　https://blog.csdn.net/lxbin/article/details/114005757

# %% [markdown]
# ## Split Train Test dataset

# %%
dataset_train = dataset_dropna.loc[:'2022-03']
dataset_test = dataset_dropna.loc['2022-04':]

#date_arr = dataset.index.get_level_values('date') < '2020'
#dataset_train = dataset[date_arr]
#dataset_test = dataset[~date_arr]

# %%
train = dataset_train[feature_names] , dataset_train['return'] > 1.02
test = dataset_test[feature_names] , dataset_test['return'] > 1.00

# %% [markdown]
# ### 機器學習
#  - 目前只有三個，技術指標也要再增加一下feature_names

# %%
#feature_names = feature_names1

# %%
#dataset_train.index

# %% [markdown]
# #### keras

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential()

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers

import os


os.environ['KMP_DUPLICATE_LIB_OK']='True'

model = keras.models.Sequential()
model.add(tf.keras.layers.Dense(100, activation='relu',
                      input_shape=(len(feature_names),),
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(100, activation='relu',
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(100, activation='relu',
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))


model.summary()

model.compile(loss=['mean_squared_error','sparse_categorical_crossentropy'],
              optimizer="adam",
              metrics=['accuracy']
             )

print('start fitting')
history = model.fit(dataset_train[feature_names], dataset_train[predi_target],
                    batch_size=888,         #1000  #每一个batch的大小
                    epochs=400, #225          #迭代次数
                    verbose=1,
                    validation_split=0.1,
                    #validation_data =        #(测试集的输入特征，测试集的标签），
                    #validation_split =       # 从测试集中划分多少比例给训练集，
                    #validation_freq = 20        #测试的epoch间隔数                     
                   )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               3200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 23,501
# Trainable params: 23,501
# Non-trainable params: 0
# _________________________________________________________________
# start fitting
# Epoch 1/400
# 100/100 [==============================] - 2s 8ms/step - loss: 0.1521 - accuracy: 1.0155e-04 - val_loss: 0.0748 - val_accuracy: 1.0154e-04
# Epoch 2/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0845 - accuracy: 6.7703e-05 - val_loss: 0.0751 - val_accuracy: 3.0463e-04
# Epoch 3/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0769 - accuracy: 1.1284e-04 - val_loss: 0.0747 - val_accuracy: 3.0463e-04
# Epoch 4/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0748 - accuracy: 1.2412e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 5/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0741 - accuracy: 1.2412e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 6/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0738 - accuracy: 1.3541e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 7/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0735 - accuracy: 1.1284e-04 - val_loss: 0.0746 - val_accuracy: 2.0309e-04
# Epoch 8/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0735 - accuracy: 1.2412e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 9/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0734 - accuracy: 1.3541e-04 - val_loss: 0.0746 - val_accuracy: 2.0309e-04
# Epoch 10/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0734 - accuracy: 1.1284e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 11/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0733 - accuracy: 1.2412e-04 - val_loss: 0.0746 - val_accuracy: 2.0309e-04
# Epoch 12/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0733 - accuracy: 1.2412e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 13/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0733 - accuracy: 1.3541e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 14/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 1.3541e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 15/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0732 - accuracy: 1.3541e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 16/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0733 - accuracy: 1.3541e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 17/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0733 - accuracy: 1.3541e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 18/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 1.2412e-04 - val_loss: 0.0746 - val_accuracy: 2.0309e-04
# Epoch 19/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 1.3541e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 20/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 1.3541e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 21/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 1.3541e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 22/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0732 - accuracy: 1.3541e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 23/400
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0732 - accuracy: 1.2412e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 24/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0732 - accuracy: 1.3541e-04 - val_loss: 0.0746 - val_accuracy: 3.0463e-04
# Epoch 25/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 1.4669e-04 - val_loss: 0.0745 - val_accuracy: 3.0463e-04
# Epoch 26/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0732 - accuracy: 1.3541e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 27/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0732 - accuracy: 1.4669e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 28/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 1.2412e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 29/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 1.2412e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 30/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 1.2412e-04 - val_loss: 0.0745 - val_accuracy: 3.0463e-04
# Epoch 31/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0732 - accuracy: 1.5797e-04 - val_loss: 0.0745 - val_accuracy: 2.0309e-04
# Epoch 32/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0731 - accuracy: 1.3541e-04 - val_loss: 0.0744 - val_accuracy: 2.0309e-04
# Epoch 33/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0731 - accuracy: 1.2412e-04 - val_loss: 0.0744 - val_accuracy: 2.0309e-04
# Epoch 34/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0730 - accuracy: 1.2412e-04 - val_loss: 0.0743 - val_accuracy: 2.0309e-04
# Epoch 35/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0730 - accuracy: 1.2412e-04 - val_loss: 0.0742 - val_accuracy: 1.0154e-04
# Epoch 36/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0730 - accuracy: 1.0155e-04 - val_loss: 0.0742 - val_accuracy: 1.0154e-04
# Epoch 37/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0730 - accuracy: 1.0155e-04 - val_loss: 0.0742 - val_accuracy: 1.0154e-04
# Epoch 38/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0729 - accuracy: 6.7703e-05 - val_loss: 0.0742 - val_accuracy: 1.0154e-04
# Epoch 39/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0729 - accuracy: 7.8986e-05 - val_loss: 0.0742 - val_accuracy: 1.0154e-04
# Epoch 40/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0729 - accuracy: 5.6419e-05 - val_loss: 0.0742 - val_accuracy: 1.0154e-04
# Epoch 41/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0728 - accuracy: 6.7703e-05 - val_loss: 0.0742 - val_accuracy: 1.0154e-04
# Epoch 42/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0728 - accuracy: 5.6419e-05 - val_loss: 0.0742 - val_accuracy: 1.0154e-04
# Epoch 43/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0728 - accuracy: 6.7703e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 44/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0728 - accuracy: 6.7703e-05 - val_loss: 0.0742 - val_accuracy: 1.0154e-04
# Epoch 45/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0728 - accuracy: 7.8986e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 46/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0728 - accuracy: 4.5135e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 47/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0728 - accuracy: 6.7703e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 48/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 4.5135e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 49/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0727 - accuracy: 5.6419e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 50/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0728 - accuracy: 9.0270e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 51/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 7.8986e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 52/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 7.8986e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 53/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 5.6419e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 54/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 5.6419e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 55/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 7.8986e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 56/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 6.7703e-05 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 57/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 7.8986e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 58/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0727 - accuracy: 6.7703e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 59/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0726 - accuracy: 6.7703e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 60/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0726 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 1.0154e-04
# Epoch 61/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0726 - accuracy: 6.7703e-05 - val_loss: 0.0742 - val_accuracy: 0.0000e+00
# Epoch 62/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0726 - accuracy: 9.0270e-05 - val_loss: 0.0740 - val_accuracy: 1.0154e-04
# Epoch 63/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0726 - accuracy: 6.7703e-05 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 64/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0726 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 65/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0726 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 1.0154e-04
# Epoch 66/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 5.6419e-05 - val_loss: 0.0741 - val_accuracy: 1.0154e-04
# Epoch 67/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0726 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 68/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0726 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 69/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 1.0154e-04
# Epoch 70/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0726 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 71/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 72/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 5.6419e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 73/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 5.6419e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 74/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 75/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0725 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 76/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 9.0270e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 77/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0725 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 78/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 79/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0725 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 1.0154e-04
# Epoch 80/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 81/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 82/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0724 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 83/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 84/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 4.5135e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 85/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 86/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 87/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 88/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 89/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 90/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0723 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 91/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 5.6419e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 92/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 93/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0723 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 94/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 1.0155e-04 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 95/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 96/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 97/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 98/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0723 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 99/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 100/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0723 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 101/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 102/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 103/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 104/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 5.6419e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 105/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 106/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 107/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 108/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 109/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 110/400
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0722 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 111/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 112/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 113/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 114/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 5.6419e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 115/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 116/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 117/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 118/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 119/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0722 - accuracy: 5.6419e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 120/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 121/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 122/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 123/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 124/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 5.6419e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 125/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 126/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0721 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 127/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 128/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 5.6419e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 129/400
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0721 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 130/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 131/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0721 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 132/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0721 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 133/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0721 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 134/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 135/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0720 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 136/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 5.6419e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 137/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0720 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 138/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 139/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0720 - accuracy: 7.8986e-05 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 140/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 141/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 142/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0720 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 143/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 144/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0719 - accuracy: 5.6419e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 145/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 146/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 147/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 148/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 7.8986e-05 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 149/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 150/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 151/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0719 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 152/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 153/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 154/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 155/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 156/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 157/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 158/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0719 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 159/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 160/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 161/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 162/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 163/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 164/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 165/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0719 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 166/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 167/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 168/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 169/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 170/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 5.6419e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 171/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 172/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 173/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 5.6419e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 174/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 175/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 176/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0718 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 177/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 178/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 179/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 180/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0717 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 181/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 182/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0718 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 183/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 184/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 5.6419e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 185/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 186/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 1.0154e-04
# Epoch 187/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 188/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 189/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 190/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 191/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0718 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 192/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 1.2412e-04 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 193/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0717 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 194/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 195/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 196/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 197/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 198/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 199/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 200/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 5.6419e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 201/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 4.5135e-05 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 202/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0718 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 203/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 7.8986e-05 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 204/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 1.0155e-04 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 205/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 206/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 207/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0716 - accuracy: 5.6419e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 208/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 209/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 210/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 211/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0717 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 212/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 213/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 214/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0717 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 215/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 216/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 217/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 218/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 1.0155e-04 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 219/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 220/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 221/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0716 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 222/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0716 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 223/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 224/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 9.0270e-05 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 225/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 226/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 227/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 228/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 229/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 230/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 231/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 232/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0716 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 233/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 234/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 235/400
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0716 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 236/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 237/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 1.0155e-04 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 238/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 239/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 240/400
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0715 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 241/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 4.5135e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 242/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 243/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 1.1284e-04 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 244/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 245/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 246/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 247/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 248/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 249/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 6.7703e-05 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 250/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 251/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 252/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0715 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 253/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 254/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 255/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 256/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 257/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 258/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 259/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 1.0154e-04
# Epoch 260/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 261/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 262/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 263/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 264/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0715 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 265/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0714 - accuracy: 5.6419e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 266/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0714 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 267/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0714 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 268/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0715 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 269/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 270/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0714 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 271/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 272/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0714 - accuracy: 1.0155e-04 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 273/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 274/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 275/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 276/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 1.0155e-04 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 277/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 1.0155e-04 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 278/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 279/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 1.0155e-04 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 280/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 281/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 282/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 283/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 1.1284e-04 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 284/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 285/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 286/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 287/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 1.0155e-04 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 288/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 289/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 290/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 291/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 292/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 1.1284e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 293/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 294/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 295/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 296/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 297/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 298/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 299/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 1.0155e-04 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 300/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0713 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 301/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 302/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 5.6419e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 303/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 304/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 305/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 306/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 307/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 308/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0713 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 309/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 310/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 311/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 312/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 313/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 314/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 315/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 1.0155e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 316/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 317/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 318/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 319/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 320/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 321/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0713 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 322/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0714 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 323/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 324/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0713 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 325/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 326/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 327/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 328/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 5.6419e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 329/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 330/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0713 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 331/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 332/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 333/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 334/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 1.1284e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 335/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 336/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 337/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 338/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 339/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 4.5135e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 340/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 341/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 342/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 343/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 344/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 345/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 346/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 347/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 348/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 349/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 350/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 351/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 352/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 353/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 354/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 1.1284e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 355/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 356/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0711 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 357/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 358/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 359/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 360/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 361/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 362/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 363/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 364/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 365/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 9.0270e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 366/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 1.0154e-04
# Epoch 367/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 1.1284e-04 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 368/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 4.5135e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 369/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 370/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0711 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 371/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 372/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0711 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 373/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 374/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 375/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 376/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 6.7703e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 377/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0710 - accuracy: 1.2412e-04 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 378/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0711 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 379/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0712 - accuracy: 1.0155e-04 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 380/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0710 - accuracy: 6.7703e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 381/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0711 - accuracy: 9.0270e-05 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 382/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0710 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 383/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 384/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 385/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 386/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 387/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 388/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0711 - accuracy: 7.8986e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 389/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 9.0270e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 390/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 9.0270e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 391/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 392/400
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0711 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 393/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 9.0270e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 394/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0710 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 395/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 396/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 1.0155e-04 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 397/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 398/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0710 - accuracy: 6.7703e-05 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 399/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0710 - accuracy: 7.8986e-05 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 400/400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 7.8986e-05 - val_loss: 0.0739 - val_accuracy: 0.0000e+00

# %% [markdown]
# ##### 結果

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.plot(history.history['val_loss'][1:])
plt.plot(history.history['loss'][1:])

# %%
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.plot(history.history['val_accuracy'][1:])
plt.plot(history.history['accuracy'][1:])

# %% [markdown]
# #### lightgbm Model

# %%
##############################################　　　自己加入的　　　##############################################
import lightgbm as lgb

cf = lgb.LGBMRegressor(n_estimators=5000)

print('---cf.fit---')
print(cf.fit(*train))
print('---cf.score---')
print(cf.score(*test))
print('---predict---')
print(cf.predict(test[0]))
# Out:
# ---cf.fit---
# LGBMRegressor(n_estimators=5000)
# ---cf.score---
# -0.2423853773129383
# ---predict---
# [0.17473493 0.14619246 0.27823067 ... 0.28138076 0.5466134  0.32704003]

# %% [markdown]
# ##### 參數優化_1110

# %%
#import lightgbm

fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [test],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMRegressor(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000) #LGBMClassifier
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

# %%
gs.fit(*train, **fit_params)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.551637
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.515378
# Early stopping, best iteration is:
# [81]	valid's auc: 0.51825
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.577413
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [60]	valid's auc: 0.553905
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.510085
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.576216
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.54313
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.519468
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.591512
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549105
# Early stopping, best iteration is:
# [82]	valid's auc: 0.551193
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.515118
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.58085
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.544412
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.51809
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.560608
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [33]	valid's auc: 0.549294
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.523255
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.60171
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547737
# Early stopping, best iteration is:
# [97]	valid's auc: 0.548548
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.516742
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.581949
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.545947
# Early stopping, best iteration is:
# [104]	valid's auc: 0.547547
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.511988
# Early stopping, best iteration is:
# [81]	valid's auc: 0.513548
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.568511
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [48]	valid's auc: 0.551663
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.52545
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.587382
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551186
# Early stopping, best iteration is:
# [80]	valid's auc: 0.552656
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.523796
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.580781
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [58]	valid's auc: 0.552287
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [48]	valid's auc: 0.512065
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.579111
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.551986
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.524396
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.58086
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548294
# Early stopping, best iteration is:
# [74]	valid's auc: 0.551246
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.529359
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.570742
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.542174
# Early stopping, best iteration is:
# [128]	valid's auc: 0.546176
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.520762
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.581966
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548321
# Early stopping, best iteration is:
# [104]	valid's auc: 0.550074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.545768
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.583446
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.554326
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [60]	valid's auc: 0.50867
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.576637
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551165
# Early stopping, best iteration is:
# [112]	valid's auc: 0.552394
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.525654
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.591185
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [39]	valid's auc: 0.549957
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [33]	valid's auc: 0.523066
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.587673
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.546443
# Early stopping, best iteration is:
# [167]	valid's auc: 0.551513
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.51362
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.561535
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.549191
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5156
# Early stopping, best iteration is:
# [103]	valid's auc: 0.515757
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.577181
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.546674
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.516258
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.57793
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.553072
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.544434
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.596348
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.544751
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.518284
# Early stopping, best iteration is:
# [135]	valid's auc: 0.523262
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562599
# Early stopping, best iteration is:
# [109]	valid's auc: 0.562933
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548551
# Early stopping, best iteration is:
# [92]	valid's auc: 0.549686
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.532984
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.591258
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.551758
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.517291
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.579247
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.544101
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.527733
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.591196
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.551161
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.520365
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.583175
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.551869
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.514543
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.576812
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549264
# Early stopping, best iteration is:
# [110]	valid's auc: 0.551008
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.530011
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.596864
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.540494
# Early stopping, best iteration is:
# [73]	valid's auc: 0.542371
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.516657
# Early stopping, best iteration is:
# [78]	valid's auc: 0.519112
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.566588
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [53]	valid's auc: 0.548045
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.517175
# Early stopping, best iteration is:
# [122]	valid's auc: 0.519259
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [48]	valid's auc: 0.563317
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [24]	valid's auc: 0.550344
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.522579
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.583026
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.547595
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.522613
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.578569
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.543946
# Early stopping, best iteration is:
# [146]	valid's auc: 0.547163
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.5128
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.59138
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548589
# Early stopping, best iteration is:
# [124]	valid's auc: 0.551254
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.519864
# Early stopping, best iteration is:
# [111]	valid's auc: 0.521743
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.567882
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.550634
# Early stopping, best iteration is:
# [88]	valid's auc: 0.55291
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.509918
# Early stopping, best iteration is:
# [78]	valid's auc: 0.512836
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.583457
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.548295
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.525258
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.583768
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [36]	valid's auc: 0.543629
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.527941
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.586032
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.553353
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.520442
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.574665
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.550057
# Early stopping, best iteration is:
# [74]	valid's auc: 0.552934
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.526657
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.576767
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [36]	valid's auc: 0.551516
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.511257
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.579652
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.545841
# Early stopping, best iteration is:
# [76]	valid's auc: 0.548094
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.527941
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.586691
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.544748
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.516024
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.563842
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.546768
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.520537
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.580337
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [42]	valid's auc: 0.553833
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.52451
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.595202
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.551869
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [42]	valid's auc: 0.519004
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.5878
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55279
# Early stopping, best iteration is:
# [109]	valid's auc: 0.555111
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.526034
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.579364
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547081
# [200]	valid's auc: 0.553566
# Early stopping, best iteration is:
# [191]	valid's auc: 0.553975
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.520127
# Early stopping, best iteration is:
# [120]	valid's auc: 0.524091
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.571496
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [35]	valid's auc: 0.550447
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.517069
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.579621
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.54452
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.527733
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.585874
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.556886
# Early stopping, best iteration is:
# [107]	valid's auc: 0.558911
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.517547
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.583714
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.552933
# Early stopping, best iteration is:
# [101]	valid's auc: 0.553191
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [36]	valid's auc: 0.51409
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.575879
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.548769
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.522654
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.578559
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.553278
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.513053
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.57647
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551584
# Early stopping, best iteration is:
# [78]	valid's auc: 0.554055
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.532875
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.586191
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.543478
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.518673
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.59138
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551768
# Early stopping, best iteration is:
# [104]	valid's auc: 0.552426
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.520263
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [26]	valid's auc: 0.56451
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548856
# Early stopping, best iteration is:
# [74]	valid's auc: 0.550477
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.53393
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.596818
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [38]	valid's auc: 0.55494
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.541588
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.578407
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548284
# Early stopping, best iteration is:
# [76]	valid's auc: 0.550664
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.513481
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.573578
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.550486
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.516173
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.579822
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.549256
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.545028
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.579678
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.553732
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.514805
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.581416
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.554168
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.527934
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.593055
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.54297
# Early stopping, best iteration is:
# [144]	valid's auc: 0.550135
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.517444
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.609225
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549141
# Early stopping, best iteration is:
# [72]	valid's auc: 0.552878
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.522684
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.573308
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549442
# [200]	valid's auc: 0.555341
# Early stopping, best iteration is:
# [212]	valid's auc: 0.555885
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.51991
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.564369
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [58]	valid's auc: 0.555378
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.526438
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.595073
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.54194
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.513967
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.591114
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.552459
# Early stopping, best iteration is:
# [126]	valid's auc: 0.55456
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.522072
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.615438
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.544374
# Early stopping, best iteration is:
# [111]	valid's auc: 0.549113
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.517198
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.61541
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.546095
# Early stopping, best iteration is:
# [117]	valid's auc: 0.55068
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.517671
# Early stopping, best iteration is:
# [112]	valid's auc: 0.520986
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.565913
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [60]	valid's auc: 0.543032
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.527733
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.591214
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55497
# Early stopping, best iteration is:
# [82]	valid's auc: 0.55698
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.532327
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.592593
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.548689
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.514964
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.566581
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.550284
# Early stopping, best iteration is:
# [85]	valid's auc: 0.553195
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [23]	valid's auc: 0.520594
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.58813
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551337
# Early stopping, best iteration is:
# [90]	valid's auc: 0.555011
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.531448
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.591555
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548854
# Early stopping, best iteration is:
# [164]	valid's auc: 0.550947
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.516015
# Early stopping, best iteration is:
# [111]	valid's auc: 0.518322
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.56736
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.550275
# Early stopping, best iteration is:
# [116]	valid's auc: 0.553913
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.524654
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.581378
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.555492
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.513198
# Early stopping, best iteration is:
# [121]	valid's auc: 0.516119
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.588528
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549121
# [200]	valid's auc: 0.552179
# Early stopping, best iteration is:
# [187]	valid's auc: 0.554187
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.52256
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.580531
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [48]	valid's auc: 0.553934
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.516013
# Early stopping, best iteration is:
# [84]	valid's auc: 0.518221
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.578061
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [27]	valid's auc: 0.553133
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.511743
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.578848
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548003
# Early stopping, best iteration is:
# [89]	valid's auc: 0.551269
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.519965
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.577695
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.54689
# [200]	valid's auc: 0.551195
# Early stopping, best iteration is:
# [206]	valid's auc: 0.551723
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.512736
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.571449
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.550784
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.525844
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.588985
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [38]	valid's auc: 0.549612
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.519472
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.584878
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.551687
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [17]	valid's auc: 0.519292
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.585419
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551699
# Early stopping, best iteration is:
# [84]	valid's auc: 0.553248
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.511447
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.584211
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.556022
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.520192
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.587919
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.553294
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.519095
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.579538
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.553025
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.533767
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.586497
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.543114
# Early stopping, best iteration is:
# [83]	valid's auc: 0.547523
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.54585
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.586104
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547886
# Early stopping, best iteration is:
# [79]	valid's auc: 0.551281
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.544203
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.579686
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549165
# Early stopping, best iteration is:
# [76]	valid's auc: 0.552107
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.527847
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.595376
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.571381
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.514233
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.590316
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549244
# Early stopping, best iteration is:
# [70]	valid's auc: 0.551242
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [24]	valid's auc: 0.518028
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.597527
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [51]	valid's auc: 0.554563
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.519444
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.588421
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.551297
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.516846
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.582837
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.555132
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.523824
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.589418
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.542851
# [200]	valid's auc: 0.548144
# Early stopping, best iteration is:
# [174]	valid's auc: 0.549633
# RandomizedSearchCV(cv=3,
#                    estimator=LGBMRegressor(metric='None', n_estimators=5000,
#                                            n_jobs=4, random_state=314),
#                    n_iter=100,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000022C93F32E48>,
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000022C931606C8>,
#                                         'min_child_weight': [1e-05, 0.001, 0.01,
#                                                              0.1, 1, 10.0,
#                                                              100.0, 1000.0,
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000022C93F3EFC8>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000022C93F326C8>},
#                    random_state=314, scoring='roc_auc', verbose=True)

# %%
print(gs.best_score_)
gs.best_estimator_
# Out:
# 0.5710072060309196
# LGBMRegressor(colsample_bytree=0.5793392441900451, metric='None',
#               min_child_samples=183, min_child_weight=100.0, n_estimators=5000,
#               n_jobs=4, num_leaves=47, random_state=314, reg_alpha=50,
#               reg_lambda=100, subsample=0.5229986208802528)

# %%
#
#gs.best_estimator_
#LGBMClassifier(colsample_bytree=0.6433117836032942, metric='None',
#               min_child_samples=224, min_child_weight=1e-05, n_estimators=5000,
#               n_jobs=4, num_leaves=20, random_state=314, reg_alpha=10,
#               reg_lambda=10, subsample=0.8945613420997809)

# %%
##cf = lgb.LGBMClassifier(boosting_type='gbdt', class_weight=None,
##               colsample_bytree=0.4467801334566121, importance_type='split',
##               learning_rate=0.1, max_depth=-1, metric='None',
##               min_child_samples=107, min_child_weight=1, min_split_gain=0.0,
##               n_estimators=5000, n_jobs=4, num_leaves=43, objective=None,
##               random_state=314, reg_alpha=10, reg_lambda=100, silent=True,
##               subsample=0.40294551048668437, subsample_for_bin=200000,
##               subsample_freq=0)
##
##
##cf.fit(dataset_train[feature_names],dataset_train['return'] > 1.05, **fit_params)
##cf.score(dataset_test[feature_names],dataset_test['return'] > 1.05)
##下面那行調整中

# %%
##原本的上面那行
cf = lgb.LGBMRegressor(colsample_bytree=0.5550517967002531, metric='None',
              min_child_samples=170, n_estimators=5000, n_jobs=4, num_leaves=28,
              random_state=314, reg_alpha=50, reg_lambda=50,
              subsample=0.6173317263225124)

cf.fit(dataset_train[feature_names],dataset_train['return'] > 1.0, **fit_params)
cf.score(dataset_test[feature_names],dataset_test['return'] > 1.0)
# Out:
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.545589
# Early stopping, best iteration is:
# [76]	valid's auc: 0.546683
# -0.011470208601984444

# %%
cf.feature_importances_
# Out:
# array([ 95,  86,  84, 105,  96,  69, 117,  91,  76,  73,  27,  70,  77,
#         73,  50,  79,  51,  64,  75,  68,  50,  28,  24,  57,  36,  30,
#         72,  56,  43,  59,  71])

# %%
feature_imp = pd.DataFrame(zip(cf.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
sns.barplot(x="Value", y="Feature", data=feature_imp)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Feature'>

# %% [raw]
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551389
# Early stopping, best iteration is:
# [89]	valid's auc: 0.553699
# 0.003857956228475623

# %%
#print(cf.fit(*train))

# %%
#import lightgbm as lgb
#gbm = lgb.LGBMClassifier(n_estimators=100, random_state=5, learning_rate=0.01)
#gbm.fit(dataset_train[feature_names], dataset_train['return'] > 1)

# %%
#import tqdm
#
#n = 3
#
#X = []
#y = []
#indexes = []
#dataset_scaled_x = dataset_scaled[feature_names]
#
#for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-n)):
#    X.append(dataset_scaled_x.iloc[i:i+n].values)
#    y.append(dataset_scaled['return'].iloc[i+n-1])
#    indexes.append(dataset_scaled.index[i+n-1])
##dataset_scaled.head()

# %%
#import numpy as np
#X = np.array(X)
#y = np.array(y)

# %%
##import lightgbm as lgb
#cf = lgb.LGBMRegressor(colsample_bytree=0.7740467183023685, metric='None',
#               min_child_samples=395, min_child_weight=0.01, n_estimators=5000,
#               n_jobs=4, num_leaves=9, random_state=314, reg_alpha=5,
#               reg_lambda=10, subsample=0.4643892520208455)
#    
#cf.fit(dataset_train[feature_names].astype(float), dataset_train['rank'])

# %% [markdown]
# #### Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

cf2 = RandomForestRegressor(n_estimators=100)
cf2.fit(dataset_train[feature_names].astype(float), dataset_train[predi_target])
# Out:
# RandomForestRegressor()

# %% [markdown]
# ##### 參數優化_1110

# %%
#from scipy.stats import randint as sp_randint 
#from sklearn.model_selection import RandomizedSearchCV 
## build a classifier 
#cf2 = RandomForestRegressor(n_estimators=100) 
## specify parameters and distributions to sample from 
#param_dist = {"max_depth": [3, None], 
#              "max_features": sp_randint(1, 11), 
#              "min_samples_split": sp_randint(2, 11), 
#              "min_samples_leaf": sp_randint(1, 11), 
#              "bootstrap": [True, False], 
#              "criterion": ["mse", "mae"]} 
## run randomized search 
#n_iter_search = 20 
#rs = RandomizedSearchCV(cf2, param_distributions=param_dist, 
#                                   n_iter=n_iter_search)

# %%
#rs.fit(dataset_train[features], dataset_train['return'] >1)

# %% [markdown]
# ##### Split Train Test dataset

# %%
feature_imp = pd.DataFrame(zip(cf2.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
sns.barplot(x="Value", y="Feature", data=feature_imp)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Feature'>

# %%
select = dataset.index.get_level_values('date') < '2022-03'
dataset_train = dataset[select]
dataset_test = dataset[~select]

# %% [markdown]
# ### Ensemble learning

# %%
dataset_drop = dataset.dropna(subset=feature_names+['return'])

vals = model.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result1'] = pd.Series(vals.swapaxes(0,1)[0], dataset_drop.index)

vals = cf.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result2'] = pd.Series(vals, dataset_drop.index)

vals = cf2.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result3'] = pd.Series(vals, dataset_drop.index)

dataset_drop = dataset_drop.reset_index().set_index("date")
# Out:
# 5185/5185 [==============================] - 5s 883us/step

# %% [markdown]
# ## backtest

# %% [markdown]
# ## 把量加進來做篩選
#  * https://hahow.in/courses/5b9d3a6dca498a001e917383/shapeussions/60c96f5b018697e8a6131cbc

# %%
#把量加進來
vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

vol_filter=vol_ma5>1000
vol_filter=vol_filter[vol_filter].fillna(0)
#vol_filter
t1 = vol_filter

# %%
#condition2

# %%
vol_filter = t1.reindex(every_month, method='ffill')#.loc['2010-02-15']
#vol_filter.loc['2010-02-15']

# %%
#t1 = vol_ma5.iloc[-1].dropna()
#t1.to_csv('./tmp/132.csv')
#t1.hist(bins=10)

# %%
#市值
#t1 = (predi_target >= predi_target.nlargest(20).iloc[-1]) * condition_Filter_v2.astype(float)()

# %%
import math
from tqdm import tqdm

vol = 1000
test_period = '2022-04'

dates = sorted(list(set(dataset_drop.index)))

rs = []
rs_v1 = []
rs_v2 = []
rs_v3 = []

for d in tqdm(dates):
    #print(d)
    dataset_time = dataset_drop.loc[d]
    
    dataset_time = drop_extreme_case(dataset_time , feature_names , thresh=0.01)
    
    #print(dataset_time)
    
    predi_target = dataset_time['result1'] + dataset_time['result2'] + dataset_time['result3'] 
    
    #predi_target = predi_target * (dataset_time['vol_ma5'] >vol).astype(float)
            ###

    
    condition1 = dataset_time['vol_ma5'] > vol
    condition_Filter_v1 = condition1
    predi_target_v1 = predi_target * condition_Filter_v1.astype(float)
    
    condition2 = (1e9 < dataset_time['市值']) < 1e10
    
    condition_Filter_v2 =  condition1 + condition2
    predi_target_v2 = predi_target * condition_Filter_v2.astype(float)
    
    condition_P = (predi_target >= predi_target.nlargest(20).iloc[-1])
    condition_v1 = (predi_target_v1 >= predi_target_v1.nlargest(20).iloc[-1])
    condition_v2 = (predi_target_v2 >= predi_target_v2.nlargest(20).iloc[-1])
    
    predi_target = predi_target * (dataset_time['vol_ma5'] >vol).astype(float)
    condition_v3 = (predi_target >= predi_target.nlargest(20).iloc[-1]) & condition_Filter_v2 #.astype(float)
    
    #print(vol_filter.loc[d])
    #print(condition)
    
    r = dataset_time['return'][condition_P].mean()
    rs.append(r * (1-3/1000-1.425/1000*2*0.6))
    
    r_v1 = dataset_time['return'][condition_v1].mean()
    rs_v1.append(r_v1 * (1-3/1000-1.425/1000*2*0.6))    
    
    r_v2 = dataset_time['return'][condition_v2].mean()
    rs_v2.append(r_v2 * (1-3/1000-1.425/1000*2*0.6))    

    r_v3 = dataset_time['return'][condition_v3].mean()
    rs_v3.append(r_v3 * (1-3/1000-1.425/1000*2*0.6))    
        
rs = pd.Series(rs, index=dates)[test_period:].cumprod()
rs_v1 = pd.Series(rs_v1, index=dates)[test_period:].cumprod() #*
rs_v2 = pd.Series(rs_v2, index=dates)[test_period:].cumprod() #*
rs_v3 = pd.Series(rs_v3, index=dates)[test_period:].cumprod() #*

s0050 = close['0050'][test_period:]

pd.DataFrame({'nn strategy return':rs.reindex(s0050.index, method='ffill'),
              'nn strategy return_V1(vol>100)':rs_v1.reindex(s0050.index, method='ffill'),
              #'nn strategy return_V2(vol+market cap)':rs_v2.reindex(s0050.index, method='ffill'),
              #'nn strategy return_V3(vol+market cap)':rs_v3.reindex(s0050.index, method='ffill'),
              '0050 return':s0050/s0050[0]
             }).plot()



import winsound
frequency = 2000
duration = 100
winsound.Beep(frequency, duration)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 159/159 [00:07<00:00, 20.10it/s]

# %%
#import pickle
#
#return_history_1026 = pd.Series(rs, index=dates)['2021':].cumprod()
##eq = (gain[hold == 1].mean(axis=1)).fillna(1).cumprod()
#
#pickle.dump(rs, open('return_history_1026.pkl', 'wb'))

# %%
#import pyfolio as pf
#import pandas as pd
#
#close.index = close.index.tz_localize("Asia/Taipei")
##pf.create_returns_tear_sheet(close['0050'].pct_change())
#
## 得到 上一個單元的 回測結果
#ret = pickle.load(open("return_history_1026.pkl", "rb"))
#
## 將回測報酬率取出來
#ret = ret.pct_change().dropna()
#ret.index = pd.to_datetime(ret.index).tz_localize('Asia/Taipei')
#
## 利用pyfolio 比較報酬率
#pf.create_returns_tear_sheet(ret, benchmark_rets=close['0050'].pct_change())

# %% [markdown]
# ### 當月持股狀況

# %%
# get the latest dataset
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()


last_dataset = drop_extreme_case(last_dataset, feature_names , thresh=0.01)
t1 = last_dataset

# remove NaN testcases
last_dataset = last_dataset.dropna(subset=feature_names)

# predict

vals = model.predict(last_dataset[feature_names].astype(float))
last_dataset['result1'] = pd.Series(vals.swapaxes(0,1)[0], last_dataset.index)

vals = cf.predict(last_dataset[feature_names].astype(float))
last_dataset['result2'] = pd.Series(vals, last_dataset.index)

vals = cf2.predict(last_dataset[feature_names].astype(float))
last_dataset['result3'] = pd.Series(vals, last_dataset.index)


# calculate score

predi_target = last_dataset['result1'] + last_dataset['result2'] + last_dataset['result3']

#
##predi_target = predi_target * vol_filter.iloc[-1] #******加上量的濾網


predi_target = predi_target * (last_dataset['vol_ma5'] >vol).astype(float)  #排除平均成交量小於MA1000張
#predi_target = predi_target * (last_dataset['市值'] < 1e10).astype(float)   #排除市值小於100億以下的股票

condition0 = (predi_target >= predi_target.nlargest(20).iloc[-1])
condition1 = last_dataset['vol_ma5'] >vol
condition2 = last_dataset['市值'] < 1e10

condition = condition0 & condition1 #& condition2

#vol_filter

# plot rank distribution
predi_target[predi_target!=0].hist(bins=20)


# show the best 20 stocks
slist1 = predi_target[condition].reset_index()['stock_id']

#https://keras-cn.readthedocs.io/en/latest/models/model/
# Out:
# 35/35 [==============================] - 0s 872us/step

# %%
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()

# %%
#rank.sort_values(ascending=False).head(20)

# %% [markdown]
# ## 平均分配資產於股票之中

# %%
close = data.get("收盤價")

money = 150000
stock_prices = close[slist1].iloc[-1]


print("股票平分張數:")
money / len(stock_prices) / stock_prices / 1000
# Out:
# 股票平分張數:
# stock_id
# 1102    0.170648
# 1104    0.276243
# 1434    0.267380
# 1904    0.231839
# 2027    0.172811
# 2535    0.249169
# 2801    0.428571
# 2812    0.535714
# 2834    0.541516
# 2885    0.334821
# 2887    0.438596
# 2890    0.450450
# 2892    0.278810
# 3264    0.141509
# 3558    0.027125
# 4566    0.114155
# 5457    0.138632
# 6196    0.059524
# 9904    0.238095
# 9939    0.076531
# Name: 2023-04-25 00:00:00, dtype: float64

# %%
last_dataset['市值'][slist1]
# Out:
# stock_id  date
# 1102      2023-04-15    1.547797e+11
# 1104      2023-04-15    1.741869e+10
# 1434      2023-04-15    4.767601e+10
# 1904      2023-04-15    3.197372e+10
# 2027      2023-04-15    9.199477e+10
# 2535      2023-04-15    1.144105e+10
# 2801      2023-04-15             NaN
# 2812      2023-04-15    6.743107e+10
# 2834      2023-04-15             NaN
# 2885      2023-04-15    2.831603e+11
# 2887      2023-04-15    2.190766e+11
# 2890      2023-04-15    1.923856e+11
# 2892      2023-04-15             NaN
# 3264      2023-04-15    2.813576e+10
# 3558      2023-04-15    1.542965e+10
# 4566      2023-04-15    3.981809e+09
# 5457      2023-04-15    9.909243e+09
# 6196      2023-04-15    2.613243e+10
# 9904      2023-04-15    9.444453e+10
# 9939      2023-04-15    2.906638e+10
# Name: 市值, dtype: float64

# %%
last_dataset['vol_ma5'][slist1]
# Out:
# stock_id  date
# 1102      2023-04-15     4043.0210
# 1104      2023-04-15     1602.2104
# 1434      2023-04-15     1082.3094
# 1904      2023-04-15     1027.4636
# 2027      2023-04-15     7675.6376
# 2535      2023-04-15     1553.8228
# 2801      2023-04-15     7472.2320
# 2812      2023-04-15     5578.7066
# 2834      2023-04-15    23671.2020
# 2885      2023-04-15    10836.3704
# 2887      2023-04-15    11356.2252
# 2890      2023-04-15    15040.0400
# 2892      2023-04-15     8417.1734
# 3264      2023-04-15     3894.1770
# 3558      2023-04-15     4315.3446
# 4566      2023-04-15     1064.4334
# 5457      2023-04-15     1102.0402
# 6196      2023-04-15     1060.5542
# 9904      2023-04-15     6641.1518
# 9939      2023-04-15     1035.9020
# Name: vol_ma5, dtype: float64

# %% [markdown]
# ###################################################################################################
# ## 移動窗格最佳化
# [有空來試試看連結](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/61b4c90147843d0006cf2593https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/61b4c90147843d0006cf2593)
# ###################################################################################################

# %%
import lightgbm as lgb

from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt

import numpy as np

# %matplotlib inline

def select(df):

    rank = df['pre']

    condition1 = (rank >= rank.nlargest(1).iloc[-1])

    return df['return'][condition1].mean() * (1-3/1000-1.425/1000*2*0.6)

end = 5

cf = lgb.LGBMRegressor(n_estimators=500)



train_time = ['2015','2016','2017','2018','2019']

s_time = ['2007','2008','2009','2010','2011']

test_time = ['2016','2017','2018','2019','2020']

#dataset_copy = dataset_dropna.copy()

store_mse = []


for time in range(end):

    print('%d 次執行中'%(time))

    dataset_dropna2_train = dataset_copy.loc[s_time[time]:train_time[time]] #2007~ 2015   2008~2016   2009~2017  2010~2018  ....

    dataset_dropna2_test = dataset_copy.loc[test_time[time]:test_time[time]]#            2016                2017               2018              2019  .....

    
 cf.fit(dataset_dropna2_train[feature_names].astype(float), dataset_dropna2_train['rank'])

    
 predict = cf.predict(dataset_dropna2_test[feature_names])

    dataset_dropna2_test['pre'] = predict

dates = dataset_dropna2_test.index.get_level_values('date')

b = dataset_dropna2_test.groupby(dates).apply(select).cumprod()

s0050 = close['0050'][test_time[time]:test_time[time]]

s0056 = close['0056'][test_time[time]:test_time[time]]

pd.DataFrame({'Best 1 stocks return(include handling fee)':b.reindex(s0050.index, method='ffill'), 

              '0050':s0050/s0050[0],'0056':s0056/s0056[0]}).plot()

plt.ylabel('return')
# Out:
#   File "<tokenize>", line 45
#     cf.fit(dataset_dropna2_train[feature_names].astype(float), dataset_dropna2_train['rank'])
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def mystrategy(data):

    close = data.get("收盤價", 120)

    vol = data.get('成交股數', 120)
 

    condition1 = close.max() / close.min()

    rev = data.get("當月營收", 14)

    condition2 = (rev.iloc[-1] / rev.iloc[-13])

    condition3 = (rev.iloc[-2] / rev.iloc[-14])

    稅後淨利 = data.get('本期淨利（淨損）', 5)

    # 股東權益，有兩個名稱，有些公司叫做權益總計，有些叫做權益總額，所以得把它們抓出來

    權益總計 = data.get('權益總計', 5)

    權益總額 = data.get('權益總額', 5)

    # 並且把它們合併起來

    權益總計.fillna(權益總額, inplace=True)

    roe = 稅後淨利 / 權益總計

    condition4 = roe.iloc[-1] / roe.iloc[-5]

    select_stock = (condition1.rank() + # 該數值越小越好

    condition2.rank(ascending=False) + # 該值越大越好 

    condition3.rank(ascending=False) + # 該值越大越好

    condition4.rank(ascending=False) # 該值越大越好 

    ).rank() <= 10
    
    df=select_stock[select_stock]
    vol=vol[df.index].iloc[-1]
    cond_vol=vol>(1000*1000)

    return cond_vol[cond_vol]

# %%
stocks = mystrategy(data)
stocks

# %%
    權益總計 = data.get('權益總計', 5)

    權益總額 = data.get('權益總額', 5)

    # 並且把它們合併起來

    權益總計.fillna(權益總額, inplace=True)

# %%
權益總計

# %%
close = data.get("收盤價", 120)
vol = data.get('成交股數', 120)
condition1 = close.max() / close.min()
rev = data.get("當月營收", 14)
condition2 = (rev.iloc[-1] / rev.iloc[-13])
condition3 = (rev.iloc[-2] / rev.iloc[-14])
稅後淨利 = data.get('本期淨利（淨損）', 5)
# 股東權益，有兩個名稱，有些公司叫做權益總計，有些叫做權益總額，所以得把它們抓出來
權益總計 = data.get('權益總計', 5)
權益總額 = data.get('權益總額', 5)
# 並且把它們合併起來
權益總計.fillna(權益總額, inplace=True)
roe = 稅後淨利 / 權益總計
condition4 = roe.iloc[-1] / roe.iloc[-5]
select_stock = (condition1.rank() + # 該數值越小越好
condition2.rank(ascending=False) + # 該值越大越好 
condition3.rank(ascending=False) + # 該值越大越好
condition4.rank(ascending=False) # 該值越大越好 
).rank() <= 10
df=select_stock[select_stock]
vol=vol[df.index].iloc[-1]
cond_vol=vol>(1000*1000)

# %%
condition4
