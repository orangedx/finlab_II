# %% [markdown]
# # Random Forest Classifier

# %% [markdown]
# ## Get dataset

# %%
import finlab.ml as ml

dataset = ml.fundamental_features()

print(dataset.shape)
dataset = dataset.dropna(thresh=int(len(dataset)*0.5), axis=1).dropna(how='any')
print(dataset.shape)

# %% [markdown]
# ## Add labels

# %%
feature_names = list(dataset.columns)

# %%
ml.add_profit_prediction(dataset)
dataset.head()
# Out:
# D:\Finlab\AI選股策略\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
# D:\Finlab\AI選股策略\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
# D:\Finlab\AI選股策略\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
# D:\Finlab\AI選股策略\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
#                      T3395營業利益  T7210營運現金流  T3950歸屬母公司淨利    T7211折舊  \
# stock_id date
# 1101     2014-05-15  3684224.0   6895832.0     4015175.0  1594505.0
#          2014-08-14  5938317.0   4452573.0     -754894.0  1573692.0
#          2014-11-14  5544164.0   3701961.0     3621052.0  1587492.0
#          2015-03-31  4690964.0   4936554.0     6459366.0  1575810.0
#          2015-05-15  1693508.0   5654152.0      349121.0  1711428.0
#
#                       T0100流動資產   T1100流動負債  T7324取得不動產廠房及設備  T3970經常稅後淨利  \
# stock_id date
# 1101     2014-05-15  92121458.0  74388787.0        -940633.0    2791235.0
#          2014-08-14  89163129.0  81190613.0        -465009.0    4828695.0
#          2014-11-14  89472928.0  78920574.0        -911057.0    4934486.0
#          2015-03-31  96605816.0  68632044.0       -1384489.0    4029460.0
#          2015-05-15  92471096.0  69579858.0        -818460.0     974518.0
#
#                      R101_ROA稅後息前  R11V_ROA綜合損益  ...   R501_流動比率   R502_速動比率  \
# stock_id date                                    ...
# 1101     2014-05-15     -1.732411      1.630076  ...  123.837828  101.776758
#          2014-08-14     -0.952778      0.152556  ...  109.819505   91.450337
#          2014-11-14     -0.948101      2.168353  ...  113.370853   93.976558
#          2015-03-31     -1.265106      3.002608  ...  140.759054  117.966121
#          2015-05-15     -2.315297      0.069454  ...  132.899231  109.303861
#
#                      R503_利息支出率   R678_營運資金  R607_總資產週轉次數  R610_存貨週轉率  \
# stock_id date
# 1101     2014-05-15   -9.792979  17732671.0      0.093998    2.191306
#          2014-08-14  -17.435186   7972516.0      0.112552    2.381079
#          2014-11-14  -17.800651  10552354.0      0.106864    2.306032
#          2015-03-31  -13.169666  27973772.0      0.103034    2.268994
#          2015-05-15   -7.153186  22891238.0      0.073611    1.817298
#
#                      R612_固定資產週轉次數  R613_淨值週轉率次  R69B_自由現金流量    return
# stock_id date
# 1101     2014-05-15       0.245688     0.171327    4901868.0  1.073347
#          2014-08-14       0.297377     0.208493   16542181.0  0.984816
#          2014-11-14       0.282283     0.200028    4768224.0  0.969163
#          2015-03-31       0.275197     0.187942  -10525322.0  0.956818
#          2015-05-15       0.195713     0.132250    8494249.0  0.850077
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Split Train Test dataset

# %%
date_arr = dataset.index.get_level_values('date') < '2021'
dataset_train = dataset[date_arr]
dataset_test = dataset[~date_arr]

# %% [markdown]
# ## Training

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

cf = RandomForestClassifier(n_estimators=100)

train = dataset_train[feature_names] , dataset_train['return'] > 1.5 
test = dataset_test[feature_names] , dataset_test['return'] > 1 

cf.fit(*train)
cf.score(*test)
cf.predict(test[0])
# Out:
# array([False, False, False, ..., False, False, False])

# %%
cf.score(*test)
# Out:
# 0.6315265329349836

# %% [markdown]
# ### Xgboost

# %%
import xgboost
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

cf_xgb = xgboost.XGBClassifier()
cf_xgb.fit(*train)
cf_xgb.score(*test)
# Out:
# C:\Users\User\.conda\envs\finlab\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:10:36] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.6309574619433774

# %% [markdown]
# ### lightgbm

# %%
import lightgbm

fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [test],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 500

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

gs.fit(*train, **fit_params)
# Out:
# Fitting 3 folds for each of 1000 candidates, totalling 3000 fits
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.542653
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.530333
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [27]	valid's auc: 0.531439
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.544082
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.529711
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [26]	valid's auc: 0.537039
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.527103
# Early stopping, best iteration is:
# [84]	valid's auc: 0.527103
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551128
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.534251
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.535471
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.543844
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.523162
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.526329
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.551255
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.528565
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.54397
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552932
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.532208
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.544822
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552542
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.532949
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.54821
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547864
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.533909
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549794
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.560365
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.527377
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552648
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.54689
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.520991
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550373
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.548803
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550552
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.545748
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.554917
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.537265
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546488
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.55135
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.533979
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.536505
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.560425
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.539862
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55837
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.528799
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.521299
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.526165
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.526475
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.517661
# Early stopping, best iteration is:
# [129]	valid's auc: 0.517676
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.520429
# Early stopping, best iteration is:
# [121]	valid's auc: 0.520442
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.541998
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.526746
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.531508
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.553825
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.533771
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553593
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546458
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.523901
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [17]	valid's auc: 0.533963
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555177
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.536129
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.538304
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556945
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.53811
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.540559
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.555088
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.537843
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558655
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.55568
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.53748
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555754
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557492
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.528242
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.540179
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.549801
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.526796
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.530206
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.561068
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548248
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.559295
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553915
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.532042
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [31]	valid's auc: 0.533339
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.548335
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.529865
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548327
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.553654
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.533797
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55282
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.551738
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.529153
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.530598
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.538236
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.525372
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.523472
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550233
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.534117
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.554255
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556239
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.54098
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558739
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552222
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.531161
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.548221
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.54686
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.531782
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.545158
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.551709
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [35]	valid's auc: 0.526902
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [18]	valid's auc: 0.531994
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.543278
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.530273
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [48]	valid's auc: 0.530066
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.55176
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.527539
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.530992
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.549211
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.532011
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556761
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.543378
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.521109
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55022
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553625
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.542047
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557291
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.548532
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.521593
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [20]	valid's auc: 0.532531
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.551649
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.535408
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552486
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.541513
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.521106
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.524244
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548431
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.531553
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.534548
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556521
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.534761
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556297
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.548826
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.529689
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.531124
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.557573
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.53714
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553504
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55685
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.535616
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.539611
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.551082
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.539115
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.545714
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.556113
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.541357
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558226
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.558407
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.534714
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.554386
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55416
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.540325
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556279
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.561438
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.54706
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55837
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556023
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.541685
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.541875
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.56306
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552394
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55837
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.544936
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [21]	valid's auc: 0.531389
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [27]	valid's auc: 0.536043
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550955
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.528918
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.533111
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551625
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.539837
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.54333
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.549039
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.537066
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.534263
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.560063
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.532939
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [16]	valid's auc: 0.534172
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.556309
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.525449
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.528353
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.54857
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.533153
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.536671
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.549788
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.527897
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.525763
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.548018
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.516187
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.546187
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.56006
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.544954
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549029
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555323
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.532535
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.54485
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.559523
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549213
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546846
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553162
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.524167
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.562526
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.550349
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.522854
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553046
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.56469
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.542127
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558514
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556007
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547807
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.54243
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557573
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.535695
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55281
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.546721
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [26]	valid's auc: 0.519127
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.528688
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.542796
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.517356
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.534423
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556723
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.536389
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.561402
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.520462
# Early stopping, best iteration is:
# [120]	valid's auc: 0.520697
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.555109
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.525946
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.542176
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.546612
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.529941
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553574
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.56469
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.542127
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557603
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.559222
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.524121
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.529044
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.548892
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.532952
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558664
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.548529
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [31]	valid's auc: 0.527647
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.53269
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546534
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.519799
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.53687
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552747
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.535548
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.536977
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.542928
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.527791
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.53259
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.555064
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.535764
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557363
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.526496
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.517253
# Early stopping, best iteration is:
# [129]	valid's auc: 0.517282
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.520951
# Early stopping, best iteration is:
# [95]	valid's auc: 0.520967
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.551046
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.534624
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547128
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.550469
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.529727
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [24]	valid's auc: 0.53196
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.537405
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.530853
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.539558
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555658
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.542914
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55028
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.539848
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.528481
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.531391
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.554502
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.531619
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548151
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.548298
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.539168
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.53136
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555024
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.537781
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558494
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.550314
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.527176
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.530594
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.551848
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.52876
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553165
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553679
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.543334
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548169
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# ...
# [3]	valid's auc: 0.547285
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.547266
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.516017
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.545923
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.540639
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.531588
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.538795
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.526302
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.522682
# Early stopping, best iteration is:
# [129]	valid's auc: 0.522764
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.520168
# Early stopping, best iteration is:
# [75]	valid's auc: 0.520209
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [51]	valid's auc: 0.528555
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.520783
# Early stopping, best iteration is:
# [92]	valid's auc: 0.520798
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5206
# Early stopping, best iteration is:
# [100]	valid's auc: 0.5206
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549486
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.522249
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.527507
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.558348
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.524765
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.537489
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.554982
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.538797
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546085
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.543396
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.531887
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [27]	valid's auc: 0.536135
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552112
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.531047
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.541799
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555729
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.533568
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.538363
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.543086
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.511885
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.537113
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.551237
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.531084
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548345
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548628
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.528596
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.545309
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.549799
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.527956
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.53659
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550887
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.519343
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.538359
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553016
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.539671
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553774
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555234
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.542236
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549613
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.540396
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.534592
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.535828
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.552337
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.540743
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.543985
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.56011
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.540851
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547285
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548747
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.532075
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552369
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547291
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.533551
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.542197
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.544017
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.532137
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.53307
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.55405
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [35]	valid's auc: 0.527133
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [33]	valid's auc: 0.532372
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555567
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.537745
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.537727
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.546431
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.526563
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [16]	valid's auc: 0.529183
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.54459
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [17]	valid's auc: 0.528575
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [23]	valid's auc: 0.531595
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.554867
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.540617
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.541622
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551861
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.518223
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.524878
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.546948
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.528304
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.529208
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.56006
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.547231
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549837
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.5472
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.519798
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.524722
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.540962
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.528418
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.538283
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.56011

# %%
gs.best_estimator_
# Out:
# {'colsample_bytree': 0.9442008821254966,
#  'min_child_samples': 248,
#  'min_child_weight': 0.1,
#  'num_leaves': 9,
#  'reg_alpha': 10,
#  'reg_lambda': 1,
#  'subsample': 0.557608335163303}

# %%
cf_lgbm = lightgbm.LGBMClassifier(colsample_bytree=0.9442008821254966, metric='None',
               min_child_samples=248, min_child_weight=0.1, n_estimators=5000,
               n_jobs=4, num_leaves=9, random_state=314, reg_alpha=10,
               reg_lambda=1, subsample=0.557608335163303)

        #(boosting_type='gbdt', class_weight=None,
        #colsample_bytree=0.7792703648870174, importance_type='split',
        #learning_rate=0.1, max_depth=-1, metric='None',
        #min_child_samples=344, min_child_weight=0.01, min_split_gain=0.0,
        #n_estimators=5000, n_jobs=4, num_leaves=10, objective=None,
        #random_state=314, reg_alpha=0, reg_lambda=10, silent=True,
        #subsample=0.8503048560728566, subsample_for_bin=200000,
        #subsample_freq=0)

cf_lgbm.fit(dataset_train[feature_names],dataset_train['return'] > 1.5, **fit_params)
cf_lgbm.score(dataset_test[feature_names],dataset_test['return'] > 1)
# Out:
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.537773
# 0.6315265329349836

# %% [markdown]
# ## Prediction

# %%
prediction = gs.predict_proba(test[0])
#prediction = cf_lgbm.predict_proba(test[0])

prediction = prediction.swapaxes(0,1)[1]
prediction
# Out:
# array([0.01959998, 0.01959998, 0.01959998, ..., 0.03289643, 0.03512988,
#        0.03512988])

# %% [markdown]
# ## Backtest

# %%
#from PIL import Image, ImageOps, ImageEnhance, __version__ as PILLOW_VERSION
#from pylab import rcParams


# %matplotlib inline
returns = dataset_test['return'][prediction > 0.5]
dates = returns.index.get_level_values("date")
returns.groupby(dates).mean().cumprod().plot(color='red')

returns = dataset_test['return'][prediction < 0.5]
dates = returns.index.get_level_values("date")
returns.groupby(dates).mean().cumprod().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# from pylab import rcParams
