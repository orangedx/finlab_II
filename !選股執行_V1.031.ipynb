# %% [markdown]
# # Final Project

# %%
# 移除不必要的警告
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 獲取歷史資料

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.gpu_device_name())
print(tf.config.experimental.set_visible_devices)
print('GPU:', tf.config.list_physical_devices('GPU'))
print('CPU:', tf.config.list_physical_devices(device_type='CPU'))
print(tf.config.list_physical_devices('GPU'))
print(tf.test.is_gpu_available()) # 输出可用的GPU数量
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU'))) # 查询GPU设备
# Out:
# 2023-06-18 15:30:47.857877: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-18 15:30:47.959321: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-18 15:30:47.959339: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-06-18 15:30:48.517964: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-18 15:30:48.518051: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-18 15:30:48.518059: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2.11.0
#
# <function set_visible_devices at 0x7f77fcdbc320>
# GPU: []
# CPU: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# []
# WARNING:tensorflow:From /tmp/ipykernel_66907/182153768.py:8: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False
# Num GPUs Available:  0
# 2023-06-18 15:30:49.206849: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-18 15:30:49.290542: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-18 15:30:49.290876: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-18 15:30:49.291184: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-18 15:30:49.291238: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-06-18 15:30:49.291283: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-06-18 15:30:49.291324: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-06-18 15:30:49.321636: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-06-18 15:30:49.321706: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-06-18 15:30:49.321717: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-06-18 15:30:49.322192: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-18 15:30:49.322514: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-18 15:30:49.322754: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-06-18 15:30:49.323600: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-18 15:30:49.323887: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-18 15:30:49.324120: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
from finlab.data import Data
#from finlab.ml import fundamental_features
#fdf = fundamental_features()

data = Data()

close = data.get("收盤價")
open_ = data.get("開盤價")
high = data.get("最高價")
low = data.get("最低價")
vol = data.get("成交股數")

PB = data.get("股價淨值比")
pe = data.get("本益比")
DY = data.get("殖利率(%)")

#bi = data.get("營業利益")


#close = data.get_adj("收盤價").round(2)

#財務指標
rev = data.get("當月營收")
l_rev = data.get("去年當月營收")

#t123 = data.get('土地')

#bargin_i=data.get("投信買賣超股數")/data.get("成交股數")
#bargin_f=data.get("外資自營商買賣超股數")/data.get("成交股數")
#bargin_s=data.get("自營商買賣超股數(自行買賣)")/data.get("成交股數")
#

vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

rev.index = rev.index.shift(5, "d")         #每月頻率
#周頻率

# %% [markdown]
# ### 計算features

# %%
#MFI  = data.talib("MFI")
##MFI.tail()
#ub,mb,lb =data.talib("BBANDS")

# %% [markdown]
# #### 營收相關

# %%
##############################################　　　自己加入的　　　##############################################
import pandas as pd
import numpy as np

from finlab.__init__ import talib_all_stock
from talib import abstract

# %%
def bias(n):
    return close / close.rolling(n, min_periods=1).mean()

def acc(n):
    return close.shift(n) / (close.shift(2*n) + close) * 2

def rsv(n):
    l = close.rolling(n, min_periods=1).min() 
    h = close.rolling(n, min_periods=1).max()
    
    return (close - l) / (h - l)

def mom(n):
    return (rev / rev.shift(1)).shift(n)

#def yoy(n):
#    return (rev.shift(n) / rev.shift(12+n)) -
def yoy(n):
    denominator = rev.shift(12 + n)
    result = rev.shift(n) / denominator - 1
    result[denominator < 0] = 0  # 如果分母为负，将对应的结果设置为0
    return result

def delta_yoy(n):
    yoy_current = yoy(n)
    yoy_previous = yoy(n + 1)
    delta = yoy_current - yoy_previous
    return delta


# 均線
def ma(n):
    return close.rolling(n).mean()

# 標準差
def std(n):
    return close.rolling(n).std()

# 相對強弱指標（RSI）
def rsi(n):
    diff = close.diff()
    up = diff.where(diff > 0, 0)
    down = -diff.where(diff < 0, 0)
    avg_gain = up.rolling(n).mean()
    avg_loss = down.rolling(n).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# 隨機指標（KD）
def kd(n):
    l = close.rolling(n).min()
    h = close.rolling(n).max()
    rsv = (close - l) / (h - l)
    k = rsv.rolling(3).mean()
    d = k.rolling(3).mean()
    return k - d

# 量能指標（OBV）
def obv():
    obv = pd.Series(0, index=close.index)
    obv[close > close.shift()] = vol[close > close.shift()]
    obv[close < close.shift()] = -vol[close < close.shift()]
    obv = obv.cumsum()
    return obv

def oscillator(n):
    return (close - close.rolling(n).mean()) / close.rolling(n).std()

def variance(n):
    return close.rolling(n).var()

# %%
def atr(n):
    tr = high - low
    tr = tr.fillna(0)  # 处理缺失值，将NaN替换为0
    atr = tr.rolling(n, min_periods=1).mean()
    return atr
    
def willr(n):
    highest_high = high.rolling(n, min_periods=1).max()
    lowest_low = low.rolling(n, min_periods=1).min()
    willr = (highest_high - close) / (highest_high - lowest_low) * -100
    return willr

def cci(n):
    typical_price = (high + low + close) / 3
    mean_typical_price = typical_price.rolling(n, min_periods=1).mean()
    mean_deviation = (typical_price - mean_typical_price).abs().rolling(n, min_periods=1).mean()
    cci = (typical_price - mean_typical_price) / (0.015 * mean_deviation)
    return cci

def linearreg_slope(n):
    slope = (close - close.shift(n)) / n
    return slope

def cdp(n):
    typical_price = (high + low + close) / 3
    pivot_point = (high + low + close) / 3
    previous_day_high = high.shift(1)
    previous_day_low = low.shift(1)
    
    hlr = pivot_point - previous_day_low
    hhr = previous_day_high - pivot_point
    
    cdp = (pivot_point + previous_day_high + previous_day_low + close) / 4
    ah = cdp + hhr
    nh = cdp * 2 - previous_day_low
    nl = cdp * 2 - previous_day_high
    al = cdp - hlr
    
    return cdp, ah, nh, nl, al
    
def tsf(n):
    forecast_period = n
    forecast = close.rolling(n).apply(lambda x: np.polyfit(np.arange(len(x)), x, deg=1)[1] + np.polyfit(np.arange(len(x)), x, deg=1)[0] * len(x))
    return forecast.shift(-forecast_period)

# %%
features = {
#    'mom{}'.format(n): mom(n) for n in range(1, 10)
}

features.update({
    'bias_{}'.format(n): bias(n) for n in [5, 10, 20, 60, 120, 240]
})

features.update({
    'acc_{}'.format(n): acc(n) for n in [5, 10, 20, 60, 120, 240]
})

features.update({
    'rsv_{}'.format(n): rsv(n) for n in [5, 10, 20, 60, 120, 240]
})

#features.update({
#    'PB': PB,
#    'PE': pe,
#    'DY': DY
#})

features.update({
    'yoy_{}'.format(n): yoy(n) for n in range(0, 5)
})

features.update({
    'delta_yoy_{}'.format(n): delta_yoy(n) for n in range(0, 5)
})

features.update({
    'atr_{}'.format(n): atr(n) for n in [10, 14, 20]
})

features.update({
    'willr_{}'.format(n): willr(n) for n in [14, 20, 30]
})

#features.update({
#    'cci_{}'.format(n): cci(n) for n in [20, 30, 40]
#})
features.update({
    'linearreg_slope_{}'.format(n): linearreg_slope(n) for n in [14, 28, 56, 112, 224]
})

#features.update({
#    'ma{}'.format(n): ma(n) for n in [5, 10, 20, 60, 120, 240]
#})

#features.update({
#    'std{}'.format(n): std(n) for n in [5, 10, 20, 60, 120, 240]
#})
#
#features.update({
#    'rsi{}'.format(n): rsi(n) for n in [5, 10, 20, 60, 120, 240]
#})
#
#features.update({
#    'k{}'.format(n): kd(n)[0] for n in [5, 10, 20, 60, 120, 240]
#})
#
#features.update({
#    'd{}'.format(n): kd(n)[1] for n in [5, 10, 20, 60, 120, 240]
#})
#
#features.update({
#    'osc{}'.format(n): oscillator(n) for n in [5, 10, 20, 60, 120, 240]
#})
#
#features.update({
#    'var{}'.format(n): variance(n) for n in [5, 10, 20, 60, 120, 240]
#})
#
#
#features.update({
#    'obv': obv()
#})
#


#features.update({
#    'kd{}'.format(n): kd(n) for n in [5, 10, 20, 60, 120, 240]
#})

# %%
##def yoy(n):
##    if rev.shift(n) < 0:
##        return rev.shift(n)
##    else :
##        return (rev.shift(n) / rev.shift(12+n)) -1
##
##yoy(1)

# %%
#bi(60).dropna(how='all')

# %% [markdown]
# 兩個feature結合[[連結網址]](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7)
#
# ---
# ```python
# from finlab import ml
# from finlab.data import Data
#
# data = Data()
# rsi = data.talib("RSI")
#
# dataset = ml.fundamental_features()
# ml.add_feature(dataset, 'RSI', rsi)
# ```

# %%
#dataset

# %% [markdown]
# #### 財報指標

# %%
#from finlab.ml import fundamental_features
#dataset_fundamental = fundamental_features()

# %%
#dataset_fundamental

# %% [markdown]
# #### 技術指標

# %% [raw]
# ```
# https://www.twblogs.net/a/5d3f3173bd9eee517422735f
# W-WED
# https://docs.python.org/zh-tw/3/library/calendar.html
# ```

# %% [markdown]
# 加入其他features
# * http://finlabcourse.imotor.com/viewthread.php?tid=660&extra=page%3D1
#
# ```python
# from finlab import ml
# from finlab.data import Data
#
# data = Data()
# rsi = data.talib("RSI")
#
# dataset = ml.fundamental_features()
# ml.add_feature(dataset, 'RSI', rsi)
# ```

# %% [markdown]
# #### 組合dataset

# %%
import pandas as pd

# %% [markdown]
# #### 確認各指標清單

# %%
#t1 = data.talib("NATR",timeperiod=14)
#t1.to_csv('myfile.csv')

# %% [markdown]
# ### 製作dataset
#
# ##### 設定買賣頻率

# %%
#rev.index = rev.index.tz_localize("Asia/Taipei")
every_month = rev.index
every_month
# Out:
# DatetimeIndex(['2005-02-15', '2005-03-15', '2005-04-15', '2005-05-15',
#                '2005-06-15', '2005-07-15', '2005-08-15', '2005-09-15',
#                '2005-10-15', '2005-11-15',
#                ...
#                '2022-09-15', '2022-10-15', '2022-11-15', '2022-12-15',
#                '2023-01-15', '2023-02-15', '2023-03-15', '2023-04-15',
#                '2023-05-15', '2023-06-15'],
#               dtype='datetime64[ns]', name='date', length=221, freq=None)

# %% [markdown]
# #### 將dataframe 組裝起來

# %%
# features['bias20'].reindex(every_month, method='ffill')

for name, f in features.items():
    features[name] = f.reindex(every_month, method='ffill')

# %%
for name, f in features.items():
    features[name] = f.unstack()

# %%
import pandas as pd
dataset = pd.DataFrame(features)

# %%
##我要把金融股拿掉 所以把28開頭全去掉
#dataset = dataset[~dataset.index.get_level_values('stock_id').str.startswith('28')]

# %% [markdown]
# ##### 裝自己要的

# %%
from finlab import ml

# %%
#from finlab import ml
#from finlab.data import Data

upper, middle, lower = data.talib("BBANDS", amount=0)
bband =  ((close -(upper+lower)/2) / (upper-lower)/2 )
ml.add_feature(dataset, 'BBANDS', bband)

real = data.talib("TSF") #时间序列预测
real = real /close
ml.add_feature(dataset, 'TSF', real /close)

real = data.talib("LINEARREG_ANGLE") #线性回归的角度
ml.add_feature(dataset, 'LINEARREG_ANGLE', real)

real = data.talib("DX") #DX ：动向指标或趋向指标
ml.add_feature(dataset, 'DX', real)

real = data.talib("BOP") #BOP ：均势指标
ml.add_feature(dataset, 'BOP', real)

real = data.talib("CORREL") #CORREL ：皮尔逊相关系数
ml.add_feature(dataset, 'CORREL', real)

real = ""

# %%
#real = data.talib("ADOSC") #BOP ：均势指标
#real

# %%
#dataset=""

# %%
feature_names = list(dataset.columns)

# %%
feature_names
# Out:
# ['bias_5',
#  'bias_10',
#  'bias_20',
#  'bias_60',
#  'bias_120',
#  'bias_240',
#  'acc_5',
#  'acc_10',
#  'acc_20',
#  'acc_60',
#  'acc_120',
#  'acc_240',
#  'rsv_5',
#  'rsv_10',
#  'rsv_20',
#  'rsv_60',
#  'rsv_120',
#  'rsv_240',
#  'yoy_0',
#  'yoy_1',
#  'yoy_2',
#  'yoy_3',
#  'yoy_4',
#  'delta_yoy_0',
#  'delta_yoy_1',
#  'delta_yoy_2',
#  'delta_yoy_3',
#  'delta_yoy_4',
#  'atr_10',
#  'atr_14',
#  'atr_20',
#  'willr_14',
#  'willr_20',
#  'willr_30',
#  'linearreg_slope_14',
#  'linearreg_slope_28',
#  'linearreg_slope_56',
#  'linearreg_slope_112',
#  'linearreg_slope_224',
#  'BBANDS',
#  'TSF',
#  'LINEARREG_ANGLE',
#  'DX',
#  'BOP',
#  'CORREL']

# %%
#feature_names

# %% [markdown]
# ##### 下面的feature **不要** 列入訓練

# %%
股本 = data.get('股本合計').reindex(close.index, method='ffill')
市值 = 股本 * close / 10 * 1000
#t1['2330'].dropna()
ml.add_feature(dataset, '市值', 市值)

# %%
ml.add_feature(dataset, 'vol_ma5', vol_ma5)

#dataset

# %%
##############################################　　　自己加入的　　　##############################################
dataset.index = dataset.index.set_names(['stock_id','date'], level=[0,1])


#dataset.index.levels[1].name = 'date'
#dataset.index.levels[0].name = 'stock_id'

#因為你pandas更新到新版了
## profit.index.levels[0].name = 'year'
## profit.index.levels[1].name = 'month'
#這兩行的語法被棄用，請改成
#profit.index=profit.index.set_names('year', level=0)
#profit.index=profit.index.set_names('month', level=1)
#or profit.index=profit.index.set_names(['year','month'], level=[0,1])
#直接一行
#就可以了

# %%
#list(dataset_fundamental.index)

# %%
#dataset_fundamental.reindex(dataset.index).dropna()

# %% [markdown]
# data[組合](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7)
# ```python
# new_df = pd.concat([dataset_fundamental['R406_經常利益成長率'],dataset],axis=1).dropna(how='any')
# ```

# %%
#new_df = pd.concat([dataset_fundamental,dataset],axis=1).dropna(how='any')
#dataset1 = new_df.fillna(method='ffill')#[(new_df.index.get_level_values('stock_id')=='2330')]
##dataset = dataset1

# %%
#feature_names=list(dataset1.columns)
#feature_names

# %% [markdown]
# ### 新增 label(績效/排名)
#  - 定義一下要比績效還是要比排名

# %%
from finlab import ml

ml.add_profit_prediction(dataset)
ml.add_rank_prediction(dataset)

# %%
#profit(return) rank
predi_target = 'rank'

# %% [markdown]
# ### 刪除太大太小的歷史資料

# %%
print(dataset.shape)

def drop_extreme_case(dataset, feature_names, thresh=0.01):
    
    extreme_cases = pd.Series(False, index=dataset.index)
    for f in feature_names:
        tf = dataset[f]
        extreme_cases = extreme_cases | (tf < tf.quantile(thresh)) | (tf > tf.quantile(1-thresh))
    dataset = dataset[~extreme_cases]
    return dataset

dataset_drop_extreme_case = drop_extreme_case(dataset , feature_names , thresh=0.01)

print(dataset_drop_extreme_case.shape)

##(436774, 25)
##(388157, 25)
# Out:
# (456144, 49)
# (384479, 49)

# %%
dataset_dropna = dataset_drop_extreme_case.dropna(how='any')
dataset_dropna = dataset_dropna.reset_index().set_index("date")

# %%
#dataset_drop_extreme_case.index.get_level_values("date")

# %%
##################################################################################################################
##############################################　　　自己加入的　　　##############################################
##################################################################################################################

dataset_dropna.index = pd.to_datetime(dataset_dropna.index)
dataset_dropna = dataset_dropna.sort_index()

#修復＜class ‘numpy.ndarray‘＞　https://blog.csdn.net/lxbin/article/details/114005757

# %% [markdown]
# ## Split Train Test dataset

# %%
# 計算要分割的索引位置
split_index = int(len(dataset_dropna) * 0.85)

# 分割資料集
dataset_train = dataset_dropna.iloc[:split_index]
dataset_test = dataset_dropna.iloc[split_index:]

# %%
dataset_test
# Out:
#            stock_id    bias_5   bias_10   bias_20   bias_60  bias_120  \
# date
# 2022-01-15     3317  0.969218  0.905558  0.894033  0.892511  0.920554
# 2022-01-15     3558  1.012106  1.010601  1.018930  1.049869  1.073599
# 2022-01-15     2867  1.048183  1.064378  1.073651  1.073187  1.074999
# 2022-01-15     3535  0.991667  0.990841  0.992908  0.993322  1.038621
# 2022-01-15     4745  0.995063  0.988306  0.985982  1.030820  1.043999
# ...             ...       ...       ...       ...       ...       ...
# 2023-05-15     1110  0.995729  1.001611  1.010566  1.034626  1.036399
# 2023-05-15     1813  1.000000  1.001112  1.007613  1.005362  0.998668
# 2023-05-15     5425  0.987275  0.974764  0.952079  0.903766  1.002618
# 2023-05-15     3285  1.007014  1.009797  1.009923  1.007056  1.032888
# 2023-05-15     9962  0.989011  0.990991  0.990000  0.943793  1.033470
#
#             bias_240     acc_5    acc_10    acc_20  ...        BBANDS  \
# date                                                ...
# 2022-01-15  1.019074  1.036691  1.061712  1.062459  ... -1.335494e-01
# 2022-01-15  1.035756  0.977995  1.016865  1.006061  ...  1.529904e-01
# 2022-01-15  1.083354  0.957203  0.970588  0.938272  ...  2.102419e-01
# 2022-01-15  1.015118  0.971034  1.026499  0.994475  ... -5.458336e-02
# 2022-01-15  0.975017  1.001894  1.005671  1.063745  ... -1.132191e-01
# ...              ...       ...       ...       ...  ...           ...
# 2023-05-15  1.021300  1.013514  0.991892  1.002732  ... -1.961161e-01
# 2023-05-15  1.049114  1.008949  0.991071  0.991111  ... -5.898200e-13
# 2023-05-15  1.057564  1.026968  0.945361  1.069409  ... -2.053899e-01
# 2023-05-15  1.032070  0.994975  0.985000  1.000000  ...  1.804987e-01
# 2023-05-15  1.157176  1.074550  0.928311  1.023981  ... -1.364802e-01
#
#                  TSF  LINEARREG_ANGLE         DX       BOP    CORREL  \
# date
# 2022-01-15  0.014626       -40.170248  36.191600 -0.575758  0.957004
# 2022-01-15  0.009661        -3.471271  31.967727  0.777778  0.931223
# 2022-01-15  0.096949         1.907056  78.874902  0.485294  0.959146
# 2022-01-15  0.056341        -0.887699  22.530877 -0.769231  0.860747
# 2022-01-15  0.038311        -1.812712  33.172793 -1.000000  0.628054
# ...              ...              ...        ...       ...       ...
# 2023-05-15  0.054167         2.246605  24.576107 -0.500000  0.945874
# 2023-05-15  0.044621         1.366025  26.474244  0.500000  0.413903
# 2023-05-15  0.011286        -5.623305  25.016913 -0.625000  0.975312
# 2023-05-15  0.049472         0.912877  40.664237  0.250000  0.496270
# 2023-05-15  0.052007         4.842835  16.017421 -0.666667  0.959071
#
#                       市值     vol_ma5    return      rank
# date
# 2022-01-15  4.281480e+09   1903.6702  1.006925  0.604421
# 2022-01-15  5.004212e+09     95.8554  1.122172  0.960442
# 2022-01-15  2.648145e+10  20414.2812  0.953061  0.147760
# 2022-01-15  1.411084e+09   1351.1254  1.114441  0.954625
# 2022-01-15  2.029180e+09     17.5794  1.101887  0.941245
# ...                  ...         ...       ...       ...
# 2023-05-15  1.066781e+10    343.0268  1.013441  0.280652
# 2023-05-15  1.049299e+09     34.5226  0.933333  0.032058
# 2023-05-15  2.371369e+10   4902.9408  1.104972  0.735096
# 2023-05-15  8.589795e+08     26.4988  1.025000  0.355456
# 2023-05-15  1.786362e+09    862.8846  1.002494  0.196288
#
# [20130 rows x 50 columns]

# %%
train = dataset_train[feature_names] , dataset_train['return'] > 1.00
test = dataset_test[feature_names] , dataset_test['return'] > 1.00

# %% [markdown]
# ### 機器學習
#  - 目前只有三個，技術指標也要再增加一下feature_names

# %%
#feature_names = feature_names1

# %%
#dataset_train.index

# %% [markdown]
# #### keras

# %%
import os

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


os.environ['KMP_DUPLICATE_LIB_OK']='True'

model = keras.models.Sequential()
model.add(layers.BatchNormalization(input_shape=(len(feature_names),)))
model.add(layers.Dense(100, activation='relu',
                      input_shape=(len(feature_names),),
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dropout(0.35))
model.add(layers.Dense(100, activation='relu',
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dropout(0.35))
model.add(layers.Dense(1, activation='sigmoid'))


model.summary()

optimizer = keras.optimizers.Adam(lr=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#model.compile(loss='mean_squared_error',
#              optimizer="adam",)

print('----------start fitting----------')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

get_best_model = keras.callbacks.ModelCheckpoint(
    filepath='./best_model/v1_03.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1,
    patience=10,
    save_best_only=True)

history = model.fit(dataset_train[feature_names], dataset_train[predi_target],
                    batch_size=1000,
                    epochs=1000,
                    verbose=1,
                    validation_split=0.1,
                    callbacks=[es, get_best_model] #es, get_best_model
                    )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 45)               180
#  ormalization)
#
#  dense (Dense)               (None, 100)               4600
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 14,981
# Trainable params: 14,891
# Non-trainable params: 90
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# ----------start fitting----------
# Epoch 1/1000
#  97/103 [===========================>..] - ETA: 0s - loss: 0.7769 - accuracy: 1.7526e-04
# Epoch 1: val_loss improved from inf to 0.69591, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 1s 6ms/step - loss: 0.7733 - accuracy: 1.6559e-04 - val_loss: 0.6959 - val_accuracy: 5.2599e-04
# Epoch 2/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.7028 - accuracy: 1.4286e-04
# Epoch 2: val_loss improved from 0.69591 to 0.69263, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.7027 - accuracy: 1.5585e-04 - val_loss: 0.6926 - val_accuracy: 3.5066e-04
# Epoch 3/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6957 - accuracy: 1.1111e-04
# Epoch 3: val_loss improved from 0.69263 to 0.69225, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6957 - accuracy: 1.3637e-04 - val_loss: 0.6922 - val_accuracy: 5.2599e-04
# Epoch 4/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6941 - accuracy: 1.5306e-04
# Epoch 4: val_loss improved from 0.69225 to 0.69188, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 1.5585e-04 - val_loss: 0.6919 - val_accuracy: 4.3833e-04
# Epoch 5/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6933 - accuracy: 1.5306e-04
# Epoch 5: val_loss improved from 0.69188 to 0.69158, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6933 - accuracy: 1.5585e-04 - val_loss: 0.6916 - val_accuracy: 2.6300e-04
# Epoch 6/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6928 - accuracy: 1.9192e-04
# Epoch 6: val_loss improved from 0.69158 to 0.69142, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6928 - accuracy: 1.9482e-04 - val_loss: 0.6914 - val_accuracy: 3.5066e-04
# Epoch 7/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6924 - accuracy: 1.8182e-04
# Epoch 7: val_loss improved from 0.69142 to 0.69118, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6923 - accuracy: 1.7533e-04 - val_loss: 0.6912 - val_accuracy: 4.3833e-04
# Epoch 8/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6923 - accuracy: 1.8367e-04
# Epoch 8: val_loss did not improve from 0.69118
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6923 - accuracy: 1.8508e-04 - val_loss: 0.6912 - val_accuracy: 3.5066e-04
# Epoch 9/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6919 - accuracy: 2.0408e-04
# Epoch 9: val_loss improved from 0.69118 to 0.69090, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6919 - accuracy: 2.0456e-04 - val_loss: 0.6909 - val_accuracy: 1.7533e-04
# Epoch 10/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6917 - accuracy: 1.6162e-04
# Epoch 10: val_loss improved from 0.69090 to 0.69081, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6917 - accuracy: 1.6559e-04 - val_loss: 0.6908 - val_accuracy: 1.7533e-04
# Epoch 11/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6917 - accuracy: 1.8182e-04
# Epoch 11: val_loss improved from 0.69081 to 0.69080, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6916 - accuracy: 1.8508e-04 - val_loss: 0.6908 - val_accuracy: 1.7533e-04
# Epoch 12/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6914 - accuracy: 1.8367e-04
# Epoch 12: val_loss improved from 0.69080 to 0.69069, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6914 - accuracy: 2.0456e-04 - val_loss: 0.6907 - val_accuracy: 1.7533e-04
# Epoch 13/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6914 - accuracy: 1.6327e-04
# Epoch 13: val_loss did not improve from 0.69069
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6914 - accuracy: 1.6559e-04 - val_loss: 0.6909 - val_accuracy: 1.7533e-04
# Epoch 14/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6912 - accuracy: 2.0202e-04
# Epoch 14: val_loss did not improve from 0.69069
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6912 - accuracy: 1.9482e-04 - val_loss: 0.6909 - val_accuracy: 1.7533e-04
# Epoch 15/1000
#  95/103 [==========================>...] - ETA: 0s - loss: 0.6911 - accuracy: 1.6842e-04
# Epoch 15: val_loss did not improve from 0.69069
# 103/103 [==============================] - 1s 6ms/step - loss: 0.6910 - accuracy: 1.8508e-04 - val_loss: 0.6909 - val_accuracy: 1.7533e-04
# Epoch 16/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6911 - accuracy: 1.5152e-04
# Epoch 16: val_loss did not improve from 0.69069
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6911 - accuracy: 1.4611e-04 - val_loss: 0.6909 - val_accuracy: 1.7533e-04
# Epoch 17/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6910 - accuracy: 2.2449e-04
# Epoch 17: val_loss improved from 0.69069 to 0.69062, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6910 - accuracy: 2.3378e-04 - val_loss: 0.6906 - val_accuracy: 1.7533e-04
# Epoch 18/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6909 - accuracy: 1.4286e-04
# Epoch 18: val_loss did not improve from 0.69062
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6909 - accuracy: 1.5585e-04 - val_loss: 0.6908 - val_accuracy: 1.7533e-04
# Epoch 19/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6909 - accuracy: 1.5306e-04
# Epoch 19: val_loss did not improve from 0.69062
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6909 - accuracy: 1.4611e-04 - val_loss: 0.6908 - val_accuracy: 1.7533e-04
# Epoch 20/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6908 - accuracy: 1.9192e-04
# Epoch 20: val_loss improved from 0.69062 to 0.69062, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6908 - accuracy: 1.9482e-04 - val_loss: 0.6906 - val_accuracy: 1.7533e-04
# Epoch 21/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6907 - accuracy: 2.0408e-04
# Epoch 21: val_loss did not improve from 0.69062
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6907 - accuracy: 1.9482e-04 - val_loss: 0.6908 - val_accuracy: 1.7533e-04
# Epoch 22/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6906 - accuracy: 1.7347e-04
# Epoch 22: val_loss did not improve from 0.69062
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 1.7533e-04 - val_loss: 0.6909 - val_accuracy: 1.7533e-04
# Epoch 23/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6906 - accuracy: 2.0202e-04
# Epoch 23: val_loss did not improve from 0.69062
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 1.9482e-04 - val_loss: 0.6909 - val_accuracy: 1.7533e-04
# Epoch 24/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6906 - accuracy: 1.9192e-04
# Epoch 24: val_loss did not improve from 0.69062
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 1.8508e-04 - val_loss: 0.6907 - val_accuracy: 1.7533e-04
# Epoch 25/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6904 - accuracy: 1.4141e-04
# Epoch 25: val_loss improved from 0.69062 to 0.69056, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6904 - accuracy: 1.3637e-04 - val_loss: 0.6906 - val_accuracy: 1.7533e-04
# Epoch 26/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6904 - accuracy: 1.9388e-04
# Epoch 26: val_loss improved from 0.69056 to 0.69047, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6904 - accuracy: 1.8508e-04 - val_loss: 0.6905 - val_accuracy: 1.7533e-04
# Epoch 27/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6902 - accuracy: 1.8182e-04
# Epoch 27: val_loss did not improve from 0.69047
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6902 - accuracy: 1.7533e-04 - val_loss: 0.6907 - val_accuracy: 1.7533e-04
# Epoch 28/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6902 - accuracy: 1.4286e-04
# Epoch 28: val_loss did not improve from 0.69047
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6902 - accuracy: 1.4611e-04 - val_loss: 0.6908 - val_accuracy: 1.7533e-04
# Epoch 29/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6901 - accuracy: 1.7172e-04
# Epoch 29: val_loss did not improve from 0.69047
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6901 - accuracy: 1.6559e-04 - val_loss: 0.6908 - val_accuracy: 1.7533e-04
# Epoch 30/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6901 - accuracy: 2.0408e-04
# Epoch 30: val_loss did not improve from 0.69047
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6901 - accuracy: 2.0456e-04 - val_loss: 0.6906 - val_accuracy: 2.6300e-04
# Epoch 31/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6901 - accuracy: 2.0202e-04
# Epoch 31: val_loss did not improve from 0.69047
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6902 - accuracy: 1.9482e-04 - val_loss: 0.6906 - val_accuracy: 1.7533e-04
# Epoch 32/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6900 - accuracy: 1.5152e-04
# Epoch 32: val_loss did not improve from 0.69047
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6900 - accuracy: 1.6559e-04 - val_loss: 0.6908 - val_accuracy: 1.7533e-04
# Epoch 33/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6899 - accuracy: 1.9388e-04
# Epoch 33: val_loss did not improve from 0.69047
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6899 - accuracy: 2.0456e-04 - val_loss: 0.6907 - val_accuracy: 1.7533e-04
# Epoch 34/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6899 - accuracy: 1.3265e-04
# Epoch 34: val_loss did not improve from 0.69047
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6899 - accuracy: 1.2663e-04 - val_loss: 0.6906 - val_accuracy: 1.7533e-04
# Epoch 35/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6899 - accuracy: 1.8182e-04
# Epoch 35: val_loss improved from 0.69047 to 0.69043, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6900 - accuracy: 1.7533e-04 - val_loss: 0.6904 - val_accuracy: 1.7533e-04
# Epoch 36/1000
#  97/103 [===========================>..] - ETA: 0s - loss: 0.6898 - accuracy: 1.7526e-04
# Epoch 36: val_loss did not improve from 0.69043
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6899 - accuracy: 1.8508e-04 - val_loss: 0.6906 - val_accuracy: 1.7533e-04
# Epoch 37/1000
#  97/103 [===========================>..] - ETA: 0s - loss: 0.6896 - accuracy: 1.6495e-04
# Epoch 37: val_loss did not improve from 0.69043
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6896 - accuracy: 1.6559e-04 - val_loss: 0.6905 - val_accuracy: 8.7665e-05
# Epoch 38/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6897 - accuracy: 2.0202e-04
# Epoch 38: val_loss did not improve from 0.69043
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 1.9482e-04 - val_loss: 0.6908 - val_accuracy: 1.7533e-04
# Epoch 39/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6897 - accuracy: 1.8182e-04
# Epoch 39: val_loss improved from 0.69043 to 0.69038, saving model to ./best_model/v1_03.h5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 1.7533e-04 - val_loss: 0.6904 - val_accuracy: 8.7665e-05
# Epoch 40/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6896 - accuracy: 2.0408e-04
# Epoch 40: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6896 - accuracy: 2.0456e-04 - val_loss: 0.6909 - val_accuracy: 8.7665e-05
# Epoch 41/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6896 - accuracy: 2.0408e-04
# Epoch 41: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6896 - accuracy: 2.0456e-04 - val_loss: 0.6907 - val_accuracy: 1.7533e-04
# Epoch 42/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6895 - accuracy: 1.6162e-04
# Epoch 42: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6895 - accuracy: 1.6559e-04 - val_loss: 0.6904 - val_accuracy: 1.7533e-04
# Epoch 43/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6897 - accuracy: 1.7172e-04
# Epoch 43: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 1.6559e-04 - val_loss: 0.6905 - val_accuracy: 1.7533e-04
# Epoch 44/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6893 - accuracy: 1.6327e-04
# Epoch 44: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 1.6559e-04 - val_loss: 0.6907 - val_accuracy: 8.7665e-05
# Epoch 45/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6893 - accuracy: 1.4141e-04
# Epoch 45: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6893 - accuracy: 1.4611e-04 - val_loss: 0.6906 - val_accuracy: 1.7533e-04
# Epoch 46/1000
#  97/103 [===========================>..] - ETA: 0s - loss: 0.6892 - accuracy: 1.8557e-04
# Epoch 46: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6893 - accuracy: 1.7533e-04 - val_loss: 0.6909 - val_accuracy: 1.7533e-04
# Epoch 47/1000
#  98/103 [===========================>..] - ETA: 0s - loss: 0.6894 - accuracy: 1.7347e-04
# Epoch 47: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 1.7533e-04 - val_loss: 0.6906 - val_accuracy: 1.7533e-04
# Epoch 48/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6892 - accuracy: 1.5152e-04
# Epoch 48: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 1.5585e-04 - val_loss: 0.6907 - val_accuracy: 1.7533e-04
# Epoch 49/1000
#  99/103 [===========================>..] - ETA: 0s - loss: 0.6892 - accuracy: 1.8182e-04
# Epoch 49: val_loss did not improve from 0.69038
# 103/103 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 1.9482e-04 - val_loss: 0.6905 - val_accuracy: 1.7533e-04
# Epoch 49: early stopping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.plot(history.history['val_loss'][10:])
plt.plot(history.history['loss'][10:])

# %%
#type(dataset_train[feature_names])

# %% [markdown]
# ##### 結果

# %%
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.plot(history.history['val_accuracy'][1:])
plt.plot(history.history['accuracy'][1:])

# %%
import matplotlib.pyplot as plt

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(history.history['val_accuracy'][1:], label='Validation Accuracy')
plt.plot(history.history['accuracy'][1:], label='Training Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #### lightgbm Model

# %%
##############################################　　　自己加入的　　　##############################################
import lightgbm as lgb

cf = lgb.LGBMRegressor(n_estimators=5000)

print('---cf.fit---')
print(cf.fit(*train))
print('---cf.score---')
print(cf.score(*test))
print('---predict---')
print(cf.predict(test[0]))
# Out:
# ---cf.fit---
# LGBMRegressor(n_estimators=5000)
# ---cf.score---
# -0.09432771226173098
# ---predict---
# [-0.03718033  0.55492734  0.26531152 ...  0.43038333  0.5028921
#   0.60158902]

# %% [markdown]
# ##### 參數優化_1110

# %%
#import lightgbm

fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [test],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

param_test = {
            'num_leaves': sp_randint(10, 100),
            'min_child_samples': sp_randint(50, 200),
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
            'subsample': sp_uniform(loc=0.1, scale=0.9),
            'colsample_bytree': sp_uniform(loc=0.2, scale=0.8),
            'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
            'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]
            }
            

#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 200

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMRegressor(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000) #LGBMClassifier
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

# %%
gs.fit(*train, **fit_params)
# Out:
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [35]	valid's auc: 0.565995
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.516089
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.540101
# Early stopping, best iteration is:
# [152]	valid's auc: 0.541066
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [32]	valid's auc: 0.569016
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.525759
# Early stopping, best iteration is:
# [155]	valid's auc: 0.527087
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [67]	valid's auc: 0.541266
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [59]	valid's auc: 0.579519
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [53]	valid's auc: 0.526758
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.541618
# Early stopping, best iteration is:
# [72]	valid's auc: 0.543136
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.565814
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.521084
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.538505
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.562293
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [54]	valid's auc: 0.518459
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [49]	valid's auc: 0.540696
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [22]	valid's auc: 0.564401
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.520121
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [67]	valid's auc: 0.542146
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [4]	valid's auc: 0.561853
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.520081
# Early stopping, best iteration is:
# [98]	valid's auc: 0.521687
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.540387
# [200]	valid's auc: 0.542859
# Early stopping, best iteration is:
# [201]	valid's auc: 0.542953
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [25]	valid's auc: 0.560043
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [52]	valid's auc: 0.515407
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [25]	valid's auc: 0.546225
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [31]	valid's auc: 0.557526
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.526471
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.53621
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [51]	valid's auc: 0.559475
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.512897
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [69]	valid's auc: 0.53807
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [46]	valid's auc: 0.569195
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.524604
# Early stopping, best iteration is:
# [80]	valid's auc: 0.526792
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.543812
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.558614
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.518062
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.541581
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.557664
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [18]	valid's auc: 0.517509
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.537506
# Early stopping, best iteration is:
# [72]	valid's auc: 0.538728
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [49]	valid's auc: 0.561711
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.514314
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [49]	valid's auc: 0.542063
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [32]	valid's auc: 0.557965
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [28]	valid's auc: 0.519409
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.541063
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.55711
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [23]	valid's auc: 0.513573
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.538271
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.562789
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.518862
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [60]	valid's auc: 0.54209
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [22]	valid's auc: 0.557118
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.516876
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [41]	valid's auc: 0.539253
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.560058
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.51709
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [21]	valid's auc: 0.538173
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.566358
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [41]	valid's auc: 0.519612
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.538353
# Early stopping, best iteration is:
# [72]	valid's auc: 0.539079
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [7]	valid's auc: 0.556847
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.519915
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [36]	valid's auc: 0.54304
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [25]	valid's auc: 0.561348
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [30]	valid's auc: 0.515358
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [36]	valid's auc: 0.538234
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.559971
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.5184
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.536236
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.562949
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.516165
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [59]	valid's auc: 0.537961
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [34]	valid's auc: 0.563166
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.513146
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [44]	valid's auc: 0.54049
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.57568
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [41]	valid's auc: 0.524921
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.538504
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [30]	valid's auc: 0.556492
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.516735
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.539802
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.565024
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.518011
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [61]	valid's auc: 0.542908
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [7]	valid's auc: 0.557882
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [31]	valid's auc: 0.520743
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [60]	valid's auc: 0.543328
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.560405
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.514248
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	valid's auc: 0.536334
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	valid's auc: 0.569014
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [55]	valid's auc: 0.525718
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.533973
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [23]	valid's auc: 0.561497
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.518057
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.544329
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.563083
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [18]	valid's auc: 0.515006
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [46]	valid's auc: 0.534163
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [30]	valid's auc: 0.562974
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.52195
# Early stopping, best iteration is:
# [79]	valid's auc: 0.525487
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [41]	valid's auc: 0.54366
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.562605
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [27]	valid's auc: 0.51762
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.542621
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.567496
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [58]	valid's auc: 0.51686
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.536165
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.571419
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.525535
# Early stopping, best iteration is:
# [81]	valid's auc: 0.528302
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.542405
# Early stopping, best iteration is:
# [106]	valid's auc: 0.543146
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.567925
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [44]	valid's auc: 0.52593
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.53425
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [20]	valid's auc: 0.559512
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [31]	valid's auc: 0.516608
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.542455
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [22]	valid's auc: 0.564983
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.519466
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [65]	valid's auc: 0.539397
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.580442
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [51]	valid's auc: 0.525852
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.538659
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [47]	valid's auc: 0.56448
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [58]	valid's auc: 0.531505
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.538712
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [29]	valid's auc: 0.559165
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.517219
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	valid's auc: 0.540175
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [23]	valid's auc: 0.580734
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [51]	valid's auc: 0.52967
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.537902
# Early stopping, best iteration is:
# [105]	valid's auc: 0.539087
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [31]	valid's auc: 0.555904
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [56]	valid's auc: 0.520186
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [23]	valid's auc: 0.546481
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.567293
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.5261
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [25]	valid's auc: 0.543096
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.563441
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.519705
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.537168
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [21]	valid's auc: 0.575501
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.526407
# Early stopping, best iteration is:
# [77]	valid's auc: 0.531087
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.538504
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.558679
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.520329
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.544464
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.561913
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [32]	valid's auc: 0.516299
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [60]	valid's auc: 0.540918
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [20]	valid's auc: 0.560718
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.516404
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [41]	valid's auc: 0.535001
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.559342
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.517237
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.539345
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [49]	valid's auc: 0.558898
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [58]	valid's auc: 0.516022
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	valid's auc: 0.540241
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [21]	valid's auc: 0.5775
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.528502
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [66]	valid's auc: 0.540887
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.558458
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [16]	valid's auc: 0.518911
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [41]	valid's auc: 0.536258
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [23]	valid's auc: 0.561957
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [27]	valid's auc: 0.516668
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.540713
# Early stopping, best iteration is:
# [95]	valid's auc: 0.541991
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.556941
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	valid's auc: 0.512958
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.5392
# Early stopping, best iteration is:
# [74]	valid's auc: 0.540907
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.565283
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.514167
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [52]	valid's auc: 0.541886
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [31]	valid's auc: 0.559021
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [55]	valid's auc: 0.516724
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [35]	valid's auc: 0.534377
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.567661
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [62]	valid's auc: 0.530808
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [58]	valid's auc: 0.540998
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [25]	valid's auc: 0.556028
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [47]	valid's auc: 0.515444
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.534658
# Early stopping, best iteration is:
# [72]	valid's auc: 0.536319
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [9]	valid's auc: 0.580915
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [58]	valid's auc: 0.530156
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [64]	valid's auc: 0.54208
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.557724
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [38]	valid's auc: 0.518063
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.538705
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [32]	valid's auc: 0.554868
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [38]	valid's auc: 0.516934
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.541553
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [32]	valid's auc: 0.565069
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [44]	valid's auc: 0.516079
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.538152
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [50]	valid's auc: 0.568263
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.525482
# Early stopping, best iteration is:
# [72]	valid's auc: 0.528015
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.540513
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.564685
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [40]	valid's auc: 0.517728
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.538579
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.562736
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [33]	valid's auc: 0.514589
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.540367
# Early stopping, best iteration is:
# [81]	valid's auc: 0.541837
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.576141
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.55484
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.549344
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.566787
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.522343
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [64]	valid's auc: 0.542291
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [6]	valid's auc: 0.573561
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [45]	valid's auc: 0.523022
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.538504
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [50]	valid's auc: 0.557943
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [58]	valid's auc: 0.521163
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.540219
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.559869
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.517539
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.536813
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [23]	valid's auc: 0.562082
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [34]	valid's auc: 0.518786
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.540126
# Early stopping, best iteration is:
# [114]	valid's auc: 0.540427
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.564141
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.520118
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [51]	valid's auc: 0.5398
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.566506
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.518116
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.53748
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [20]	valid's auc: 0.568508
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.522555
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.539241
# Early stopping, best iteration is:
# [99]	valid's auc: 0.539394
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.567008
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [32]	valid's auc: 0.517713
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [53]	valid's auc: 0.538223
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.556236
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [55]	valid's auc: 0.519178
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.542658
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [57]	valid's auc: 0.566483
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.524969
# Early stopping, best iteration is:
# [78]	valid's auc: 0.528169
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.543128
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.561747
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [27]	valid's auc: 0.514034
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.53897
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [22]	valid's auc: 0.56228
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.5156
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.537451
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.563163
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [4]	valid's auc: 0.515439
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [57]	valid's auc: 0.535228
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [23]	valid's auc: 0.557624
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [7]	valid's auc: 0.516339
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.536381
# Early stopping, best iteration is:
# [100]	valid's auc: 0.536381
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.561994
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [40]	valid's auc: 0.518269
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.543616
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.558804
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.518125
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.541272
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.558283
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.514433
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.544466
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [36]	valid's auc: 0.559168
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [33]	valid's auc: 0.521506
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.539616
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [9]	valid's auc: 0.562499
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.522186
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.543904
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.571924
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.524933
# Early stopping, best iteration is:
# [79]	valid's auc: 0.529385
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [55]	valid's auc: 0.541652
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.561904
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [56]	valid's auc: 0.527099
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [38]	valid's auc: 0.540209
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.560709
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.51203
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.543336
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	valid's auc: 0.563833
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [48]	valid's auc: 0.525031
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [65]	valid's auc: 0.540018
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.581546
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [49]	valid's auc: 0.529402
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.536526
# Early stopping, best iteration is:
# [106]	valid's auc: 0.538434
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.561563
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [56]	valid's auc: 0.512708
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.543507
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.560887
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.520286
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [57]	valid's auc: 0.539643
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [28]	valid's auc: 0.562727
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.517409
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.536841
# Early stopping, best iteration is:
# [96]	valid's auc: 0.537274
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.559154
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.51747
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.536549
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [9]	valid's auc: 0.580914
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [56]	valid's auc: 0.525844
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.540758
# Early stopping, best iteration is:
# [104]	valid's auc: 0.542258
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [21]	valid's auc: 0.567959
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.523577
# Early stopping, best iteration is:
# [106]	valid's auc: 0.525436
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.541465
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.557002
# Early stopping, best iteration is:
# [80]	valid's auc: 0.560533
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.517385
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.545128
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [34]	valid's auc: 0.55979
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [33]	valid's auc: 0.518159
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [67]	valid's auc: 0.539933
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [23]	valid's auc: 0.580355
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.524742
# Early stopping, best iteration is:
# [71]	valid's auc: 0.527709
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.54496
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.576196
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.529235
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.536023
# Early stopping, best iteration is:
# [141]	valid's auc: 0.54126
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [30]	valid's auc: 0.55764
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [40]	valid's auc: 0.523026
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [49]	valid's auc: 0.539379
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [48]	valid's auc: 0.569189
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [35]	valid's auc: 0.522016
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.537345
# Early stopping, best iteration is:
# [90]	valid's auc: 0.539126
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.562483
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.518885
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.543027
# Early stopping, best iteration is:
# [115]	valid's auc: 0.544425
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [22]	valid's auc: 0.563747
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.51542
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	valid's auc: 0.53866
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [65]	valid's auc: 0.557351
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.512346
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [29]	valid's auc: 0.542209
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [6]	valid's auc: 0.561464
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.516612
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.535045
# Early stopping, best iteration is:
# [70]	valid's auc: 0.536631
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [6]	valid's auc: 0.579171
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.525341
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.53817
# Early stopping, best iteration is:
# [70]	valid's auc: 0.540091
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.573892
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.52044
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [36]	valid's auc: 0.543538
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	valid's auc: 0.565624
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [40]	valid's auc: 0.524808
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [5]	valid's auc: 0.536725
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.55773
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [25]	valid's auc: 0.518448
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.543887
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [21]	valid's auc: 0.557411
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [5]	valid's auc: 0.518832
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [48]	valid's auc: 0.539571
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.560821
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [58]	valid's auc: 0.515151
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [49]	valid's auc: 0.540327
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.559806
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.51418
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [53]	valid's auc: 0.543406
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [18]	valid's auc: 0.562987
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.520514
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [66]	valid's auc: 0.539011
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [16]	valid's auc: 0.565929
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [55]	valid's auc: 0.528297
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.54168
# Early stopping, best iteration is:
# [84]	valid's auc: 0.543355
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.555506
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.523598
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.544374
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.560367
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [58]	valid's auc: 0.517266
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.538967
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.562895
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.517145
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.540583
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [33]	valid's auc: 0.560955
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [7]	valid's auc: 0.51729
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.538482
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [26]	valid's auc: 0.560978
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.514554
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.533872
# Early stopping, best iteration is:
# [98]	valid's auc: 0.534123
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.581196
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [48]	valid's auc: 0.528426
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.541396
# Early stopping, best iteration is:
# [109]	valid's auc: 0.54173
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.567374
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.526055
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [54]	valid's auc: 0.543266
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [16]	valid's auc: 0.56061
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.514605
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [40]	valid's auc: 0.537275
# Training until validation scores don't improve for 30 rounds
# ...
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.543826
# Early stopping, best iteration is:
# [113]	valid's auc: 0.546096
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [7]	valid's auc: 0.559006
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.520653
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [36]	valid's auc: 0.546938
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [13]	valid's auc: 0.556362
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.514826
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [40]	valid's auc: 0.53949
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [52]	valid's auc: 0.56419
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [59]	valid's auc: 0.531779
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.540605
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.558843
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [28]	valid's auc: 0.514894
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [51]	valid's auc: 0.5433
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.559755
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.516184
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.540462
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.555349
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.522914
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [25]	valid's auc: 0.543834
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [36]	valid's auc: 0.558922
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [34]	valid's auc: 0.515716
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.541094
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.559656
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [50]	valid's auc: 0.523604
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [51]	valid's auc: 0.53805
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [34]	valid's auc: 0.561617
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	valid's auc: 0.517069
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.535187
# Early stopping, best iteration is:
# [80]	valid's auc: 0.536165
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.579875
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.559904
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.554625
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [35]	valid's auc: 0.564934
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [33]	valid's auc: 0.519304
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.542753
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [22]	valid's auc: 0.560981
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [5]	valid's auc: 0.525118
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [68]	valid's auc: 0.539183
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.582433
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.526842
# Early stopping, best iteration is:
# [84]	valid's auc: 0.529399
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.540539
# Early stopping, best iteration is:
# [99]	valid's auc: 0.54175
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.562167
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [29]	valid's auc: 0.51388
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [60]	valid's auc: 0.543585
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.577111
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.524423
# Early stopping, best iteration is:
# [103]	valid's auc: 0.525956
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.534801
# Early stopping, best iteration is:
# [92]	valid's auc: 0.535787
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.564929
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.520493
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	valid's auc: 0.543816
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.562634
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.512353
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [47]	valid's auc: 0.539696
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [6]	valid's auc: 0.577793
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [50]	valid's auc: 0.527718
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [5]	valid's auc: 0.542022
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [28]	valid's auc: 0.564367
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [32]	valid's auc: 0.521655
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.545099
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.560858
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [34]	valid's auc: 0.514153
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [54]	valid's auc: 0.536955
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [31]	valid's auc: 0.55767
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.514312
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [51]	valid's auc: 0.540387
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [16]	valid's auc: 0.563165
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.515169
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [65]	valid's auc: 0.536117
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [20]	valid's auc: 0.559283
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [30]	valid's auc: 0.518678
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.537287
# Early stopping, best iteration is:
# [71]	valid's auc: 0.539149
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.570263
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.525406
# Early stopping, best iteration is:
# [78]	valid's auc: 0.528214
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.539689
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.554919
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [32]	valid's auc: 0.514772
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [65]	valid's auc: 0.540349
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [23]	valid's auc: 0.575093
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.525217
# Early stopping, best iteration is:
# [72]	valid's auc: 0.52646
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.537881
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [25]	valid's auc: 0.564865
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [33]	valid's auc: 0.515856
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.540757
# Early stopping, best iteration is:
# [76]	valid's auc: 0.541612
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.553882
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [62]	valid's auc: 0.512676
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [11]	valid's auc: 0.536822
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.56525
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.518483
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [53]	valid's auc: 0.540414
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.560969
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [38]	valid's auc: 0.518938
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [24]	valid's auc: 0.543167
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [41]	valid's auc: 0.57013
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [62]	valid's auc: 0.528514
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.538463
# Early stopping, best iteration is:
# [71]	valid's auc: 0.540615
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	valid's auc: 0.557165
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.51593
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	valid's auc: 0.533602
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [29]	valid's auc: 0.558662
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [38]	valid's auc: 0.520095
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.542563
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	valid's auc: 0.562444
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [27]	valid's auc: 0.518178
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [35]	valid's auc: 0.535992
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.563518
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [14]	valid's auc: 0.519711
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.541019
# Early stopping, best iteration is:
# [95]	valid's auc: 0.542473
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [49]	valid's auc: 0.559832
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [27]	valid's auc: 0.516524
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [25]	valid's auc: 0.540006
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [34]	valid's auc: 0.564435
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.517612
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.538348
# Early stopping, best iteration is:
# [120]	valid's auc: 0.540324
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [15]	valid's auc: 0.565492
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [38]	valid's auc: 0.52065
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.541829
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [54]	valid's auc: 0.541959
# RandomizedSearchCV(cv=3,
#                    estimator=LGBMRegressor(metric='None', n_estimators=5000,
#                                            n_jobs=4, random_state=314),
#                    n_iter=200,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f76a08a70d0>,
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f76a08c3c50>,
#                                         'min_child_weight': [1e-05, 0.001, 0.01,
#                                                              0.1, 1, 10.0,
#                                                              100.0, 1000.0,
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f76a08c3a50>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f76a08c3e10>},
#                    random_state=314, scoring='roc_auc', verbose=True)

# %%
print(gs.best_score_)
gs.best_estimator_
# Out:
# 0.5465149948618715
# LGBMRegressor(colsample_bytree=0.5854426254099221, metric='None',
#               min_child_samples=149, min_child_weight=1000.0, n_estimators=5000,
#               n_jobs=4, num_leaves=24, random_state=314, reg_alpha=1,
#               reg_lambda=100, subsample=0.5415608167468725)

# %%
#
#gs.best_estimator_
#LGBMClassifier(colsample_bytree=0.6433117836032942, metric='None',
#               min_child_samples=224, min_child_weight=1e-05, n_estimators=5000,
#               n_jobs=4, num_leaves=20, random_state=314, reg_alpha=10,
#               reg_lambda=10, subsample=0.8945613420997809)

# %%
##cf = lgb.LGBMClassifier(boosting_type='gbdt', class_weight=None,
##               colsample_bytree=0.4467801334566121, importance_type='split',
##               learning_rate=0.1, max_depth=-1, metric='None',
##               min_child_samples=107, min_child_weight=1, min_split_gain=0.0,
##               n_estimators=5000, n_jobs=4, num_leaves=43, objective=None,
##               random_state=314, reg_alpha=10, reg_lambda=100, silent=True,
##               subsample=0.40294551048668437, subsample_for_bin=200000,
##               subsample_freq=0)
##
##
##cf.fit(dataset_train[feature_names],dataset_train['return'] > 1.05, **fit_params)
##cf.score(dataset_test[feature_names],dataset_test['return'] > 1.05)
##下面那行調整中

# %%
##原本的上面那行
cf = lgb.LGBMRegressor(colsample_bytree=0.5120207478845764, metric='None',
              min_child_samples=179, min_child_weight=0.1, n_estimators=5000,
              n_jobs=4, num_leaves=21, random_state=314, reg_alpha=7,
              reg_lambda=50, subsample=0.39424714146928697)

cf.fit(dataset_train[feature_names],dataset_train['return'] > 1.0, **fit_params)
cf.score(dataset_test[feature_names],dataset_test['return'] > 1.0)

#-0.0022746308430701134
#0.052801756206640516
# Out:
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [12]	valid's auc: 0.543861
# 0.003620429043243223

# %%
cf.feature_importances_
# Out:
# array([11,  4, 16, 17, 16,  6,  6,  3,  4, 11,  1,  5,  3,  0,  6,  2,  0,
#         9,  5, 11,  1,  0,  0,  7,  3,  0,  0,  1, 11,  1,  1, 15, 12,  2,
#         6,  7,  0,  1,  4,  3,  3,  8, 13,  1,  4], dtype=int32)

# %%
feature_imp = pd.DataFrame(zip(cf.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
plt.figure(figsize=(10,10))
sns.barplot(x="Value", y="Feature", data=feature_imp)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Feature'>

# %% [raw]
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551389
# Early stopping, best iteration is:
# [89]	valid's auc: 0.553699
# 0.003857956228475623

# %%
#print(cf.fit(*train))

# %%
#import lightgbm as lgb
#gbm = lgb.LGBMClassifier(n_estimators=100, random_state=5, learning_rate=0.01)
#gbm.fit(dataset_train[feature_names], dataset_train['return'] > 1)

# %%
#import tqdm
#
#n = 3
#
#X = []
#y = []
#indexes = []
#dataset_scaled_x = dataset_scaled[feature_names]
#
#for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-n)):
#    X.append(dataset_scaled_x.iloc[i:i+n].values)
#    y.append(dataset_scaled['return'].iloc[i+n-1])
#    indexes.append(dataset_scaled.index[i+n-1])
##dataset_scaled.head()

# %%
#import numpy as np
#X = np.array(X)
#y = np.array(y)

# %%
##import lightgbm as lgb
#cf = lgb.LGBMRegressor(colsample_bytree=0.7740467183023685, metric='None',
#               min_child_samples=395, min_child_weight=0.01, n_estimators=5000,
#               n_jobs=4, num_leaves=9, random_state=314, reg_alpha=5,
#               reg_lambda=10, subsample=0.4643892520208455)
#    
#cf.fit(dataset_train[feature_names].astype(float), dataset_train['rank'])

# %% [markdown]
# #### Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

cf2 = RandomForestRegressor(n_estimators=100)
cf2.fit(dataset_train[feature_names].astype(float), dataset_train[predi_target])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_66907/364799542.py in <module>
#       2
#       3 cf2 = RandomForestRegressor(n_estimators=100)
# ----> 4 cf2.fit(dataset_train[feature_names].astype(float), dataset_train[predi_target])
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     391                     verbose=self.verbose, class_weight=self.class_weight,
#     392                     n_samples_bootstrap=n_samples_bootstrap)
# --> 393                 for i, t in enumerate(trees))
#     394
#     395             # Collect newly grown trees
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1086                 self._iterating = self._original_iterator is not None
#    1087
# -> 1088             while self.dispatch_one_batch(iterator):
#    1089                 pass
#    1090
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     288             return [func(*args, **kwargs)
# --> 289                     for func, args, kwargs in self.items]
#     290
#     291     def __reduce__(self):
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     288             return [func(*args, **kwargs)
# --> 289                     for func, args, kwargs in self.items]
#     290
#     291     def __reduce__(self):
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     167                                                         indices=indices)
#     168
# --> 169         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     170     else:
#     171         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1254             sample_weight=sample_weight,
#    1255             check_input=check_input,
# -> 1256             X_idx_sorted=X_idx_sorted)
#    1257         return self
#    1258
#
# ~/miniconda3/envs/finlab/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     392                                            min_impurity_split)
#     393
# --> 394         builder.build(self.tree_, X, y, sample_weight)
#     395
#     396         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ##### 參數優化_1110

# %%
#from scipy.stats import randint as sp_randint 
#from sklearn.model_selection import RandomizedSearchCV 
## build a classifier 
#cf2 = RandomForestRegressor(n_estimators=100) 
## specify parameters and distributions to sample from 
#param_dist = {"max_depth": [3, None], 
#              "max_features": sp_randint(1, 11), 
#              "min_samples_split": sp_randint(2, 11), 
#              "min_samples_leaf": sp_randint(1, 11), 
#              "bootstrap": [True, False], 
#              "criterion": ["mse", "mae"]} 
## run randomized search 
#n_iter_search = 20 
#rs = RandomizedSearchCV(cf2, param_distributions=param_dist, 
#                                   n_iter=n_iter_search)

# %%
#rs.fit(dataset_train[features], dataset_train['return'] >1)

# %% [markdown]
# ##### Split Train Test dataset

# %%
feature_imp = pd.DataFrame(zip(cf2.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
plt.figure(figsize=(10,10))
sns.barplot(x="Value", y="Feature", data=feature_imp)

# %%
#select = dataset.index.get_level_values('date') < '2022-03'
#dataset_train = dataset[select]
#dataset_test = dataset[~select]

# %% [markdown]
# ### Ensemble learning

# %%
dataset_drop = dataset.dropna(subset=feature_names+['return'])

vals = model.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result1'] = pd.Series(vals.swapaxes(0,1)[0], dataset_drop.index)

vals = cf.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result2'] = pd.Series(vals, dataset_drop.index)

vals = cf2.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result3'] = pd.Series(vals, dataset_drop.index)

dataset_drop = dataset_drop.reset_index().set_index("date")

# %% [markdown]
# ## backtest

# %% [markdown]
# ## 把量加進來做篩選
#  * https://hahow.in/courses/5b9d3a6dca498a001e917383/shapeussions/60c96f5b018697e8a6131cbc

# %%
#把量加進來
vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

vol_filter=vol_ma5>1000
vol_filter=vol_filter[vol_filter].fillna(0)
#vol_filter
t1 = vol_filter

# %%
#condition2

# %%
vol_filter = t1.reindex(every_month, method='ffill')#.loc['2010-02-15']
#vol_filter.loc['2010-02-15']

# %%
#t1 = vol_ma5.iloc[-1].dropna()
#t1.to_csv('./tmp/132.csv')
#t1.hist(bins=10)

# %%
#市值
#t1 = (predi_target >= predi_target.nlargest(20).iloc[-1]) * condition_Filter_v2.astype(float)()

# %%
import math
from tqdm import tqdm

vol = 500
test_period = '2022-08'

dates = sorted(list(set(dataset_drop.index)))

rs = []
rs_v1 = []
rs_v2 = []
rs_v3 = []

for d in tqdm(dates):
    #print(d)
    dataset_time = dataset_drop.loc[d]
    
    dataset_time = drop_extreme_case(dataset_time , feature_names , thresh=0.01)
    
    #print(dataset_time)
    
    predi_target = dataset_time['result1'] + dataset_time['result2'] + dataset_time['result3'] 
    
    #predi_target = predi_target * (dataset_time['vol_ma5'] >vol).astype(float)
            ###

    
    condition1 = dataset_time['vol_ma5'] > vol
    condition_Filter_v1 = condition1
    predi_target_v1 = predi_target * condition_Filter_v1.astype(float)
    
    condition2 = (1e9 < dataset_time['市值']) < 1e10
    
    condition_Filter_v2 =  condition1 + condition2
    predi_target_v2 = predi_target * condition_Filter_v2.astype(float)
    
    condition_P = (predi_target >= predi_target.nlargest(20).iloc[-1])
    condition_v1 = (predi_target_v1 >= predi_target_v1.nlargest(20).iloc[-1])
    condition_v2 = (predi_target_v2 >= predi_target_v2.nlargest(20).iloc[-1])
    
    predi_target = predi_target * (dataset_time['vol_ma5'] >vol).astype(float)
    condition_v3 = (predi_target >= predi_target.nlargest(20).iloc[-1]) & condition_Filter_v2 #.astype(float)
    
    #print(vol_filter.loc[d])
    #print(condition)
    
    r = dataset_time['return'][condition_P].mean()
    rs.append(r * (1-3/1000-1.425/1000*2*0.6))
    
    r_v1 = dataset_time['return'][condition_v1].mean()
    rs_v1.append(r_v1 * (1-3/1000-1.425/1000*2*0.6))    
    
    r_v2 = dataset_time['return'][condition_v2].mean()
    rs_v2.append(r_v2 * (1-3/1000-1.425/1000*2*0.6))    

    r_v3 = dataset_time['return'][condition_v3].mean()
    rs_v3.append(r_v3 * (1-3/1000-1.425/1000*2*0.6))    
        
rs = pd.Series(rs, index=dates)[test_period:].cumprod()
rs_v1 = pd.Series(rs_v1, index=dates)[test_period:].cumprod() #*
rs_v2 = pd.Series(rs_v2, index=dates)[test_period:].cumprod() #*
rs_v3 = pd.Series(rs_v3, index=dates)[test_period:].cumprod() #*

s0050 = close['0050'][test_period:]

pd.DataFrame({'nn strategy return':rs.reindex(s0050.index, method='ffill'),
              'nn strategy return_V1(vol>100)':rs_v1.reindex(s0050.index, method='ffill'),
              #'nn strategy return_V2(vol+market cap)':rs_v2.reindex(s0050.index, method='ffill'),
              #'nn strategy return_V3(vol+market cap)':rs_v3.reindex(s0050.index, method='ffill'),
              '0050 return':s0050/s0050[0]
             }).plot()



#import winsound
#frequency = 2000
#duration = 100
#winsound.Beep(frequency, duration)

# %%
#import pickle
#
#return_history_1026 = pd.Series(rs, index=dates)['2021':].cumprod()
##eq = (gain[hold == 1].mean(axis=1)).fillna(1).cumprod()
#
#pickle.dump(rs, open('return_history_1026.pkl', 'wb'))

# %%
#import pyfolio as pf
#import pandas as pd
#
#close.index = close.index.tz_localize("Asia/Taipei")
##pf.create_returns_tear_sheet(close['0050'].pct_change())
#
## 得到 上一個單元的 回測結果
#ret = pickle.load(open("return_history_1026.pkl", "rb"))
#
## 將回測報酬率取出來
#ret = ret.pct_change().dropna()
#ret.index = pd.to_datetime(ret.index).tz_localize('Asia/Taipei')
#
## 利用pyfolio 比較報酬率
#pf.create_returns_tear_sheet(ret, benchmark_rets=close['0050'].pct_change())

# %% [markdown]
# ### 當月持股狀況

# %%
dataset.index.levels[1].max()

# %%
# get the latest dataset
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()


last_dataset = drop_extreme_case(last_dataset, feature_names , thresh=0.01)
t1 = last_dataset

# remove NaN testcases
last_dataset = last_dataset.dropna(subset=feature_names)

# predict

vals = model.predict(last_dataset[feature_names].astype(float))
last_dataset['result1'] = pd.Series(vals.swapaxes(0,1)[0], last_dataset.index)

vals = cf.predict(last_dataset[feature_names].astype(float))
last_dataset['result2'] = pd.Series(vals, last_dataset.index)

vals = cf2.predict(last_dataset[feature_names].astype(float))
last_dataset['result3'] = pd.Series(vals, last_dataset.index)


# calculate score

predi_target = last_dataset['result1'] + last_dataset['result2'] + last_dataset['result3']

#
##predi_target = predi_target * vol_filter.iloc[-1] #******加上量的濾網


predi_target = predi_target * (last_dataset['vol_ma5'] >vol).astype(float)  #排除平均成交量小於MA1000張
#predi_target = predi_target * (last_dataset['市值'] < 1e10).astype(float)   #排除市值小於100億以下的股票

condition0 = (predi_target >= predi_target.nlargest(20).iloc[-1])
condition1 = last_dataset['vol_ma5'] >vol
condition2 = last_dataset['市值'] < 1e10

condition = condition0 & condition1 #& condition2

#vol_filter

# plot rank distribution
predi_target[predi_target!=0].hist(bins=20)


# show the best 20 stocks
slist1 = predi_target[condition].reset_index()['stock_id']

#https://keras-cn.readthedocs.io/en/latest/models/model/

# %%
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()

# %%
#rank.sort_values(ascending=False).head(20)

# %% [markdown]
# ## 平均分配資產於股票之中

# %%
close = data.get("收盤價")

money = 494111-1000
stock_prices = close[slist1].iloc[-1]

print("股票平分金額:" + str(money/20))

print("股票平分張數:")
money / len(stock_prices) / stock_prices / 1000

# %%
last_dataset['市值'][slist1]

# %%
last_dataset['vol_ma5'][slist1]

# %% [markdown]
# ###################################################################################################
# ## 移動窗格最佳化
# [有空來試試看連結](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/61b4c90147843d0006cf2593)
#
# ###################################################################################################

# %%
from sklearn.ensemble import RandomForestClassifier

# 創建Random Forest模型
random_forest = RandomForestClassifier(n_estimators=100)

# 使用訓練資料訓練模型
random_forest.fit(X_train, y_train)

# 使用測試資料評估模型
accuracy = random_forest.score(X_test, y_test)
print("Random Forest 模型的準確率：", accuracy)

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

def select(df):
    rank = df['pre']
    condition1 = (rank >= rank.nlargest(1).iloc[-1])
    return df['return'][condition1].mean() * (1-3/1000-1.425/1000*2*0.6)

end = 5
cf = lgb.LGBMRegressor(n_estimators=500)
train_time = ['2015','2016','2017','2018','2019']
s_time = ['2007','2008','2009','2010','2011']
test_time = ['2016','2017','2018','2019','2020']
store_mse = []

# List to store the predictions
predictions = []

for time in range(end):
    print('%d 次執行中'%(time))
    dataset_dropna2_train = dataset_copy.loc[s_time[time]:train_time[time]] #2007~ 2015   2008~2016   2009~2017  2010~2018  ....
    dataset_dropna2_test = dataset_copy.loc[test_time[time]:test_time[time]]#            2016                2017               2018              2019  .....
    
    cf.fit(dataset_dropna2_train[feature_names].astype(float), dataset_dropna2_train['rank'])
    
    predict = cf.predict(dataset_dropna2_test[feature_names])
    dataset_dropna2_test['pre'] = predict
    predictions.append(dataset_dropna2_test['pre'])  # Save the predictions
    
    dates = dataset_dropna2_test.index.get_level_values('date')
    b = dataset_dropna2_test.groupby(dates).apply(select).cumprod()
    s0050 = close['0050'][test_time[time]:test_time[time]]
    s0056 = close['0056'][test_time[time]:test_time[time]]
    pd.DataFrame({'Best 1 stocks return(include handling fee)': b.reindex(s0050.index, method='ffill'),
                  '0050': s0050/s0050[0], '0056': s0056/s0056[0]}).plot()
    plt.ylabel('return')

# %%
def mystrategy(data):

    close = data.get("收盤價", 120)

    vol = data.get('成交股數', 120)
 

    condition1 = close.max() / close.min()

    rev = data.get("當月營收", 14)

    condition2 = (rev.iloc[-1] / rev.iloc[-13])

    condition3 = (rev.iloc[-2] / rev.iloc[-14])

    稅後淨利 = data.get('本期淨利（淨損）', 5)

    # 股東權益，有兩個名稱，有些公司叫做權益總計，有些叫做權益總額，所以得把它們抓出來

    權益總計 = data.get('權益總計', 5)

    權益總額 = data.get('權益總額', 5)

    # 並且把它們合併起來

    權益總計.fillna(權益總額, inplace=True)

    roe = 稅後淨利 / 權益總計

    condition4 = roe.iloc[-1] / roe.iloc[-5]

    select_stock = (condition1.rank() + # 該數值越小越好

    condition2.rank(ascending=False) + # 該值越大越好 

    condition3.rank(ascending=False) + # 該值越大越好

    condition4.rank(ascending=False) # 該值越大越好 

    ).rank() <= 10
    
    df=select_stock[select_stock]
    vol=vol[df.index].iloc[-1]
    cond_vol=vol>(1000*1000)

    return cond_vol[cond_vol]

# %%
stocks = mystrategy(data)
stocks

# %%
    權益總計 = data.get('權益總計', 5)

    權益總額 = data.get('權益總額', 5)

    # 並且把它們合併起來

    權益總計.fillna(權益總額, inplace=True)

# %%
權益總計

# %%
close = data.get("收盤價", 120)
vol = data.get('成交股數', 120)
condition1 = close.max() / close.min()
rev = data.get("當月營收", 14)
condition2 = (rev.iloc[-1] / rev.iloc[-13])
condition3 = (rev.iloc[-2] / rev.iloc[-14])
稅後淨利 = data.get('本期淨利（淨損）', 5)
# 股東權益，有兩個名稱，有些公司叫做權益總計，有些叫做權益總額，所以得把它們抓出來
權益總計 = data.get('權益總計', 5)
權益總額 = data.get('權益總額', 5)
# 並且把它們合併起來
權益總計.fillna(權益總額, inplace=True)
roe = 稅後淨利 / 權益總計
condition4 = roe.iloc[-1] / roe.iloc[-5]
select_stock = (condition1.rank() + # 該數值越小越好
condition2.rank(ascending=False) + # 該值越大越好 
condition3.rank(ascending=False) + # 該值越大越好
condition4.rank(ascending=False) # 該值越大越好 
).rank() <= 10
df=select_stock[select_stock]
vol=vol[df.index].iloc[-1]
cond_vol=vol>(1000*1000)

# %%
condition4

# %%
from tensorflow.keras.layers import Layer
from tensorflow.keras import initializers, regularizers, constraints
from tensorflow.keras import backend as K

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape = (input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape =(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
history = model.fit(
    dataset_train,  
    dataset_train > 1, 
    batch_size=2000, 
    epochs=10,
    validation_split=0.2, 
    callbacks=[get_best_model])

# %%
####################################
dataset_B = dataset

# %%
dataset.reset_index(inplace=True)
dataset = dataset.drop(columns=['stock_id']).set_index('date')
dataset

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()

# %%
import tqdm

n = 3

X = []
y = []
indexes = []
dataset_scaled_x = dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-n)):
    X.append(dataset_scaled_x.iloc[i:i+n].values)
    y.append(dataset_scaled['return'].iloc[i+n-1])
    indexes.append(dataset_scaled.index[i+n-1])
#dataset_scaled.head()

import numpy as np
X = np.array(X)
y = np.array(y)
indexes = np.array(indexes)

# %%
# from tensorflow.keras.engine.topology import Layer
from tensorflow.keras.layers import Layer
from tensorflow.keras import initializers, regularizers, constraints
from tensorflow.keras import backend as K


class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape = (input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape =(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

from tensorflow import keras

input_shape = X[0].shape # 還沒有 X ，請自己試試看！（參考u22-lstm.ipynb）
SEQ_LEN = input_shape[0]

model = keras.models.Sequential()

model.add(keras.layers.LSTM(128, input_shape=input_shape, return_sequences=True))
#model.add(keras.layers.Dropout(0.8))
#model.add(keras.layers.BatchNormalization())
model.add(Attention(SEQ_LEN))
model.add(keras.layers.Dense(32, activation="relu"))
#model.add(keras.layers.Dropout(0.8))
model.add(keras.layers.Dense(1))
model.compile(optimizer=keras.optimizers.Adam(0.0005), loss='binary_crossentropy' , metrics = ['accuracy'])

# %%
import datetime
X_train = X[indexes < datetime.datetime(2016, 1, 1)]
y_train = y[indexes < datetime.datetime(2016, 1, 1)]


get_best_model = keras.callbacks.ModelCheckpoint(
    filepath='./checkpoint_hw_4_1',
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)


history = model.fit(
    X_train,  
    y_train > 1, 
    batch_size=2000, 
    epochs=10,
    validation_split=0.2, 
    callbacks=[get_best_model])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# u22-lstm 程式碼(evaluation and backtest)
model.load_weights("./checkpoint_hw_4_1")
ey = model.predict(X)
ey = pd.Series(ey.swapaxes(0,1)[0], index=indexes)
ey.plot()

# %%
eq = close['0050']
returns = (eq.shift(-1) - eq)

signal = (ey > ey.quantile(0.6)).rolling(10).sum() > 0
signal = signal.shift(1).fillna(False)

eq = (returns[signal]['2021':]).cumsum()
eq.plot()

# %%
close['0050']
