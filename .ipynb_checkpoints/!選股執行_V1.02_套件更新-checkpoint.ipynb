# %% [markdown]
# # Final Project

# %%
# 移除不必要的警告
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 獲取歷史資料

# %%
from finlab.data import Data
#from finlab.ml import fundamental_features
#fdf = fundamental_features()

data = Data()

close = data.get("收盤價")
open_ = data.get("開盤價")
high = data.get("最高價")
low = data.get("最低價")
vol = data.get("成交股數")

PB = data.get("股價淨值比")
pe = data.get("本益比")

#bi = data.get("營業利益")


#close = data.get_adj("收盤價").round(2)

#財務指標
rev = data.get("當月營收")
l_rev = data.get("去年當月營收")

#t123 = data.get('土地')

bargin_i=data.get("投信買賣超股數")/data.get("成交股數")
bargin_f=data.get("外資自營商買賣超股數")/data.get("成交股數")
bargin_s=data.get("自營商買賣超股數(自行買賣)")/data.get("成交股數")
#

vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

rev.index = rev.index.shift(5, "d")         #每月頻率
#周頻率

# %% [markdown]
# ### 計算features

# %%
#MFI  = data.talib("MFI")
##MFI.tail()
#ub,mb,lb =data.talib("BBANDS")

# %% [markdown]
# #### 營收相關

# %%
##############################################　　　自己加入的　　　##############################################
import pandas as pd
from finlab.__init__ import talib_all_stock
from talib import abstract

# %%
def bias(n):
    return close / close.rolling(n, min_periods=1).mean()

def acc(n):
    return close.shift(n) / (close.shift(2*n) + close) * 2

def rsv(n):
    l = close.rolling(n, min_periods=1).min() 
    h = close.rolling(n, min_periods=1).max()
    
    return (close - l) / (h - l)

def mom(n):
    return (rev / rev.shift(1)).shift(n)

def yoy(n):
    if rev.shift(12+n) < 0:## or (rev.shift(n) < 0):
   ##     return 0
   ## else :
        return (rev.shift(n) / rev.shift(12+n)) -1

def bi(n):
    return bargin_i/bargin_i.rolling(n).mean()

def bf(n):
    return bargin_f/bargin_f.rolling(n).mean()
    
def bs(n):
    return bargin_s/bargin_s.rolling(n).mean()

#-------------------------------------------

features = {
    'mom1': mom(1),
    'mom2': mom(2),
    'mom3': mom(3),
    'mom4': mom(4),
    'mom5': mom(5),
    'mom6': mom(6),
    'mom7': mom(7),
    'mom8': mom(8),
    'mom9': mom(9),

    
    'bias5': bias(5),
    'bias10': bias(10),
    'bias20': bias(20),
    'bias60': bias(60),
    'bias120': bias(120),
    'bias240': bias(240),
    
    'acc5': acc(5),
    'acc10': acc(10),
    'acc20': acc(20),
    'acc60': acc(60),
    'acc120': acc(120),
    'acc240': acc(240),
    
    'rsv5': rsv(5),
    'rsv10': rsv(10),
    'rsv20': rsv(20),
    'rsv60': rsv(60),
    'rsv120': rsv(120),
    'rsv240': rsv(240),
###############################################
    'yoy': yoy(1),
    'delta_yoy':yoy(1)-yoy(2),
    
    'PB':PB,
    'PE':pe,
    
    #'v/ma':vol/vol_ma5,
   #'bi5' : bi(5),
   #'bi10' : bi(10),
   #'bi20' : bi(20),
   #'bi60' : bi(60),
   # 
   #'bf5' : bf(5),
   # #'bf10' : bf(10),
   # #'bf20' : bf(20),
   # #'bf60' : bf(60),
   # 
   # 'bs5' : bs(5),
   # 'bs10' : bs(10),
   # 'bs20' : bs(20),
   # 'bs60' : bs(60),
    
}
# Out:
#   File "C:\Users\orang\AppData\Local\Temp\ipykernel_13892\246770419.py", line 14
#     if
#        ^
# SyntaxError: invalid syntax

# %%
yoy(0)
# Out:
# stock_id        1101      1102      1103      1104  1107      1108      1109  \
# date
# 2005-02-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2005-03-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2005-04-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2005-05-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2005-06-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# ...              ...       ...       ...       ...   ...       ...       ...
# 2022-11-15  0.188504 -0.196042  0.084332  0.136037   NaN  0.449827 -0.201942
# 2022-12-15 -0.008009 -0.075633  0.121301  0.066769   NaN  0.431791 -0.143446
# 2023-01-15  0.162910 -0.113063  0.333061  0.272864   NaN  0.309856 -0.336393
# 2023-02-15 -0.025629 -0.351210  0.209836 -0.148473   NaN -0.091673 -0.474314
# 2023-03-15  0.339072  0.522002  0.574272  0.698135   NaN  0.717416  1.262398
#
# stock_id        1110      1201      1203  ...      9944      9945      9946  \
# date                                      ...
# 2005-02-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2005-03-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2005-04-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2005-05-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2005-06-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# ...              ...       ...       ...  ...       ...       ...       ...
# 2022-11-15  0.304901  0.005675  0.212145  ...  0.010391  0.178078 -0.673026
# 2022-12-15  0.234091 -0.024680  0.384607  ... -0.037130  0.413395 -0.057254
# 2023-01-15 -0.092717 -0.099534  0.200326  ... -0.138579  0.619756 -0.773686
# 2023-02-15 -0.173711 -0.050133 -0.085944  ... -0.347208 -0.330394 -0.703003
# 2023-03-15  0.787794  0.153275  0.136535  ... -0.003137  0.870228 -0.314591
#
# stock_id        9949      9950      9951      9955      9958      9960  \
# date
# 2005-02-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-03-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-04-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-05-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-15       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-11-15  0.048772 -0.156177  0.245812 -0.294261  0.004491  0.010218
# 2022-12-15 -0.179187  1.294386  0.322786 -0.276645  0.101934  0.063968
# 2023-01-15 -0.041727  1.189093  0.225264 -0.463853  0.165291 -0.309252
# 2023-02-15 -0.215372  0.128140 -0.142444 -0.464537 -0.120989 -0.058771
# 2023-03-15 -0.176815  0.214471  0.215990 -0.350520  0.002525  0.314465
#
# stock_id        9962
# date
# 2005-02-15       NaN
# 2005-03-15       NaN
# 2005-04-15       NaN
# 2005-05-15       NaN
# 2005-06-15       NaN
# ...              ...
# 2022-11-15  0.129923
# 2022-12-15 -0.084119
# 2023-01-15  0.568746
# 2023-02-15  0.330021
# 2023-03-15  0.221827
#
# [218 rows x 2021 columns]

# %%
#bi(60).dropna(how='all')

# %% [markdown]
# #### 財報指標

# %% [markdown]
# 兩個feature結合[[連結網址]](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7)
#
# ---
# ```python
# from finlab import ml
# from finlab.data import Data
#
# data = Data()
# rsi = data.talib("RSI")
#
# dataset = ml.fundamental_features()
# ml.add_feature(dataset, 'RSI', rsi)
# ```

# %%
from finlab.ml import fundamental_features
dataset_fundamental = fundamental_features()

# %%
#dataset_fundamental

# %% [markdown]
# #### 技術指標

# %% [raw]
# # https://zhuanlan.zhihu.com/p/342075180 talib函数功能一览表
#
# def bias(n):
#     return close / close.rolling(n, min_periods=1).mean()
#
# def acc(n):
#     return close.shift(n) / (close.shift(2*n) + close) * 2
#
# def rsv(n):
#     l = close.rolling(n, min_periods=1).min()
#     h = close.rolling(n, min_periods=1).max()
#
#     return (close - l) / (h - l)
#
# def mom(n):
#     return (rev / rev.shift(1)).shift(n)
#
#
# def bi_(n):
#     return (bargin_i / vol.shift(1)).shift(n)
#
# def bf(n):
#     return (bargin_f / vol.shift(1)).shift(n)
#
# def bs(n):
#     return (bargin_s / vol.shift(1)).shift(n)
#
# def rsi(n):
#     #return talib_all_stock(ndays=10000, func=abstract.RSI, timeperiod=n)
#     return data.talib("RSI",timeperiod=n)
#
# def MFI(n):
#     return data.talib("MFI",timeperiod=n)
#
# def obv(n):
#     return data.talib("OBV",timeperiod=n)
#
#
#
# features = {
#
#     #'ATR14':data.talib("ATR",timeperiod=14),
#     #'NATR14':data.talib('NATR',timeperiod=14),
#     #'TRANGE':data.talib('TRANGE'),
#     #'Adosc3':data.talib('ADOSC',timeperiod=3),
#
#     #"MFI5":MFI(5),
#     #"MFI10":MFI(10),
#
#     #'rsi6': rsi(6),  #DataFrame
#     #'rsi10': rsi(10),  #DataFrame
#     #'rsi14': rsi(14),  #DataFrame
#     #'rsi20': rsi(20),  #DataFrame
#     #'rsi50': rsi(50),  #DataFrame
#
#     'mom1': mom(1),
#     'mom2': mom(2),
#     'mom3': mom(3),
#     'mom4': mom(4),
#     'mom5': mom(5),
#     'mom6': mom(6),
#     'mom7': mom(7),
#     'mom8': mom(8),
#     'mom9': mom(9),
#
#     'yoy': yoy(1),
#     'delta_yoy':yoy(1)-yoy(2),
#
# #    'ff':ff,
#     'PB':PB,
#     'PE':pe,
# #
#     'bias5': bias(5),
#     'bias10': bias(10),
#     'bias20': bias(20),
#     'bias60': bias(60),
#     'bias120': bias(120),
#     'bias240': bias(240),
#
#     'acc5': acc(5),
#     'acc10': acc(10),
#     'acc20': acc(20),
#     'acc60': acc(60),
#     'acc120': acc(120),
#     'acc240': acc(240),
#
#     #'rsv5': rsv(5),
#     #'rsv10': rsv(10),
#     #'rsv20': rsv(20),
#     #'rsv60': rsv(60),
#     #'rsv120': rsv(120),
#     #'rsv240': rsv(240),
# }

# %% [raw]
# ```
# https://www.twblogs.net/a/5d3f3173bd9eee517422735f
# W-WED
# https://docs.python.org/zh-tw/3/library/calendar.html
# ```

# %% [markdown]
# 加入其他features
# * http://finlabcourse.imotor.com/viewthread.php?tid=660&extra=page%3D1
#
# ```python
# from finlab import ml
# from finlab.data import Data
#
# data = Data()
# rsi = data.talib("RSI")
#
# dataset = ml.fundamental_features()
# ml.add_feature(dataset, 'RSI', rsi)
# ```

# %% [markdown]
# #### 組合dataset

# %%
import pandas as pd

# %% [markdown]
# #### 確認各指標清單

# %%
#t1 = data.talib("NATR",timeperiod=14)
#t1.to_csv('myfile.csv')

# %% [markdown]
# ### 製作dataset
#
# ##### 設定買賣頻率

# %%
#rev.index = rev.index.tz_localize("Asia/Taipei")
every_month = rev.index
every_month
# Out:
# DatetimeIndex(['2005-02-15', '2005-03-15', '2005-04-15', '2005-05-15',
#                '2005-06-15', '2005-07-15', '2005-08-15', '2005-09-15',
#                '2005-10-15', '2005-11-15',
#                ...
#                '2022-06-15', '2022-07-15', '2022-08-15', '2022-09-15',
#                '2022-10-15', '2022-11-15', '2022-12-15', '2023-01-15',
#                '2023-02-15', '2023-03-15'],
#               dtype='datetime64[ns]', name='date', length=218, freq=None)

# %% [markdown]
# #### 將dataframe 組裝起來

# %%
# features['bias20'].reindex(every_month, method='ffill')

for name, f in features.items():
    features[name] = f.reindex(every_month, method='ffill')

# %%
for name, f in features.items():
    features[name] = f.unstack()

# %%
import pandas as pd
dataset = pd.DataFrame(features)

# %%
feature_names = list(dataset.columns)

# %% [markdown]
# ##### 裝自己要的

# %%
from finlab import ml

# %%
股本 = data.get('股本合計').reindex(close.index, method='ffill')
市值 = 股本 * close / 10 * 1000
#t1['2330'].dropna()
ml.add_feature(dataset, '市值', 市值)

# %%
ml.add_feature(dataset, 'vol_ma5', vol_ma5)

dataset
# Out:
#                          mom1      mom2      mom3      mom4      mom5  \
# stock_id date
# 0015     2005-02-15       NaN       NaN       NaN       NaN       NaN
#          2005-03-15       NaN       NaN       NaN       NaN       NaN
#          2005-04-15       NaN       NaN       NaN       NaN       NaN
#          2005-05-15       NaN       NaN       NaN       NaN       NaN
#          2005-06-15       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 9962     2022-11-15  0.830797  1.280940  0.641536  1.694666  0.917472
#          2022-12-15  1.163303  0.830797  1.280940  0.641536  1.694666
#          2023-01-15  1.004024  1.163303  0.830797  1.280940  0.641536
#          2023-02-15  1.249495  1.004024  1.163303  0.830797  1.280940
#          2023-03-15  0.729045  1.249495  1.004024  1.163303  0.830797
#
#                          mom6      mom7      mom8      mom9     bias5  ...  \
# stock_id date                                                          ...
# 0015     2005-02-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-03-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-04-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-05-15       NaN       NaN       NaN       NaN       NaN  ...
#          2005-06-15       NaN       NaN       NaN       NaN       NaN  ...
# ...                       ...       ...       ...       ...       ...  ...
# 9962     2022-11-15  0.678559  1.435387  1.209077  0.859901  1.024242  ...
#          2022-12-15  0.917472  0.678559  1.435387  1.209077  1.024939  ...
#          2023-01-15  1.694666  0.917472  0.678559  1.435387  1.004331  ...
#          2023-02-15  0.641536  1.694666  0.917472  0.678559  1.005587  ...
#          2023-03-15  1.280940  0.641536  1.694666  0.917472  1.001813  ...
#
#                         rsv20    rsv60    rsv120    rsv240       yoy  \
# stock_id date
# 0015     2005-02-15       NaN      NaN       NaN       NaN       NaN
#          2005-03-15       NaN      NaN       NaN       NaN       NaN
#          2005-04-15       NaN      NaN       NaN       NaN       NaN
#          2005-05-15       NaN      NaN       NaN       NaN       NaN
#          2005-06-15       NaN      NaN       NaN       NaN       NaN
# ...                       ...      ...       ...       ...       ...
# 9962     2022-11-15  1.000000  1.00000  0.933962  0.440000  0.003516
#          2022-12-15  1.000000  0.98750  0.989899  0.435556  0.129923
#          2023-01-15  0.895833  0.94382  0.957627  0.586667 -0.084119
#          2023-02-15  1.000000  1.00000  1.000000  0.697778  0.568746
#          2023-03-15  0.927273  0.96875  0.978723  0.902222  0.330021
#
#                      delta_yoy    PB    PE            市值    vol_ma5
# stock_id date
# 0015     2005-02-15        NaN   NaN   NaN           NaN        NaN
#          2005-03-15        NaN   NaN   NaN           NaN        NaN
#          2005-04-15        NaN   NaN   NaN           NaN        NaN
#          2005-05-15        NaN   NaN   NaN           NaN        NaN
#          2005-06-15        NaN   NaN   NaN           NaN        NaN
# ...                        ...   ...   ...           ...        ...
# 9962     2022-11-15  -0.722271  1.33  7.01  1.524723e+09   462.1834
#          2022-12-15   0.126406  1.32  6.99  1.520212e+09   632.1574
#          2023-01-15  -0.214041  1.46  7.70  1.673587e+09  3007.9848
#          2023-02-15   0.652864  1.55  8.22  1.786362e+09   932.8926
#          2023-03-15  -0.238725  1.73  9.17  1.993869e+09  1073.6878
#
# [447554 rows x 33 columns]

# %%
##############################################　　　自己加入的　　　##############################################
dataset.index = dataset.index.set_names(['stock_id','date'], level=[0,1])


#dataset.index.levels[1].name = 'date'
#dataset.index.levels[0].name = 'stock_id'

#因為你pandas更新到新版了
## profit.index.levels[0].name = 'year'
## profit.index.levels[1].name = 'month'
#這兩行的語法被棄用，請改成
#profit.index=profit.index.set_names('year', level=0)
#profit.index=profit.index.set_names('month', level=1)
#or profit.index=profit.index.set_names(['year','month'], level=[0,1])
#直接一行
#就可以了

# %%
#list(dataset_fundamental.index)

# %%
#dataset_fundamental.reindex(dataset.index).dropna()

# %% [markdown]
# data[組合](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7)
# ```python
# new_df = pd.concat([dataset_fundamental['R406_經常利益成長率'],dataset],axis=1).dropna(how='any')
# ```

# %%
new_df = pd.concat([dataset_fundamental,dataset],axis=1).dropna(how='any')
dataset1 = new_df.fillna(method='ffill')#[(new_df.index.get_level_values('stock_id')=='2330')]
#dataset = dataset1

# %%
#feature_names=list(dataset1.columns)
#feature_names

# %% [markdown]
# ### 新增 label(績效/排名)
#  - 定義一下要比績效還是要比排名

# %%
from finlab import ml

ml.add_profit_prediction(dataset)
ml.add_rank_prediction(dataset)

# %%
#profit(return) rank
predi_target = 'rank'

# %% [markdown]
# ### 刪除太大太小的歷史資料

# %%
print(dataset.shape)

def drop_extreme_case(dataset, feature_names, thresh=0.01):
    
    extreme_cases = pd.Series(False, index=dataset.index)
    for f in feature_names:
        tf = dataset[f]
        extreme_cases = extreme_cases | (tf < tf.quantile(thresh)) | (tf > tf.quantile(1-thresh))
    dataset = dataset[~extreme_cases]
    return dataset

dataset_drop_extreme_case = drop_extreme_case(dataset , feature_names , thresh=0.01)

print(dataset_drop_extreme_case.shape)

##(436774, 25)
##(388157, 25)
# Out:
# (447554, 35)
# (387226, 35)

# %%
dataset_dropna = dataset_drop_extreme_case.dropna(how='any')
dataset_dropna = dataset_dropna.reset_index().set_index("date")

# %%
#dataset_drop_extreme_case.index.get_level_values("date")

# %%
##################################################################################################################
##############################################　　　自己加入的　　　##############################################
##################################################################################################################

dataset_dropna.index = pd.to_datetime(dataset_dropna.index)
dataset_dropna = dataset_dropna.sort_index()

#修復＜class ‘numpy.ndarray‘＞　https://blog.csdn.net/lxbin/article/details/114005757

# %% [markdown]
# ## Split Train Test dataset

# %%
dataset_train = dataset_dropna.loc[:'2020']
dataset_test = dataset_dropna.loc['2021':]

#date_arr = dataset.index.get_level_values('date') < '2020'
#dataset_train = dataset[date_arr]
#dataset_test = dataset[~date_arr]

# %%
train = dataset_train[feature_names] , dataset_train['return'] > 1.02
test = dataset_test[feature_names] , dataset_test['return'] > 1.00

# %% [markdown]
# ### 機器學習
#  - 目前只有三個，技術指標也要再增加一下feature_names

# %%
#feature_names = feature_names1

# %%
#dataset_train.index

# %% [markdown]
# #### kerascolumns

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers

import os


os.environ['KMP_DUPLICATE_LIB_OK']='True'

model = keras.models.Sequential()
model.add(layers.Dense(100, activation='relu',
                      input_shape=(len(feature_names),),
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dense(100, activation='relu',
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dropout(0.7))
model.add(layers.Dense(1, activation='sigmoid'))


model.summary()

model.compile(loss='mean_squared_error',
              optimizer="adam",)

print('start fitting')
history = model.fit(dataset_train[feature_names], dataset_train[predi_target],
                    batch_size=1000,         #1000  #每一个batch的大小
                    epochs=1000, #225          #迭代次数
                    verbose=1,
                    validation_split=0.1,
                    #validation_data =        #(测试集的输入特征，测试集的标签），
                    #validation_split =       # 从测试集中划分多少比例给训练集，
                    #validation_freq = 20        #测试的epoch间隔数                     
                   )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               3200
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 13,401
# Trainable params: 13,401
# Non-trainable params: 0
# _________________________________________________________________
# start fitting
# Epoch 1/1000
# 75/75 [==============================] - 1s 5ms/step - loss: 0.1791 - val_loss: 0.0699
# Epoch 2/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0739 - val_loss: 0.0699
# Epoch 3/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0738 - val_loss: 0.0700
# Epoch 4/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0737 - val_loss: 0.0701
# Epoch 5/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0737 - val_loss: 0.0699
# Epoch 6/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0737 - val_loss: 0.0699
# Epoch 7/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0736 - val_loss: 0.0699
# Epoch 8/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0737 - val_loss: 0.0699
# Epoch 9/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0736 - val_loss: 0.0699
# Epoch 10/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0736 - val_loss: 0.0700
# Epoch 11/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0736 - val_loss: 0.0699
# Epoch 12/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0736 - val_loss: 0.0699
# Epoch 13/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0736 - val_loss: 0.0698
# Epoch 14/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0736 - val_loss: 0.0699
# Epoch 15/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0698
# Epoch 16/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0698
# Epoch 17/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0698
# Epoch 18/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0699
# Epoch 19/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0698
# Epoch 20/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0698
# Epoch 21/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0699
# Epoch 22/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0698
# Epoch 23/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0698
# Epoch 24/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0698
# Epoch 25/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0699
# Epoch 26/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0697
# Epoch 27/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0698
# Epoch 28/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0698
# Epoch 29/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0697
# Epoch 30/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0697
# Epoch 31/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0699
# Epoch 32/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0699
# Epoch 33/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0697
# Epoch 34/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0698
# Epoch 35/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0699
# Epoch 36/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0698
# Epoch 37/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0697
# Epoch 38/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0698
# Epoch 39/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0698
# Epoch 40/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0698
# Epoch 41/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0697
# Epoch 42/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0698
# Epoch 43/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0697
# Epoch 44/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0700
# Epoch 45/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0698
# Epoch 46/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0698
# Epoch 47/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0697
# Epoch 48/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0698
# Epoch 49/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0697
# Epoch 50/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0698
# Epoch 51/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0698
# Epoch 52/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0697
# Epoch 53/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0697
# Epoch 54/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0697
# Epoch 55/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0697
# Epoch 56/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0697
# Epoch 57/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0697
# Epoch 58/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0697
# Epoch 59/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0696
# Epoch 60/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0699
# Epoch 61/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0698
# Epoch 62/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0699
# Epoch 63/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0699
# Epoch 64/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0696
# Epoch 65/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0698
# Epoch 66/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0696
# Epoch 67/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0698
# Epoch 68/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0699
# Epoch 69/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0699
# Epoch 70/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0697
# Epoch 71/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0699
# Epoch 72/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0698
# Epoch 73/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0698
# Epoch 74/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0698
# Epoch 75/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0697
# Epoch 76/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0701
# Epoch 77/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0698
# Epoch 78/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0696
# Epoch 79/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0700
# Epoch 80/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0699
# Epoch 81/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0698
# Epoch 82/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0696
# Epoch 83/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0698
# Epoch 84/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0697
# Epoch 85/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0696
# Epoch 86/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0697
# Epoch 87/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0696
# Epoch 88/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0696
# Epoch 89/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0696
# Epoch 90/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0731 - val_loss: 0.0696
# Epoch 91/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0696
# Epoch 92/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0696
# Epoch 93/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0697
# Epoch 94/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0696
# Epoch 95/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0698
# Epoch 96/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0698
# Epoch 97/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0697
# Epoch 98/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0697
# Epoch 99/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0696
# Epoch 100/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0698
# Epoch 101/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0697
# Epoch 102/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0697
# Epoch 103/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0696
# Epoch 104/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0699
# Epoch 105/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0697
# Epoch 106/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0699
# Epoch 107/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0696
# Epoch 108/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0696
# Epoch 109/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0699
# Epoch 110/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0699
# Epoch 111/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0699
# Epoch 112/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0697
# Epoch 113/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0702
# Epoch 114/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0699
# Epoch 115/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0696
# Epoch 116/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0698
# Epoch 117/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0696
# Epoch 118/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0697
# Epoch 119/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0696
# Epoch 120/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0699
# Epoch 121/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0697
# Epoch 122/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0699
# Epoch 123/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0698
# Epoch 124/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0700
# Epoch 125/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0699
# Epoch 126/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0697
# Epoch 127/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0698
# Epoch 128/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0695
# Epoch 129/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0699
# Epoch 130/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0702
# Epoch 131/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0696
# Epoch 132/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0697
# Epoch 133/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0697
# Epoch 134/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0698
# Epoch 135/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0696
# Epoch 136/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0696
# Epoch 137/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0699
# Epoch 138/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0697
# Epoch 139/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0698
# Epoch 140/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0702
# Epoch 141/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0702
# Epoch 142/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0697
# Epoch 143/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0698
# Epoch 144/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0699
# Epoch 145/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0700
# Epoch 146/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0696
# Epoch 147/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0701
# Epoch 148/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0697
# Epoch 149/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0702
# Epoch 150/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0696
# Epoch 151/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0696
# Epoch 152/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0699
# Epoch 153/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0701
# Epoch 154/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0700
# Epoch 155/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0698
# Epoch 156/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0699
# Epoch 157/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0700
# Epoch 158/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0697
# Epoch 159/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0697
# Epoch 160/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0699
# Epoch 161/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0696
# Epoch 162/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 163/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 164/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0727 - val_loss: 0.0696
# Epoch 165/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0697
# Epoch 166/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0696
# Epoch 167/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0696
# Epoch 168/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 169/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0697
# Epoch 170/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0699
# Epoch 171/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 172/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0698
# Epoch 173/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 174/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 175/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0697
# Epoch 176/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0696
# Epoch 177/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0699
# Epoch 178/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 179/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 180/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0697
# Epoch 181/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0699
# Epoch 182/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0697
# Epoch 183/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 184/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0705
# Epoch 185/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0699
# Epoch 186/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 187/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 188/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0699
# Epoch 189/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0700
# Epoch 190/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0702
# Epoch 191/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0697
# Epoch 192/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0697
# Epoch 193/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0724 - val_loss: 0.0699
# Epoch 194/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0698
# Epoch 195/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0698
# Epoch 196/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0697
# Epoch 197/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0698
# Epoch 198/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0698
# Epoch 199/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0698
# Epoch 200/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0699
# Epoch 201/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0701
# Epoch 202/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0702
# Epoch 203/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0700
# Epoch 204/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0698
# Epoch 205/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0697
# Epoch 206/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0698
# Epoch 207/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0699
# Epoch 208/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0697
# Epoch 209/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0701
# Epoch 210/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0697
# Epoch 211/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0699
# Epoch 212/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0702
# Epoch 213/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0697
# Epoch 214/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0700
# Epoch 215/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0702
# Epoch 216/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0700
# Epoch 217/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0699
# Epoch 218/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0698
# Epoch 219/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0700
# Epoch 220/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0699
# Epoch 221/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0699
# Epoch 222/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0724 - val_loss: 0.0698
# Epoch 223/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0699
# Epoch 224/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0700
# Epoch 225/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0700
# Epoch 226/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0704
# Epoch 227/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0699
# Epoch 228/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0709
# Epoch 229/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0701
# Epoch 230/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0700
# Epoch 231/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0698
# Epoch 232/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0698
# Epoch 233/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0699
# Epoch 234/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0702
# Epoch 235/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0707
# Epoch 236/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0699
# Epoch 237/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0700
# Epoch 238/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0698
# Epoch 239/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0699
# Epoch 240/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0701
# Epoch 241/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0698
# Epoch 242/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0704
# Epoch 243/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0702
# Epoch 244/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0703
# Epoch 245/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0701
# Epoch 246/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0701
# Epoch 247/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0723 - val_loss: 0.0706
# Epoch 248/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0700
# Epoch 249/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0702
# Epoch 250/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0700
# Epoch 251/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0701
# Epoch 252/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0701
# Epoch 253/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0702
# Epoch 254/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0701
# Epoch 255/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0700
# Epoch 256/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0707
# Epoch 257/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0699
# Epoch 258/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0705
# Epoch 259/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0701
# Epoch 260/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0701
# Epoch 261/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0700
# Epoch 262/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0699
# Epoch 263/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0698
# Epoch 264/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0699
# Epoch 265/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0704
# Epoch 266/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0700
# Epoch 267/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0722 - val_loss: 0.0702
# Epoch 268/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0701
# Epoch 269/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0701
# Epoch 270/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0702
# Epoch 271/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0701
# Epoch 272/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0702
# Epoch 273/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0701
# Epoch 274/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0700
# Epoch 275/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0702
# Epoch 276/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0704
# Epoch 277/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0702
# Epoch 278/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0700
# Epoch 279/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0702
# Epoch 280/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0701
# Epoch 281/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0702
# Epoch 282/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0701
# Epoch 283/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0700
# Epoch 284/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0700
# Epoch 285/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0700
# Epoch 286/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0699
# Epoch 287/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0703
# Epoch 288/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0701
# Epoch 289/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0701
# Epoch 290/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0703
# Epoch 291/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0721 - val_loss: 0.0704
# Epoch 292/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0701
# Epoch 293/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0703
# Epoch 294/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0705
# Epoch 295/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0704
# Epoch 296/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0703
# Epoch 297/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0700
# Epoch 298/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0706
# Epoch 299/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0711
# Epoch 300/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0701
# Epoch 301/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0702
# Epoch 302/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0700
# Epoch 303/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0702
# Epoch 304/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0704
# Epoch 305/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0704
# Epoch 306/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0706
# Epoch 307/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0702
# Epoch 308/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0703
# Epoch 309/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0702
# Epoch 310/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0719 - val_loss: 0.0701
# Epoch 311/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0700
# Epoch 312/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0700
# Epoch 313/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0704
# Epoch 314/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0701
# Epoch 315/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0699
# Epoch 316/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0700
# Epoch 317/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0705
# Epoch 318/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0701
# Epoch 319/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0702
# Epoch 320/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0700
# Epoch 321/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0704
# Epoch 322/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0706
# Epoch 323/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0705
# Epoch 324/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0705
# Epoch 325/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0702
# Epoch 326/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0702
# Epoch 327/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0703
# Epoch 328/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0706
# Epoch 329/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0708
# Epoch 330/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0702
# Epoch 331/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0704
# Epoch 332/1000
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0719 - val_loss: 0.0704
# Epoch 333/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0704
# Epoch 334/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0704
# Epoch 335/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0701
# Epoch 336/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0704
# Epoch 337/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0708
# Epoch 338/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0707
# Epoch 339/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0702
# Epoch 340/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0701
# Epoch 341/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0707
# Epoch 342/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0704
# Epoch 343/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0703
# Epoch 344/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0701
# Epoch 345/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0703
# Epoch 346/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0704
# Epoch 347/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0705
# Epoch 348/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0702
# Epoch 349/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0702
# Epoch 350/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0704
# Epoch 351/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0704
# Epoch 352/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0706
# Epoch 353/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0706
# Epoch 354/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0705
# Epoch 355/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0707
# Epoch 356/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0704
# Epoch 357/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0702
# Epoch 358/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0703
# Epoch 359/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0704
# Epoch 360/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0708
# Epoch 361/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0704
# Epoch 362/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0706
# Epoch 363/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0706
# Epoch 364/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0708
# Epoch 365/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0709
# Epoch 366/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0709
# Epoch 367/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0706
# Epoch 368/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0705
# Epoch 369/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0717 - val_loss: 0.0706
# Epoch 370/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0706
# Epoch 371/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0706
# Epoch 372/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0705
# Epoch 373/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0703
# Epoch 374/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0705
# Epoch 375/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0707
# Epoch 376/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0705
# Epoch 377/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0702
# Epoch 378/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0706
# Epoch 379/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0708
# Epoch 380/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0709
# Epoch 381/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0706
# Epoch 382/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0708
# Epoch 383/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0717 - val_loss: 0.0708
# Epoch 384/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0704
# Epoch 385/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0717 - val_loss: 0.0709
# Epoch 386/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0704
# Epoch 387/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0703
# Epoch 388/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0709
# Epoch 389/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0706
# Epoch 390/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0705
# Epoch 391/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0706
# Epoch 392/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0709
# Epoch 393/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0708
# Epoch 394/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0718 - val_loss: 0.0707
# Epoch 395/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0705
# Epoch 396/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0707
# Epoch 397/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0710
# Epoch 398/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0710
# Epoch 399/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0717 - val_loss: 0.0707
# Epoch 400/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0707
# Epoch 401/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0708
# Epoch 402/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0709
# Epoch 403/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0706
# Epoch 404/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0707
# Epoch 405/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0707
# Epoch 406/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0717 - val_loss: 0.0705
# Epoch 407/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0706
# Epoch 408/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0715 - val_loss: 0.0711
# Epoch 409/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0716 - val_loss: 0.0714
# Epoch 410/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0705
# Epoch 411/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0717 - val_loss: 0.0705
# Epoch 412/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0712
# Epoch 413/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0706
# Epoch 414/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0716 - val_loss: 0.0706
# Epoch 415/1000
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0717 - val_loss: 0.0710
# Epoch 416/1000
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0716 - val_loss: 0.0709
# Epoch 417/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0717 - val_loss: 0.0707
# Epoch 418/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0707
# Epoch 419/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0716 - val_loss: 0.0709
# Epoch 420/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0709
# Epoch 421/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0709
# Epoch 422/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0713
# Epoch 423/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0707
# Epoch 424/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0707
# Epoch 425/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0715 - val_loss: 0.0710
# Epoch 426/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0708
# Epoch 427/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0706
# Epoch 428/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0715 - val_loss: 0.0707
# Epoch 429/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0707
# Epoch 430/1000
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0714 - val_loss: 0.0711
# Epoch 431/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0716 - val_loss: 0.0710
# Epoch 432/1000
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0716 - val_loss: 0.0707
# Epoch 433/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0716 - val_loss: 0.0704
# Epoch 434/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0715 - val_loss: 0.0710
# Epoch 435/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0706
# Epoch 436/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0707
# Epoch 437/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0715 - val_loss: 0.0708
# Epoch 438/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0715 - val_loss: 0.0707
# Epoch 439/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0716 - val_loss: 0.0710
# Epoch 440/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0714 - val_loss: 0.0706
# Epoch 441/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0715 - val_loss: 0.0711
# Epoch 442/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0715 - val_loss: 0.0711
# Epoch 443/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0711
# Epoch 444/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0715 - val_loss: 0.0709
# Epoch 445/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0715 - val_loss: 0.0709
# Epoch 446/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0712
# Epoch 447/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0714 - val_loss: 0.0708
# Epoch 448/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0710
# Epoch 449/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0714 - val_loss: 0.0713
# Epoch 450/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0708
# Epoch 451/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0715 - val_loss: 0.0707
# Epoch 452/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0713 - val_loss: 0.0708
# Epoch 453/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0714 - val_loss: 0.0712
# Epoch 454/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0710
# Epoch 455/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0714 - val_loss: 0.0708
# Epoch 456/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0716
# Epoch 457/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0714 - val_loss: 0.0714
# Epoch 458/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0714 - val_loss: 0.0708
# Epoch 459/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0714 - val_loss: 0.0706
# Epoch 460/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0709
# Epoch 461/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0715 - val_loss: 0.0709
# Epoch 462/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0714 - val_loss: 0.0714
# Epoch 463/1000
# ...
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0722
# Epoch 845/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 846/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0720
# Epoch 847/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 848/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0729
# Epoch 849/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0720
# Epoch 850/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0725
# Epoch 851/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0722
# Epoch 852/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0726
# Epoch 853/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0722
# Epoch 854/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0723
# Epoch 855/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0722
# Epoch 856/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0719
# Epoch 857/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0720
# Epoch 858/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 859/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0717
# Epoch 860/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0721
# Epoch 861/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0721
# Epoch 862/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0731
# Epoch 863/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0723
# Epoch 864/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0725
# Epoch 865/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0726
# Epoch 866/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 867/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0718
# Epoch 868/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 869/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0717
# Epoch 870/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0720
# Epoch 871/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0723
# Epoch 872/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 873/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0722
# Epoch 874/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0720
# Epoch 875/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0725
# Epoch 876/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0721
# Epoch 877/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0720
# Epoch 878/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0725
# Epoch 879/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0720
# Epoch 880/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0721
# Epoch 881/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0725
# Epoch 882/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0720
# Epoch 883/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0728
# Epoch 884/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 885/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0720
# Epoch 886/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0722
# Epoch 887/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 888/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 889/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 890/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0717
# Epoch 891/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0720
# Epoch 892/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0719
# Epoch 893/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0718
# Epoch 894/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0720
# Epoch 895/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0719
# Epoch 896/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0719
# Epoch 897/1000
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0704 - val_loss: 0.0724
# Epoch 898/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0719
# Epoch 899/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0720
# Epoch 900/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0705 - val_loss: 0.0719
# Epoch 901/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0728
# Epoch 902/1000
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0705 - val_loss: 0.0717
# Epoch 903/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0722
# Epoch 904/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0720
# Epoch 905/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721
# Epoch 906/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0725
# Epoch 907/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0725
# Epoch 908/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0725
# Epoch 909/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0724
# Epoch 910/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 911/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0724
# Epoch 912/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0724
# Epoch 913/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 914/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 915/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0720
# Epoch 916/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0721
# Epoch 917/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0725
# Epoch 918/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 919/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0725
# Epoch 920/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0725
# Epoch 921/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0723
# Epoch 922/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0721
# Epoch 923/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 924/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0729
# Epoch 925/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0726
# Epoch 926/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0726
# Epoch 927/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0724
# Epoch 928/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0723
# Epoch 929/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0707 - val_loss: 0.0721
# Epoch 930/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 931/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0723
# Epoch 932/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0703 - val_loss: 0.0730
# Epoch 933/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0723
# Epoch 934/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0723
# Epoch 935/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0728
# Epoch 936/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 937/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0723
# Epoch 938/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0724
# Epoch 939/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0731
# Epoch 940/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0726
# Epoch 941/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721
# Epoch 942/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721
# Epoch 943/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0724
# Epoch 944/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0722
# Epoch 945/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0725
# Epoch 946/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0724
# Epoch 947/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0725
# Epoch 948/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721
# Epoch 949/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0720
# Epoch 950/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0729
# Epoch 951/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0721
# Epoch 952/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0726
# Epoch 953/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0724
# Epoch 954/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721
# Epoch 955/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721
# Epoch 956/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0724
# Epoch 957/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0722
# Epoch 958/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 959/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0722
# Epoch 960/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0723
# Epoch 961/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0723
# Epoch 962/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0726
# Epoch 963/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0725
# Epoch 964/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0731
# Epoch 965/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0703 - val_loss: 0.0725
# Epoch 966/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0720
# Epoch 967/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0724
# Epoch 968/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0721
# Epoch 969/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0725
# Epoch 970/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 971/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0726
# Epoch 972/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0724
# Epoch 973/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0726
# Epoch 974/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0724
# Epoch 975/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721
# Epoch 976/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0726
# Epoch 977/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0729
# Epoch 978/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0723
# Epoch 979/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721
# Epoch 980/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0720
# Epoch 981/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721
# Epoch 982/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0725
# Epoch 983/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0724
# Epoch 984/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0722
# Epoch 985/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0723
# Epoch 986/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0724
# Epoch 987/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0703 - val_loss: 0.0724
# Epoch 988/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0724
# Epoch 989/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0725
# Epoch 990/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0723
# Epoch 991/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0725
# Epoch 992/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0723
# Epoch 993/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0722
# Epoch 994/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0730
# Epoch 995/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0722
# Epoch 996/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0726
# Epoch 997/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0706 - val_loss: 0.0722
# Epoch 998/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0726
# Epoch 999/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0726
# Epoch 1000/1000
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0705 - val_loss: 0.0721

# %% [markdown]
# ##### 結果

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['val_loss'][1:])
plt.plot(history.history['loss'][1:])

# %% [markdown]
# #### lightgbm Model

# %%
##############################################　　　自己加入的　　　##############################################
import lightgbm as lgb

cf = lgb.LGBMRegressor(n_estimators=5000)

print('---cf.fit---')
print(cf.fit(*train))
print('---cf.score---')
print(cf.score(*test))
print('---predict---')
print(cf.predict(test[0]))
# Out:
# ---cf.fit---
# LGBMRegressor(n_estimators=5000)
# ---cf.score---
# -0.1606459704454144
# ---predict---
# [0.38307311 0.29531569 0.59632024 ... 0.23252527 0.94191622 0.34887666]

# %% [markdown]
# ##### 參數優化_1110

# %%
#import lightgbm

fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [test],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

# %%
gs.fit(*train, **fit_params)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [100]	valid's auc: 0.541539
# [100]	valid's auc: 0.541387
# [100]	valid's auc: 0.543224
# [100]	valid's auc: 0.562839
# [100]	valid's auc: 0.545896
# [100]	valid's auc: 0.541191
# [100]	valid's auc: 0.54242
# [100]	valid's auc: 0.545816
# [100]	valid's auc: 0.542288
# [100]	valid's auc: 0.544679
# [100]	valid's auc: 0.54162
# [100]	valid's auc: 0.547522
# [100]	valid's auc: 0.54203
# [200]	valid's auc: 0.546444
# [100]	valid's auc: 0.543897
# [100]	valid's auc: 0.546379
# [100]	valid's auc: 0.543882
# [100]	valid's auc: 0.544914
# [100]	valid's auc: 0.546404
# [100]	valid's auc: 0.543886
# [100]	valid's auc: 0.543044
# [100]	valid's auc: 0.546487
# [100]	valid's auc: 0.542634
# [100]	valid's auc: 0.541826
# [100]	valid's auc: 0.548082
# [100]	valid's auc: 0.539907
# [100]	valid's auc: 0.544303
# [100]	valid's auc: 0.543809
# [100]	valid's auc: 0.546135
# [100]	valid's auc: 0.543328
# [100]	valid's auc: 0.545042
# [100]	valid's auc: 0.546772
# [100]	valid's auc: 0.546623
# [100]	valid's auc: 0.544758
# [100]	valid's auc: 0.566945
# [100]	valid's auc: 0.545491
# [100]	valid's auc: 0.544833
# [100]	valid's auc: 0.543478
# [200]	valid's auc: 0.544512
# [100]	valid's auc: 0.540996
# [100]	valid's auc: 0.547175
# [100]	valid's auc: 0.541085
# [200]	valid's auc: 0.543084
# [100]	valid's auc: 0.541672
# [200]	valid's auc: 0.54838
# [100]	valid's auc: 0.544618
# [100]	valid's auc: 0.541789
# [100]	valid's auc: 0.545503
# [100]	valid's auc: 0.547413
# [100]	valid's auc: 0.545011
# [100]	valid's auc: 0.548343
# [100]	valid's auc: 0.546998
# [100]	valid's auc: 0.544417
# [100]	valid's auc: 0.543765
# [100]	valid's auc: 0.568702
# [100]	valid's auc: 0.543695
# [100]	valid's auc: 0.545174
# [100]	valid's auc: 0.547166
# [100]	valid's auc: 0.546753
# RandomizedSearchCV(cv=3,
#                    estimator=LGBMClassifier(metric='None', n_estimators=5000,
#                                             n_jobs=4, random_state=314,
#                                             silent=True),
#                    n_iter=100,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000291979625F0>,
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000292A7F3C...
#                                         'min_child_weight': [1e-05, 0.001, 0.01,
#                                                              0.1, 1, 10.0,
#                                                              100.0, 1000.0,
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000292B0462F50>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000292B0463340>},
#                    random_state=314, scoring='roc_auc', verbose=True)

# %%
gs.best_estimator_
# Out:
# LGBMClassifier(colsample_bytree=0.4467801334566121, metric='None',
#                min_child_samples=107, min_child_weight=1, n_estimators=5000,
#                n_jobs=4, num_leaves=43, random_state=314, reg_alpha=10,
#                reg_lambda=100, silent=True, subsample=0.40294551048668437)

# %%
#
#gs.best_estimator_
#LGBMClassifier(colsample_bytree=0.6433117836032942, metric='None',
#               min_child_samples=224, min_child_weight=1e-05, n_estimators=5000,
#               n_jobs=4, num_leaves=20, random_state=314, reg_alpha=10,
#               reg_lambda=10, subsample=0.8945613420997809)

# %%
cf = lgb.LGBMRegressor(colsample_bytree=0.8864187893944312, metric='None',
               min_child_samples=361, min_child_weight=10.0, n_estimators=5000,
               n_jobs=4, num_leaves=32, random_state=314, reg_alpha=7,
               reg_lambda=50, subsample=0.5708328703954919)

cf.fit(dataset_train[feature_names],dataset_train['return'] > 1.01, **fit_params)
cf.score(dataset_test[feature_names],dataset_test['return'] > 1.01)
# Out:
# 0.012642402575650857

# %%
cf.feature_importances_
# Out:
# array([30, 20, 23, 20, 11, 15, 28,  3, 17, 28,  1, 27, 14, 13, 10,  4, 19,
#         8, 11,  5,  2,  5,  0, 20, 12,  5, 13, 13,  1,  7, 18])

# %%
feature_imp = pd.DataFrame(zip(cf.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
sns.barplot(x="Value", y="Feature", data=feature_imp)
# Out:
# <AxesSubplot: xlabel='Value', ylabel='Feature'>

# %% [raw]
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551389
# Early stopping, best iteration is:
# [89]	valid's auc: 0.553699
# 0.003857956228475623

# %%
#print(cf.fit(*train))

# %%
#import lightgbm as lgb
#gbm = lgb.LGBMClassifier(n_estimators=100, random_state=5, learning_rate=0.01)
#gbm.fit(dataset_train[feature_names], dataset_train['return'] > 1)

# %%
#import tqdm
#
#n = 3
#
#X = []
#y = []
#indexes = []
#dataset_scaled_x = dataset_scaled[feature_names]
#
#for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-n)):
#    X.append(dataset_scaled_x.iloc[i:i+n].values)
#    y.append(dataset_scaled['return'].iloc[i+n-1])
#    indexes.append(dataset_scaled.index[i+n-1])
##dataset_scaled.head()

# %%
#import numpy as np
#X = np.array(X)
#y = np.array(y)

# %%
##import lightgbm as lgb
#cf = lgb.LGBMRegressor(colsample_bytree=0.7740467183023685, metric='None',
#               min_child_samples=395, min_child_weight=0.01, n_estimators=5000,
#               n_jobs=4, num_leaves=9, random_state=314, reg_alpha=5,
#               reg_lambda=10, subsample=0.4643892520208455)
#    
#cf.fit(dataset_train[feature_names].astype(float), dataset_train['rank'])

# %% [markdown]
# #### Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

cf2 = RandomForestRegressor(n_estimators=100)
cf2.fit(dataset_train[feature_names].astype(float), dataset_train[predi_target])
# Out:
# RandomForestRegressor()

# %% [markdown]
# ##### 參數優化_1110

# %%
#from scipy.stats import randint as sp_randint 
#from sklearn.model_selection import RandomizedSearchCV 
## build a classifier 
#clf = RandomForestRegressor(n_estimators=100) 
## specify parameters and distributions to sample from 
#param_dist = {"max_depth": [3, None], 
#              "max_features": sp_randint(1, 11), 
#              "min_samples_split": sp_randint(2, 11), 
#              "min_samples_leaf": sp_randint(1, 11), 
#              "bootstrap": [True, False], 
#              "criterion": ["mse", "mae"]} 
## run randomized search 
#n_iter_search = 20 
#rs = RandomizedSearchCV(clf, param_distributions=param_dist, 
#                                   n_iter=n_iter_search)

# %%
#rs.fit(dataset_train[features], dataset_train['return'] > 1)

# %% [markdown]
# ##### Split Train Test dataset

# %%
feature_imp = pd.DataFrame(zip(cf2.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
sns.barplot(x="Value", y="Feature", data=feature_imp)
# Out:
# <AxesSubplot: xlabel='Value', ylabel='Feature'>

# %%
select = dataset.index.get_level_values('date') < '2021'
dataset_train = dataset[select]
dataset_test = dataset[~select]

# %% [markdown]
# ### Ensemble learning

# %%
dataset_drop = dataset.dropna(subset=feature_names+['return'])

vals = model.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result1'] = pd.Series(vals.swapaxes(0,1)[0], dataset_drop.index)

vals = cf.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result2'] = pd.Series(vals, dataset_drop.index)

vals = cf2.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result3'] = pd.Series(vals, dataset_drop.index)

dataset_drop = dataset_drop.reset_index().set_index("date")
# Out:
# 5103/5103 [==============================] - 4s 815us/step

# %% [markdown]
# ## backtest

# %% [markdown]
# ## 把量加進來做篩選
#  * https://hahow.in/courses/5b9d3a6dca498a001e917383/shapeussions/60c96f5b018697e8a6131cbc

# %%
#把量加進來
vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

vol_filter=vol_ma5>1000
vol_filter=vol_filter[vol_filter].fillna(0)
#vol_filter
t1 = vol_filter

# %%
#condition2

# %%
vol_filter = t1.reindex(every_month, method='ffill')#.loc['2010-02-15']
#vol_filter.loc['2010-02-15']

# %%
#t1 = vol_ma5.iloc[-1].dropna()
#t1.to_csv('./tmp/132.csv')
#t1.hist(bins=10)

# %%
#市值
#t1 = (predi_target >= predi_target.nlargest(20).iloc[-1]) * condition_Filter_v2.astype(float)()

# %%
import math
from tqdm import tqdm

vol = 100
test_period = '2021'

dates = sorted(list(set(dataset_drop.index)))

rs = []
rs_v1 = []
rs_v2 = []
rs_v3 = []

for d in tqdm(dates):
    #print(d)
    dataset_time = dataset_drop.loc[d]
    
    dataset_time = drop_extreme_case(dataset_time , feature_names , thresh=0.01)
    
    #print(dataset_time)
    
    predi_target = dataset_time['result1'] + dataset_time['result2'] + dataset_time['result3'] 
    
    #predi_target = predi_target * (dataset_time['vol_ma5'] >vol).astype(float)
            ###

    
    condition1 = dataset_time['vol_ma5'] > vol
    condition_Filter_v1 = condition1
    predi_target_v1 = predi_target * condition_Filter_v1.astype(float)
    
    condition2 = (1e10 < dataset_time['市值']) < 1e11
    
    condition_Filter_v2 =  condition1 + condition2
    predi_target_v2 = predi_target * condition_Filter_v2.astype(float)
    
    condition_P = (predi_target >= predi_target.nlargest(20).iloc[-1])
    condition_v1 = (predi_target_v1 >= predi_target_v1.nlargest(20).iloc[-1])
    condition_v2 = (predi_target_v2 >= predi_target_v2.nlargest(20).iloc[-1])
    
    predi_target = predi_target * (dataset_time['vol_ma5'] >vol).astype(float)
    condition_v3 = (predi_target >= predi_target.nlargest(20).iloc[-1]) & condition_Filter_v2 #.astype(float)
    
    #print(vol_filter.loc[d])
    #print(condition)
    
    r = dataset_time['return'][condition_P].mean()
    rs.append(r * (1-3/1000-1.425/1000*2*0.6))
    
    r_v1 = dataset_time['return'][condition_v1].mean()
    rs_v1.append(r_v1 * (1-3/1000-1.425/1000*2*0.6))    
    
    r_v2 = dataset_time['return'][condition_v2].mean()
    rs_v2.append(r_v2 * (1-3/1000-1.425/1000*2*0.6))    

    r_v3 = dataset_time['return'][condition_v3].mean()
    rs_v3.append(r_v3 * (1-3/1000-1.425/1000*2*0.6))    
        
rs = pd.Series(rs, index=dates)[test_period:].cumprod()
rs_v1 = pd.Series(rs_v1, index=dates)[test_period:].cumprod() #*
rs_v2 = pd.Series(rs_v2, index=dates)[test_period:].cumprod() #*
rs_v3 = pd.Series(rs_v3, index=dates)[test_period:].cumprod() #*

s0050 = close['0050'][test_period:]

pd.DataFrame({'nn strategy return':rs.reindex(s0050.index, method='ffill'),
              'nn strategy return_V1(vol>100)':rs_v1.reindex(s0050.index, method='ffill'),
              'nn strategy return_V2(vol+market cap)':rs_v2.reindex(s0050.index, method='ffill'),
              #'nn strategy return_V3(vol+market cap)':rs_v3.reindex(s0050.index, method='ffill'),
              '0050 return':s0050/s0050[0]}).plot()



import winsound
frequency = 2000
duration = 100
winsound.Beep(frequency, duration)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [01:24<00:00,  1.86it/s]

# %%
#import pickle
#
#return_history_1026 = pd.Series(rs, index=dates)['2021':].cumprod()
##eq = (gain[hold == 1].mean(axis=1)).fillna(1).cumprod()
#
#pickle.dump(rs, open('return_history_1026.pkl', 'wb'))

# %%
#import pyfolio as pf
#import pandas as pd
#
#close.index = close.index.tz_localize("Asia/Taipei")
##pf.create_returns_tear_sheet(close['0050'].pct_change())
#
## 得到 上一個單元的 回測結果
#ret = pickle.load(open("return_history_1026.pkl", "rb"))
#
## 將回測報酬率取出來
#ret = ret.pct_change().dropna()
#ret.index = pd.to_datetime(ret.index).tz_localize('Asia/Taipei')
#
## 利用pyfolio 比較報酬率
#pf.create_returns_tear_sheet(ret, benchmark_rets=close['0050'].pct_change())

# %% [markdown]
# ### 當月持股狀況

# %%
# get the latest dataset
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()


last_dataset = drop_extreme_case(last_dataset, feature_names , thresh=0.01)
t1 = last_dataset

# remove NaN testcases
last_dataset = last_dataset.dropna(subset=feature_names)

# predict

vals = model.predict(last_dataset[feature_names].astype(float))
last_dataset['result1'] = pd.Series(vals.swapaxes(0,1)[0], last_dataset.index)

vals = cf.predict(last_dataset[feature_names].astype(float))
last_dataset['result2'] = pd.Series(vals, last_dataset.index)

vals = cf2.predict(last_dataset[feature_names].astype(float))
last_dataset['result3'] = pd.Series(vals, last_dataset.index)


# calculate score

predi_target = last_dataset['result1'] + last_dataset['result2'] + last_dataset['result3']

#
##predi_target = predi_target * vol_filter.iloc[-1] #******加上量的濾網


predi_target = predi_target * (last_dataset['vol_ma5'] >vol).astype(float)  #排除平均成交量小於MA1000張
#predi_target = predi_target * (last_dataset['市值'] < 1e10).astype(float)   #排除市值小於100億以下的股票

condition0 = (predi_target >= predi_target.nlargest(20).iloc[-1])
condition1 = last_dataset['vol_ma5'] >vol
condition2 = last_dataset['市值'] < 1e10

condition = condition0 & condition1 #& condition2

#vol_filter

# plot rank distribution
predi_target[predi_target!=0].hist(bins=20)


# show the best 20 stocks
slist1 = predi_target[condition].reset_index()['stock_id']

#https://keras-cn.readthedocs.io/en/latest/models/model/
# Out:
# 35/35 [==============================] - 0s 1ms/step

# %%
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()

# %%
#rank.sort_values(ascending=False).head(20)

# %% [markdown]
# ## 平均分配資產於股票之中

# %%
close = data.get("收盤價")

money = 150000
stock_prices = close[slist1].iloc[-1]


print("股票平分張數:")
money / len(stock_prices) / stock_prices / 1000
# Out:
# 股票平分張數:
# stock_id
# 1104    0.312500
# 1434    0.270270
# 2317    0.072816
# 2404    0.032751
# 2514    0.434783
# 2546    0.130208
# 2832    0.356295
# 2834    0.524476
# 3036    0.112108
# 4707    0.592885
# 4938    0.108069
# 4958    0.064935
# 6136    0.397878
# 6414    0.031915
# 6438    0.078206
# 8064    0.408719
# 8446    0.085421
# 8905    0.297030
# 9911    0.116279
# 9930    0.157068
# Name: 2023-03-13 00:00:00, dtype: float64

# %%
last_dataset['市值'][slist1]
# Out:
# stock_id  date
# 1104      2023-03-15    1.568662e+10
# 1434      2023-03-15    4.674944e+10
# 2317      2023-03-15    1.427888e+12
# 2404      2023-03-15    4.364435e+10
# 2514      2023-03-15    6.809080e+09
# 2546      2023-03-15    6.718418e+09
# 2832      2023-03-15             NaN
# 2834      2023-03-15             NaN
# 3036      2023-03-15    6.814763e+10
# 4707      2023-03-15    4.460748e+09
# 4938      2023-03-15    1.851907e+11
# 4958      2023-03-15    1.093842e+11
# 6136      2023-03-15    2.177861e+09
# 6414      2023-03-15    2.491870e+10
# 6438      2023-03-15    6.850300e+09
# 8064      2023-03-15    3.024407e+09
# 8446      2023-03-15    4.645884e+09
# 8905      2023-03-15    3.015860e+09
# 9911      2023-03-15    1.426232e+10
# 9930      2023-03-15    1.186780e+10
# Name: 市值, dtype: float64

# %%
last_dataset['vol_ma5'][slist1]
# Out:
# stock_id  date
# 1104      2023-03-15      771.6780
# 1434      2023-03-15     1718.9458
# 2317      2023-03-15    43730.0146
# 2404      2023-03-15     1025.0168
# 2514      2023-03-15      104.8712
# 2546      2023-03-15      160.8440
# 2832      2023-03-15      359.2790
# 2834      2023-03-15    24855.7174
# 3036      2023-03-15     1185.2578
# 4707      2023-03-15      915.9594
# 4938      2023-03-15     4074.4172
# 4958      2023-03-15     5974.3150
# 6136      2023-03-15      211.0152
# 6414      2023-03-15      907.2654
# 6438      2023-03-15      563.9798
# 8064      2023-03-15      617.7780
# 8446      2023-03-15      100.4906
# 8905      2023-03-15      210.3686
# 9911      2023-03-15      104.6062
# 9930      2023-03-15      103.7112
# Name: vol_ma5, dtype: float64

# %% [markdown]
# ###################################################################################################
# ## 移動窗格最佳化
# [有空來試試看連結](https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/61b4c90147843d0006cf2593https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/61b4c90147843d0006cf2593)
# ###################################################################################################

# %%
import lightgbm as lgb

from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt

import numpy as np

# %matplotlib inline

def select(df):

    rank = df['pre']

    condition1 = (rank >= rank.nlargest(1).iloc[-1])

    return df['return'][condition1].mean() * (1-3/1000-1.425/1000*2*0.6)

end = 5

cf = lgb.LGBMRegressor(n_estimators=500)



train_time = ['2015','2016','2017','2018','2019']

s_time = ['2007','2008','2009','2010','2011']

test_time = ['2016','2017','2018','2019','2020']

#dataset_copy = dataset_dropna.copy()

store_mse = []


for time in range(end):

    print('%d 次執行中'%(time))

    dataset_dropna2_train = dataset_copy.loc[s_time[time]:train_time[time]] #2007~ 2015   2008~2016   2009~2017  2010~2018  ....

    dataset_dropna2_test = dataset_copy.loc[test_time[time]:test_time[time]]#            2016                2017               2018              2019  .....

    
 cf.fit(dataset_dropna2_train[feature_names].astype(float), dataset_dropna2_train['rank'])

    
 predict = cf.predict(dataset_dropna2_test[feature_names])

    dataset_dropna2_test['pre'] = predict

dates = dataset_dropna2_test.index.get_level_values('date')

b = dataset_dropna2_test.groupby(dates).apply(select).cumprod()

s0050 = close['0050'][test_time[time]:test_time[time]]

s0056 = close['0056'][test_time[time]:test_time[time]]

pd.DataFrame({'Best 1 stocks return(include handling fee)':b.reindex(s0050.index, method='ffill'), 

              '0050':s0050/s0050[0],'0056':s0056/s0056[0]}).plot()

plt.ylabel('return')
# Out:
#   File <tokenize>:45
#     cf.fit(dataset_dropna2_train[feature_names].astype(float), dataset_dropna2_train['rank'])
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def mystrategy(data):

    close = data.get("收盤價", 120)

    vol = data.get('成交股數', 120)
 

    condition1 = close.max() / close.min()

    rev = data.get("當月營收", 14)

    condition2 = (rev.iloc[-1] / rev.iloc[-13])

    condition3 = (rev.iloc[-2] / rev.iloc[-14])

    稅後淨利 = data.get('本期淨利（淨損）', 5)

    # 股東權益，有兩個名稱，有些公司叫做權益總計，有些叫做權益總額，所以得把它們抓出來

    權益總計 = data.get('權益總計', 5)

    權益總額 = data.get('權益總額', 5)

    # 並且把它們合併起來

    權益總計.fillna(權益總額, inplace=True)

    roe = 稅後淨利 / 權益總計

    condition4 = roe.iloc[-1] / roe.iloc[-5]

    select_stock = (condition1.rank() + # 該數值越小越好

    condition2.rank(ascending=False) + # 該值越大越好 

    condition3.rank(ascending=False) + # 該值越大越好

    condition4.rank(ascending=False) # 該值越大越好 

    ).rank() <= 10
    
    df=select_stock[select_stock]
    vol=vol[df.index].iloc[-1]
    cond_vol=vol>(1000*1000)

    return cond_vol[cond_vol]

# %%
stocks = mystrategy(data)
stocks

# %%
    權益總計 = data.get('權益總計', 5)

    權益總額 = data.get('權益總額', 5)

    # 並且把它們合併起來

    權益總計.fillna(權益總額, inplace=True)

# %%
權益總計

# %%
close = data.get("收盤價", 120)
vol = data.get('成交股數', 120)
condition1 = close.max() / close.min()
rev = data.get("當月營收", 14)
condition2 = (rev.iloc[-1] / rev.iloc[-13])
condition3 = (rev.iloc[-2] / rev.iloc[-14])
稅後淨利 = data.get('本期淨利（淨損）', 5)
# 股東權益，有兩個名稱，有些公司叫做權益總計，有些叫做權益總額，所以得把它們抓出來
權益總計 = data.get('權益總計', 5)
權益總額 = data.get('權益總額', 5)
# 並且把它們合併起來
權益總計.fillna(權益總額, inplace=True)
roe = 稅後淨利 / 權益總計
condition4 = roe.iloc[-1] / roe.iloc[-5]
select_stock = (condition1.rank() + # 該數值越小越好
condition2.rank(ascending=False) + # 該值越大越好 
condition3.rank(ascending=False) + # 該值越大越好
condition4.rank(ascending=False) # 該值越大越好 
).rank() <= 10
df=select_stock[select_stock]
vol=vol[df.index].iloc[-1]
cond_vol=vol>(1000*1000)

# %%
condition4
