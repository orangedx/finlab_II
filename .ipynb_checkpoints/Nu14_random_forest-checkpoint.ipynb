# %% [markdown]
# # Random Forest Classifier

# %% [markdown]
# ## Get dataset

# %%
from finlab.ml import fundamental_features
dataset = fundamental_features()
dataset = dataset.dropna(thresh=int(len(dataset)*0.5), axis=1).dropna(how='any')
dataset.head()
# Out:
# D:\Finlab\AI選股策略\finlab\ml.py:49: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3900繼續營業部門稅前純益 = T3900繼續營業部門稅前純益[T3900繼續營業部門稅前純益.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:52: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3970經常稅後淨利 = T3970經常稅後淨利[T3970經常稅後淨利.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:55: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T2000權益總計 =  T2000權益總計[T2000權益總計.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:58: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3295營業毛利 =  T3295營業毛利[T3295營業毛利.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:61: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3100營業收入淨額 = T3100營業收入淨額[T3100營業收入淨額.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:64: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3700營業外收入及支出 = T3700營業外收入及支出[T3700營業外收入及支出.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:72: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3910所得稅費用 = T3910所得稅費用[T3910所得稅費用.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:75: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3300營業費用 = T3300營業費用[T3300營業費用.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:78: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T7211折舊 = T7211折舊[T7211折舊.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:81: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T7212攤提 = T7212攤提[T7212攤提.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:87: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0170存貨 = T0170存貨[T0170存貨.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:90: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   股本 = 股本[股本.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:98: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0400不動產廠房設備合計 =T0400不動產廠房設備合計[T0400不動產廠房設備合計.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:101: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0960非流動資產 = T0960非流動資產[T0960非流動資產.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:104: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0180預付費用及預付款 = T0180預付費用及預付款[T0180預付費用及預付款.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:107: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T1800非流動負債 = T1800非流動負債[T1800非流動負債.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:110: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0190其他流動資產 = T0190其他流動資產[T0190其他流動資產.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:113: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T1100流動負債 = T1100流動負債[T1100流動負債.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:116: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0100流動資產 =T0100流動資產[T0100流動資產.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:119: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3501財物成本 = T3501財物成本[T3501財物成本.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:125: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3971本期綜合損益總額 = T3971本期綜合損益總額[T3971本期綜合損益總額.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:128: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3395營業利益 = T3395營業利益[T3395營業利益.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:137: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   R202用人費用率 = R202用人費用率[R202用人費用率.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:140: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3356研究發展費 = T3356研究發展費[T3356研究發展費.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:143: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T7210營運現金流 = T7210營運現金流[T7210營運現金流.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:146: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3950歸屬母公司淨利 = T3950歸屬母公司淨利[T3950歸屬母公司淨利.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:149: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T1000負債總額 =T1000負債總額[T1000負債總額.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:152: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3200營業成本 = T3200營業成本[T3200營業成本.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:156: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T7324取得不動產廠房及設備 = T7324取得不動產廠房及設備[ T7324取得不動產廠房及設備.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:158: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   應收帳款關係人淨額 = 應收帳款關係人淨額[應收帳款關係人淨額.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:161: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   應收票據淨額 = 應收票據淨額[應收票據淨額.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:164: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   應收票據關係人淨額 = 應收票據關係人淨額[應收票據關係人淨額.columns & 收盤價.columns]
# D:\Finlab\AI選股策略\finlab\ml.py:167: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   應收帳款淨額 = 應收帳款淨額[應收帳款淨額.columns & 收盤價.columns]
#                      T3395營業利益  T7210營運現金流  T3950歸屬母公司淨利    T7211折舊  \
# stock_id date
# 1101     2014-05-15  3684224.0   6895832.0     4015175.0  1594505.0
#          2014-08-14  5938317.0   4452573.0     -754894.0  1573692.0
#          2014-11-14  5544164.0   3701961.0     3621052.0  1587492.0
#          2015-03-31  4690964.0   4936554.0     6459366.0  1575810.0
#          2015-05-15  1693508.0   5654152.0      349121.0  1711428.0
#
#                       T0100流動資產   T1100流動負債  T7324取得不動產廠房及設備  T3970經常稅後淨利  \
# stock_id date
# 1101     2014-05-15  92121458.0  74388787.0        -940633.0    2791235.0
#          2014-08-14  89163129.0  81190613.0        -465009.0    4828695.0
#          2014-11-14  89472928.0  78920574.0        -911057.0    4934486.0
#          2015-03-31  96605816.0  68632044.0       -1384489.0    4029460.0
#          2015-05-15  92471096.0  69579858.0        -818460.0     974518.0
#
#                      R101_ROA稅後息前  R11V_ROA綜合損益  ...  R409_淨值成長率   R501_流動比率  \
# stock_id date                                    ...
# 1101     2014-05-15     -1.732411      1.630076  ...    8.866880  123.837828
#          2014-08-14     -0.952778      0.152556  ...    5.954576  109.819505
#          2014-11-14     -0.948101      2.168353  ...    5.657634  113.370853
#          2015-03-31     -1.265106      3.002608  ...    5.467505  140.759054
#          2015-05-15     -2.315297      0.069454  ...    2.505042  132.899231
#
#                       R502_速動比率  R503_利息支出率   R678_營運資金  R607_總資產週轉次數  \
# stock_id date
# 1101     2014-05-15  101.776758   -9.792979  17732671.0      0.093998
#          2014-08-14   91.450337  -17.435186   7972516.0      0.112552
#          2014-11-14   93.976558  -17.800651  10552354.0      0.106864
#          2015-03-31  117.966121  -13.169666  27973772.0      0.103034
#          2015-05-15  109.303861   -7.153186  22891238.0      0.073611
#
#                      R610_存貨週轉率  R612_固定資產週轉次數  R613_淨值週轉率次  R69B_自由現金流量
# stock_id date
# 1101     2014-05-15    2.191306       0.245688     0.171327    4901868.0
#          2014-08-14    2.381079       0.297377     0.208493   16542181.0
#          2014-11-14    2.306032       0.282283     0.200028    4768224.0
#          2015-03-31    2.268994       0.275197     0.187942  -10525322.0
#          2015-05-15    1.817298       0.195713     0.132250    8494249.0
#
# [5 rows x 48 columns]

# %%
#dataset.count

# %% [markdown]
# ## Add labels

# %%
features = dataset.columns
features
# Out:
# Index(['T3395營業利益', 'T7210營運現金流', 'T3950歸屬母公司淨利', 'T7211折舊', 'T0100流動資產',
#        'T1100流動負債', 'T7324取得不動產廠房及設備', 'T3970經常稅後淨利', 'R101_ROA稅後息前',
#        'R11V_ROA綜合損益', 'R103_ROE稅後', 'R11U_ROE綜合損益', 'R145_稅前息前折舊前淨利率',
#        'R105_營業毛利率', 'R106_營業利益率', 'R107_稅前淨利率', 'R108_稅後淨利率', 'R112_業外收支營收率',
#        'R179_貝里比率', 'R203_研究發展費用率', 'R205_現金流量比率', 'R207_稅率', 'R304_每股營業額',
#        'R305_每股營業利益', 'R303_每股現金流量', 'R306_每股稅前淨利', 'R314_每股綜合損益',
#        'R316_每股稅後淨利', 'R504_總負債除總淨值', 'R505_負債比率', 'R506_淨值除資產', 'R401_營收成長率',
#        'R402_營業毛利成長率', 'R403_營業利益成長率', 'R404_稅前淨利成長率', 'R405_稅後淨利成長率',
#        'R406_經常利益成長率', 'R408_資產總額成長率', 'R409_淨值成長率', 'R501_流動比率', 'R502_速動比率',
#        'R503_利息支出率', 'R678_營運資金', 'R607_總資產週轉次數', 'R610_存貨週轉率',
#        'R612_固定資產週轉次數', 'R613_淨值週轉率次', 'R69B_自由現金流量'],
#       dtype='object')

# %%
features = dataset.columns

import finlab.ml as ml

ml.add_profit_prediction(dataset)
dataset = dataset.dropna()
dataset.tail()
# Out:
# D:\Finlab\AI選股策略\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
# D:\Finlab\AI選股策略\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
# D:\Finlab\AI選股策略\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
# D:\Finlab\AI選股策略\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
#                      T3395營業利益  T7210營運現金流  T3950歸屬母公司淨利  T7211折舊  T0100流動資產  \
# stock_id date
# 9955     2021-05-15   -14190.0    -36705.0      -23126.0  13085.0   905765.0
#          2021-08-14    -1226.0     37433.0       -5726.0  13354.0   916099.0
#          2021-11-14   -37997.0        79.0      -38235.0  13434.0   857562.0
#          2022-03-31   -32938.0     83913.0      -29586.0  13726.0   775754.0
# 9958     2019-11-14   -85253.0   -442692.0      582284.0  27935.0  4069394.0
#
#                      T1100流動負債  T7324取得不動產廠房及設備  T3970經常稅後淨利  R101_ROA稅後息前  \
# stock_id date
# 9955     2021-05-15   937218.0         -28012.0     -22146.0     -0.672387
#          2021-08-14   975974.0         -10148.0      -4762.0     -0.064968
#          2021-11-14  1004035.0         -44299.0     -38094.0     -1.199887
#          2022-03-31   787560.0         -17055.0     -33385.0     -1.052262
# 9958     2019-11-14  2448411.0        -393727.0     569881.0      5.721157
#
#                      R11V_ROA綜合損益  ...   R501_流動比率   R502_速動比率  R503_利息支出率  \
# stock_id date                      ...
# 9955     2021-05-15     -0.794341  ...   96.644004   27.735383  -16.401733
#          2021-08-14     -0.194349  ...   93.865103   27.034634 -185.867976
#          2021-11-14     -1.301170  ...   85.411564   21.324057  -10.051391
#          2022-03-31     -1.022680  ...   98.500940   32.245670  -12.085356
# 9958     2019-11-14      5.497913  ...  166.205510  117.021489    3.926655
#
#                      R678_營運資金  R607_總資產週轉次數  R610_存貨週轉率  R612_固定資產週轉次數  \
# stock_id date
# 9955     2021-05-15   -31453.0      0.157824    0.706660       0.240481
#          2021-08-14   -59875.0      0.114065    0.490104       0.175881
#          2021-11-14  -146473.0      0.099051    0.479878       0.152001
#          2022-03-31   -11806.0      0.137395    0.731239       0.206921
# 9958     2019-11-14  1620983.0      0.055079    0.574952       0.143254
#
#                      R613_淨值週轉率次  R69B_自由現金流量    return
# stock_id date
# 9955     2021-05-15     0.291256      72112.0  0.982857
#          2021-08-14     0.215064      47162.0  1.000000
#          2021-11-14     0.188869     106237.0  1.889535
#          2022-03-31     0.263727    -137271.0  0.709231
# 9958     2019-11-14     0.108409    2143039.0  1.054274
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Split Train Test dataset

# %%
select = dataset.index.get_level_values('date') < '2017'
dataset_train = dataset[select]
dataset_test = dataset[~select]

dataset_train.head()
# Out:
#                      T3395營業利益  T7210營運現金流  T3950歸屬母公司淨利    T7211折舊  \
# stock_id date
# 1101     2014-05-15  3684224.0   6895832.0     4015175.0  1594505.0
#          2014-08-14  5938317.0   4452573.0     -754894.0  1573692.0
#          2014-11-14  5544164.0   3701961.0     3621052.0  1587492.0
#          2015-03-31  4690964.0   4936554.0     6459366.0  1575810.0
#          2015-05-15  1693508.0   5654152.0      349121.0  1711428.0
#
#                       T0100流動資產   T1100流動負債  T7324取得不動產廠房及設備  T3970經常稅後淨利  \
# stock_id date
# 1101     2014-05-15  92121458.0  74388787.0        -940633.0    2791235.0
#          2014-08-14  89163129.0  81190613.0        -465009.0    4828695.0
#          2014-11-14  89472928.0  78920574.0        -911057.0    4934486.0
#          2015-03-31  96605816.0  68632044.0       -1384489.0    4029460.0
#          2015-05-15  92471096.0  69579858.0        -818460.0     974518.0
#
#                      R101_ROA稅後息前  R11V_ROA綜合損益  ...   R501_流動比率   R502_速動比率  \
# stock_id date                                    ...
# 1101     2014-05-15     -1.732411      1.630076  ...  123.837828  101.776758
#          2014-08-14     -0.952778      0.152556  ...  109.819505   91.450337
#          2014-11-14     -0.948101      2.168353  ...  113.370853   93.976558
#          2015-03-31     -1.265106      3.002608  ...  140.759054  117.966121
#          2015-05-15     -2.315297      0.069454  ...  132.899231  109.303861
#
#                      R503_利息支出率   R678_營運資金  R607_總資產週轉次數  R610_存貨週轉率  \
# stock_id date
# 1101     2014-05-15   -9.792979  17732671.0      0.093998    2.191306
#          2014-08-14  -17.435186   7972516.0      0.112552    2.381079
#          2014-11-14  -17.800651  10552354.0      0.106864    2.306032
#          2015-03-31  -13.169666  27973772.0      0.103034    2.268994
#          2015-05-15   -7.153186  22891238.0      0.073611    1.817298
#
#                      R612_固定資產週轉次數  R613_淨值週轉率次  R69B_自由現金流量    return
# stock_id date
# 1101     2014-05-15       0.245688     0.171327    4901868.0  1.073347
#          2014-08-14       0.297377     0.208493   16542181.0  0.984816
#          2014-11-14       0.282283     0.200028    4768224.0  0.969163
#          2015-03-31       0.275197     0.187942  -10525322.0  0.956818
#          2015-05-15       0.195713     0.132250    8494249.0  0.850077
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Training

# %%
from sklearn.ensemble import RandomForestClassifier

cf = RandomForestClassifier(n_estimators=200,max_features=30)

cf.fit(dataset_train[features], dataset_train['return'] > 1.5) # >1 正報酬率
cf.score(dataset_test[features], dataset_test['return'] > 1) # >1 正報酬率
# Out:
# 0.4857398301296379

# %%
cf.score
# Out:
# <bound method ClassifierMixin.score of RandomForestClassifier(max_features=30, n_estimators=200)>

# %% [markdown]
# ## Prediction

# %%
import pandas as pd
prediction = cf.predict(dataset_test[features])

# %% [markdown]
# ## Backtest

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %matplotlib inline

returns1 = dataset_test['return'][prediction == True]
dates = returns1.index.get_level_values('date')
returns1.groupby(dates).mean().cumprod().plot(color="red")

returns2 = dataset_test['return'][prediction == False]
dates = returns2.index.get_level_values('date')
returns2.groupby(dates).mean().cumprod().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
returns1 = dataset_test['return'][prediction]
dates = returns1.index.get_level_values('date')
returns1.groupby(dates).mean()#.cumprod().plot(color="red")
# Out:
# date
# 2017-03-31    1.132530
# 2019-08-14    1.102625
# 2020-05-15    1.200896
# 2020-11-14    1.081897
# 2021-03-31    0.904372
# 2021-05-15    0.993204
# 2021-08-14    0.778189
# 2021-11-14    1.038422
# 2022-03-31    0.896936
# Name: return, dtype: float64

# %% [markdown]
# ## Feature Importance

# %%
importance = pd.Series(cf.feature_importances_, index=features).sort_values(ascending=False)
importance
# Out:
# R408_資產總額成長率       0.028346
# R203_研究發展費用率       0.027637
# R402_營業毛利成長率       0.027168
# R610_存貨週轉率         0.024449
# R409_淨值成長率         0.024275
# R503_利息支出率         0.023906
# T7324取得不動產廠房及設備    0.023448
# R403_營業利益成長率       0.023133
# R401_營收成長率         0.023055
# R404_稅前淨利成長率       0.022538
# R303_每股現金流量        0.022184
# T0100流動資產          0.022060
# R205_現金流量比率        0.021974
# R607_總資產週轉次數       0.021884
# T7211折舊            0.021678
# R406_經常利益成長率       0.021598
# R405_稅後淨利成長率       0.021506
# R501_流動比率          0.021450
# R112_業外收支營收率       0.021424
# R304_每股營業額         0.021007
# R105_營業毛利率         0.020971
# R101_ROA稅後息前       0.020923
# R11U_ROE綜合損益       0.020850
# R613_淨值週轉率次        0.020799
# R305_每股營業利益        0.020651
# R505_負債比率          0.020582
# R69B_自由現金流量        0.020234
# R678_營運資金          0.020180
# R612_固定資產週轉次數      0.019972
# R502_速動比率          0.019909
# T1100流動負債          0.019840
# T7210營運現金流         0.019509
# R506_淨值除資產         0.019428
# R504_總負債除總淨值       0.019414
# R11V_ROA綜合損益       0.019378
# R179_貝里比率          0.019328
# R314_每股綜合損益        0.019296
# R103_ROE稅後         0.019261
# R316_每股稅後淨利        0.018578
# R145_稅前息前折舊前淨利率    0.018512
# T3950歸屬母公司淨利       0.018351
# T3970經常稅後淨利        0.017723
# R306_每股稅前淨利        0.017626
# T3395營業利益          0.017467
# R107_稅前淨利率         0.017358
# R106_營業利益率         0.017216
# R108_稅後淨利率         0.016547
# R207_稅率            0.015380
# dtype: float64

# %% [markdown]
# ## New Strategy using feature importance

# %%
from finlab.data import Data
data = Data()
close = data.get('收盤價')
sma = close.rolling(60, min_periods=10).mean()
bias = close / sma

ml.add_feature(dataset, 'bias', bias)
dataset.head()
# Out:
#                      T3395營業利益  T7210營運現金流  T3950歸屬母公司淨利    T7211折舊  \
# stock_id date
# 1101     2014-05-15  3684224.0   6895832.0     4015175.0  1594505.0
#          2014-08-14  5938317.0   4452573.0     -754894.0  1573692.0
#          2014-11-14  5544164.0   3701961.0     3621052.0  1587492.0
#          2015-03-31  4690964.0   4936554.0     6459366.0  1575810.0
#          2015-05-15  1693508.0   5654152.0      349121.0  1711428.0
#
#                       T0100流動資產   T1100流動負債  T7324取得不動產廠房及設備  T3970經常稅後淨利  \
# stock_id date
# 1101     2014-05-15  92121458.0  74388787.0        -940633.0    2791235.0
#          2014-08-14  89163129.0  81190613.0        -465009.0    4828695.0
#          2014-11-14  89472928.0  78920574.0        -911057.0    4934486.0
#          2015-03-31  96605816.0  68632044.0       -1384489.0    4029460.0
#          2015-05-15  92471096.0  69579858.0        -818460.0     974518.0
#
#                      R101_ROA稅後息前  R11V_ROA綜合損益  ...   R502_速動比率  R503_利息支出率  \
# stock_id date                                    ...
# 1101     2014-05-15     -1.732411      1.630076  ...  101.776758   -9.792979
#          2014-08-14     -0.952778      0.152556  ...   91.450337  -17.435186
#          2014-11-14     -0.948101      2.168353  ...   93.976558  -17.800651
#          2015-03-31     -1.265106      3.002608  ...  117.966121  -13.169666
#          2015-05-15     -2.315297      0.069454  ...  109.303861   -7.153186
#
#                       R678_營運資金  R607_總資產週轉次數  R610_存貨週轉率  R612_固定資產週轉次數  \
# stock_id date
# 1101     2014-05-15  17732671.0      0.093998    2.191306       0.245688
#          2014-08-14   7972516.0      0.112552    2.381079       0.297377
#          2014-11-14  10552354.0      0.106864    2.306032       0.282283
#          2015-03-31  27973772.0      0.103034    2.268994       0.275197
#          2015-05-15  22891238.0      0.073611    1.817298       0.195713
#
#                      R613_淨值週轉率次  R69B_自由現金流量    return      bias
# stock_id date
# 1101     2014-05-15     0.171327    4901868.0  1.073347  0.960967
#          2014-08-14     0.208493   16542181.0  0.984816  1.021982
#          2014-11-14     0.200028    4768224.0  0.969163  0.971380
#          2015-03-31     0.187942  -10525322.0  0.956818  1.040769
#          2015-05-15     0.132250    8494249.0  0.850077  0.988372
#
# [5 rows x 50 columns]

# %%
items = list(importance.index[:20])

def select(df):
    rank = df[items].rank(pct=True).sum(axis=1)
    return df[rank > rank.quantile(0.9)]['return'][df['bias'] > 1].mean()

dates = dataset.index.get_level_values('date')
dataset.groupby(dates).apply(select).cumprod().plot(color='red')
dataset['return'].groupby(dates).mean().cumprod().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='date'>
