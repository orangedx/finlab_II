# %% [markdown]
# # Final Project

# %%
# 移除不必要的警告
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 獲取歷史資料

# %%
from finlab.data import Data
from finlab.ml import fundamental_features
fdf = fundamental_features()

data = Data()

close = data.get("收盤價")
open_ = data.get("開盤價")
high = data.get("最高價")
low = data.get("最低價")
vol = data.get("成交股數")

PB = data.get("股價淨值比")
pe = data.get("本益比")

#close = data.get_adj("收盤價").round(2)

#財務指標
rev = data.get("當月營收")
l_rev = data.get("去年當月營收")

#t123 = data.get('土地')

#bargin_i=data.get("投信買賣超股數")
#bargin_f=data.get("外資自營商買賣超股數")
#bargin_s=data.get("自營商買賣超股數(自行買賣)")
#

rev.index = rev.index.shift(5, "d")         #每月頻率
#周頻率

# %% [raw]
# ```
# https://www.twblogs.net/a/5d3f3173bd9eee517422735f
# W-WED
# https://docs.python.org/zh-tw/3/library/calendar.html
# ```

# %% [markdown]
# ### 計算features

# %%
#MFI  = data.talib("MFI")
##MFI.tail()
#ub,mb,lb =data.talib("BBANDS")

# %% [markdown]
# #### 營收相關

# %%
##############################################　　　自己加入的　　　##############################################
import pandas as pd
from finlab.__init__ import talib_all_stock
from talib import abstract

# %%
def bias(n):
    return close / close.rolling(n, min_periods=1).mean()

def acc(n):
    return close.shift(n) / (close.shift(2*n) + close) * 2

def rsv(n):
    l = close.rolling(n, min_periods=1).min()
    h = close.rolling(n, min_periods=1).max()
    
    return (close - l) / (h - l)

def mom(n):
    return (rev / rev.shift(1)).shift(n)

def yoy(n):
    return (rev.shift(n) / rev.shift(12+n)) -1


features = {
    'mom1': mom(1),
    'mom2': mom(2),
    'mom3': mom(3),
    'mom4': mom(4),
    'mom5': mom(5),
    'mom6': mom(6),
    'mom7': mom(7),
    'mom8': mom(8),
    'mom9': mom(9),
    
    'bias5': bias(5),
    'bias10': bias(10),
    'bias20': bias(20),
    'bias60': bias(60),
    'bias120': bias(120),
    'bias240': bias(240),
    
    'acc5': acc(5),
    'acc10': acc(10),
    'acc20': acc(20),
    'acc60': acc(60),
    'acc120': acc(120),
    'acc240': acc(240),
    
    'rsv5': rsv(5),
    'rsv10': rsv(10),
    'rsv20': rsv(20),
    'rsv60': rsv(60),
    'rsv120': rsv(120),
    'rsv240': rsv(240),
###############################################
    'yoy': yoy(1),
    'delta_yoy':(yoy(1)/yoy(2))-1,
    
    'PB':PB,
    'PE':pe,       
}

# %% [markdown]
# #### 財報指標

# %% [markdown]
# 兩個feature結合
# [https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7]

# %%
from finlab.ml import fundamental_features
dataset_fundamental = fundamental_features()

# %% [markdown]
# #### 技術指標

# %%
# https://zhuanlan.zhihu.com/p/342075180 talib函数功能一览表

def bias(n):
    return close / close.rolling(n, min_periods=1).mean()

def acc(n):
    return close.shift(n) / (close.shift(2*n) + close) * 2

def rsv(n):
    l = close.rolling(n, min_periods=1).min()
    h = close.rolling(n, min_periods=1).max()
    
    return (close - l) / (h - l)

def mom(n):
    return (rev / rev.shift(1)).shift(n)


def bi_(n):
    return (bargin_i / vol.shift(1)).shift(n)

def bf(n):
    return (bargin_f / vol.shift(1)).shift(n)
    
def bs(n):
    return (bargin_s / vol.shift(1)).shift(n)

def rsi(n):
    #return talib_all_stock(ndays=10000, func=abstract.RSI, timeperiod=n)
    return data.talib("RSI",timeperiod=n)

def MFI(n):
    return data.talib("MFI",timeperiod=n)

def obv(n):
    return data.talib("OBV",timeperiod=n)



features = {
    
    #'ATR14':data.talib("ATR",timeperiod=14),
    #'NATR14':data.talib('NATR',timeperiod=14),
    #'TRANGE':data.talib('TRANGE'),
    #'Adosc3':data.talib('ADOSC',timeperiod=3),
    
    #"MFI5":MFI(5),
    #"MFI10":MFI(10),
    
    #'rsi6': rsi(6),  #DataFrame
    #'rsi10': rsi(10),  #DataFrame
    #'rsi14': rsi(14),  #DataFrame
    #'rsi20': rsi(20),  #DataFrame
    #'rsi50': rsi(50),  #DataFrame
   
    'mom1': mom(1),
    'mom2': mom(2),
    'mom3': mom(3),
    'mom4': mom(4),
    'mom5': mom(5),
    'mom6': mom(6),
    'mom7': mom(7),
    'mom8': mom(8),
    'mom9': mom(9),
    
    'yoy': yoy(1),
    'delta_yoy':yoy(1)-yoy(2),
    
#    'ff':ff,
    'PB':PB,
    'PE':pe,   
#  
    'bias5': bias(5),
    'bias10': bias(10),
    'bias20': bias(20),
    'bias60': bias(60),
    'bias120': bias(120),
    'bias240': bias(240),
    
    'acc5': acc(5),
    'acc10': acc(10),
    'acc20': acc(20),
    'acc60': acc(60),
    'acc120': acc(120),
    'acc240': acc(240),
    
    #'rsv5': rsv(5),
    #'rsv10': rsv(10),
    #'rsv20': rsv(20),
    #'rsv60': rsv(60),
    #'rsv120': rsv(120),
    #'rsv240': rsv(240),
}

# %% [markdown]
# #### 組合dataset

# %%
import pandas as pd

# %% [markdown]
# #### 確認各指標清單

# %%
list1=sorted(features)
list1
# Out:
# ['PB',
#  'PE',
#  'acc10',
#  'acc120',
#  'acc20',
#  'acc240',
#  'acc5',
#  'acc60',
#  'bias10',
#  'bias120',
#  'bias20',
#  'bias240',
#  'bias5',
#  'bias60',
#  'delta_yoy',
#  'mom1',
#  'mom2',
#  'mom3',
#  'mom4',
#  'mom5',
#  'mom6',
#  'mom7',
#  'mom8',
#  'mom9',
#  'yoy']

# %%
#t1 = data.talib("NATR",timeperiod=14)
#t1.to_csv('myfile.csv')

# %% [markdown]
# ### 製作dataset
#
# ##### 設定買賣頻率

# %%
#rev.index = rev.index.tz_localize("Asia/Taipei")
every_month = rev.index
every_month
# Out:
# DatetimeIndex(['2005-02-15', '2005-03-15', '2005-04-15', '2005-05-15',
#                '2005-06-15', '2005-07-15', '2005-08-15', '2005-09-15',
#                '2005-10-15', '2005-11-15',
#                ...
#                '2022-02-15', '2022-03-15', '2022-04-15', '2022-05-15',
#                '2022-06-15', '2022-07-15', '2022-08-15', '2022-09-15',
#                '2022-10-15', '2022-11-15'],
#               dtype='datetime64[ns]', name='date', length=214, freq=None)

# %% [markdown]
# #### 將dataframe 組裝起來

# %%
# features['bias20'].reindex(every_month, method='ffill')

for name, f in features.items():
    features[name] = f.reindex(every_month, method='ffill')

# %%
for name, f in features.items():
    features[name] = f.unstack()

# %%
import pandas as pd
dataset = pd.DataFrame(features)

# %%
feature_names = list(dataset.columns)

# %%
##############################################　　　自己加入的　　　##############################################
dataset.index = dataset.index.set_names(['stock_id','date'], level=[0,1])


#dataset.index.levels[1].name = 'date'
#dataset.index.levels[0].name = 'stock_id'

#因為你pandas更新到新版了
## profit.index.levels[0].name = 'year'
## profit.index.levels[1].name = 'month'
#這兩行的語法被棄用，請改成
#profit.index=profit.index.set_names('year', level=0)
#profit.index=profit.index.set_names('month', level=1)
#or profit.index=profit.index.set_names(['year','month'], level=[0,1])
#直接一行
#就可以了

# %% [markdown]
# ### 新增 label

# %%
from finlab import ml

ml.add_profit_prediction(dataset)
ml.add_rank_prediction(dataset)

# %% [markdown]
# ### 刪除太大太小的歷史資料

# %%
print(dataset.shape)

def drop_extreme_case(dataset, feature_names, thresh=0.01):
    
    extreme_cases = pd.Series(False, index=dataset.index)
    for f in feature_names:
        tf = dataset[f]
        extreme_cases = extreme_cases | (tf < tf.quantile(thresh)) | (tf > tf.quantile(1-thresh))
    dataset = dataset[~extreme_cases]
    return dataset

dataset_drop_extreme_case = drop_extreme_case(dataset , list1 , thresh=0.01)

print(dataset_drop_extreme_case.shape)

##(436560, 27)
##(377538, 27)

##(505602, 75)
##(446580, 75)
# Out:
# (436774, 27)
# (377770, 27)

# %%
dataset_dropna = dataset_drop_extreme_case.dropna(how='any')
dataset_dropna = dataset_dropna.reset_index().set_index("date")

# %%
dataset_drop_extreme_case.index.get_level_values("date")
# Out:
# DatetimeIndex(['2005-02-15', '2005-03-15', '2005-04-15', '2005-05-15',
#                '2005-06-15', '2005-07-15', '2005-08-15', '2005-09-15',
#                '2005-10-15', '2005-11-15',
#                ...
#                '2021-11-15', '2021-12-15', '2022-02-15', '2022-03-15',
#                '2022-04-15', '2022-06-15', '2022-08-15', '2022-09-15',
#                '2022-10-15', '2022-11-15'],
#               dtype='datetime64[ns]', name='date', length=377770, freq=None)

# %%
##############################################　　　自己加入的　　　##############################################

dataset_dropna.index = pd.to_datetime(dataset_dropna.index)
dataset_dropna = dataset_dropna.sort_index()

#修復＜class ‘numpy.ndarray‘＞　https://blog.csdn.net/lxbin/article/details/114005757

# %%
dataset_train = dataset_dropna[:'2020']
dataset_test = dataset_dropna['2021':]

# %% [markdown]
# ### 機器學習
#  - 目前只有三個，技術指標也要在增加一下

# %% [markdown]
# #### keras

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers

import os


os.environ['KMP_DUPLICATE_LIB_OK']='True'

model = keras.models.Sequential()
model.add(layers.Dense(100, activation='relu',
                      input_shape=(len(feature_names),),
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dense(100, activation='relu',
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dropout(0.7))
model.add(layers.Dense(1, activation='sigmoid'))


model.summary()

model.compile(loss='mean_squared_error',
              optimizer="adam",)

print('start fitting')
history = model.fit(dataset_train[feature_names], dataset_train['rank'],
                    batch_size=1000,         #1000  #每一个batch的大小
                    epochs=225, #225          #迭代次数
                    verbose=1,
                    validation_split=0.1,
                    #validation_data =        #(测试集的输入特征，测试集的标签），
                    #validation_split =       # 从测试集中划分多少比例给训练集，
                    #validation_freq = 20        #测试的epoch间隔数                     
                   )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2600
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 12,801
# Trainable params: 12,801
# Non-trainable params: 0
# _________________________________________________________________
# start fitting
# Epoch 1/225
# 103/103 [==============================] - ETA: 0s - loss: 0.260 - ETA: 0s - loss: 0.250 - ETA: 0s - loss: 0.230 - ETA: 0s - loss: 0.199 - ETA: 0s - loss: 0.169 - ETA: 0s - loss: 0.149 - ETA: 0s - loss: 0.135 - 1s 5ms/step - loss: 0.1281 - val_loss: 0.0714
# Epoch 2/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0736 - val_loss: 0.0714
# Epoch 3/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0736 - val_loss: 0.0713
# Epoch 4/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0736 - val_loss: 0.0714
# Epoch 5/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 6/225
# 103/103 [==============================] - ETA: 0s - loss: 0.082 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 7/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 8/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0714
# Epoch 9/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 10/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 11/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 12/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 13/225
# 103/103 [==============================] - ETA: 0s - loss: 0.079 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 14/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 15/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 16/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 17/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0712
# Epoch 18/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 19/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 20/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 21/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 22/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 23/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 24/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 25/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 1s 5ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 26/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 1s 5ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 27/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 1s 5ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 28/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 29/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 30/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 31/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 32/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0713
# Epoch 33/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0711
# Epoch 34/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 35/225
# 103/103 [==============================] - ETA: 0s - loss: 0.078 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0711
# Epoch 36/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0711
# Epoch 37/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 38/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 39/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 40/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0713
# Epoch 41/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 42/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 43/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 44/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0711
# Epoch 45/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0711
# Epoch 46/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 47/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 48/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 49/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0711
# Epoch 50/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0712
# Epoch 51/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 52/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0712
# Epoch 53/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0711
# Epoch 54/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 55/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 56/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 57/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 58/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 59/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 60/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 61/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0712
# Epoch 62/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 63/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 64/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 65/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0712
# Epoch 66/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 67/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 68/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 69/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 70/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0712
# Epoch 71/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0712
# Epoch 72/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 73/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 74/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0712
# Epoch 75/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 76/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 77/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 78/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 79/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 80/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 81/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 82/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 83/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 84/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 85/225
# 103/103 [==============================] - ETA: 0s - loss: 0.077 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 86/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 87/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 88/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 89/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 90/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 91/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 92/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 93/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 94/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 95/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 96/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 97/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 98/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0711
# Epoch 99/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 100/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0711
# Epoch 101/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 102/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 103/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 104/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 105/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 106/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 107/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 108/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 109/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 110/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 111/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 112/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 113/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 114/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 115/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 116/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 1s 5ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 117/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0730 - val_loss: 0.0712
# Epoch 118/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 1s 6ms/step - loss: 0.0731 - val_loss: 0.0711
# Epoch 119/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 1s 5ms/step - loss: 0.0731 - val_loss: 0.0712
# Epoch 120/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 5ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 121/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 122/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 123/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 124/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 125/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 126/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 127/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0711
# Epoch 128/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0711
# Epoch 129/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 130/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 131/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 132/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 133/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 134/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 135/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 136/225
# 103/103 [==============================] - ETA: 0s - loss: 0.077 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 137/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 138/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 139/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 140/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 141/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 142/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 143/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 144/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0712
# Epoch 145/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 146/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 147/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 148/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0711
# Epoch 149/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 150/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 151/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 152/225
# 103/103 [==============================] - ETA: 0s - loss: 0.078 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0713
# Epoch 153/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 154/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 155/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 156/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 157/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 158/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 159/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 160/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 161/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 162/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 163/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 164/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 165/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 166/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 167/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 168/225
# 103/103 [==============================] - ETA: 0s - loss: 0.077 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 169/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 170/225
# 103/103 [==============================] - ETA: 0s - loss: 0.066 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 171/225
# 103/103 [==============================] - ETA: 0s - loss: 0.078 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 172/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 173/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 174/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 175/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 176/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0710
# Epoch 177/225
# 103/103 [==============================] - ETA: 0s - loss: 0.077 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 178/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 179/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 180/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0710
# Epoch 181/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 182/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 183/225
# 103/103 [==============================] - ETA: 0s - loss: 0.067 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0710
# Epoch 184/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 185/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 186/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 187/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 188/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 189/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 190/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 191/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0711
# Epoch 192/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0711
# Epoch 193/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 194/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 195/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 196/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 197/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0711
# Epoch 198/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0710
# Epoch 199/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 200/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0710
# Epoch 201/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0711
# Epoch 202/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 203/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 204/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 205/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 206/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 207/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 208/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 209/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0710
# Epoch 210/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0710
# Epoch 211/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0711
# Epoch 212/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0710
# Epoch 213/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0711
# Epoch 214/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 215/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0710
# Epoch 216/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 217/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0710
# Epoch 218/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 219/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 220/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 221/225
# 103/103 [==============================] - ETA: 0s - loss: 0.067 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 222/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0710
# Epoch 223/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 224/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0708
# Epoch 225/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709

# %% [markdown]
# ##### 結果

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['val_loss'][1:])
plt.plot(history.history['loss'][1:])

# %% [markdown]
# #### lightgbm Model

# %%
##############################################　　　自己加入的　　　##############################################
import lightgbm as lgb

cf = lgb.LGBMRegressor(n_estimators=5000)

train = dataset_train[feature_names] , dataset_train['return'] > 1
test = dataset_test[feature_names] , dataset_test['return'] > 1 

print('---cf.fit---')
print(cf.fit(*train))
print('---cf.score---')
print(cf.score(*test))
print('---predict---')
print(cf.predict(test[0]))
# Out:
# ---cf.fit---
# LGBMRegressor(n_estimators=5000)
# ---cf.score---
# -0.06752270102275948
# ---predict---
# [0.35687734 0.75352246 0.59765913 ... 0.18311661 0.37304874 0.18961644]

# %% [markdown]
# ##### 參數優化_1110

# %%
#import lightgbm

fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [test],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

gs.fit(*train, **fit_params)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557452
# Early stopping, best iteration is:
# [77]	valid's auc: 0.559566
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532937
# Early stopping, best iteration is:
# [111]	valid's auc: 0.533782
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.554779
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.556225
# Early stopping, best iteration is:
# [79]	valid's auc: 0.558375
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532228
# Early stopping, best iteration is:
# [97]	valid's auc: 0.532625
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.552109
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.566821
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533025
# Early stopping, best iteration is:
# [89]	valid's auc: 0.534405
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [58]	valid's auc: 0.555274
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555913
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.536172
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.545579
# Early stopping, best iteration is:
# [81]	valid's auc: 0.547557
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.552896
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.529926
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.554678
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.561393
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.530835
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.551431
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.564808
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.538838
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.557176
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.563362
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.521098
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [20]	valid's auc: 0.555804
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.558247
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.533452
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [62]	valid's auc: 0.553934
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561483
# Early stopping, best iteration is:
# [85]	valid's auc: 0.563256
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.536875
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.554623
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [51]	valid's auc: 0.557921
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.536207
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.552048
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.569283
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533258
# Early stopping, best iteration is:
# [78]	valid's auc: 0.535379
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.554796
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.564305
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.529364
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.559437
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562182
# Early stopping, best iteration is:
# [90]	valid's auc: 0.5644
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.530812
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.555017
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561045
# Early stopping, best iteration is:
# [112]	valid's auc: 0.563276
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.522785
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [36]	valid's auc: 0.556565
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557721
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.54064
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.555284
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558242
# Early stopping, best iteration is:
# [90]	valid's auc: 0.559565
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.523228
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.552842
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [53]	valid's auc: 0.561369
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528052
# Early stopping, best iteration is:
# [74]	valid's auc: 0.529713
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.549613
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.554238
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.535432
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547912
# Early stopping, best iteration is:
# [83]	valid's auc: 0.550261
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.56092
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.529283
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [30]	valid's auc: 0.555061
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551779
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.524622
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.546207
# Early stopping, best iteration is:
# [82]	valid's auc: 0.547869
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.555958
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.545702
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [42]	valid's auc: 0.558857
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [54]	valid's auc: 0.559782
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529323
# Early stopping, best iteration is:
# [91]	valid's auc: 0.530655
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.551779
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558507
# Early stopping, best iteration is:
# [90]	valid's auc: 0.560129
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529918
# Early stopping, best iteration is:
# [84]	valid's auc: 0.530577
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.55663
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560762
# Early stopping, best iteration is:
# [77]	valid's auc: 0.562139
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531582
# Early stopping, best iteration is:
# [110]	valid's auc: 0.531929
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [24]	valid's auc: 0.55608
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.556786
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.531318
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.555344
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561687
# Early stopping, best iteration is:
# [103]	valid's auc: 0.561999
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528905
# [200]	valid's auc: 0.531383
# Early stopping, best iteration is:
# [172]	valid's auc: 0.533304
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.555286
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559935
# Early stopping, best iteration is:
# [102]	valid's auc: 0.56012
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.522946
# Early stopping, best iteration is:
# [125]	valid's auc: 0.524237
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.550827
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.565148
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.528839
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.553369
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559358
# Early stopping, best iteration is:
# [78]	valid's auc: 0.561212
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529549
# Early stopping, best iteration is:
# [105]	valid's auc: 0.530321
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551618
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557701
# Early stopping, best iteration is:
# [118]	valid's auc: 0.559092
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.527441
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.555216
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.55483
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.534724
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.554485
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562809
# Early stopping, best iteration is:
# [110]	valid's auc: 0.564411
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.526372
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.557679
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559693
# Early stopping, best iteration is:
# [84]	valid's auc: 0.56226
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534812
# Early stopping, best iteration is:
# [103]	valid's auc: 0.535407
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.553435
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.560883
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.535948
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.555145
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.56076
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.532801
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [54]	valid's auc: 0.552109
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.555191
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.533684
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [54]	valid's auc: 0.549016
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [48]	valid's auc: 0.559794
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.533174
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [24]	valid's auc: 0.551871
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559736
# Early stopping, best iteration is:
# [90]	valid's auc: 0.56108
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.529245
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.553973
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.56046
# Early stopping, best iteration is:
# [123]	valid's auc: 0.562537
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.545529
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.554114
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5622
# Early stopping, best iteration is:
# [118]	valid's auc: 0.564001
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533368
# Early stopping, best iteration is:
# [89]	valid's auc: 0.533921
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.556386
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.553839
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.523466
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [33]	valid's auc: 0.556061
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561298
# Early stopping, best iteration is:
# [98]	valid's auc: 0.561633
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [62]	valid's auc: 0.53197
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.555056
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.56789
# Early stopping, best iteration is:
# [112]	valid's auc: 0.569321
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.524703
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.554803
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561838
# Early stopping, best iteration is:
# [78]	valid's auc: 0.564209
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.536945
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.556994
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559679
# Early stopping, best iteration is:
# [140]	valid's auc: 0.561668
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.525332
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [58]	valid's auc: 0.551041
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.561891
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532795
# Early stopping, best iteration is:
# [80]	valid's auc: 0.534028
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.553898
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562209
# Early stopping, best iteration is:
# [85]	valid's auc: 0.565457
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.525282
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [62]	valid's auc: 0.555417
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [18]	valid's auc: 0.554385
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.540817
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.55112
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [28]	valid's auc: 0.558264
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.545565
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [36]	valid's auc: 0.561467
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.565281
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [54]	valid's auc: 0.535459
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.55564
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.56162
# Early stopping, best iteration is:
# [88]	valid's auc: 0.563068
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.534805
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.557042
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.561533
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.539228
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.554048
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557251
# [200]	valid's auc: 0.559436
# Early stopping, best iteration is:
# [178]	valid's auc: 0.559456
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.535225
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [31]	valid's auc: 0.558423
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [61]	valid's auc: 0.560868
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530085
# Early stopping, best iteration is:
# [77]	valid's auc: 0.534138
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.550979
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.562806
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.527932
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [53]	valid's auc: 0.55705
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.557597
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.531168
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.559673
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.562526
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.52471
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.555126
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559567
# Early stopping, best iteration is:
# [85]	valid's auc: 0.562107
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528597
# Early stopping, best iteration is:
# [95]	valid's auc: 0.53093
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.551907
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.555172
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.530712
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [52]	valid's auc: 0.55613
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [26]	valid's auc: 0.556756
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.529868
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.555917
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.557372
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.533721
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.553563
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.557229
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.552017
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.557906
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560146
# Early stopping, best iteration is:
# [122]	valid's auc: 0.562491
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531874
# Early stopping, best iteration is:
# [141]	valid's auc: 0.534898
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.553075
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.565613
# Early stopping, best iteration is:
# [125]	valid's auc: 0.566989
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.523838
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.549794
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557913
# Early stopping, best iteration is:
# [144]	valid's auc: 0.559751
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528056
# Early stopping, best iteration is:
# [144]	valid's auc: 0.531005
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.553561
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560338
# Early stopping, best iteration is:
# [134]	valid's auc: 0.563259
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52912
# Early stopping, best iteration is:
# [85]	valid's auc: 0.529793
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [33]	valid's auc: 0.553517
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560819
# Early stopping, best iteration is:
# [125]	valid's auc: 0.563902
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.538039
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.556023
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.559677
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.526445
# Early stopping, best iteration is:
# [112]	valid's auc: 0.529434
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.55171
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.556322
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.544409
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [29]	valid's auc: 0.552217
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555345
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.532216
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.554533
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557509
# Early stopping, best iteration is:
# [133]	valid's auc: 0.56076
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.524484
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.552679
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562505
# Early stopping, best iteration is:
# [79]	valid's auc: 0.56403
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534293
# Early stopping, best iteration is:
# [154]	valid's auc: 0.536861
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551221
# Early stopping, best iteration is:
# [73]	valid's auc: 0.553596
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [58]	valid's auc: 0.559339
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534133
# Early stopping, best iteration is:
# [118]	valid's auc: 0.534724
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.55391
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.561177
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.53584
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.55677
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.556654
# Early stopping, best iteration is:
# [81]	valid's auc: 0.558236
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53108
# Early stopping, best iteration is:
# [132]	valid's auc: 0.533334
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.551882
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.559787
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.537873
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.555475
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.55913
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.531821
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.552685
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.553818
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.522204
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.555267
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559004
# Early stopping, best iteration is:
# [91]	valid's auc: 0.560653
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.534191
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.554719
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.56119
# Early stopping, best iteration is:
# [77]	valid's auc: 0.564187
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.525952
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.556352
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.556343
# Early stopping, best iteration is:
# [84]	valid's auc: 0.558772
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.533918
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.558576
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558436
# Early stopping, best iteration is:
# [77]	valid's auc: 0.56085
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.529067
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.553898
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.558398
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.535951
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.55955
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560954
# Early stopping, best iteration is:
# [95]	valid's auc: 0.562088
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.534122
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.559319
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562602
# Early stopping, best iteration is:
# [96]	valid's auc: 0.563653
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.532483
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.551158
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560789
# Early stopping, best iteration is:
# [88]	valid's auc: 0.56204
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.529019
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [32]	valid's auc: 0.558364
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559896
# Early stopping, best iteration is:
# [121]	valid's auc: 0.563182
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528025
# Early stopping, best iteration is:
# [90]	valid's auc: 0.52998
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551057
# Early stopping, best iteration is:
# [70]	valid's auc: 0.552265
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555803
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.53152
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.558524
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.554911
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.52536
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.557096
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.552801
# Early stopping, best iteration is:
# [95]	valid's auc: 0.553543
# RandomizedSearchCV(cv=3,
#                    estimator=LGBMClassifier(metric='None', n_estimators=5000,
#                                             n_jobs=4, random_state=314),
#                    n_iter=100,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001B6D8797E48>,
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001B6D8797948>,
#                                         'min_child_weight': [1e-05, 0.001, 0.01,
#                                                              0.1, 1, 10.0,
#                                                              100.0, 1000.0,
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001B6D8797688>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001B6D8797C88>},
#                    random_state=314, scoring='roc_auc', verbose=True)

# %%
gs.best_estimator_
# Out:
# LGBMClassifier(colsample_bytree=0.7916380440478592, metric='None',
#                min_child_samples=211, min_child_weight=1, n_estimators=5000,
#                n_jobs=4, num_leaves=45, random_state=314, reg_alpha=2,
#                reg_lambda=20, subsample=0.5211522776637936)

# %%
#
#gs.best_estimator_
#LGBMClassifier(colsample_bytree=0.6433117836032942, metric='None',
#               min_child_samples=224, min_child_weight=1e-05, n_estimators=5000,
#               n_jobs=4, num_leaves=20, random_state=314, reg_alpha=10,
#               reg_lambda=10, subsample=0.8945613420997809)

# %%
cf = lgb.LGBMRegressor(colsample_bytree=0.4893610123694421, metric='None',
               min_child_samples=325, n_estimators=5000, n_jobs=4,
               num_leaves=44, random_state=314, reg_alpha=7, reg_lambda=20,
               subsample=0.3338474163716765)

cf.fit(dataset_train[feature_names],dataset_train['return'] > 1, **fit_params)
cf.score(dataset_test[feature_names],dataset_test['return'] > 1)
# Out:
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55389
# Early stopping, best iteration is:
# [82]	valid's auc: 0.554967
# 0.00294508945193217

# %% [raw]
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551389
# Early stopping, best iteration is:
# [89]	valid's auc: 0.553699
# 0.003857956228475623

# %%
#print(cf.fit(*train))

# %%
#import lightgbm as lgb
#gbm = lgb.LGBMClassifier(n_estimators=100, random_state=5, learning_rate=0.01)
#gbm.fit(dataset_train[feature_names], dataset_train['return'] > 1)

# %%
#import tqdm
#
#n = 3
#
#X = []
#y = []
#indexes = []
#dataset_scaled_x = dataset_scaled[feature_names]
#
#for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-n)):
#    X.append(dataset_scaled_x.iloc[i:i+n].values)
#    y.append(dataset_scaled['return'].iloc[i+n-1])
#    indexes.append(dataset_scaled.index[i+n-1])
##dataset_scaled.head()

# %%
#import numpy as np
#X = np.array(X)
#y = np.array(y)

# %%
##import lightgbm as lgb
#cf = lgb.LGBMRegressor(colsample_bytree=0.7740467183023685, metric='None',
#               min_child_samples=395, min_child_weight=0.01, n_estimators=5000,
#               n_jobs=4, num_leaves=9, random_state=314, reg_alpha=5,
#               reg_lambda=10, subsample=0.4643892520208455)
#    
#cf.fit(dataset_train[feature_names].astype(float), dataset_train['rank'])

# %% [markdown]
# #### Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

cf2 = RandomForestRegressor(n_estimators=100)
cf2.fit(dataset_train[feature_names].astype(float), dataset_train['rank'])
# Out:
# RandomForestRegressor()

# %% [markdown]
# ##### 參數優化_1110

# %%
from scipy.stats import randint as sp_randint 
from sklearn.model_selection import RandomizedSearchCV 
# build a classifier 
clf = RandomForestRegressor(n_estimators=100) 
# specify parameters and distributions to sample from 
param_dist = {"max_depth": [3, None], 
              "max_features": sp_randint(1, 11), 
              "min_samples_split": sp_randint(2, 11), 
              "min_samples_leaf": sp_randint(1, 11), 
              "bootstrap": [True, False], 
              "criterion": ["mse", "mae"]} 
# run randomized search 
n_iter_search = 20 
rs = RandomizedSearchCV(clf, param_distributions=param_dist, 
                                   n_iter=n_iter_search)

# %%
rs.fit(dataset_train[features], dataset_train['return'] > 1)

# %% [markdown]
# ##### Split Train Test dataset

# %%
feature_imp = pd.DataFrame(zip(cf.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
sns.barplot(x="Value", y="Feature", data=feature_imp)

# %%
select = dataset.index.get_level_values('date') < '2021'
dataset_train = dataset[select]
dataset_test = dataset[~select]

# %% [markdown]
# ### Ensemble learning

# %%
dataset_drop = dataset.dropna(subset=feature_names+['return'])

vals = model.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result1'] = pd.Series(vals.swapaxes(0,1)[0], dataset_drop.index)

vals = cf.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result2'] = pd.Series(vals, dataset_drop.index)

vals = cf2.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result3'] = pd.Series(vals, dataset_drop.index)

dataset_drop = dataset_drop.reset_index().set_index("date")

# %% [markdown]
# ## backtest

# %% [markdown]
# 把量加進來做篩選
#  * https://hahow.in/courses/5b9d3a6dca498a001e917383/shapeussions/60c96f5b018697e8a6131cbc

# %%
#把量加進來
vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

vol_filter=vol_ma5>1000
vol_filter=vol_filter[vol_filter].fillna(0)
#vol_filter

# %%
#t1 = vol_ma5.iloc[-1].dropna()
#t1.to_csv('./tmp/132.csv')
#t1.hist(bins=10)

# %%
import math


dates = sorted(list(set(dataset_drop.index)))

rs = []
for d in dates:
    
    dataset_time = dataset_drop.loc[d]
    
    dataset_time = drop_extreme_case(dataset_time , list1 , thresh=0.01)
    
    rank = (dataset_time['result1'] + dataset_time['result2'] + dataset_time['result3'] ) #* vol_filter.loc[d]


    condition = (rank >= rank.nlargest(20).iloc[-1]) 
    
    r = dataset_time['return'][condition].mean()

    rs.append(r * (1-3/1000-1.425/1000*2*0.6))

rs = pd.Series(rs, index=dates)['2021':].cumprod()

s0050 = close['0050']['2021':]

pd.DataFrame({'nn strategy return':rs.reindex(s0050.index, method='ffill'), '0050 return':s0050/s0050[0]}).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#import pickle
#
#return_history_1026 = pd.Series(rs, index=dates)['2021':].cumprod()
##eq = (gain[hold == 1].mean(axis=1)).fillna(1).cumprod()
#
#pickle.dump(rs, open('return_history_1026.pkl', 'wb'))

# %%
#import pyfolio as pf
#import pandas as pd
#
#close.index = close.index.tz_localize("Asia/Taipei")
##pf.create_returns_tear_sheet(close['0050'].pct_change())
#
## 得到 上一個單元的 回測結果
#ret = pickle.load(open("return_history_1026.pkl", "rb"))
#
## 將回測報酬率取出來
#ret = ret.pct_change().dropna()
#ret.index = pd.to_datetime(ret.index).tz_localize('Asia/Taipei')
#
## 利用pyfolio 比較報酬率
#pf.create_returns_tear_sheet(ret, benchmark_rets=close['0050'].pct_change())

# %% [markdown]
# ### 當月持股狀況

# %%
#dataset.index.levels[1]

# %%
# get the latest dataset
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()


last_dataset = drop_extreme_case(last_dataset, list1 , thresh=0.01)


# remove NaN testcases
last_dataset = last_dataset.dropna(subset=feature_names)

# predict

vals = model.predict(last_dataset[feature_names].astype(float))
last_dataset['result1'] = pd.Series(vals.swapaxes(0,1)[0], last_dataset.index)

vals = cf.predict(last_dataset[feature_names].astype(float))
last_dataset['result2'] = pd.Series(vals, last_dataset.index)

vals = cf2.predict(last_dataset[feature_names].astype(float))
last_dataset['result3'] = pd.Series(vals, last_dataset.index)


# calculate score

rank = last_dataset['result1'] + last_dataset['result2'] + last_dataset['result3']

#
rank = rank * vol_filter.iloc[-1] #******加上量的濾網

condition = (rank >= rank.nlargest(20).iloc[-1])
#vol_filter

# plot rank distribution
rank.hist(bins=20)


# show the best 20 stocks
slist1 = rank[condition].reset_index()['stock_id']

#https://keras-cn.readthedocs.io/en/latest/models/model/

# %%
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()

# %%
#rank.sort_values(ascending=False).head(20)

# %% [markdown]
# ## 平均分配資產於股票之中

# %%
close = data.get("收盤價")

money = 60000
stock_prices = close[slist1].iloc[-1]


print("股票平分張數:")
money / len(stock_prices) / stock_prices / 1000
# Out:
# 股票平分張數:
# stock_id
# 1336    0.117878
# 1609    0.158730
# 1785    0.095694
# 2049    0.016349
# 2105    0.087719
# 2345    0.011811
# 2356    0.116732
# 2363    0.178571
# 2387    0.074349
# 2474    0.016260
# 2481    0.051195
# 2610    0.169492
# 2618    0.115163
# 2641    0.168539
# 3441    0.084986
# 3665    0.011834
# 3694    0.145631
# 4551    0.019108
# 6223    0.031780
# 6282    0.101523
# Name: 2022-11-14 00:00:00, dtype: float64
