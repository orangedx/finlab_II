# %% [markdown]
# # Random Forest Classifier

# %% [markdown]
# ## Get dataset

# %%
import finlab.ml as ml

dataset = ml.fundamental_features()

print(dataset.shape)
dataset = dataset.dropna(thresh=int(len(dataset)*0.5), axis=1).dropna(how='any')
print(dataset.shape)
# Out:
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:49: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3900繼續營業部門稅前純益 = T3900繼續營業部門稅前純益[T3900繼續營業部門稅前純益.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:52: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3970經常稅後淨利 = T3970經常稅後淨利[T3970經常稅後淨利.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:55: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T2000權益總計 =  T2000權益總計[T2000權益總計.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:58: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3295營業毛利 =  T3295營業毛利[T3295營業毛利.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:61: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3100營業收入淨額 = T3100營業收入淨額[T3100營業收入淨額.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:64: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3700營業外收入及支出 = T3700營業外收入及支出[T3700營業外收入及支出.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:72: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3910所得稅費用 = T3910所得稅費用[T3910所得稅費用.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:75: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3300營業費用 = T3300營業費用[T3300營業費用.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:78: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T7211折舊 = T7211折舊[T7211折舊.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:81: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T7212攤提 = T7212攤提[T7212攤提.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:87: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0170存貨 = T0170存貨[T0170存貨.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:90: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   股本 = 股本[股本.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:98: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0400不動產廠房設備合計 =T0400不動產廠房設備合計[T0400不動產廠房設備合計.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:101: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0960非流動資產 = T0960非流動資產[T0960非流動資產.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:104: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0180預付費用及預付款 = T0180預付費用及預付款[T0180預付費用及預付款.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:107: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T1800非流動負債 = T1800非流動負債[T1800非流動負債.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:110: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0190其他流動資產 = T0190其他流動資產[T0190其他流動資產.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:113: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T1100流動負債 = T1100流動負債[T1100流動負債.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:116: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T0100流動資產 =T0100流動資產[T0100流動資產.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:119: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3501財物成本 = T3501財物成本[T3501財物成本.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:125: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3971本期綜合損益總額 = T3971本期綜合損益總額[T3971本期綜合損益總額.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:128: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3395營業利益 = T3395營業利益[T3395營業利益.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:137: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   R202用人費用率 = R202用人費用率[R202用人費用率.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:140: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3356研究發展費 = T3356研究發展費[T3356研究發展費.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:143: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T7210營運現金流 = T7210營運現金流[T7210營運現金流.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:146: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3950歸屬母公司淨利 = T3950歸屬母公司淨利[T3950歸屬母公司淨利.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:149: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T1000負債總額 =T1000負債總額[T1000負債總額.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:152: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T3200營業成本 = T3200營業成本[T3200營業成本.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:156: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   T7324取得不動產廠房及設備 = T7324取得不動產廠房及設備[ T7324取得不動產廠房及設備.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:158: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   應收帳款關係人淨額 = 應收帳款關係人淨額[應收帳款關係人淨額.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:161: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   應收票據淨額 = 應收票據淨額[應收票據淨額.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:164: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   應收票據關係人淨額 = 應收票據關係人淨額[應收票據關係人淨額.columns & 收盤價.columns]
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\ml.py:167: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   應收帳款淨額 = 應收帳款淨額[應收帳款淨額.columns & 收盤價.columns]
# (65231, 48)
# (32903, 48)

# %% [markdown]
# ## Add labels

# %%
feature_names = list(dataset.columns)

# %%
ml.add_profit_prediction(dataset)
dataset.head()
# Out:
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
# D:\Finlab\用 Python 理財：打造自己的 AI 股票理專\finlab\data.py:103: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   all_index = (df.index | item.index).sort_values()
#                      T3395營業利益  T7210營運現金流  T3950歸屬母公司淨利    T7211折舊  \
# stock_id date
# 1101     2014-05-15  3684224.0   6895832.0     4015175.0  1594505.0
#          2014-08-14  5938317.0   4452573.0     -754894.0  1573692.0
#          2014-11-14  5544164.0   3701961.0     3621052.0  1587492.0
#          2015-03-31  4690964.0   4936554.0     6459366.0  1575810.0
#          2015-05-15  1693508.0   5654152.0      349121.0  1711428.0
#
#                       T0100流動資產   T1100流動負債  T7324取得不動產廠房及設備  T3970經常稅後淨利  \
# stock_id date
# 1101     2014-05-15  92121458.0  74388787.0        -940633.0    2791235.0
#          2014-08-14  89163129.0  81190613.0        -465009.0    4828695.0
#          2014-11-14  89472928.0  78920574.0        -911057.0    4934486.0
#          2015-03-31  96605816.0  68632044.0       -1384489.0    4029460.0
#          2015-05-15  92471096.0  69579858.0        -818460.0     974518.0
#
#                      R101_ROA稅後息前  R11V_ROA綜合損益  ...   R501_流動比率   R502_速動比率  \
# stock_id date                                    ...
# 1101     2014-05-15     -1.732411      1.630076  ...  123.837828  101.776758
#          2014-08-14     -0.952778      0.152556  ...  109.819505   91.450337
#          2014-11-14     -0.948101      2.168353  ...  113.370853   93.976558
#          2015-03-31     -1.265106      3.002608  ...  140.759054  117.966121
#          2015-05-15     -2.315297      0.069454  ...  132.899231  109.303861
#
#                      R503_利息支出率   R678_營運資金  R607_總資產週轉次數  R610_存貨週轉率  \
# stock_id date
# 1101     2014-05-15   -9.792979  17732671.0      0.093998    2.191306
#          2014-08-14  -17.435186   7972516.0      0.112552    2.381079
#          2014-11-14  -17.800651  10552354.0      0.106864    2.306032
#          2015-03-31  -13.169666  27973772.0      0.103034    2.268994
#          2015-05-15   -7.153186  22891238.0      0.073611    1.817298
#
#                      R612_固定資產週轉次數  R613_淨值週轉率次  R69B_自由現金流量    return
# stock_id date
# 1101     2014-05-15       0.245688     0.171327    4901868.0  1.073347
#          2014-08-14       0.297377     0.208493   16542181.0  0.984816
#          2014-11-14       0.282283     0.200028    4768224.0  0.969163
#          2015-03-31       0.275197     0.187942  -10525322.0  0.956818
#          2015-05-15       0.195713     0.132250    8494249.0  0.850077
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Split Train Test dataset

# %%
date_arr = dataset.index.get_level_values('date') < '2021'
dataset_train = dataset[date_arr]
dataset_test = dataset[~date_arr]

# %% [markdown]
# ## Training

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

cf = RandomForestClassifier(n_estimators=100)

train = dataset_train[feature_names] , dataset_train['return'] > 1.5 
test = dataset_test[feature_names] , dataset_test['return'] > 1 

cf.fit(*train)
cf.score(*test)
cf.predict(test[0])
# Out:
# array([False, False, False, ..., False, False, False])

# %%
cf.score(*test)
# Out:
# 0.6323550465282749

# %% [markdown]
# ### Xgboost

# %%
import xgboost
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

cf_xgb = xgboost.XGBClassifier()
cf_xgb.fit(*train)
cf_xgb.score(*test)
# Out:
# C:\Users\User\.conda\envs\finlab\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:11:15] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.6324982104509663

# %% [markdown]
# ### lightgbm

# %%
import lightgbm

fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [test],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 500

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

gs.fit(*train, **fit_params)
# Out:
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550529
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.533572
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [20]	valid's auc: 0.533031
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.548211
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [17]	valid's auc: 0.532307
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [28]	valid's auc: 0.53452
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.544306
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.528748
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.527842
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.538888
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.531199
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.535315
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.550046
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.521653
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.538661
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547465
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.534288
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.535099
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553502
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.525913
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.537555
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.554391
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.533965
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.549137
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548735
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.529803
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.545604
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.550918
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.528107
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.540462
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548641
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.544003
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549448
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.556004
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.533077
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.541221
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.553517
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.5325
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.536683
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.56644
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.53734
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558714
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.529089
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.523763
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.517643
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [61]	valid's auc: 0.524858
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [68]	valid's auc: 0.514441
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.519736
# Early stopping, best iteration is:
# [81]	valid's auc: 0.519741
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.545088
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.529618
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.530434
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.551403
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.529761
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551316
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.546264
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.530756
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.540113
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.550524
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.53399
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.537091
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55811
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.539608
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546318
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.5555
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.537729
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552717
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.555848
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.548747
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553217
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.555844
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.534392
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.531348
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550514
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.531709
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [17]	valid's auc: 0.527697
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.565786
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.54943
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558832
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550826
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [19]	valid's auc: 0.52932
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.534853
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55007
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.534753
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.544767
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.548416
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.534918
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.544276
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.548895
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.524833
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.538072
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.536905
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.517911
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.522397
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.54548
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.530501
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.549476
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.554725
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.531242
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557548
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547923
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.530134
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.537762
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555749
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.533135
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.543182
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.555263
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.528988
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.539108
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.546216
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [16]	valid's auc: 0.533234
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [26]	valid's auc: 0.535861
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.555263
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.52788
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.53912
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551449
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.528184
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547504
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.542296
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.524171
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55036
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550861
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.537844
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550888
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.545416
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.530289
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [18]	valid's auc: 0.535716
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.550091
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.537055
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550726
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.530389
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.522035
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.522252
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.544183
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.528084
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.537726
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556629
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.533236
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.55052
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.549088
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.530015
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.540428
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557371
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.534059
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557206
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.555307
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.532647
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.543406
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.548562
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.543089
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.545731
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.556017
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.536139
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557123
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.550991
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.531648
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552341
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.558271
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.535922
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557372
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.560238
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.542205
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558383
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552359
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.534266
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.53825
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.56241
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.540021
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558383
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.548945
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [23]	valid's auc: 0.531257
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [27]	valid's auc: 0.535692
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.546018
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.527479
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.534949
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.556085
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.528776
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.549395
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.550066
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.527529
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [19]	valid's auc: 0.53605
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.556663
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.532436
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.536657
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.559355
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [31]	valid's auc: 0.522713
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [18]	valid's auc: 0.533024
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.543609
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.531106
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.538759
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.54945
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.523089
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.532388
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550513
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.514444
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.533932
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.55867
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.545403
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.541058
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551857
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.538083
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.544688
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.554866
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.542506
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.54405
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547911
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.534929
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.56218
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.552313
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.522179
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.541018
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.563132
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.53536
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558828
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.559913
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546007
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550002
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553623
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.534758
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [20]	valid's auc: 0.535066
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.543318
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.524304
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.533228
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546754
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.524201
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.536708
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557024
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.54046
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.560613
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.519342
# Early stopping, best iteration is:
# [149]	valid's auc: 0.519424
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.551637
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.528912
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.533074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.540325
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546311
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.542575
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.563132
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.53536
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558828
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.556195
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.52304
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.535303
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551802
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.531796
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.545797
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.55192
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.530366
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.537793
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.542702
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.529245
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.536365
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.55687
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.534377
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.552333
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.547186
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.534808
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.5303
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.550749
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.537837
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550453
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528445
# Early stopping, best iteration is:
# [102]	valid's auc: 0.528505
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.520366
# Early stopping, best iteration is:
# [94]	valid's auc: 0.520366
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.518945
# Early stopping, best iteration is:
# [102]	valid's auc: 0.519469
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.552773
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.537329
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.539963
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550037
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.53171
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.533744
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.538306
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.515972
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.527063
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.55445
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.539698
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.543831
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.538013
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.524919
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.542231
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.553832
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.535472
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549365
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.544876
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.530031
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.532585
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.558885
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.536522
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557901
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.560273
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [35]	valid's auc: 0.527413
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.535711
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.557887
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.529207
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.542691
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553602
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.537287
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.54842
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# ...
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.548194
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.524367
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.538014
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.54407
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.522752
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.526834
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550239
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.53903
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.529271
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553125
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.531273
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.537442
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.547223
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.524538
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.535184
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551743
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.528253
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.541712
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.550157
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.525882
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.531501
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.558978
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.533161
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.537833
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.545821
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.515766
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.532657
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.557149
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.531422
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.536736
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549861
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.538619
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.544497
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.555517
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.537423
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.545277
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532932
# Early stopping, best iteration is:
# [102]	valid's auc: 0.532932
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.522856
# Early stopping, best iteration is:
# [146]	valid's auc: 0.522874
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531391
# Early stopping, best iteration is:
# [72]	valid's auc: 0.531491
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.549623
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.532329
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.539123
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.555083
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.539605
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [26]	valid's auc: 0.536481
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.550545
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.533384
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.553504
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.546232
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.525121
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.537093
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.549274
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.531411
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.534193
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.559002
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.535596
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557728
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.551267
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.535735
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.547859
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.546472
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [21]	valid's auc: 0.529721
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546817
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.568317
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.533896
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.559388
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.561639
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.543054
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.543233
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.557798
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.535435
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557749
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.561528
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.53533
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557826
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.550174
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [21]	valid's auc: 0.530452
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.535576
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.557548
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.541743
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.5547
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.55753
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.537429
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551275
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.552422
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.536292
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.543838
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.543394
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.511003
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.521519
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.542735
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.532846
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.536341
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.54749
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [18]	valid's auc: 0.528901
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [28]	valid's auc: 0.53284
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.551919
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.539321
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.546374
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.542353
# RandomizedSearchCV(cv=3,
#                    estimator=LGBMClassifier(metric='None', n_estimators=5000,
#                                             n_jobs=4, random_state=314),
#                    n_iter=500,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001FA8A3D5148>,
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001FA8A3D3AC8>,
#                                         'min_child_weight': [1e-05, 0.001, 0.01,
#                                                              0.1, 1, 10.0,
#                                                              100.0, 1000.0,
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001FA89CEE308>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001FA8A3D3BC8>},
#                    random_state=314, scoring='roc_auc', verbose=True)

# %%
gs.best_estimator_
# Out:
# LGBMClassifier(colsample_bytree=0.8177320587717147, metric='None',
#                min_child_samples=333, min_child_weight=0.1, n_estimators=5000,
#                n_jobs=4, num_leaves=6, random_state=314, reg_alpha=10,
#                reg_lambda=50, subsample=0.3500434254207897)

# %%
cf_lgbm = lightgbm.LGBMClassifier(colsample_bytree=0.9442008821254966, metric='None',
               min_child_samples=248, min_child_weight=0.1, n_estimators=5000,
               n_jobs=4, num_leaves=9, random_state=314, reg_alpha=10,
               reg_lambda=1, subsample=0.557608335163303)

        #(boosting_type='gbdt', class_weight=None,
        #colsample_bytree=0.7792703648870174, importance_type='split',
        #learning_rate=0.1, max_depth=-1, metric='None',
        #min_child_samples=344, min_child_weight=0.01, min_split_gain=0.0,
        #n_estimators=5000, n_jobs=4, num_leaves=10, objective=None,
        #random_state=314, reg_alpha=0, reg_lambda=10, silent=True,
        #subsample=0.8503048560728566, subsample_for_bin=200000,
        #subsample_freq=0)

cf_lgbm.fit(dataset_train[feature_names],dataset_train['return'] > 1.5, **fit_params)
cf_lgbm.score(dataset_test[feature_names],dataset_test['return'] > 1)
# Out:
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.53783
# 0.6323550465282749

# %% [markdown]
# ## Prediction

# %%
prediction = gs.predict_proba(test[0])
#prediction = cf_lgbm.predict_proba(test[0])

prediction = prediction.swapaxes(0,1)[1]
prediction
# Out:
# array([0.02662094, 0.02662094, 0.02662094, ..., 0.03492933, 0.03492933,
#        0.02958879])

# %% [markdown]
# ## Backtest

# %%
#from PIL import Image, ImageOps, ImageEnhance, __version__ as PILLOW_VERSION
#from pylab import rcParams


# %matplotlib inline
returns = dataset_test['return'][prediction > 0.5]
dates = returns.index.get_level_values("date")
returns.groupby(dates).mean().cumprod().plot(color='red')

returns = dataset_test['return'][prediction < 0.5]
dates = returns.index.get_level_values("date")
returns.groupby(dates).mean().cumprod().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# from pylab import rcParams
