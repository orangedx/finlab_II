# %% [markdown]
# # 五線譜

# %%
from finlab.data import Data
import pandas as pd
import datetime
data = Data()

days = 750
data.date = datetime.date(2018,1,1)
c = data.get('收盤價', 10000000000)

# %% [markdown]
# # 計算五條線跟斜率

# %%
y = c.iloc[-days:]
x = pd.Series(list(range(days)), index=y.index)
midy = y.mean(axis=0)
midx = days/2

beta = (y - midy).mul(x - midx, axis=0).sum()/((x-midx)**2).sum()
alpha = midy - midx * beta


# 計算中線跟標準差
X = pd.DataFrame({k: x for k in y.columns})
mid_line = ((X * beta + alpha))
std = (y - mid_line).std()

# %%
cond = y.iloc[-1] < mid_line.iloc[-1] - 2*std
cond[cond]
# Out:
# stock_id
# 00673R    True
# 00710B    True
# 00716R    True
# 00717     True
# 1416      True
# 1527      True
# 1709      True
# 2383      True
# 4438      True
# 6239      True
# 911622    True
# dtype: bool

# %% [markdown]
# # 畫圖

# %%
# %matplotlib inline

def plot_rainbow(s):
    y[s].plot()

    mid_line[s].plot()

    (mid_line[s] + std[s]).plot()
    (mid_line[s] + 2*std[s]).plot()

    (mid_line[s] - std[s]).plot()
    (mid_line[s] - 2*std[s]).plot()
    
plot_rainbow('0050')

# %% [markdown]
# # 選股

# %%
# 小於下方一條線的股票
condition = c.iloc[-1] < mid_line.iloc[-1] - 2*std
condition[condition]
# Out:
# stock_id
# 00693U    True
# 1215      True
# 1305      True
# 1504      True
# 1538      True
# 1568      True
# 1906      True
# 1909      True
# 2308      True
# 2355      True
# 2439      True
# 2444      True
# 2466      True
# 2722      True
# 2723      True
# 2820      True
# 3044      True
# 3536      True
# 5243      True
# 6117      True
# 6271      True
# 6412      True
# 8070      True
# 8411      True
# 9938      True
# dtype: bool

# %%
plot_rainbow('2439')

# %%
def strategy(data):
    
    # 計算 alpha beta (截點跟焦點)
    days = 800
    c = data.get('收盤價', days)
    
    # 請參考 https://zh.wikipedia.org/w/index.php?title=%E7%B7%9A%E6%80%A7%E5%9B%9E%E6%AD%B8
    # 中的單變量回歸

    y = c.iloc[-days:]
    x = pd.Series(list(range(days)), index=y.index)
    midy = y.mean(axis=0)
    midx = days/2

    beta = (y - midy).mul(x - midx, axis=0).sum()/((x-midx)**2).sum()
    alpha = midy - midx * beta


    # 計算中線跟標準差
    X = pd.DataFrame({k: x for k in beta.index})
    mid_line = ((X * beta + alpha))
    std = (y - mid_line).std()
    
    conditions = [
        (c.iloc[-1] < mid_line.iloc[-1] - 2*std),
        c.iloc[-1] > c.iloc[-20:].mean()
    ]
    
    selected_stock = sum(conditions) == len(conditions)
    
    return selected_stock[selected_stock]
    
from finlab.backtest import backtest
import datetime
start = datetime.date(2008, 1, 1)
end = datetime.date(2018, 1, 1)
data.cache=True
backtest(start, end, 250, strategy, data)
# Out:
# 2008-01-01 - 2008-09-07 報酬率: -26.56 % nstock 33
# /Users/koreal6803/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort