# %% [markdown]
# # Final Project

# %%
# 移除不必要的警告
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 獲取歷史資料

# %%
from finlab.data import Data
from finlab.ml import fundamental_features
fdf = fundamental_features()

data = Data()

close = data.get("收盤價")
open_ = data.get("開盤價")
high = data.get("最高價")
low = data.get("最低價")
vol = data.get("成交股數")

PB = data.get("股價淨值比")
pe = data.get("本益比")

#close = data.get_adj("收盤價").round(2)

#財務指標
rev = data.get("當月營收")
l_rev = data.get("去年當月營收")

#t123 = data.get('土地')

#bargin_i=data.get("投信買賣超股數")
#bargin_f=data.get("外資自營商買賣超股數")
#bargin_s=data.get("自營商買賣超股數(自行買賣)")
#

rev.index = rev.index.shift(5, "d")         #每月頻率
#周頻率

# %% [raw]
# ```
# https://www.twblogs.net/a/5d3f3173bd9eee517422735f
# W-WED
# https://docs.python.org/zh-tw/3/library/calendar.html
# ```

# %% [markdown]
# ### 計算features

# %%
#MFI  = data.talib("MFI")
##MFI.tail()
#ub,mb,lb =data.talib("BBANDS")

# %% [markdown]
# #### 營收相關

# %%
##############################################　　　自己加入的　　　##############################################
import pandas as pd
from finlab.__init__ import talib_all_stock
from talib import abstract

# %%
def bias(n):
    return close / close.rolling(n, min_periods=1).mean()

def acc(n):
    return close.shift(n) / (close.shift(2*n) + close) * 2

def rsv(n):
    l = close.rolling(n, min_periods=1).min()
    h = close.rolling(n, min_periods=1).max()
    
    return (close - l) / (h - l)

def mom(n):
    return (rev / rev.shift(1)).shift(n)

def yoy(n):
    return (rev.shift(n) / rev.shift(12+n)) -1


features = {
    'mom1': mom(1),
    'mom2': mom(2),
    'mom3': mom(3),
    'mom4': mom(4),
    'mom5': mom(5),
    'mom6': mom(6),
    'mom7': mom(7),
    'mom8': mom(8),
    'mom9': mom(9),
    
    'bias5': bias(5),
    'bias10': bias(10),
    'bias20': bias(20),
    'bias60': bias(60),
    'bias120': bias(120),
    'bias240': bias(240),
    
    'acc5': acc(5),
    'acc10': acc(10),
    'acc20': acc(20),
    'acc60': acc(60),
    'acc120': acc(120),
    'acc240': acc(240),
    
    'rsv5': rsv(5),
    'rsv10': rsv(10),
    'rsv20': rsv(20),
    'rsv60': rsv(60),
    'rsv120': rsv(120),
    'rsv240': rsv(240),
###############################################
    'yoy': yoy(1),
    'delta_yoy':yoy(1)-yoy(2),
    
    'PB':PB,
    'PE':pe,       
}

# %% [markdown]
# #### 財報指標

# %% [markdown]
# 兩個feature結合
# [https://hahow.in/courses/5b9d3a6dca498a001e917383/discussions/5d18b63eac23d80020ae4ce7]

# %%
from finlab.ml import fundamental_features
dataset_fundamental = fundamental_features()

# %% [markdown]
# #### 技術指標

# %% [raw]
# # https://zhuanlan.zhihu.com/p/342075180 talib函数功能一览表
#
# def bias(n):
#     return close / close.rolling(n, min_periods=1).mean()
#
# def acc(n):
#     return close.shift(n) / (close.shift(2*n) + close) * 2
#
# def rsv(n):
#     l = close.rolling(n, min_periods=1).min()
#     h = close.rolling(n, min_periods=1).max()
#
#     return (close - l) / (h - l)
#
# def mom(n):
#     return (rev / rev.shift(1)).shift(n)
#
#
# def bi_(n):
#     return (bargin_i / vol.shift(1)).shift(n)
#
# def bf(n):
#     return (bargin_f / vol.shift(1)).shift(n)
#
# def bs(n):
#     return (bargin_s / vol.shift(1)).shift(n)
#
# def rsi(n):
#     #return talib_all_stock(ndays=10000, func=abstract.RSI, timeperiod=n)
#     return data.talib("RSI",timeperiod=n)
#
# def MFI(n):
#     return data.talib("MFI",timeperiod=n)
#
# def obv(n):
#     return data.talib("OBV",timeperiod=n)
#
#
#
# features = {
#
#     #'ATR14':data.talib("ATR",timeperiod=14),
#     #'NATR14':data.talib('NATR',timeperiod=14),
#     #'TRANGE':data.talib('TRANGE'),
#     #'Adosc3':data.talib('ADOSC',timeperiod=3),
#
#     #"MFI5":MFI(5),
#     #"MFI10":MFI(10),
#
#     #'rsi6': rsi(6),  #DataFrame
#     #'rsi10': rsi(10),  #DataFrame
#     #'rsi14': rsi(14),  #DataFrame
#     #'rsi20': rsi(20),  #DataFrame
#     #'rsi50': rsi(50),  #DataFrame
#
#     'mom1': mom(1),
#     'mom2': mom(2),
#     'mom3': mom(3),
#     'mom4': mom(4),
#     'mom5': mom(5),
#     'mom6': mom(6),
#     'mom7': mom(7),
#     'mom8': mom(8),
#     'mom9': mom(9),
#
#     'yoy': yoy(1),
#     'delta_yoy':yoy(1)-yoy(2),
#
# #    'ff':ff,
#     'PB':PB,
#     'PE':pe,
# #
#     'bias5': bias(5),
#     'bias10': bias(10),
#     'bias20': bias(20),
#     'bias60': bias(60),
#     'bias120': bias(120),
#     'bias240': bias(240),
#
#     'acc5': acc(5),
#     'acc10': acc(10),
#     'acc20': acc(20),
#     'acc60': acc(60),
#     'acc120': acc(120),
#     'acc240': acc(240),
#
#     #'rsv5': rsv(5),
#     #'rsv10': rsv(10),
#     #'rsv20': rsv(20),
#     #'rsv60': rsv(60),
#     #'rsv120': rsv(120),
#     #'rsv240': rsv(240),
# }

# %% [markdown]
# #### 組合dataset

# %%
import pandas as pd

# %% [markdown]
# #### 確認各指標清單

# %%
#list1=sorted(features)
#list1

# %%
#t1 = data.talib("NATR",timeperiod=14)
#t1.to_csv('myfile.csv')

# %% [markdown]
# ### 製作dataset
#
# ##### 設定買賣頻率

# %%
#rev.index = rev.index.tz_localize("Asia/Taipei")
every_month = rev.index
every_month
# Out:
# DatetimeIndex(['2005-02-15', '2005-03-15', '2005-04-15', '2005-05-15',
#                '2005-06-15', '2005-07-15', '2005-08-15', '2005-09-15',
#                '2005-10-15', '2005-11-15',
#                ...
#                '2022-02-15', '2022-03-15', '2022-04-15', '2022-05-15',
#                '2022-06-15', '2022-07-15', '2022-08-15', '2022-09-15',
#                '2022-10-15', '2022-11-15'],
#               dtype='datetime64[ns]', name='date', length=214, freq=None)

# %% [markdown]
# #### 將dataframe 組裝起來

# %%
# features['bias20'].reindex(every_month, method='ffill')

for name, f in features.items():
    features[name] = f.reindex(every_month, method='ffill')

# %%
for name, f in features.items():
    features[name] = f.unstack()

# %%
import pandas as pd
dataset = pd.DataFrame(features)

# %%
feature_names = list(dataset.columns)

# %%
##############################################　　　自己加入的　　　##############################################
dataset.index = dataset.index.set_names(['stock_id','date'], level=[0,1])


#dataset.index.levels[1].name = 'date'
#dataset.index.levels[0].name = 'stock_id'

#因為你pandas更新到新版了
## profit.index.levels[0].name = 'year'
## profit.index.levels[1].name = 'month'
#這兩行的語法被棄用，請改成
#profit.index=profit.index.set_names('year', level=0)
#profit.index=profit.index.set_names('month', level=1)
#or profit.index=profit.index.set_names(['year','month'], level=[0,1])
#直接一行
#就可以了

# %% [markdown]
# ### 分類dataset
#  - dataset　　自己拼的
#  - dataset_fundamental 財務相關

# %% [markdown]
# ### 新增 label

# %%
from finlab import ml

ml.add_profit_prediction(dataset)
ml.add_rank_prediction(dataset)

ml.add_profit_prediction(dataset_fundamental)
ml.add_rank_prediction(dataset_fundamental)

# %% [markdown]
# ### 刪除太大太小的歷史資料

# %%
print(dataset.shape)

def drop_extreme_case(dataset, feature_names, thresh=0.01):
    
    extreme_cases = pd.Series(False, index=dataset.index)
    for f in feature_names:
        tf = dataset[f]
        extreme_cases = extreme_cases | (tf < tf.quantile(thresh)) | (tf > tf.quantile(1-thresh))
    dataset = dataset[~extreme_cases]
    return dataset

dataset_drop_extreme_case = drop_extreme_case(dataset , list1 , thresh=0.01)

print(dataset_drop_extreme_case.shape)

#'----------------------------------------'

print(dataset_fundamental.shape)

def drop_extreme_case_f(dataset_fundamental, feature_names, thresh=0.01):
    
    extreme_cases = pd.Series(False, index=dataset_fundamental.index)
    for f in feature_names:
        tf = dataset_fundamental[f]
        extreme_cases = extreme_cases | (tf < tf.quantile(thresh)) | (tf > tf.quantile(1-thresh))
    dataset = dataset[~extreme_cases]
    return dataset_fundamental

dataset_drop_extreme_case_f = drop_extreme_case(dataset_fundamental , list1 , thresh=0.01)

print(dataset_drop_extreme_case_f.shape)

# %%
dataset_dropna = dataset_drop_extreme_case.dropna(how='any')
dataset_dropna = dataset_dropna.reset_index().set_index("date")

# %%
dataset_drop_extreme_case.index.get_level_values("date")
# Out:
# DatetimeIndex(['2005-02-15', '2005-03-15', '2005-04-15', '2005-05-15',
#                '2005-06-15', '2005-07-15', '2005-08-15', '2005-09-15',
#                '2005-10-15', '2005-11-15',
#                ...
#                '2021-11-15', '2021-12-15', '2022-02-15', '2022-03-15',
#                '2022-04-15', '2022-06-15', '2022-08-15', '2022-09-15',
#                '2022-10-15', '2022-11-15'],
#               dtype='datetime64[ns]', name='date', length=377755, freq=None)

# %%
##############################################　　　自己加入的　　　##############################################

dataset_dropna.index = pd.to_datetime(dataset_dropna.index)
dataset_dropna = dataset_dropna.sort_index()

#修復＜class ‘numpy.ndarray‘＞　https://blog.csdn.net/lxbin/article/details/114005757

# %%
dataset_train = dataset_dropna[:'2020']
dataset_test = dataset_dropna['2021':]

# %% [markdown]
# ### 機器學習
#  - 目前只有三個，技術指標也要在增加一下

# %% [markdown]
# #### keras

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers

import os


os.environ['KMP_DUPLICATE_LIB_OK']='True'

model = keras.models.Sequential()
model.add(layers.Dense(100, activation='relu',
                      input_shape=(len(feature_names),),
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dense(100, activation='relu',
                      kernel_initializer=initializers.he_normal(seed=0)))
model.add(layers.Dropout(0.7))
model.add(layers.Dense(1, activation='sigmoid'))


model.summary()

model.compile(loss='mean_squared_error',
              optimizer="adam",)

print('start fitting')
history = model.fit(dataset_train[feature_names], dataset_train['rank'],
                    batch_size=1000,         #1000  #每一个batch的大小
                    epochs=225, #225          #迭代次数
                    verbose=1,
                    validation_split=0.1,
                    #validation_data =        #(测试集的输入特征，测试集的标签），
                    #validation_split =       # 从测试集中划分多少比例给训练集，
                    #validation_freq = 20        #测试的epoch间隔数                     
                   )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               3200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 13,401
# Trainable params: 13,401
# Non-trainable params: 0
# _________________________________________________________________
# start fitting
# Epoch 1/225
# 103/103 [==============================] - ETA: 0s - loss: 0.260 - ETA: 0s - loss: 0.250 - ETA: 0s - loss: 0.232 - ETA: 0s - loss: 0.205 - ETA: 0s - loss: 0.177 - ETA: 0s - loss: 0.158 - ETA: 0s - loss: 0.145 - ETA: 0s - loss: 0.135 - 1s 5ms/step - loss: 0.1320 - val_loss: 0.0713
# Epoch 2/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0736 - val_loss: 0.0713
# Epoch 3/225
# 103/103 [==============================] - ETA: 0s - loss: 0.077 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0712
# Epoch 4/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0713
# Epoch 5/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 6/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0713
# Epoch 7/225
# 103/103 [==============================] - ETA: 0s - loss: 0.077 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0711
# Epoch 8/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 9/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0734 - val_loss: 0.0712
# Epoch 10/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0712
# Epoch 11/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 12/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0712
# Epoch 13/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0710
# Epoch 14/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 15/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 16/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 17/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0711
# Epoch 18/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 19/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 20/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0712
# Epoch 21/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0710
# Epoch 22/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 23/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0713
# Epoch 24/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0712
# Epoch 25/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0711
# Epoch 26/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0732 - val_loss: 0.0711
# Epoch 27/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0711
# Epoch 28/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 29/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0713
# Epoch 30/225
# 103/103 [==============================] - ETA: 0s - loss: 0.079 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0711
# Epoch 31/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0715
# Epoch 32/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 33/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0711
# Epoch 34/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0711
# Epoch 35/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 36/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 37/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 38/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 39/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0731 - val_loss: 0.0710
# Epoch 40/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0712
# Epoch 41/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 42/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 43/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 44/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0714
# Epoch 45/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0711
# Epoch 46/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0712
# Epoch 47/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0711
# Epoch 48/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0711
# Epoch 49/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 50/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0709
# Epoch 51/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0713
# Epoch 52/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0710
# Epoch 53/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0710
# Epoch 54/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0710
# Epoch 55/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 56/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0710
# Epoch 57/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0712
# Epoch 58/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0710
# Epoch 59/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0711
# Epoch 60/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 61/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0730 - val_loss: 0.0713
# Epoch 62/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0709
# Epoch 63/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0711
# Epoch 64/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0710
# Epoch 65/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0729 - val_loss: 0.0713
# Epoch 66/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0714
# Epoch 67/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0715
# Epoch 68/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 69/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0710
# Epoch 70/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 71/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0710
# Epoch 72/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0711
# Epoch 73/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0711
# Epoch 74/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0712
# Epoch 75/225
# 103/103 [==============================] - ETA: 0s - loss: 0.077 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0712
# Epoch 76/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 77/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0711
# Epoch 78/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0711
# Epoch 79/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0710
# Epoch 80/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0717
# Epoch 81/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 82/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0728 - val_loss: 0.0711
# Epoch 83/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0711
# Epoch 84/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0714
# Epoch 85/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0727 - val_loss: 0.0709
# Epoch 86/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0710
# Epoch 87/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0726 - val_loss: 0.0711
# Epoch 88/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0727 - val_loss: 0.0710
# Epoch 89/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0712
# Epoch 90/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0727 - val_loss: 0.0710
# Epoch 91/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0711
# Epoch 92/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0709
# Epoch 93/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0712
# Epoch 94/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0711
# Epoch 95/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0711
# Epoch 96/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0712
# Epoch 97/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0711
# Epoch 98/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0709
# Epoch 99/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0710
# Epoch 100/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0712
# Epoch 101/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0713
# Epoch 102/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0727 - val_loss: 0.0710
# Epoch 103/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0713
# Epoch 104/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0710
# Epoch 105/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0726 - val_loss: 0.0712
# Epoch 106/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0726 - val_loss: 0.0713
# Epoch 107/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0727 - val_loss: 0.0711
# Epoch 108/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0712
# Epoch 109/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0709
# Epoch 110/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0710
# Epoch 111/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0709
# Epoch 112/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0726 - val_loss: 0.0709
# Epoch 113/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0726 - val_loss: 0.0715
# Epoch 114/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0725 - val_loss: 0.0710
# Epoch 115/225
# 103/103 [==============================] - ETA: 0s - loss: 0.080 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0712
# Epoch 116/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0710
# Epoch 117/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0711
# Epoch 118/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0726 - val_loss: 0.0716
# Epoch 119/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0712
# Epoch 120/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0710
# Epoch 121/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0726 - val_loss: 0.0710
# Epoch 122/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0713
# Epoch 123/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0711
# Epoch 124/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 1s 5ms/step - loss: 0.0725 - val_loss: 0.0712
# Epoch 125/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0711
# Epoch 126/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0709
# Epoch 127/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0710
# Epoch 128/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0712
# Epoch 129/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0714
# Epoch 130/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0725 - val_loss: 0.0711
# Epoch 131/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0712
# Epoch 132/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0710
# Epoch 133/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0712
# Epoch 134/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0711
# Epoch 135/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0724 - val_loss: 0.0712
# Epoch 136/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0710
# Epoch 137/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0710
# Epoch 138/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0707
# Epoch 139/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0725 - val_loss: 0.0711
# Epoch 140/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0710
# Epoch 141/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0711
# Epoch 142/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0716
# Epoch 143/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0724 - val_loss: 0.0713
# Epoch 144/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0717
# Epoch 145/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0716
# Epoch 146/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0713
# Epoch 147/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0710
# Epoch 148/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0711
# Epoch 149/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0709
# Epoch 150/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0711
# Epoch 151/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0724 - val_loss: 0.0713
# Epoch 152/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0712
# Epoch 153/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0710
# Epoch 154/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0724 - val_loss: 0.0715
# Epoch 155/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0709
# Epoch 156/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0713
# Epoch 157/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0715
# Epoch 158/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0709
# Epoch 159/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0711
# Epoch 160/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0710
# Epoch 161/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0714
# Epoch 162/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0712
# Epoch 163/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0712
# Epoch 164/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0712
# Epoch 165/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0712
# Epoch 166/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0710
# Epoch 167/225
# 103/103 [==============================] - ETA: 0s - loss: 0.067 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0709
# Epoch 168/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0709
# Epoch 169/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0710
# Epoch 170/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0710
# Epoch 171/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0723 - val_loss: 0.0710
# Epoch 172/225
# 103/103 [==============================] - ETA: 0s - loss: 0.067 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0709
# Epoch 173/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0723 - val_loss: 0.0714
# Epoch 174/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0713
# Epoch 175/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0709
# Epoch 176/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0712
# Epoch 177/225
# 103/103 [==============================] - ETA: 0s - loss: 0.075 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0713
# Epoch 178/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0711
# Epoch 179/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0710
# Epoch 180/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0715
# Epoch 181/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0711
# Epoch 182/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0710
# Epoch 183/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0708
# Epoch 184/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0711
# Epoch 185/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0711
# Epoch 186/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0712
# Epoch 187/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0722 - val_loss: 0.0713
# Epoch 188/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0711
# Epoch 189/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0713
# Epoch 190/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0709
# Epoch 191/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0710
# Epoch 192/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0711
# Epoch 193/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0712
# Epoch 194/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0713
# Epoch 195/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0712
# Epoch 196/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0722 - val_loss: 0.0715
# Epoch 197/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0713
# Epoch 198/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0709
# Epoch 199/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0713
# Epoch 200/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0710
# Epoch 201/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0712
# Epoch 202/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0713
# Epoch 203/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0711
# Epoch 204/225
# 103/103 [==============================] - ETA: 0s - loss: 0.067 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0715
# Epoch 205/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0718
# Epoch 206/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0710
# Epoch 207/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0712
# Epoch 208/225
# 103/103 [==============================] - ETA: 0s - loss: 0.068 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0712
# Epoch 209/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0712
# Epoch 210/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0720 - val_loss: 0.0715
# Epoch 211/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0721 - val_loss: 0.0709
# Epoch 212/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0713
# Epoch 213/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0715
# Epoch 214/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0712
# Epoch 215/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0720 - val_loss: 0.0711
# Epoch 216/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0719 - val_loss: 0.0714
# Epoch 217/225
# 103/103 [==============================] - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0720 - val_loss: 0.0714
# Epoch 218/225
# 103/103 [==============================] - ETA: 0s - loss: 0.076 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0720 - val_loss: 0.0710
# Epoch 219/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0720 - val_loss: 0.0713
# Epoch 220/225
# 103/103 [==============================] - ETA: 0s - loss: 0.073 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0712
# Epoch 221/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - 0s 4ms/step - loss: 0.0719 - val_loss: 0.0711
# Epoch 222/225
# 103/103 [==============================] - ETA: 0s - loss: 0.069 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - 0s 4ms/step - loss: 0.0720 - val_loss: 0.0712
# Epoch 223/225
# 103/103 [==============================] - ETA: 0s - loss: 0.070 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0720 - val_loss: 0.0717
# Epoch 224/225
# 103/103 [==============================] - ETA: 0s - loss: 0.074 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0720 - val_loss: 0.0711
# Epoch 225/225
# 103/103 [==============================] - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.071 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - ETA: 0s - loss: 0.072 - 0s 3ms/step - loss: 0.0720 - val_loss: 0.0711

# %% [markdown]
# ##### 結果

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['val_loss'][1:])
plt.plot(history.history['loss'][1:])

# %% [markdown]
# #### lightgbm Model

# %%
##############################################　　　自己加入的　　　##############################################
import lightgbm as lgb

cf = lgb.LGBMRegressor(n_estimators=5000)

train = dataset_train[feature_names] , dataset_train['return'] > 1
test = dataset_test[feature_names] , dataset_test['return'] > 1 

print('---cf.fit---')
print(cf.fit(*train))
print('---cf.score---')
print(cf.score(*test))
print('---predict---')
print(cf.predict(test[0]))
# Out:
# ---cf.fit---
# LGBMRegressor(n_estimators=5000)
# ---cf.score---
# -0.05791987772443696
# ---predict---
# [0.49508018 0.56408623 0.50731124 ... 0.52500276 0.53999209 0.35820635]

# %% [markdown]
# ##### 參數優化_1110

# %%
#import lightgbm

fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [test],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

gs.fit(*train, **fit_params)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558409
# Early stopping, best iteration is:
# [94]	valid's auc: 0.558715
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531883
# Early stopping, best iteration is:
# [80]	valid's auc: 0.532512
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.553308
# Early stopping, best iteration is:
# [80]	valid's auc: 0.554494
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.561102
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534578
# [200]	valid's auc: 0.535255
# Early stopping, best iteration is:
# [175]	valid's auc: 0.53555
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.550792
# Early stopping, best iteration is:
# [72]	valid's auc: 0.552299
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.54855
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530423
# Early stopping, best iteration is:
# [157]	valid's auc: 0.536596
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551509
# Early stopping, best iteration is:
# [104]	valid's auc: 0.552449
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557355
# Early stopping, best iteration is:
# [143]	valid's auc: 0.560414
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.525583
# Early stopping, best iteration is:
# [111]	valid's auc: 0.527346
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547502
# Early stopping, best iteration is:
# [126]	valid's auc: 0.548432
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.558659
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.525164
# Early stopping, best iteration is:
# [142]	valid's auc: 0.528205
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548008
# Early stopping, best iteration is:
# [77]	valid's auc: 0.548787
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.563835
# Early stopping, best iteration is:
# [114]	valid's auc: 0.564838
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532658
# Early stopping, best iteration is:
# [130]	valid's auc: 0.534561
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [54]	valid's auc: 0.550821
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562758
# Early stopping, best iteration is:
# [93]	valid's auc: 0.563077
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53339
# Early stopping, best iteration is:
# [107]	valid's auc: 0.534921
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549903
# Early stopping, best iteration is:
# [90]	valid's auc: 0.550886
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.559363
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.526966
# Early stopping, best iteration is:
# [119]	valid's auc: 0.52975
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.55083
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5612
# Early stopping, best iteration is:
# [94]	valid's auc: 0.562059
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531101
# Early stopping, best iteration is:
# [70]	valid's auc: 0.531613
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [39]	valid's auc: 0.553552
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55356
# Early stopping, best iteration is:
# [76]	valid's auc: 0.55623
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531639
# Early stopping, best iteration is:
# [124]	valid's auc: 0.533323
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.550827
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561996
# Early stopping, best iteration is:
# [119]	valid's auc: 0.56372
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530687
# Early stopping, best iteration is:
# [120]	valid's auc: 0.53354
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [61]	valid's auc: 0.550804
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560101
# Early stopping, best iteration is:
# [101]	valid's auc: 0.560277
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53216
# Early stopping, best iteration is:
# [91]	valid's auc: 0.533544
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.551424
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.556306
# Early stopping, best iteration is:
# [84]	valid's auc: 0.558196
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.525864
# Early stopping, best iteration is:
# [107]	valid's auc: 0.527701
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [68]	valid's auc: 0.549802
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560474
# Early stopping, best iteration is:
# [160]	valid's auc: 0.563826
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531823
# Early stopping, best iteration is:
# [168]	valid's auc: 0.535403
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.553723
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [23]	valid's auc: 0.551991
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.526414
# Early stopping, best iteration is:
# [105]	valid's auc: 0.52751
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549877
# [200]	valid's auc: 0.550317
# Early stopping, best iteration is:
# [179]	valid's auc: 0.552487
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560242
# Early stopping, best iteration is:
# [162]	valid's auc: 0.563787
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530798
# Early stopping, best iteration is:
# [110]	valid's auc: 0.531941
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549769
# Early stopping, best iteration is:
# [90]	valid's auc: 0.549997
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [26]	valid's auc: 0.559816
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.526522
# [200]	valid's auc: 0.533501
# Early stopping, best iteration is:
# [238]	valid's auc: 0.534492
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.549989
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561698
# Early stopping, best iteration is:
# [100]	valid's auc: 0.561698
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528167
# Early stopping, best iteration is:
# [135]	valid's auc: 0.531409
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5511
# Early stopping, best iteration is:
# [149]	valid's auc: 0.552923
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55488
# [200]	valid's auc: 0.559827
# Early stopping, best iteration is:
# [185]	valid's auc: 0.559883
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.520391
# [200]	valid's auc: 0.528506
# Early stopping, best iteration is:
# [232]	valid's auc: 0.52974
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547285
# Early stopping, best iteration is:
# [128]	valid's auc: 0.549377
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.55642
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.524066
# Early stopping, best iteration is:
# [152]	valid's auc: 0.528652
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549877
# Early stopping, best iteration is:
# [128]	valid's auc: 0.551825
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.556533
# [200]	valid's auc: 0.559605
# Early stopping, best iteration is:
# [170]	valid's auc: 0.559605
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.520748
# Early stopping, best iteration is:
# [158]	valid's auc: 0.523766
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5456
# Early stopping, best iteration is:
# [89]	valid's auc: 0.546315
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55773
# Early stopping, best iteration is:
# [112]	valid's auc: 0.558943
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5252
# [200]	valid's auc: 0.530483
# Early stopping, best iteration is:
# [184]	valid's auc: 0.531302
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547827
# [200]	valid's auc: 0.551103
# Early stopping, best iteration is:
# [205]	valid's auc: 0.551397
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559877
# Early stopping, best iteration is:
# [90]	valid's auc: 0.560879
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530884
# Early stopping, best iteration is:
# [140]	valid's auc: 0.534609
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.554202
# Early stopping, best iteration is:
# [70]	valid's auc: 0.555791
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562715
# Early stopping, best iteration is:
# [108]	valid's auc: 0.563822
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532692
# Early stopping, best iteration is:
# [125]	valid's auc: 0.534438
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.551911
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558929
# [200]	valid's auc: 0.561664
# Early stopping, best iteration is:
# [181]	valid's auc: 0.562838
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53356
# [200]	valid's auc: 0.534514
# Early stopping, best iteration is:
# [215]	valid's auc: 0.534677
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.553054
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.556311
# Early stopping, best iteration is:
# [85]	valid's auc: 0.557292
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.525516
# Early stopping, best iteration is:
# [167]	valid's auc: 0.532022
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.548335
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.5574
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52873
# Early stopping, best iteration is:
# [78]	valid's auc: 0.530099
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.544729
# Early stopping, best iteration is:
# [80]	valid's auc: 0.547366
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558011
# Early stopping, best iteration is:
# [108]	valid's auc: 0.558887
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.524585
# Early stopping, best iteration is:
# [147]	valid's auc: 0.528175
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [61]	valid's auc: 0.548661
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [68]	valid's auc: 0.560686
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532719
# Early stopping, best iteration is:
# [113]	valid's auc: 0.534317
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.552432
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558701
# Early stopping, best iteration is:
# [77]	valid's auc: 0.559015
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530541
# Early stopping, best iteration is:
# [116]	valid's auc: 0.532508
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.552791
# Early stopping, best iteration is:
# [126]	valid's auc: 0.553881
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558313
# Early stopping, best iteration is:
# [80]	valid's auc: 0.560311
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528128
# Early stopping, best iteration is:
# [158]	valid's auc: 0.535054
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548449
# Early stopping, best iteration is:
# [76]	valid's auc: 0.551838
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558277
# Early stopping, best iteration is:
# [73]	valid's auc: 0.56086
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532773
# Early stopping, best iteration is:
# [70]	valid's auc: 0.533073
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.552137
# Early stopping, best iteration is:
# [102]	valid's auc: 0.553065
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560897
# Early stopping, best iteration is:
# [109]	valid's auc: 0.562177
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530344
# [200]	valid's auc: 0.531817
# Early stopping, best iteration is:
# [194]	valid's auc: 0.533091
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.552842
# Early stopping, best iteration is:
# [88]	valid's auc: 0.554269
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561614
# Early stopping, best iteration is:
# [92]	valid's auc: 0.562751
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53511
# Early stopping, best iteration is:
# [166]	valid's auc: 0.53801
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [60]	valid's auc: 0.553898
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560365
# Early stopping, best iteration is:
# [80]	valid's auc: 0.562803
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532773
# Early stopping, best iteration is:
# [158]	valid's auc: 0.535119
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.546843
# Early stopping, best iteration is:
# [80]	valid's auc: 0.550298
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.563799
# Early stopping, best iteration is:
# [95]	valid's auc: 0.56414
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531062
# Early stopping, best iteration is:
# [157]	valid's auc: 0.532813
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.553197
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55747
# Early stopping, best iteration is:
# [169]	valid's auc: 0.562425
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.522489
# [200]	valid's auc: 0.528527
# Early stopping, best iteration is:
# [173]	valid's auc: 0.528608
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.54734
# Early stopping, best iteration is:
# [81]	valid's auc: 0.548016
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558314
# Early stopping, best iteration is:
# [95]	valid's auc: 0.559898
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533995
# Early stopping, best iteration is:
# [135]	valid's auc: 0.536218
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.551483
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.556022
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.525789
# Early stopping, best iteration is:
# [130]	valid's auc: 0.529841
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [53]	valid's auc: 0.548812
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560541
# Early stopping, best iteration is:
# [151]	valid's auc: 0.565059
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.527849
# [200]	valid's auc: 0.535037
# Early stopping, best iteration is:
# [177]	valid's auc: 0.536023
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551022
# Early stopping, best iteration is:
# [82]	valid's auc: 0.552104
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557275
# Early stopping, best iteration is:
# [84]	valid's auc: 0.558713
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530602
# Early stopping, best iteration is:
# [164]	valid's auc: 0.536614
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547493
# Early stopping, best iteration is:
# [160]	valid's auc: 0.551258
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558027
# Early stopping, best iteration is:
# [127]	valid's auc: 0.559644
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.526573
# Early stopping, best iteration is:
# [150]	valid's auc: 0.532892
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.545667
# Early stopping, best iteration is:
# [77]	valid's auc: 0.546234
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.559382
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532175
# Early stopping, best iteration is:
# [128]	valid's auc: 0.534363
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [62]	valid's auc: 0.549601
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55501
# [200]	valid's auc: 0.561377
# Early stopping, best iteration is:
# [185]	valid's auc: 0.562149
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5298
# Early stopping, best iteration is:
# [167]	valid's auc: 0.539724
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549345
# Early stopping, best iteration is:
# [110]	valid's auc: 0.551806
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.562158
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531864
# Early stopping, best iteration is:
# [78]	valid's auc: 0.53363
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548872
# Early stopping, best iteration is:
# [166]	valid's auc: 0.550712
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.553226
# Early stopping, best iteration is:
# [153]	valid's auc: 0.557902
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.523221
# [200]	valid's auc: 0.528433
# Early stopping, best iteration is:
# [217]	valid's auc: 0.529287
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548399
# Early stopping, best iteration is:
# [132]	valid's auc: 0.549991
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559756
# Early stopping, best iteration is:
# [115]	valid's auc: 0.560898
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.536103
# Early stopping, best iteration is:
# [113]	valid's auc: 0.536989
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [64]	valid's auc: 0.551394
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557623
# Early stopping, best iteration is:
# [142]	valid's auc: 0.560728
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.53166
# [200]	valid's auc: 0.536063
# Early stopping, best iteration is:
# [203]	valid's auc: 0.537126
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.552595
# Early stopping, best iteration is:
# [102]	valid's auc: 0.553313
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557692
# Early stopping, best iteration is:
# [130]	valid's auc: 0.560239
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52986
# [200]	valid's auc: 0.534026
# Early stopping, best iteration is:
# [194]	valid's auc: 0.534208
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549137
# Early stopping, best iteration is:
# [133]	valid's auc: 0.549969
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.5569
# Early stopping, best iteration is:
# [126]	valid's auc: 0.557949
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.519568
# [200]	valid's auc: 0.526611
# Early stopping, best iteration is:
# [188]	valid's auc: 0.52757
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548638
# Early stopping, best iteration is:
# [159]	valid's auc: 0.551488
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560781
# Early stopping, best iteration is:
# [80]	valid's auc: 0.561656
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.52914
# Early stopping, best iteration is:
# [81]	valid's auc: 0.530661
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547869
# Early stopping, best iteration is:
# [133]	valid's auc: 0.550871
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559588
# Early stopping, best iteration is:
# [80]	valid's auc: 0.562323
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530008
# [200]	valid's auc: 0.53346
# Early stopping, best iteration is:
# [182]	valid's auc: 0.534621
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548282
# Early stopping, best iteration is:
# [78]	valid's auc: 0.548979
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560172
# Early stopping, best iteration is:
# [77]	valid's auc: 0.561499
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.535245
# Early stopping, best iteration is:
# [134]	valid's auc: 0.537203
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.551287
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557991
# Early stopping, best iteration is:
# [121]	valid's auc: 0.559683
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528837
# [200]	valid's auc: 0.533544
# Early stopping, best iteration is:
# [186]	valid's auc: 0.534297
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.55244
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559843
# Early stopping, best iteration is:
# [87]	valid's auc: 0.560453
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534491
# Early stopping, best iteration is:
# [101]	valid's auc: 0.534838
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [51]	valid's auc: 0.551284
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.558349
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.524781
# Early stopping, best iteration is:
# [122]	valid's auc: 0.528893
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551278
# Early stopping, best iteration is:
# [136]	valid's auc: 0.553209
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.554221
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.521119
# [200]	valid's auc: 0.529073
# Early stopping, best iteration is:
# [187]	valid's auc: 0.530534
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548951
# Early stopping, best iteration is:
# [81]	valid's auc: 0.549753
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561257
# Early stopping, best iteration is:
# [148]	valid's auc: 0.563099
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533463
# [200]	valid's auc: 0.536584
# Early stopping, best iteration is:
# [201]	valid's auc: 0.536707
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.554528
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [51]	valid's auc: 0.560791
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531709
# Early stopping, best iteration is:
# [134]	valid's auc: 0.535014
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.549408
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.552584
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.525216
# [200]	valid's auc: 0.530283
# Early stopping, best iteration is:
# [240]	valid's auc: 0.532606
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.548409
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560993
# Early stopping, best iteration is:
# [112]	valid's auc: 0.561823
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534311
# Early stopping, best iteration is:
# [107]	valid's auc: 0.535323
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547227
# Early stopping, best iteration is:
# [78]	valid's auc: 0.54887
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.556633
# Early stopping, best iteration is:
# [164]	valid's auc: 0.561211
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.522745
# [200]	valid's auc: 0.531623
# Early stopping, best iteration is:
# [201]	valid's auc: 0.53163
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.54734
# Early stopping, best iteration is:
# [101]	valid's auc: 0.54771
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.554204
# [200]	valid's auc: 0.560046
# Early stopping, best iteration is:
# [230]	valid's auc: 0.561532
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.522959
# Early stopping, best iteration is:
# [127]	valid's auc: 0.528217
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549831
# Early stopping, best iteration is:
# [121]	valid's auc: 0.552945
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561818
# Early stopping, best iteration is:
# [163]	valid's auc: 0.563044
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528966
# Early stopping, best iteration is:
# [120]	valid's auc: 0.533271
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.546372
# Early stopping, best iteration is:
# [88]	valid's auc: 0.548284
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561765
# Early stopping, best iteration is:
# [113]	valid's auc: 0.562917
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533097
# Early stopping, best iteration is:
# [123]	valid's auc: 0.536203
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.551759
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [24]	valid's auc: 0.56096
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530771
# Early stopping, best iteration is:
# [143]	valid's auc: 0.535042
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.546458
# Early stopping, best iteration is:
# [78]	valid's auc: 0.547028
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.55375
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532444
# Early stopping, best iteration is:
# [139]	valid's auc: 0.53377
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.549007
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558681
# Early stopping, best iteration is:
# [166]	valid's auc: 0.560868
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531615
# Early stopping, best iteration is:
# [159]	valid's auc: 0.538226
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.552488
# [200]	valid's auc: 0.552595
# Early stopping, best iteration is:
# [170]	valid's auc: 0.55566
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55592
# [200]	valid's auc: 0.560537
# Early stopping, best iteration is:
# [187]	valid's auc: 0.560945
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530405
# [200]	valid's auc: 0.53529
# Early stopping, best iteration is:
# [184]	valid's auc: 0.535948
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.54522
# Early stopping, best iteration is:
# [107]	valid's auc: 0.546226
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55591
# Early stopping, best iteration is:
# [95]	valid's auc: 0.557862
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529987
# Early stopping, best iteration is:
# [146]	valid's auc: 0.533698
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [42]	valid's auc: 0.552008
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.555443
# [200]	valid's auc: 0.558893
# Early stopping, best iteration is:
# [179]	valid's auc: 0.559731
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.531261
# Early stopping, best iteration is:
# [123]	valid's auc: 0.5332
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.550693
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557065
# Early stopping, best iteration is:
# [71]	valid's auc: 0.557984
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.524683
# [200]	valid's auc: 0.5301
# Early stopping, best iteration is:
# [198]	valid's auc: 0.530877
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.549598
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562872
# Early stopping, best iteration is:
# [102]	valid's auc: 0.563644
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529532
# [200]	valid's auc: 0.533968
# Early stopping, best iteration is:
# [182]	valid's auc: 0.534338
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.554273
# Early stopping, best iteration is:
# [120]	valid's auc: 0.555056
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.557555
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.533181
# Early stopping, best iteration is:
# [97]	valid's auc: 0.533875
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.552396
# Early stopping, best iteration is:
# [71]	valid's auc: 0.553367
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.562679
# Early stopping, best iteration is:
# [114]	valid's auc: 0.56454
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.538351
# Early stopping, best iteration is:
# [161]	valid's auc: 0.540617
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.553562
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.558647
# Early stopping, best iteration is:
# [130]	valid's auc: 0.559662
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530456
# Early stopping, best iteration is:
# [115]	valid's auc: 0.531719
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549972
# Early stopping, best iteration is:
# [115]	valid's auc: 0.550471
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.55346
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529624
# Early stopping, best iteration is:
# [108]	valid's auc: 0.529743
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.553053
# Early stopping, best iteration is:
# [84]	valid's auc: 0.553903
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560491
# Early stopping, best iteration is:
# [165]	valid's auc: 0.563809
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.531161
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.549579
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.552989
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530185
# Early stopping, best iteration is:
# [78]	valid's auc: 0.53107
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.550543
# Early stopping, best iteration is:
# [79]	valid's auc: 0.552083
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.556725
# Early stopping, best iteration is:
# [72]	valid's auc: 0.559784
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.532794
# Early stopping, best iteration is:
# [109]	valid's auc: 0.53455
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [39]	valid's auc: 0.55476
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.563263
# Early stopping, best iteration is:
# [95]	valid's auc: 0.564287
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530486
# Early stopping, best iteration is:
# [140]	valid's auc: 0.53546
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.546608
# Early stopping, best iteration is:
# [71]	valid's auc: 0.548916
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.559858
# [200]	valid's auc: 0.562703
# Early stopping, best iteration is:
# [216]	valid's auc: 0.564157
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.534244
# Early stopping, best iteration is:
# [121]	valid's auc: 0.535535
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [29]	valid's auc: 0.550621
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.555731
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.530307
# [200]	valid's auc: 0.534088
# Early stopping, best iteration is:
# [175]	valid's auc: 0.53494
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.553151
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.557907
# Early stopping, best iteration is:
# [132]	valid's auc: 0.561015
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528376
# Early stopping, best iteration is:
# [110]	valid's auc: 0.529947
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.548742
# Early stopping, best iteration is:
# [78]	valid's auc: 0.551636
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.560128
# Early stopping, best iteration is:
# [164]	valid's auc: 0.560973
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.527808
# Early stopping, best iteration is:
# [162]	valid's auc: 0.532989
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.550678
# Early stopping, best iteration is:
# [79]	valid's auc: 0.552101
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.554225
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.525381
# [200]	valid's auc: 0.532422
# Early stopping, best iteration is:
# [222]	valid's auc: 0.53337
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.547673
# Early stopping, best iteration is:
# [124]	valid's auc: 0.549271
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.561312
# [200]	valid's auc: 0.562765
# Early stopping, best iteration is:
# [240]	valid's auc: 0.563387
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529848
# [200]	valid's auc: 0.536396
# Early stopping, best iteration is:
# [196]	valid's auc: 0.536733
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.551906
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.547849
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.528715
# Early stopping, best iteration is:
# [159]	valid's auc: 0.531282
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.550204
# [200]	valid's auc: 0.551308
# Early stopping, best iteration is:
# [185]	valid's auc: 0.552293
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.55918
# Early stopping, best iteration is:
# [91]	valid's auc: 0.560531
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529216
# [200]	valid's auc: 0.532373
# Early stopping, best iteration is:
# [238]	valid's auc: 0.534198
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.551852
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.554157
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.529855
# Early stopping, best iteration is:
# [116]	valid's auc: 0.533118
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [65]	valid's auc: 0.551019
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.549874
# Early stopping, best iteration is:
# [163]	valid's auc: 0.553381
# RandomizedSearchCV(cv=3,
#                    estimator=LGBMClassifier(metric='None', n_estimators=5000,
#                                             n_jobs=4, random_state=314),
#                    n_iter=100,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001E31115F608>,
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001E30B1B7F88>,
#                                         'min_child_weight': [1e-05, 0.001, 0.01,
#                                                              0.1, 1, 10.0,
#                                                              100.0, 1000.0,
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001E311147FC8>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001E31115F508>},
#                    random_state=314, scoring='roc_auc', verbose=True)

# %%
print(gs.best_estimator_)
print('----------------')
print(gs.best_score_)
# Out:
# LGBMClassifier(colsample_bytree=0.4364296729504425, metric='None',
#                min_child_samples=192, min_child_weight=10.0, n_estimators=5000,
#                n_jobs=4, num_leaves=10, random_state=314, reg_alpha=2,
#                reg_lambda=50, subsample=0.8327756184008888)
# ----------------
# 0.562989570009484

# %%
#
#gs.best_estimator_
#LGBMClassifier(colsample_bytree=0.6433117836032942, metric='None',
#               min_child_samples=224, min_child_weight=1e-05, n_estimators=5000,
#               n_jobs=4, num_leaves=20, random_state=314, reg_alpha=10,
#               reg_lambda=10, subsample=0.8945613420997809)

# %%
cf = lgb.LGBMRegressor(colsample_bytree=0.4364296729504425, metric='None',
               min_child_samples=192, min_child_weight=10.0, n_estimators=5000,
               n_jobs=4, num_leaves=10, random_state=314, reg_alpha=2,
               reg_lambda=50, subsample=0.8327756184008888)

cf.fit(dataset_train[feature_names],dataset_train['return'] > 1, **fit_params)
cf.score(dataset_test[feature_names],dataset_test['return'] > 1)
# Out:
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.544489
# Early stopping, best iteration is:
# [131]	valid's auc: 0.548757
# 0.09208743946754538

# %%
feature_imp = pd.DataFrame(zip(cf.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
sns.barplot(x="Value", y="Feature", data=feature_imp)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Feature'>

# %% [raw]
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.551389
# Early stopping, best iteration is:
# [89]	valid's auc: 0.553699
# 0.003857956228475623

# %%
#print(cf.fit(*train))

# %%
#import lightgbm as lgb
#gbm = lgb.LGBMClassifier(n_estimators=100, random_state=5, learning_rate=0.01)
#gbm.fit(dataset_train[feature_names], dataset_train['return'] > 1)

# %%
#import tqdm
#
#n = 3
#
#X = []
#y = []
#indexes = []
#dataset_scaled_x = dataset_scaled[feature_names]
#
#for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-n)):
#    X.append(dataset_scaled_x.iloc[i:i+n].values)
#    y.append(dataset_scaled['return'].iloc[i+n-1])
#    indexes.append(dataset_scaled.index[i+n-1])
##dataset_scaled.head()

# %%
#import numpy as np
#X = np.array(X)
#y = np.array(y)

# %%
##import lightgbm as lgb
#cf = lgb.LGBMRegressor(colsample_bytree=0.7740467183023685, metric='None',
#               min_child_samples=395, min_child_weight=0.01, n_estimators=5000,
#               n_jobs=4, num_leaves=9, random_state=314, reg_alpha=5,
#               reg_lambda=10, subsample=0.4643892520208455)
#    
#cf.fit(dataset_train[feature_names].astype(float), dataset_train['rank'])

# %% [markdown]
# #### Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

cf2 = RandomForestRegressor(n_estimators=100)
cf2.fit(dataset_train[feature_names].astype(float), dataset_train['rank'])
# Out:
# RandomForestRegressor()

# %% [markdown]
# ##### 參數優化_1110

# %%
from scipy.stats import randint as sp_randint 
from sklearn.model_selection import RandomizedSearchCV 
# build a classifier 
clf = RandomForestRegressor(n_estimators=100) 
# specify parameters and distributions to sample from 
param_dist = {"max_depth": [3, None], 
              "max_features": sp_randint(1, 11), 
              "min_samples_split": sp_randint(2, 11), 
              "min_samples_leaf": sp_randint(1, 11), 
              "bootstrap": [True, False], 
              "criterion": ["mse", "mae"]} 
# run randomized search 
n_iter_search = 20 
rs = RandomizedSearchCV(clf, param_distributions=param_dist, 
                                   n_iter=n_iter_search)

# %%
#rs.fit(dataset_train[features], dataset_train['return'] > 1)

# %% [markdown]
# ##### Split Train Test dataset

# %%
feature_imp = pd.DataFrame(zip(cf.feature_importances_, feature_names), 
                           columns=['Value','Feature']).sort_values('Value', ascending=False)
feature_imp

# %matplotlib inline
import seaborn as sns
sns.barplot(x="Value", y="Feature", data=feature_imp)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Feature'>

# %%
select = dataset.index.get_level_values('date') < '2021'
dataset_train = dataset[select]
dataset_test = dataset[~select]

# %% [markdown]
# ### Ensemble learning

# %%
dataset_drop = dataset.dropna(subset=feature_names+['return'])

vals = model.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result1'] = pd.Series(vals.swapaxes(0,1)[0], dataset_drop.index)

vals = cf.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result2'] = pd.Series(vals, dataset_drop.index)

vals = cf2.predict(dataset_drop[feature_names].astype(float))
dataset_drop['result3'] = pd.Series(vals, dataset_drop.index)

dataset_drop = dataset_drop.reset_index().set_index("date")

# %% [markdown]
# ## backtest

# %% [markdown]
# 把量加進來做篩選
#  * https://hahow.in/courses/5b9d3a6dca498a001e917383/shapeussions/60c96f5b018697e8a6131cbc

# %%
#把量加進來
vol=data.get('成交股數')/1000
vol_ma5=vol.rolling(5).mean()

vol_filter=vol_ma5>1000
vol_filter=vol_filter[vol_filter].fillna(0)
#vol_filter

# %%
#t1 = vol_ma5.iloc[-1].dropna()
#t1.to_csv('./tmp/132.csv')
#t1.hist(bins=10)

# %%
import math


dates = sorted(list(set(dataset_drop.index)))

rs = []
for d in dates:
    
    dataset_time = dataset_drop.loc[d]
    
    dataset_time = drop_extreme_case(dataset_time , list1 , thresh=0.01)
    
    rank = (dataset_time['result1'] + dataset_time['result2'] + dataset_time['result3'] ) #* vol_filter.loc[d]


    condition = (rank >= rank.nlargest(20).iloc[-1]) 
    
    r = dataset_time['return'][condition].mean()

    rs.append(r * (1-3/1000-1.425/1000*2*0.6))

rs = pd.Series(rs, index=dates)['2021':].cumprod()

s0050 = close['0050']['2021':]

pd.DataFrame({'nn strategy return':rs.reindex(s0050.index, method='ffill'), '0050 return':s0050/s0050[0]}).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#import pickle
#
#return_history_1026 = pd.Series(rs, index=dates)['2021':].cumprod()
##eq = (gain[hold == 1].mean(axis=1)).fillna(1).cumprod()
#
#pickle.dump(rs, open('return_history_1026.pkl', 'wb'))

# %%
#import pyfolio as pf
#import pandas as pd
#
#close.index = close.index.tz_localize("Asia/Taipei")
##pf.create_returns_tear_sheet(close['0050'].pct_change())
#
## 得到 上一個單元的 回測結果
#ret = pickle.load(open("return_history_1026.pkl", "rb"))
#
## 將回測報酬率取出來
#ret = ret.pct_change().dropna()
#ret.index = pd.to_datetime(ret.index).tz_localize('Asia/Taipei')
#
## 利用pyfolio 比較報酬率
#pf.create_returns_tear_sheet(ret, benchmark_rets=close['0050'].pct_change())

# %% [markdown]
# ### 當月持股狀況

# %%
#dataset.index.levels[1]

# %%
# get the latest dataset
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()


last_dataset = drop_extreme_case(last_dataset, list1 , thresh=0.01)


# remove NaN testcases
last_dataset = last_dataset.dropna(subset=feature_names)

# predict

vals = model.predict(last_dataset[feature_names].astype(float))
last_dataset['result1'] = pd.Series(vals.swapaxes(0,1)[0], last_dataset.index)

vals = cf.predict(last_dataset[feature_names].astype(float))
last_dataset['result2'] = pd.Series(vals, last_dataset.index)

vals = cf2.predict(last_dataset[feature_names].astype(float))
last_dataset['result3'] = pd.Series(vals, last_dataset.index)


# calculate score

rank = last_dataset['result1'] + last_dataset['result2'] + last_dataset['result3']

#
rank = rank * vol_filter.iloc[-1] #******加上量的濾網

condition = (rank >= rank.nlargest(20).iloc[-1])
#vol_filter

# plot rank distribution
rank.hist(bins=20)


# show the best 20 stocks
slist1 = rank[condition].reset_index()['stock_id']

#https://keras-cn.readthedocs.io/en/latest/models/model/

# %%
last_date = dataset.index.levels[1].max()#"2022-10-15"
is_last_date = dataset.index.get_level_values('date') == last_date
last_dataset = dataset[is_last_date].copy()

# %%
#rank.sort_values(ascending=False).head(20)

# %% [markdown]
# ## 平均分配資產於股票之中

# %%
close = data.get("收盤價")

money = 60000
stock_prices = close[slist1].iloc[-1]


print("股票平分張數:")
money / len(stock_prices) / stock_prices / 1000
# Out:
# 股票平分張數:
# stock_id
# 1336    0.117878
# 1560    0.027650
# 2049    0.016349
# 2367    0.160000
# 2402    0.162602
# 2474    0.016260
# 2610    0.169492
# 2618    0.115163
# 2888    0.348837
# 3019    0.046875
# 3380    0.101010
# 3406    0.008499
# 3665    0.011834
# 4116    0.053476
# 4906    0.106572
# 5388    0.038760
# 6176    0.029268
# 8050    0.041958
# 9802    0.020134
# 9914    0.016484
# Name: 2022-11-14 00:00:00, dtype: float64
