# %% [markdown]
# # 作業：全新的神經網路練習
#
# 我們活在幸運的時代，機器學習被包裝成黑盒子，就算你完全不知到神經網路，也可以將 X, y 丟進神經網路去優化
#
# 下方有兩個 cell 依序為：
#
#
# 1. Attention 神經網路 layer
# 2. 含有 Attention 的 model
#
#
# 請將 u22-lstm.ipynb 當中的範例，全部複製過來，然後將當中的 LSTM 模型改成下方的神經網路模型，並且訓練、回測看看！
#
#
# 可以先將model 當作黑盒子，先不用理解 Attention Layer 是在做什麼也沒關係喔！
#
# ### 覺得想要深入研究再看 - Attention layer 的相關介紹：
# * [論文網址：Attention is all you need](https://papers.nips.cc/paper/7181-attention-is-all-you-need.pdf)
# * [比較簡單的文章介紹（中文）](https://www.itread01.com/content/1550070201.html)
# * [比較簡單的文章介紹（英文）](http://mlexplained.com/2017/12/29/attention-is-all-you-need-explained/)
# * [更簡單的文章介紹（中文）](https://medium.com/@cyeninesky3/attention-is-all-you-need-%E5%9F%BA%E6%96%BC%E6%B3%A8%E6%84%8F%E5%8A%9B%E6%A9%9F%E5%88%B6%E7%9A%84%E6%A9%9F%E5%99%A8%E7%BF%BB%E8%AD%AF%E6%A8%A1%E5%9E%8B-dcc12d251449)
# * [英文影音教學](https://www.youtube.com/watch?v=EgCPRvgltoE)

# %% [markdown]
# # 開始寫作業囉！

# %% [markdown]
# ## u22 產生 feature 和 label 的程式碼(請自行填寫)

# %%
# u22-lstm.ipynb 當中的程式碼 （preprocessing）
from finlab.data import Data
import pandas as pd

data = Data()
twii = data.get("發行量加權股價指數")
twii = twii['台股指數'].resample("15T").first().dropna()

import talib
import numpy as np
import pandas as pd

sma = talib.SMA(twii, timeperiod=120)
wma = talib.WMA(twii, timeperiod=120)
mom = talib.MOM(twii, timeperiod=120)
k, d = talib.STOCH  (twii, twii, twii, fastk_period=120, slowk_period=60, slowd_period=60)
k2, d2 = talib.STOCH(twii, twii, twii, fastk_period=240, slowk_period=120, slowd_period=120)
k3, d3 = talib.STOCH(twii, twii, twii, fastk_period=360, slowk_period=180, slowd_period=180)
k4, d4 = talib.STOCH(twii, twii, twii, fastk_period=480, slowk_period=240, slowd_period=240)
k5, d5 = talib.STOCH(twii, twii, twii, fastk_period=640, slowk_period=320, slowd_period=320)
k6, d6 = talib.STOCH(twii, twii, twii, fastk_period=720, slowk_period=360, slowd_period=360)
k7, d7 = talib.STOCH(twii, twii, twii, fastk_period=840, slowk_period=420, slowd_period=420)
k8, d8 = talib.STOCH(twii, twii, twii, fastk_period=960, slowk_period=480, slowd_period=480)

rsi = talib.RSI (twii, timeperiod=120)
rsi2 = talib.RSI(twii, timeperiod=240)
rsi3 = talib.RSI(twii, timeperiod=480)
rsi4 = talib.RSI(twii, timeperiod=640)
rsi5 = talib.RSI(twii, timeperiod=720)
rsi6 = talib.RSI(twii, timeperiod=840)

macd1, macd2, macd3 = talib.MACD(twii, fastperiod=120, slowperiod=60, signalperiod=60)
willr = talib.WILLR(twii, twii, twii, timeperiod=120)
cci = talib.CCI(twii, twii, twii, timeperiod=120)

dataset = pd.DataFrame({
    'RSIb': rsi / 50,
    'RSIb2': rsi2 / 50,
    'RSIb3': rsi3 / 50,
    'RSIb4': rsi4 / 50,
    'RSIb5': rsi5 / 50,
    'RSIb6': rsi6 / 50,
    'MOMb': mom - 0,
    'KDb': k - d,
    'KDb2': k2 - d2,
    'KDb3': k3 - d3,
    'KDb4': k4 - d4,
    'KDb5': k5 - d5,
    'KDb6': k6 - d6,
    'KDb7': k7 - d7,
    'KDb8': k8 - d8,
    
    'a5':   (twii.rolling(5).mean()   / twii),
    'a10':  (twii.rolling(10).mean()  / twii),
    'a20':  (twii.rolling(20).mean()  / twii),
    'a40':  (twii.rolling(40).mean()  / twii),
    'a80':  (twii.rolling(80).mean()  / twii),
    'a160': (twii.rolling(160).mean() / twii),
    'a320': (twii.rolling(320).mean() / twii),
    'a640': (twii.rolling(640).mean() / twii),
    'a720': (twii.rolling(720).mean() / twii),
    'a840': (twii.rolling(840).mean() / twii),
    'a960': (twii.rolling(960).mean() / twii),
    'a1024':(twii.rolling(1024).mean() / twii),
    'b1': twii/twii.shift(50),
    'b2': twii/twii.shift(100),
    'b3': twii/twii.shift(150),
    'b4': twii/twii.shift(200),
    'b5': twii/twii.shift(250),
    'b6': twii/twii.shift(300),
    'b7': twii/twii.shift(350),
    'LINEARREG_SLOPE0': talib.LINEARREG_SLOPE(twii, 60),
    'LINEARREG_SLOPE1': talib.LINEARREG_SLOPE(twii, 120),

    'ADXR0': talib.ADXR(twii, twii, twii, 60),
    'ADXR1': talib.ADXR(twii, twii, twii, 120),
    'ADXR2': talib.ADXR(twii, twii, twii, 240),
    'ADXR3': talib.ADXR(twii, twii, twii, 360),
    'ADXR4': talib.ADXR(twii, twii, twii, 480),
    'ADXR5': talib.ADXR(twii, twii, twii, 640),

    'return': twii.shift(-10) / twii,
})

feature_names = list(dataset.columns[:-1])

print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)

import lightgbm as lgb
dataset_train = dataset[:'2015']

gbm = lgb.LGBMClassifier(n_estimators=100, random_state=5, learning_rate=0.01)

gbm.fit(dataset_train[feature_names], dataset_train['return'] > 1)


from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()


import tqdm

n = 3

X = []
y = []
indexes = []
dataset_scaled_x = dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-n)):
    X.append(dataset_scaled_x.iloc[i:i+n].values)
    y.append(dataset_scaled['return'].iloc[i+n-1])
    indexes.append(dataset_scaled.index[i+n-1])
#dataset_scaled.head()

import numpy as np
X = np.array(X)
y = np.array(y)
indexes = np.array(indexes)
# Out:
# D:\ProgramData\Miniconda3\envs\finlab\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# before dropping NaN (78926, 43)
# after dropping NaN (76998, 43)
# HBox(children=(IntProgress(value=0, max=76995), HTML(value='')))

# %% [markdown]
# ## 神經網路 Model （完全不用改）

# %%
# from tensorflow.keras.engine.topology import Layer
from tensorflow.keras.layers import Layer
from tensorflow.keras import initializers, regularizers, constraints
from tensorflow.keras import backend as K


class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape = (input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape =(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

from tensorflow import keras

input_shape = X[0].shape # 還沒有 X ，請自己試試看！（參考u22-lstm.ipynb）
SEQ_LEN = input_shape[0]

model = keras.models.Sequential()

model.add(keras.layers.LSTM(128, input_shape=input_shape, return_sequences=True))
#model.add(keras.layers.Dropout(0.8))
#model.add(keras.layers.BatchNormalization())
model.add(Attention(SEQ_LEN))
model.add(keras.layers.Dense(32, activation="relu"))
#model.add(keras.layers.Dropout(0.8))
model.add(keras.layers.Dense(1))
model.compile(optimizer=keras.optimizers.Adam(0.0005), loss='binary_crossentropy' , metrics = ['accuracy'])

# %% [markdown]
# ## 神經網路訓練（完全不用改）

# %%
import datetime
X_train = X[indexes < datetime.datetime(2016, 1, 1)]
y_train = y[indexes < datetime.datetime(2016, 1, 1)]


get_best_model = keras.callbacks.ModelCheckpoint(
    filepath="./tmp/checkpoint_hw_4_1",
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)


history = model.fit(
    X_train,  
    y_train > 1, 
    batch_size=2000, 
    epochs=10,
    validation_split=0.2, 
    callbacks=[get_best_model])
# Out:
# Epoch 1/10
# 28/28 [==============================] - ETA: 0s - loss: 6.3328 - accuracy: 0.48 - ETA: 0s - loss: 5.9755 - accuracy: 0.48 - ETA: 1s - loss: 5.6533 - accuracy: 0.48 - ETA: 1s - loss: 5.3576 - accuracy: 0.47 - ETA: 1s - loss: 5.0729 - accuracy: 0.47 - ETA: 1s - loss: 4.8331 - accuracy: 0.47 - ETA: 1s - loss: 4.5995 - accuracy: 0.47 - ETA: 1s - loss: 4.4003 - accuracy: 0.47 - ETA: 1s - loss: 4.2158 - accuracy: 0.48 - ETA: 1s - loss: 4.0355 - accuracy: 0.48 - ETA: 1s - loss: 3.8781 - accuracy: 0.48 - ETA: 1s - loss: 3.7318 - accuracy: 0.48 - ETA: 0s - loss: 3.5960 - accuracy: 0.48 - ETA: 0s - loss: 3.4555 - accuracy: 0.48 - ETA: 0s - loss: 3.3272 - accuracy: 0.47 - ETA: 0s - loss: 3.1948 - accuracy: 0.48 - ETA: 0s - loss: 3.0678 - accuracy: 0.48 - ETA: 0s - loss: 2.9511 - accuracy: 0.48 - ETA: 0s - loss: 2.8434 - accuracy: 0.48 - ETA: 0s - loss: 2.7432 - accuracy: 0.48 - ETA: 0s - loss: 2.6520 - accuracy: 0.48 - ETA: 0s - loss: 2.5688 - accuracy: 0.48 - ETA: 0s - loss: 2.4925 - accuracy: 0.48 - ETA: 0s - loss: 2.4224 - accuracy: 0.48 - ETA: 0s - loss: 2.3580 - accuracy: 0.48 - ETA: 0s - loss: 2.2974 - accuracy: 0.48 - ETA: 0s - loss: 2.2416 - accuracy: 0.48 - ETA: 0s - loss: 2.2205 - accuracy: 0.48 - 3s 111ms/step - loss: 2.2205 - accuracy: 0.4851 - val_loss: 0.8466 - val_accuracy: 0.4608
# Epoch 2/10
# 28/28 [==============================] - ETA: 0s - loss: 0.7636 - accuracy: 0.50 - ETA: 0s - loss: 0.7679 - accuracy: 0.50 - ETA: 1s - loss: 0.7705 - accuracy: 0.50 - ETA: 1s - loss: 0.7683 - accuracy: 0.50 - ETA: 1s - loss: 0.7665 - accuracy: 0.49 - ETA: 1s - loss: 0.7655 - accuracy: 0.49 - ETA: 1s - loss: 0.7628 - accuracy: 0.49 - ETA: 1s - loss: 0.7613 - accuracy: 0.50 - ETA: 1s - loss: 0.7602 - accuracy: 0.49 - ETA: 1s - loss: 0.7609 - accuracy: 0.49 - ETA: 1s - loss: 0.7606 - accuracy: 0.49 - ETA: 0s - loss: 0.7604 - accuracy: 0.49 - ETA: 0s - loss: 0.7586 - accuracy: 0.49 - ETA: 0s - loss: 0.7580 - accuracy: 0.49 - ETA: 0s - loss: 0.7568 - accuracy: 0.49 - ETA: 0s - loss: 0.7554 - accuracy: 0.49 - ETA: 0s - loss: 0.7537 - accuracy: 0.49 - ETA: 0s - loss: 0.7531 - accuracy: 0.49 - ETA: 0s - loss: 0.7523 - accuracy: 0.49 - ETA: 0s - loss: 0.7516 - accuracy: 0.49 - ETA: 0s - loss: 0.7501 - accuracy: 0.49 - ETA: 0s - loss: 0.7496 - accuracy: 0.49 - ETA: 0s - loss: 0.7485 - accuracy: 0.49 - ETA: 0s - loss: 0.7475 - accuracy: 0.49 - ETA: 0s - loss: 0.7467 - accuracy: 0.49 - ETA: 0s - loss: 0.7462 - accuracy: 0.49 - ETA: 0s - loss: 0.7452 - accuracy: 0.49 - 2s 77ms/step - loss: 0.7447 - accuracy: 0.4997 - val_loss: 0.7715 - val_accuracy: 0.4640
# Epoch 3/10
# 28/28 [==============================] - ETA: 0s - loss: 0.7206 - accuracy: 0.51 - ETA: 0s - loss: 0.7234 - accuracy: 0.50 - ETA: 1s - loss: 0.7222 - accuracy: 0.50 - ETA: 1s - loss: 0.7254 - accuracy: 0.50 - ETA: 1s - loss: 0.7250 - accuracy: 0.50 - ETA: 1s - loss: 0.7237 - accuracy: 0.50 - ETA: 1s - loss: 0.7230 - accuracy: 0.50 - ETA: 1s - loss: 0.7220 - accuracy: 0.50 - ETA: 1s - loss: 0.7220 - accuracy: 0.50 - ETA: 1s - loss: 0.7220 - accuracy: 0.50 - ETA: 1s - loss: 0.7222 - accuracy: 0.50 - ETA: 0s - loss: 0.7212 - accuracy: 0.50 - ETA: 0s - loss: 0.7211 - accuracy: 0.50 - ETA: 0s - loss: 0.7206 - accuracy: 0.50 - ETA: 0s - loss: 0.7205 - accuracy: 0.50 - ETA: 0s - loss: 0.7205 - accuracy: 0.50 - ETA: 0s - loss: 0.7194 - accuracy: 0.50 - ETA: 0s - loss: 0.7187 - accuracy: 0.50 - ETA: 0s - loss: 0.7186 - accuracy: 0.50 - ETA: 0s - loss: 0.7184 - accuracy: 0.50 - ETA: 0s - loss: 0.7179 - accuracy: 0.50 - ETA: 0s - loss: 0.7180 - accuracy: 0.50 - ETA: 0s - loss: 0.7173 - accuracy: 0.50 - ETA: 0s - loss: 0.7172 - accuracy: 0.50 - ETA: 0s - loss: 0.7173 - accuracy: 0.50 - ETA: 0s - loss: 0.7174 - accuracy: 0.50 - ETA: 0s - loss: 0.7168 - accuracy: 0.50 - 2s 76ms/step - loss: 0.7169 - accuracy: 0.5086 - val_loss: 0.7473 - val_accuracy: 0.4741
# Epoch 4/10
# 28/28 [==============================] - ETA: 0s - loss: 0.7089 - accuracy: 0.52 - ETA: 1s - loss: 0.7120 - accuracy: 0.51 - ETA: 1s - loss: 0.7099 - accuracy: 0.51 - ETA: 1s - loss: 0.7081 - accuracy: 0.51 - ETA: 1s - loss: 0.7083 - accuracy: 0.51 - ETA: 1s - loss: 0.7086 - accuracy: 0.51 - ETA: 1s - loss: 0.7084 - accuracy: 0.51 - ETA: 1s - loss: 0.7080 - accuracy: 0.51 - ETA: 1s - loss: 0.7085 - accuracy: 0.51 - ETA: 1s - loss: 0.7081 - accuracy: 0.51 - ETA: 1s - loss: 0.7075 - accuracy: 0.51 - ETA: 1s - loss: 0.7073 - accuracy: 0.51 - ETA: 1s - loss: 0.7072 - accuracy: 0.51 - ETA: 0s - loss: 0.7075 - accuracy: 0.51 - ETA: 0s - loss: 0.7075 - accuracy: 0.51 - ETA: 0s - loss: 0.7078 - accuracy: 0.51 - ETA: 0s - loss: 0.7078 - accuracy: 0.51 - ETA: 0s - loss: 0.7081 - accuracy: 0.51 - ETA: 0s - loss: 0.7084 - accuracy: 0.51 - ETA: 0s - loss: 0.7080 - accuracy: 0.51 - ETA: 0s - loss: 0.7081 - accuracy: 0.51 - ETA: 0s - loss: 0.7079 - accuracy: 0.51 - ETA: 0s - loss: 0.7079 - accuracy: 0.51 - ETA: 0s - loss: 0.7081 - accuracy: 0.51 - ETA: 0s - loss: 0.7080 - accuracy: 0.51 - ETA: 0s - loss: 0.7077 - accuracy: 0.51 - ETA: 0s - loss: 0.7075 - accuracy: 0.51 - 2s 82ms/step - loss: 0.7075 - accuracy: 0.5138 - val_loss: 0.7365 - val_accuracy: 0.4740
# Epoch 5/10
# 28/28 [==============================] - ETA: 0s - loss: 0.7074 - accuracy: 0.52 - ETA: 0s - loss: 0.7034 - accuracy: 0.51 - ETA: 1s - loss: 0.7031 - accuracy: 0.51 - ETA: 1s - loss: 0.7034 - accuracy: 0.51 - ETA: 1s - loss: 0.7019 - accuracy: 0.51 - ETA: 1s - loss: 0.7030 - accuracy: 0.51 - ETA: 1s - loss: 0.7027 - accuracy: 0.51 - ETA: 1s - loss: 0.7025 - accuracy: 0.51 - ETA: 1s - loss: 0.7025 - accuracy: 0.51 - ETA: 1s - loss: 0.7017 - accuracy: 0.52 - ETA: 1s - loss: 0.7018 - accuracy: 0.51 - ETA: 1s - loss: 0.7016 - accuracy: 0.51 - ETA: 0s - loss: 0.7019 - accuracy: 0.51 - ETA: 0s - loss: 0.7018 - accuracy: 0.52 - ETA: 0s - loss: 0.7022 - accuracy: 0.52 - ETA: 0s - loss: 0.7027 - accuracy: 0.51 - ETA: 0s - loss: 0.7028 - accuracy: 0.51 - ETA: 0s - loss: 0.7029 - accuracy: 0.51 - ETA: 0s - loss: 0.7031 - accuracy: 0.51 - ETA: 0s - loss: 0.7033 - accuracy: 0.51 - ETA: 0s - loss: 0.7031 - accuracy: 0.51 - ETA: 0s - loss: 0.7029 - accuracy: 0.51 - ETA: 0s - loss: 0.7030 - accuracy: 0.51 - ETA: 0s - loss: 0.7029 - accuracy: 0.51 - ETA: 0s - loss: 0.7029 - accuracy: 0.51 - ETA: 0s - loss: 0.7027 - accuracy: 0.51 - ETA: 0s - loss: 0.7025 - accuracy: 0.51 - 2s 80ms/step - loss: 0.7024 - accuracy: 0.5185 - val_loss: 0.7296 - val_accuracy: 0.4731
# Epoch 6/10
# 28/28 [==============================] - ETA: 0s - loss: 0.7011 - accuracy: 0.52 - ETA: 0s - loss: 0.7019 - accuracy: 0.51 - ETA: 1s - loss: 0.7023 - accuracy: 0.51 - ETA: 1s - loss: 0.7033 - accuracy: 0.51 - ETA: 1s - loss: 0.7032 - accuracy: 0.51 - ETA: 1s - loss: 0.7031 - accuracy: 0.51 - ETA: 1s - loss: 0.7034 - accuracy: 0.51 - ETA: 1s - loss: 0.7029 - accuracy: 0.51 - ETA: 1s - loss: 0.7030 - accuracy: 0.51 - ETA: 1s - loss: 0.7023 - accuracy: 0.51 - ETA: 1s - loss: 0.7021 - accuracy: 0.51 - ETA: 1s - loss: 0.7013 - accuracy: 0.51 - ETA: 1s - loss: 0.7008 - accuracy: 0.51 - ETA: 0s - loss: 0.7007 - accuracy: 0.51 - ETA: 0s - loss: 0.7003 - accuracy: 0.52 - ETA: 0s - loss: 0.7004 - accuracy: 0.51 - ETA: 0s - loss: 0.6998 - accuracy: 0.52 - ETA: 0s - loss: 0.6998 - accuracy: 0.52 - ETA: 0s - loss: 0.6996 - accuracy: 0.52 - ETA: 0s - loss: 0.6995 - accuracy: 0.52 - ETA: 0s - loss: 0.6995 - accuracy: 0.52 - ETA: 0s - loss: 0.6996 - accuracy: 0.52 - ETA: 0s - loss: 0.6996 - accuracy: 0.52 - ETA: 0s - loss: 0.6993 - accuracy: 0.52 - ETA: 0s - loss: 0.6991 - accuracy: 0.52 - ETA: 0s - loss: 0.6993 - accuracy: 0.52 - ETA: 0s - loss: 0.6991 - accuracy: 0.52 - 2s 79ms/step - loss: 0.6992 - accuracy: 0.5216 - val_loss: 0.7256 - val_accuracy: 0.4767
# Epoch 7/10
# 28/28 [==============================] - ETA: 0s - loss: 0.6982 - accuracy: 0.52 - ETA: 0s - loss: 0.7023 - accuracy: 0.50 - ETA: 1s - loss: 0.6992 - accuracy: 0.51 - ETA: 1s - loss: 0.6982 - accuracy: 0.52 - ETA: 1s - loss: 0.6981 - accuracy: 0.52 - ETA: 1s - loss: 0.6972 - accuracy: 0.52 - ETA: 1s - loss: 0.6969 - accuracy: 0.52 - ETA: 1s - loss: 0.6973 - accuracy: 0.52 - ETA: 1s - loss: 0.6971 - accuracy: 0.52 - ETA: 1s - loss: 0.6973 - accuracy: 0.52 - ETA: 1s - loss: 0.6971 - accuracy: 0.52 - ETA: 1s - loss: 0.6974 - accuracy: 0.52 - ETA: 0s - loss: 0.6975 - accuracy: 0.52 - ETA: 0s - loss: 0.6971 - accuracy: 0.52 - ETA: 0s - loss: 0.6969 - accuracy: 0.52 - ETA: 0s - loss: 0.6970 - accuracy: 0.52 - ETA: 0s - loss: 0.6970 - accuracy: 0.52 - ETA: 0s - loss: 0.6969 - accuracy: 0.52 - ETA: 0s - loss: 0.6969 - accuracy: 0.52 - ETA: 0s - loss: 0.6967 - accuracy: 0.52 - ETA: 0s - loss: 0.6962 - accuracy: 0.52 - ETA: 0s - loss: 0.6962 - accuracy: 0.52 - ETA: 0s - loss: 0.6963 - accuracy: 0.52 - ETA: 0s - loss: 0.6963 - accuracy: 0.52 - ETA: 0s - loss: 0.6964 - accuracy: 0.52 - ETA: 0s - loss: 0.6966 - accuracy: 0.52 - ETA: 0s - loss: 0.6965 - accuracy: 0.52 - 2s 79ms/step - loss: 0.6966 - accuracy: 0.5276 - val_loss: 0.7228 - val_accuracy: 0.4789
# Epoch 8/10
# 28/28 [==============================] - ETA: 0s - loss: 0.6953 - accuracy: 0.52 - ETA: 0s - loss: 0.6930 - accuracy: 0.53 - ETA: 1s - loss: 0.6925 - accuracy: 0.53 - ETA: 1s - loss: 0.6927 - accuracy: 0.53 - ETA: 1s - loss: 0.6935 - accuracy: 0.53 - ETA: 1s - loss: 0.6944 - accuracy: 0.52 - ETA: 1s - loss: 0.6945 - accuracy: 0.52 - ETA: 1s - loss: 0.6940 - accuracy: 0.53 - ETA: 1s - loss: 0.6943 - accuracy: 0.52 - ETA: 1s - loss: 0.6944 - accuracy: 0.52 - ETA: 1s - loss: 0.6943 - accuracy: 0.53 - ETA: 1s - loss: 0.6939 - accuracy: 0.53 - ETA: 0s - loss: 0.6938 - accuracy: 0.53 - ETA: 0s - loss: 0.6944 - accuracy: 0.52 - ETA: 0s - loss: 0.6944 - accuracy: 0.52 - ETA: 0s - loss: 0.6944 - accuracy: 0.52 - ETA: 0s - loss: 0.6945 - accuracy: 0.52 - ETA: 0s - loss: 0.6942 - accuracy: 0.53 - ETA: 0s - loss: 0.6940 - accuracy: 0.53 - ETA: 0s - loss: 0.6943 - accuracy: 0.53 - ETA: 0s - loss: 0.6945 - accuracy: 0.52 - ETA: 0s - loss: 0.6946 - accuracy: 0.52 - ETA: 0s - loss: 0.6944 - accuracy: 0.52 - ETA: 0s - loss: 0.6946 - accuracy: 0.52 - ETA: 0s - loss: 0.6945 - accuracy: 0.52 - ETA: 0s - loss: 0.6945 - accuracy: 0.52 - ETA: 0s - loss: 0.6944 - accuracy: 0.53 - 2s 82ms/step - loss: 0.6944 - accuracy: 0.5301 - val_loss: 0.7219 - val_accuracy: 0.4800
# Epoch 9/10
# 28/28 [==============================] - ETA: 0s - loss: 0.6963 - accuracy: 0.53 - ETA: 0s - loss: 0.6943 - accuracy: 0.53 - ETA: 1s - loss: 0.6951 - accuracy: 0.53 - ETA: 1s - loss: 0.6946 - accuracy: 0.53 - ETA: 1s - loss: 0.6953 - accuracy: 0.53 - ETA: 1s - loss: 0.6965 - accuracy: 0.52 - ETA: 1s - loss: 0.6964 - accuracy: 0.52 - ETA: 1s - loss: 0.6956 - accuracy: 0.52 - ETA: 1s - loss: 0.6953 - accuracy: 0.52 - ETA: 1s - loss: 0.6949 - accuracy: 0.52 - ETA: 1s - loss: 0.6952 - accuracy: 0.52 - ETA: 1s - loss: 0.6949 - accuracy: 0.52 - ETA: 1s - loss: 0.6945 - accuracy: 0.52 - ETA: 0s - loss: 0.6940 - accuracy: 0.52 - ETA: 0s - loss: 0.6939 - accuracy: 0.53 - ETA: 0s - loss: 0.6939 - accuracy: 0.53 - ETA: 0s - loss: 0.6933 - accuracy: 0.53 - ETA: 0s - loss: 0.6931 - accuracy: 0.53 - ETA: 0s - loss: 0.6929 - accuracy: 0.53 - ETA: 0s - loss: 0.6932 - accuracy: 0.53 - ETA: 0s - loss: 0.6929 - accuracy: 0.53 - ETA: 0s - loss: 0.6927 - accuracy: 0.53 - ETA: 0s - loss: 0.6928 - accuracy: 0.53 - ETA: 0s - loss: 0.6928 - accuracy: 0.53 - ETA: 0s - loss: 0.6926 - accuracy: 0.53 - ETA: 0s - loss: 0.6925 - accuracy: 0.53 - ETA: 0s - loss: 0.6925 - accuracy: 0.53 - 2s 81ms/step - loss: 0.6924 - accuracy: 0.5328 - val_loss: 0.7191 - val_accuracy: 0.4838
# Epoch 10/10
# 28/28 [==============================] - ETA: 0s - loss: 0.6943 - accuracy: 0.53 - ETA: 0s - loss: 0.6921 - accuracy: 0.54 - ETA: 1s - loss: 0.6938 - accuracy: 0.53 - ETA: 1s - loss: 0.6929 - accuracy: 0.53 - ETA: 1s - loss: 0.6926 - accuracy: 0.53 - ETA: 1s - loss: 0.6931 - accuracy: 0.53 - ETA: 1s - loss: 0.6928 - accuracy: 0.53 - ETA: 1s - loss: 0.6922 - accuracy: 0.53 - ETA: 1s - loss: 0.6918 - accuracy: 0.53 - ETA: 1s - loss: 0.6917 - accuracy: 0.53 - ETA: 1s - loss: 0.6921 - accuracy: 0.53 - ETA: 1s - loss: 0.6919 - accuracy: 0.53 - ETA: 0s - loss: 0.6917 - accuracy: 0.53 - ETA: 0s - loss: 0.6916 - accuracy: 0.53 - ETA: 0s - loss: 0.6917 - accuracy: 0.53 - ETA: 0s - loss: 0.6916 - accuracy: 0.53 - ETA: 0s - loss: 0.6917 - accuracy: 0.53 - ETA: 0s - loss: 0.6915 - accuracy: 0.53 - ETA: 0s - loss: 0.6914 - accuracy: 0.53 - ETA: 0s - loss: 0.6915 - accuracy: 0.53 - ETA: 0s - loss: 0.6915 - accuracy: 0.53 - ETA: 0s - loss: 0.6915 - accuracy: 0.53 - ETA: 0s - loss: 0.6910 - accuracy: 0.53 - ETA: 0s - loss: 0.6908 - accuracy: 0.53 - ETA: 0s - loss: 0.6907 - accuracy: 0.53 - ETA: 0s - loss: 0.6908 - accuracy: 0.53 - ETA: 0s - loss: 0.6907 - accuracy: 0.53 - 2s 77ms/step - loss: 0.6906 - accuracy: 0.5376 - val_loss: 0.7194 - val_accuracy: 0.4830

# %% [markdown]
# ## u22-lstm.ipynb 的程式碼（驗證、回測）

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# u22-lstm 程式碼(evaluation and backtest)
model.load_weights("./tmp/checkpoint_hw_4_1")
ey = model.predict(X)
ey = pd.Series(ey.swapaxes(0,1)[0], index=indexes)
ey.plot()
# Out:
# <AxesSubplot:>

# %%
eq = twii[indexes]
returns = (eq.shift(-1) - eq)

signal = (ey > ey.quantile(0.6)).rolling(10).sum() > 0
signal = signal.shift(1).fillna(False)

eq = (returns[signal]['2016':]).cumsum()
eq.plot()
# Out:
# <AxesSubplot:xlabel='date'>
